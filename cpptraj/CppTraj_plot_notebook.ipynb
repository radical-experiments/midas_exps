# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import csv
import pandas as pd

# %%
#CppTraj RMSD Analysis single trajectory, Vanilla execution
cpptral_1 = np.mean([564.5859,568.8731,566.5191])
cpptral_2 = np.mean([283.6768,283.5894,284.4723])
cpptral_4 = np.mean([142.7122,143.9257,143.2807])
cpptral_8 = np.mean([73.1578,72.4248,72.6958])
cpptral_16 = np.mean([37.0447,37.0347,36.9493])
cpptral_32 = np.mean([18.4021,18.2681,18.3764])

cpptral_1_std = np.std([564.5859,568.8731,566.5191])
cpptral_2_std = np.std([283.6768,283.5894,284.4723])
cpptral_4_std = np.std([142.7122,143.9257,143.2807])
cpptral_8_std = np.std([73.1578,72.4248,72.6958])
cpptral_16_std = np.std([37.0447,37.0347,36.9493])
cpptral_32_std = np.std([18.4021,18.2681,18.3764])

# %%
rp_cpptraj_1_1 = csv.reader(open('rp_cpptraj/single_trajectory/rp_cpptraj_1_1-1.csv'))
rp_cpptraj_1_2 = csv.reader(open('rp_cpptraj/single_trajectory/rp_cpptraj_1_2-1.csv'))
rp_cpptraj_1_3 = csv.reader(open('rp_cpptraj/single_trajectory/rp_cpptraj_1_3-1.csv'))
rp_cpptraj_2_1 = csv.reader(open('rp_cpptraj/single_trajectory/rp_cpptraj_2_1-2.csv'))
rp_cpptraj_2_2 = csv.reader(open('rp_cpptraj/single_trajectory/rp_cpptraj_2_2-2.csv'))
rp_cpptraj_2_3 = csv.reader(open('rp_cpptraj/single_trajectory/rp_cpptraj_2_3-2.csv'))
rp_cpptraj_4_1 = csv.reader(open('rp_cpptraj/single_trajectory/rp_cpptraj_4_1-4.csv'))
rp_cpptraj_4_2 = csv.reader(open('rp_cpptraj/single_trajectory/rp_cpptraj_4_2-4.csv'))
rp_cpptraj_4_3 = csv.reader(open('rp_cpptraj/single_trajectory/rp_cpptraj_4_3-4.csv'))
rp_cpptraj_8_1 = csv.reader(open('rp_cpptraj/single_trajectory/rp_cpptraj_8_1-8.csv'))
rp_cpptraj_8_2 = csv.reader(open('rp_cpptraj/single_trajectory/rp_cpptraj_8_2-8.csv'))
rp_cpptraj_8_3 = csv.reader(open('rp_cpptraj/single_trajectory/rp_cpptraj_8_3-8.csv'))
rp_cpptraj_16_1 = csv.reader(open('rp_cpptraj/single_trajectory/rp_cpptraj_16_1-16.csv'))
rp_cpptraj_16_2 = csv.reader(open('rp_cpptraj/single_trajectory/rp_cpptraj_16_2-16.csv'))
rp_cpptraj_16_3 = csv.reader(open('rp_cpptraj/single_trajectory/rp_cpptraj_16_3-16.csv'))
rp_cpptraj_32_1 = csv.reader(open('rp_cpptraj/single_trajectory/rp_cpptraj_32_1-32.csv'))
rp_cpptraj_32_2 = csv.reader(open('rp_cpptraj/single_trajectory/rp_cpptraj_32_2-32.csv'))
rp_cpptraj_32_3 = csv.reader(open('rp_cpptraj/single_trajectory/rp_cpptraj_32_3-32.csv'))

# %%
def extract_timing(csv_file):
    import numpy as np
    results = list()
    for row in csv_file:
        if row[5]!='StageOut':
            results.append(float(row[5]))
    
    return np.array(results).max()
        
cpptraj_rp11 = extract_timing(rp_cpptraj_1_1)
cpptraj_rp12 = extract_timing(rp_cpptraj_1_2)
cpptraj_rp13 = extract_timing(rp_cpptraj_1_3)
cpptraj_rp21 = extract_timing(rp_cpptraj_2_1)
cpptraj_rp22 = extract_timing(rp_cpptraj_2_2)
cpptraj_rp23 = extract_timing(rp_cpptraj_2_3)
cpptraj_rp41 = extract_timing(rp_cpptraj_4_1)
cpptraj_rp42 = extract_timing(rp_cpptraj_4_2)
cpptraj_rp43 = extract_timing(rp_cpptraj_4_3)
cpptraj_rp81 = extract_timing(rp_cpptraj_8_1)
cpptraj_rp82 = extract_timing(rp_cpptraj_8_2)
cpptraj_rp83 = extract_timing(rp_cpptraj_8_3)
cpptraj_rp161 = extract_timing(rp_cpptraj_16_1)
cpptraj_rp162 = extract_timing(rp_cpptraj_16_2)
cpptraj_rp163 = extract_timing(rp_cpptraj_16_3)
cpptraj_rp321 = extract_timing(rp_cpptraj_32_1)
cpptraj_rp322 = extract_timing(rp_cpptraj_32_2)
cpptraj_rp323 = extract_timing(rp_cpptraj_32_3)

cpptraj_rp1 = np.mean([cpptraj_rp11,cpptraj_rp12,cpptraj_rp13])
cpptraj_rp2 = np.mean([cpptraj_rp21,cpptraj_rp22,cpptraj_rp23])
cpptraj_rp4 = np.mean([cpptraj_rp41,cpptraj_rp42,cpptraj_rp43])
cpptraj_rp8 = np.mean([cpptraj_rp81,cpptraj_rp82,cpptraj_rp83])
cpptraj_rp16 = np.mean([cpptraj_rp161,cpptraj_rp162,cpptraj_rp163])
cpptraj_rp32 = np.mean([cpptraj_rp321,cpptraj_rp322,cpptraj_rp323])

cpptraj_rp1_std = np.std([cpptraj_rp11,cpptraj_rp12,cpptraj_rp13])
cpptraj_rp2_std = np.std([cpptraj_rp21,cpptraj_rp22,cpptraj_rp23])
cpptraj_rp4_std = np.std([cpptraj_rp41,cpptraj_rp42,cpptraj_rp43])
cpptraj_rp8_std = np.std([cpptraj_rp81,cpptraj_rp82,cpptraj_rp83])
cpptraj_rp16_std = np.std([cpptraj_rp161,cpptraj_rp162,cpptraj_rp163])
cpptraj_rp32_std = np.std([cpptraj_rp321,cpptraj_rp322,cpptraj_rp323])

# %%
a=plt.figure()
plt.title('Time to Completion @ Stampede')
plt.ylabel('Time to Completion (secs)',fontsize=14)
n_groups=6
index=np.arange(n_groups)
bar_width=0.25
opacity=1.0
a1=plt.bar(index,[cpptral_1,cpptral_2,cpptral_4,cpptral_8,cpptral_16,cpptral_32],bar_width,yerr=[cpptral_1_std,cpptral_2_std,cpptral_4_std,cpptral_8_std,cpptral_16_std,cpptral_32_std],alpha=opacity,color='darkgreen')
a2=plt.bar(index+bar_width,[cpptraj_rp1,cpptraj_rp2,cpptraj_rp4,cpptraj_rp8,cpptraj_rp16,cpptraj_rp32],bar_width,yerr=[cpptraj_rp1_std,cpptraj_rp2_std,cpptraj_rp4_std,cpptraj_rp8_std,cpptraj_rp16_std,cpptraj_rp32_std],alpha=opacity,color='blue')
plt.xticks(index+bar_width,('1','2','4','8','16','32'))
plt.xlabel('Number of cores')
lgd=plt.figlegend((a1,a2),('CppTraj MPI','RADICAL-Pilot'),loc='lower center',ncol=2,fontsize=10,borderaxespad=0.15)
a.subplots_adjust(bottom=0.18)
a.savefig('cpptraj_single_traj_rp_vs_vanilla.png',dpi=800,bbox_extra_artists=(lgd,))

# %%
#CppTraj RMSD Analysis Ensemble, Vanilla execution
cppen_1 = np.mean([147.1129,155.5978,136.7208])
cppen_2 = np.mean([86.9561,89.7833,143.2377])
cppen_4 = np.mean([66.4970,53.7168,104.6815])
cppen_8 = np.mean([55.9820,42.0561,50.4622])
cppen_16 = np.mean([51.4977,42.1686,46.2849])

cppen_1_std = np.std([147.1129,155.5978,136.7208])
cppen_2_std = np.std([86.9561,89.7833,143.2377])
cppen_4_std = np.std([66.4970,53.7168,104.6815])
cppen_8_std = np.std([55.9820,42.0561,50.4622])
cppen_16_std = np.std([51.4977,42.1686,46.2849])

# %%
rp_cppen_16_1 = csv.reader(open('rp_cpptraj/ensemble/08-24-2016/rp_cpptraj_16_1-16.csv'))
rp_cppen_16_2 = csv.reader(open('rp_cpptraj/ensemble/08-24-2016/rp_cpptraj_16_2-16.csv'))
rp_cppen_16_3 = csv.reader(open('rp_cpptraj/ensemble/08-24-2016/rp_cpptraj_16_3-16.csv'))
rp_cppen_32_1 = csv.reader(open('rp_cpptraj/ensemble/08-24-2016/rp_cpptraj_32_1-32.csv'))
rp_cppen_32_2 = csv.reader(open('rp_cpptraj/ensemble/08-24-2016/rp_cpptraj_32_2-32.csv'))
rp_cppen_32_3 = csv.reader(open('rp_cpptraj/ensemble/08-24-2016/rp_cpptraj_32_3-32.csv'))
rp_cppen_64_1 = csv.reader(open('rp_cpptraj/ensemble/08-24-2016/rp_cpptraj_64_1-64.csv'))
rp_cppen_64_2 = csv.reader(open('rp_cpptraj/ensemble/08-24-2016/rp_cpptraj_64_2-64.csv'))
rp_cppen_64_3 = csv.reader(open('rp_cpptraj/ensemble/08-24-2016/rp_cpptraj_64_3-64.csv'))
rp_cppen_128_1 = csv.reader(open('rp_cpptraj/ensemble/08-24-2016/rp_cpptraj_128_1-128.csv'))
rp_cppen_128_2 = csv.reader(open('rp_cpptraj/ensemble/08-24-2016/rp_cpptraj_128_2-128.csv'))
rp_cppen_128_3 = csv.reader(open('rp_cpptraj/ensemble/08-24-2016/rp_cpptraj_128_3-128.csv'))
rp_cppen_256_1 = csv.reader(open('rp_cpptraj/ensemble/08-24-2016/rp_cpptraj_256_1-256.csv'))
rp_cppen_256_2 = csv.reader(open('rp_cpptraj/ensemble/08-24-2016/rp_cpptraj_256_2-256.csv'))
rp_cppen_256_3 = csv.reader(open('rp_cpptraj/ensemble/08-24-2016/rp_cpptraj_256_3-256.csv'))

# %%
def extract_timing(csv_file):
    import numpy as np
    results = list()
    for row in csv_file:
        if row[5]!='StageOut':
            results.append(float(row[5]))
    
    return np.array(results).max()
        
cpptraj_rpen11 = extract_timing(rp_cppen_16_1)
cpptraj_rpen12 = extract_timing(rp_cppen_16_2)
cpptraj_rpen13 = extract_timing(rp_cppen_16_3)
cpptraj_rpen21 = extract_timing(rp_cppen_32_1)
cpptraj_rpen22 = extract_timing(rp_cppen_32_2)
cpptraj_rpen23 = extract_timing(rp_cppen_32_3)
cpptraj_rpen41 = extract_timing(rp_cppen_64_1)
cpptraj_rpen42 = extract_timing(rp_cppen_64_2)
cpptraj_rpen43 = extract_timing(rp_cppen_64_3)
cpptraj_rpen81 = extract_timing(rp_cppen_128_1)
cpptraj_rpen82 = extract_timing(rp_cppen_128_2)
cpptraj_rpen83 = extract_timing(rp_cppen_128_3)
cpptraj_rpen161 = extract_timing(rp_cppen_256_1)
cpptraj_rpen162 = extract_timing(rp_cppen_256_2)
cpptraj_rpen163 = extract_timing(rp_cppen_256_3)

cpptraj_rpen1 = np.mean([cpptraj_rpen11,cpptraj_rpen12,cpptraj_rpen13])
cpptraj_rpen2 = np.mean([cpptraj_rpen21,cpptraj_rpen22,cpptraj_rpen23])
cpptraj_rpen4 = np.mean([cpptraj_rpen41,cpptraj_rpen42,cpptraj_rpen43])
cpptraj_rpen8 = np.mean([cpptraj_rpen81,cpptraj_rpen82,cpptraj_rpen83])
cpptraj_rpen16 = np.mean([cpptraj_rpen161,cpptraj_rpen162,cpptraj_rpen163])

cpptraj_rpen1_std = np.std([cpptraj_rpen11,cpptraj_rpen12,cpptraj_rpen13])
cpptraj_rpen2_std = np.std([cpptraj_rpen21,cpptraj_rpen22,cpptraj_rpen23])
cpptraj_rpen4_std = np.std([cpptraj_rpen41,cpptraj_rpen42,cpptraj_rpen43])
cpptraj_rpen8_std = np.std([cpptraj_rpen81,cpptraj_rpen82,cpptraj_rpen83])
cpptraj_rpen16_std = np.std([cpptraj_rpen161,cpptraj_rpen162,cpptraj_rpen163])

# %%
a=plt.figure()
plt.title('Time to Completion @ Stampede Ensemble mode, 8/24/2016')
plt.ylabel('Time to Completion (secs)',fontsize=14)
n_groups=5
index=np.arange(n_groups)
bar_width=0.25
opacity=1.0
a1=plt.bar(index,[cppen_1,cppen_2,cppen_4,cppen_8,cppen_16],bar_width,yerr=[cppen_1_std,cppen_2_std,cppen_4_std,cppen_8_std,cppen_16_std],alpha=opacity,color='darkgreen')
a2=plt.bar(index+bar_width,[cpptraj_rpen1,cpptraj_rpen2,cpptraj_rpen4,cpptraj_rpen8,cpptraj_rpen16],bar_width,yerr=[cpptraj_rpen1_std,cpptraj_rpen2_std,cpptraj_rpen4_std,cpptraj_rpen8_std,cpptraj_rpen16_std],alpha=opacity,color='blue')
plt.xticks(index+bar_width,('1','2','4','8','16'))
plt.xlabel('Number of nodes')
lgd=plt.figlegend((a1,a2),('CppTraj MPI','RADICAL-Pilot'),loc='lower center',ncol=2,fontsize=10,borderaxespad=0.15)
a.subplots_adjust(bottom=0.18)
a.savefig('cpptraj_single_en_rp_vs_vanilla.png',dpi=800,bbox_extra_artists=(lgd,))

# %%
columns=['Nodes','Try','Init','Trajectory Process','Data Set Sync','Action Post','Analysis','Data File Write','Other','TTC']
data = np.array([[1,1,0.0001,153.0819,0.0000,0.0000,0.0000,0.0323,0.0004,155.5978],
[1,2,0.0001,153.0819,0.0000,0.0000,0.0000,0.0323,0.0004,155.5978],
[1,3,0.0004,135.0393,0.0000,0.0000,0.0000,0.0305,0.0004,136.7208],
[1,4,0.0005,165.0113,0.0000,0.0000,0.0000,0.0299,0.0002,167.8584],
[1,5,0.0006,151.5605,0.0000,0.0000,0.0000,0.0425,0.0008,153.8299],
[1,6,0.0004,153.1182,0.0000,0.0000,0.0000,0.0298,0.0004,156.1141],
[2,1,0.0142,84.6154,0.0002,0.0000,0.0000,0.0251,0.0019,86.9561],
[2,2,0.0149,87.4713,0.0002,0.0000,0.0000,0.0326,0.0015,89.7833],
[2,3,0.0140,139.5295,0.0002,0.0000,0.0000,0.0247,0.0022,143.2377],
[2,4,0.0148,78.9509,0.0002,0.0000,0.0000,0.0285,0.0015,80.8707],
[2,5,0.0148,78.9509,0.0002,0.0000,0.0000,0.0285,0.0015,80.8707],
[2,6,0.0153,109.0029,0.0001,0.0000,0.0000,0.0285,0.0016,111.3733],
[4,1,0.0169,64.3379,0.0002,.0000,0.0000,0.0251,0.0027,66.4970],
[4,2,0.0173,51.8285,0.0002,0.0000,0.0000,0.0255,0.0023,53.7168],
[4,3,0.0161,102.3850,0.0002,0.0000,0.0000,0.0256,0.0030,104.6815],
[4,4,0.0185,64.6158,0.0002,0.0000,0.0000,0.0253,0.0025,67.2706],
[4,5,0.0173,61.5558,0.0002,0.0000,0.0000,0.5998,0.0022,64.5914],
[4,6,0.0178,66.2421,0.0002,0.0000,0.0000,0.0255,0.0021,68.2038],
[8,1,0.0179,54.0383,0.0005,0.0000,0.0000,0.0253,0.0041,55.9820],
[8,2,0.0196,39.6778,0.0006,0.0000,0.0000,0.0252,0.0034,42.0561],
[8,3,0.0193,48.5446,0.0002,0.0000,0.0000,0.0256,0.0105,50.4622],
[8,4,0.0181,54.8001,0.0002,0.0000,0.0000,0.0248,0.0541,57.0031],
[8,5,0.0188,64.9409,0.0002,0.0000,0.0000,0.0396,0.0036,66.9180],
[8,6,0.0196,44.1875,0.0006,0.0000,0.0000,0.0245,0.0035,45.9536],
[16,1,0.0201,49.3527,0.0003,0.0000,0.0000,0.0249,0.0059,51.4977],
[16,2,0.0232,40.2841,0.0008,0.0000,0.0000,0.0249,0.0059,42.1686],
[16,3,0.0306,44.3794,0.0003,0.0000,0.0000,0.0248,0.0063,46.2849],
[16,4,0.0292,64.9090,0.0003,0.0000,0.0000,0.2431,0.0060,67.0164],
[16,5,0.0224,43.6498,0.0003,0.0000,0.0000,0.0247,0.0061,45.4747],
[16,6,0.0223,41.1900,0.0007,0.0000,0.0000,0.0246,0.0058,43.2695]])

cpptraj_en_data = pd.DataFrame(data,columns=columns)

# %%
cpptraj_en_data
# Out:
#     Nodes  Try    Init  Trajectory Process  Data Set Sync  Action Post  \
# 0       1    1  0.0001            153.0819         0.0000            0
# 1       1    2  0.0001            153.0819         0.0000            0
# 2       1    3  0.0004            135.0393         0.0000            0
# 3       1    4  0.0005            165.0113         0.0000            0
# 4       1    5  0.0006            151.5605         0.0000            0
# 5       1    6  0.0004            153.1182         0.0000            0
# 6       2    1  0.0142             84.6154         0.0002            0
# 7       2    2  0.0149             87.4713         0.0002            0
# 8       2    3  0.0140            139.5295         0.0002            0
# 9       2    4  0.0148             78.9509         0.0002            0
# 10      2    5  0.0148             78.9509         0.0002            0
# 11      2    6  0.0153            109.0029         0.0001            0
# ...

# %%
cpp_init=[None]*5
cpp_init[0] = {'mean':np.mean(cpptraj_en_data['Init'][0:6]),'std':np.std(cpptraj_en_data['Init'][0:6])}
cpp_init[1] = {'mean':np.mean(cpptraj_en_data['Init'][6:12]),'std':np.std(cpptraj_en_data['Init'][6:12])}
cpp_init[2] = {'mean':np.mean(cpptraj_en_data['Init'][12:18]),'std':np.std(cpptraj_en_data['Init'][12:18])}
cpp_init[3] = {'mean':np.mean(cpptraj_en_data['Init'][18:24]),'std':np.std(cpptraj_en_data['Init'][18:24])}
cpp_init[4] = {'mean':np.mean(cpptraj_en_data['Init'][24:30]),'std':np.std(cpptraj_en_data['Init'][24:30])}
cpp_proc=[None]*5
cpp_proc[0] = {'mean':np.mean(cpptraj_en_data['Trajectory Process'][0:6]),'std':np.std(cpptraj_en_data['Trajectory Process'][0:6])}
cpp_proc[1] = {'mean':np.mean(cpptraj_en_data['Trajectory Process'][6:12]),'std':np.std(cpptraj_en_data['Trajectory Process'][6:12])}
cpp_proc[2] = {'mean':np.mean(cpptraj_en_data['Trajectory Process'][12:18]),'std':np.std(cpptraj_en_data['Trajectory Process'][12:18])}
cpp_proc[3] = {'mean':np.mean(cpptraj_en_data['Trajectory Process'][18:24]),'std':np.std(cpptraj_en_data['Trajectory Process'][18:24])}
cpp_proc[4] = {'mean':np.mean(cpptraj_en_data['Trajectory Process'][24:30]),'std':np.std(cpptraj_en_data['Trajectory Process'][24:30])}
cpp_write=[None]*5
cpp_write[0] = {'mean':np.mean(cpptraj_en_data['Data File Write'][0:6]),'std':np.std(cpptraj_en_data['Data File Write'][0:6])}
cpp_write[1] = {'mean':np.mean(cpptraj_en_data['Data File Write'][6:12]),'std':np.std(cpptraj_en_data['Data File Write'][6:12])}
cpp_write[2] = {'mean':np.mean(cpptraj_en_data['Data File Write'][12:18]),'std':np.std(cpptraj_en_data['Data File Write'][12:18])}
cpp_write[3] = {'mean':np.mean(cpptraj_en_data['Data File Write'][18:24]),'std':np.std(cpptraj_en_data['Data File Write'][18:24])}
cpp_write[4] = {'mean':np.mean(cpptraj_en_data['Data File Write'][24:30]),'std':np.std(cpptraj_en_data['Data File Write'][24:30])}

# %%
a=plt.figure()
plt.title('Time to Completion @ Stampede Ensemble mode, 8/24/2016')
plt.ylabel('Time to Completion (secs)',fontsize=14)
n_groups=5
index=np.arange(n_groups)
bar_width=0.25
opacity=1.0
a1=plt.bar(index,[cppen_1,cppen_2,cppen_4,cppen_8,cppen_16],
           bar_width,
           yerr=[cppen_1_std,cppen_2_std,cppen_4_std,cppen_8_std,cppen_16_std],
        alpha=opacity,color='darkgreen')
a13=plt.bar(index,[cpp_init[0]['mean']+cpp_proc[0]['mean']+cpp_write[0]['mean'],
                   cpp_init[1]['mean']+cpp_proc[1]['mean']+cpp_write[1]['mean'],
                   cpp_init[2]['mean']+cpp_proc[2]['mean']+cpp_write[2]['mean'],
                   cpp_init[3]['mean']+cpp_proc[3]['mean']+cpp_write[3]['mean'],
                   cpp_init[4]['mean']+cpp_proc[4]['mean']+cpp_write[4]['mean']],
                   bar_width,
             yerr=[cpp_write[0]['std'],cpp_write[1]['std'],cpp_write[2]['std'],cpp_write[3]['std'],cpp_write[4]['std']],
                   alpha=opacity,color='lightgreen')
a12=plt.bar(index,[cpp_init[0]['mean']+cpp_proc[0]['mean'],
                   cpp_init[1]['mean']+cpp_proc[1]['mean'],
                   cpp_init[2]['mean']+cpp_proc[2]['mean'],
                   cpp_init[3]['mean']+cpp_proc[3]['mean'],
                   cpp_init[4]['mean']+cpp_proc[4]['mean']],
                   bar_width,
             yerr=[cpp_proc[0]['std'],cpp_proc[1]['std'],cpp_proc[2]['std'],cpp_proc[3]['std'],cpp_proc[4]['std']],
                   alpha=opacity,color='greenyellow')
a11=plt.bar(index,[cpp_init[0]['mean'],
                   cpp_init[1]['mean'],
                   cpp_init[2]['mean'],
                   cpp_init[3]['mean'],
                   cpp_init[4]['mean']],
            bar_width,
             yerr=[cpp_init[0]['std'],
                   cpp_init[1]['std'],
                   cpp_init[2]['std'],
                   cpp_init[3]['std'],
                   cpp_init[4]['std']],
            alpha=opacity,color='lime')
a2=plt.bar(index+bar_width,[cpptraj_rpen1,cpptraj_rpen2,cpptraj_rpen4,cpptraj_rpen8,cpptraj_rpen16],bar_width,yerr=[cpptraj_rpen1_std,cpptraj_rpen2_std,cpptraj_rpen4_std,cpptraj_rpen8_std,cpptraj_rpen16_std],alpha=opacity,color='blue')
plt.xticks(index+bar_width,('1','2','4','8','16'))
plt.xlabel('Number of nodes')
lgd=plt.figlegend((a1,a11,a12,a13,a2),('CppTraj MPI','CppTraj MPI Init','CppTraj MPI Read & Exec','CppTraj MPI Write','RADICAL-Pilot'),loc='lower center',ncol=2,fontsize=10,borderaxespad=0.15)
a.subplots_adjust(bottom=0.22)
a.savefig('cpptraj_single_en_rp_vs_vanilla_detail.png',dpi=800,bbox_extra_artists=(lgd,))

# %%
rp_cppen2_16_1 = csv.reader(open('rp_cpptraj/ensemble/09-10-2016/rp_cpptraj_1-16.csv'))
rp_cppen2_16_2 = csv.reader(open('rp_cpptraj/ensemble/09-10-2016/rp_cpptraj_2-16.csv'))
rp_cppen2_16_3 = csv.reader(open('rp_cpptraj/ensemble/09-10-2016/rp_cpptraj_3-16.csv'))
rp_cppen2_32_1 = csv.reader(open('rp_cpptraj/ensemble/09-10-2016/rp_cpptraj_1-32.csv'))
rp_cppen2_32_2 = csv.reader(open('rp_cpptraj/ensemble/09-10-2016/rp_cpptraj_2-32.csv'))
rp_cppen2_32_3 = csv.reader(open('rp_cpptraj/ensemble/09-10-2016/rp_cpptraj_3-32.csv'))
rp_cppen2_64_1 = csv.reader(open('rp_cpptraj/ensemble/09-10-2016/rp_cpptraj_1-64.csv'))
rp_cppen2_64_2 = csv.reader(open('rp_cpptraj/ensemble/09-10-2016/rp_cpptraj_2-64.csv'))
rp_cppen2_64_3 = csv.reader(open('rp_cpptraj/ensemble/09-10-2016/rp_cpptraj_3-64.csv'))
rp_cppen2_128_1 = csv.reader(open('rp_cpptraj/ensemble/09-10-2016/rp_cpptraj_1-128.csv'))
rp_cppen2_128_2 = csv.reader(open('rp_cpptraj/ensemble/09-10-2016/rp_cpptraj_2-128.csv'))
rp_cppen2_128_3 = csv.reader(open('rp_cpptraj/ensemble/09-10-2016/rp_cpptraj_3-128.csv'))
rp_cppen2_256_1 = csv.reader(open('rp_cpptraj/ensemble/09-10-2016/rp_cpptraj_1-256.csv'))
rp_cppen2_256_2 = csv.reader(open('rp_cpptraj/ensemble/09-10-2016/rp_cpptraj_2-256.csv'))
rp_cppen2_256_3 = csv.reader(open('rp_cpptraj/ensemble/09-10-2016/rp_cpptraj_3-256.csv'))
rp_cppen2_512_1 = csv.reader(open('rp_cpptraj/ensemble/09-10-2016/rp_cpptraj_1-512.csv'))
rp_cppen2_512_2 = csv.reader(open('rp_cpptraj/ensemble/09-10-2016/rp_cpptraj_2-512.csv'))
rp_cppen2_512_3 = csv.reader(open('rp_cpptraj/ensemble/09-10-2016/rp_cpptraj_3-512.csv'))

# %%
def extract_timing(csv_file):
    import numpy as np
    results = list()
    for row in csv_file:
        if row[5]!='StageOut':
            results.append(float(row[5]))
    
    return np.array(results).max()
        
cpptraj2_rpen11 = extract_timing(rp_cppen2_16_1)
cpptraj2_rpen12 = extract_timing(rp_cppen2_16_2)
cpptraj2_rpen13 = extract_timing(rp_cppen2_16_3)
cpptraj2_rpen21 = extract_timing(rp_cppen2_32_1)
cpptraj2_rpen22 = extract_timing(rp_cppen2_32_2)
cpptraj2_rpen23 = extract_timing(rp_cppen2_32_3)
cpptraj2_rpen41 = extract_timing(rp_cppen2_64_1)
cpptraj2_rpen42 = extract_timing(rp_cppen2_64_2)
cpptraj2_rpen43 = extract_timing(rp_cppen2_64_3)
cpptraj2_rpen81 = extract_timing(rp_cppen2_128_1)
cpptraj2_rpen82 = extract_timing(rp_cppen2_128_2)
cpptraj2_rpen83 = extract_timing(rp_cppen2_128_3)
cpptraj2_rpen161 = extract_timing(rp_cppen2_256_1)
cpptraj2_rpen162 = extract_timing(rp_cppen2_256_2)
cpptraj2_rpen163 = extract_timing(rp_cppen2_256_3)
cpptraj2_rpen321 = extract_timing(rp_cppen2_512_1)
cpptraj2_rpen322 = extract_timing(rp_cppen2_512_2)
cpptraj2_rpen323 = extract_timing(rp_cppen2_512_3)

cpptraj2_rpen1 = np.mean([cpptraj2_rpen11,cpptraj2_rpen12,cpptraj2_rpen13])
cpptraj2_rpen2 = np.mean([cpptraj2_rpen21,cpptraj2_rpen22,cpptraj2_rpen23])
cpptraj2_rpen4 = np.mean([cpptraj2_rpen41,cpptraj2_rpen42,cpptraj2_rpen43])
cpptraj2_rpen8 = np.mean([cpptraj2_rpen81,cpptraj2_rpen82,cpptraj2_rpen83])
cpptraj2_rpen16 = np.mean([cpptraj2_rpen161,cpptraj2_rpen162,cpptraj2_rpen163])
cpptraj2_rpen32 = np.mean([cpptraj2_rpen321,cpptraj2_rpen322,cpptraj2_rpen323])

cpptraj2_rpen1_std = np.std([cpptraj2_rpen11,cpptraj2_rpen12,cpptraj2_rpen13])
cpptraj2_rpen2_std = np.std([cpptraj2_rpen21,cpptraj2_rpen22,cpptraj2_rpen23])
cpptraj2_rpen4_std = np.std([cpptraj2_rpen41,cpptraj2_rpen42,cpptraj2_rpen43])
cpptraj2_rpen8_std = np.std([cpptraj2_rpen81,cpptraj2_rpen82,cpptraj2_rpen83])
cpptraj2_rpen16_std = np.std([cpptraj2_rpen161,cpptraj2_rpen162,cpptraj2_rpen163])
cpptraj2_rpen32_std = np.std([cpptraj2_rpen321,cpptraj2_rpen322,cpptraj2_rpen323])

# %%
columns=['Nodes','Try','Init','Trajectory Process','Data Set Sync','Action Post','Analysis','Data File Write','Other','TTC']
data = np.array([[1,1,0.0005,627.7522,0.0000,0.0000,0.0000,0.3715,0.0004,630.0309],
                 [1,2,0.0007,652.8754,0.0000,0.0000,0.0000,1.5218,0.0007,656.6856],
                 [1,3,0.0002,629.4422,0.0000,0.0000,0.0000,0.1761,0.0002,631.3444],
                 [1,4,0.0004,640.7008,0.0000,0.0000,0.0000,0.1247,0.0003,643.2673],
                 [1,5,0.0003,621.3298,0.0000,0.0000,0.0000,0.1150,0.0006,623.2559],
                 [1,6,0.0009,675.2068,0.0000,0.0000,0.0000,0.1003,0.0007,677.2395],
                 [2,1,0.0143,421.8016,0.0005,0.0000,0.0000,2.2617,0.0019,425.9322],
                 [2,2,0.0158,418.5940,0.0004,0.0000,0.0000,0.0964,0.0017,421.7219],
                 [2,3,0.0135,432.4918,0.0004,0.0000,0.0000,0.0958,0.0020,434.4470],
                 [2,4,0.0144,444.8708,0.0004,0.0000,0.0000,0.0958,0.0016,446.9530],
                 [2,5,0.0147,420.4109,0.0004,0.0000,0.0000,0.0958,0.0024,422.5436],
                 [2,6,0.0145,409.9911,0.0004,0.0000,0.0000,0.0959,0.0015,413.4290],
                 [4,1,0.0166,309.7665,0.0005,0.0000,0.0000,0.0959,0.0024,311.8590],
                 [4,2,0.0167,304.8118,0.0005,0.0000,0.0000,0.0962,0.0023,307.4265],
                 [4,3,0.0171,300.3880,0.0004,0.0000,0.0000,0.0963,0.0024,302.3436],
                 [4,4,0.0175,293.9411,0.0005,0.0000,0.0000,0.0964,0.0022,295.8611],
                 [4,5,0.0180,303.0006,0.0005,0.0000,0.0000,0.0963,0.0029,305.0374],
                 [4,6,0.0157,281.9998,0.0005,0.0000,0.0000,0.0957,0.0028,283.8670],
                 [8,1,0.0196,286.3350,0.0009,0.0000,0.0000,0.0983,0.0035,288.2411],
                 [8,2,0.0192,279.1272,0.0009,0.0000,0.0000,0.0970,0.0040,281.5757],
                 [8,3,0.0187,285.5613,0.0005,0.0000,0.0000,0.0971,0.0034,287.4620],
                 [8,4,0.0187,280.1820,0.0005,0.0000,0.0000,0.0958,0.0041,282.7221],
                 [8,5,0.0191,267.3934,0.0009,0.0000,0.0000,0.0988,0.0037,269.3263],
                 [8,6,0.0195,269.3410,0.0008,0.0000,0.0000,0.0985,0.0034,271.2947],
                 [16,1,0.0231, 265.2704,0.0006,0.0000,0.000,0.0959,0.0159,268.1451],
                 [16,2,0.0269,268.4838,0.0006,0.0000,0.0000,0.0993,0.0175,270.2926],
                 [16,3,0.0211,261.3523,0.0005,0.0000,0.0000,0.0978,0.0233,265.1687],
                 [16,4,0.0224,260.0943,0.0005,0.0000,0.0000,0.0984,0.0127,262.0587],
                 [16,5,0.0228,258.4089,0.0005,0.0000,0.0000,0.0979,0.0062,260.5150],
                 [16,6,0.0228,259.3761,0.0005,0.0000,0.0000,0.0985,0.0170,261.8271],
                 [32,1,0.0307,289.2984,0.0375,0.0000,0.0000,0.0968,0.0185,292.7704],
                 [32,2,0.0404,271.3133,0.0427,0.0000,0.0000,0.0974,0.0193,276.6428],
                 [32,3,0.0323,284.9578,0.0330,0.0000,0.0000,2.9612,0.0253,343.2014],
                 [32,4,0.0304,232.5049,0.0357,0.0004,0.0000,0.0974,0.0209,234.6099],
                 [32,5,0.0305,227.0118,0.0398,0.0000,0.0000,0.0971,0.0226,229.9660],
                 [32,6,0.0300,229.1908,0.0305,0.0000,0.0000,0.0979,0.0245,231.6696]])

cpptraj2_en_data = pd.DataFrame(data,columns=columns)

# %%
cpp2_init=[None]*6
cpp2_init[0] = {'mean':np.mean(cpptraj2_en_data['Init'][0:6]),'std':np.std(cpptraj2_en_data['Init'][0:6])}
cpp2_init[1] = {'mean':np.mean(cpptraj2_en_data['Init'][6:12]),'std':np.std(cpptraj2_en_data['Init'][6:12])}
cpp2_init[2] = {'mean':np.mean(cpptraj2_en_data['Init'][12:18]),'std':np.std(cpptraj2_en_data['Init'][12:18])}
cpp2_init[3] = {'mean':np.mean(cpptraj2_en_data['Init'][18:24]),'std':np.std(cpptraj2_en_data['Init'][18:24])}
cpp2_init[4] = {'mean':np.mean(cpptraj2_en_data['Init'][24:30]),'std':np.std(cpptraj2_en_data['Init'][24:30])}
cpp2_init[5] = {'mean':np.mean(cpptraj2_en_data['Init'][30:36]),'std':np.std(cpptraj2_en_data['Init'][30:36])}
cpp2_proc=[None]*6
cpp2_proc[0] = {'mean':np.mean(cpptraj2_en_data['Trajectory Process'][0:6]),'std':np.std(cpptraj2_en_data['Trajectory Process'][0:6])}
cpp2_proc[1] = {'mean':np.mean(cpptraj2_en_data['Trajectory Process'][6:12]),'std':np.std(cpptraj2_en_data['Trajectory Process'][6:12])}
cpp2_proc[2] = {'mean':np.mean(cpptraj2_en_data['Trajectory Process'][12:18]),'std':np.std(cpptraj2_en_data['Trajectory Process'][12:18])}
cpp2_proc[3] = {'mean':np.mean(cpptraj2_en_data['Trajectory Process'][18:24]),'std':np.std(cpptraj2_en_data['Trajectory Process'][18:24])}
cpp2_proc[4] = {'mean':np.mean(cpptraj2_en_data['Trajectory Process'][24:30]),'std':np.std(cpptraj2_en_data['Trajectory Process'][24:30])}
cpp2_proc[5] = {'mean':np.mean(cpptraj2_en_data['Trajectory Process'][30:36]),'std':np.std(cpptraj2_en_data['Trajectory Process'][30:36])}
cpp2_write=[None]*6
cpp2_write[0] = {'mean':np.mean(cpptraj2_en_data['Data File Write'][0:6]),'std':np.std(cpptraj2_en_data['Data File Write'][0:6])}
cpp2_write[1] = {'mean':np.mean(cpptraj2_en_data['Data File Write'][6:12]),'std':np.std(cpptraj2_en_data['Data File Write'][6:12])}
cpp2_write[2] = {'mean':np.mean(cpptraj2_en_data['Data File Write'][12:18]),'std':np.std(cpptraj2_en_data['Data File Write'][12:18])}
cpp2_write[3] = {'mean':np.mean(cpptraj2_en_data['Data File Write'][18:24]),'std':np.std(cpptraj2_en_data['Data File Write'][18:24])}
cpp2_write[4] = {'mean':np.mean(cpptraj2_en_data['Data File Write'][24:30]),'std':np.std(cpptraj2_en_data['Data File Write'][24:30])}
cpp2_write[5] = {'mean':np.mean(cpptraj2_en_data['Data File Write'][30:36]),'std':np.std(cpptraj2_en_data['Data File Write'][30:36])}
cpp2_ttc=[None]*6
cpp2_ttc[0] = {'mean':np.mean(cpptraj2_en_data['TTC'][0:6]),'std':np.std(cpptraj2_en_data['TTC'][0:6])}
cpp2_ttc[1] = {'mean':np.mean(cpptraj2_en_data['TTC'][6:12]),'std':np.std(cpptraj2_en_data['TTC'][6:12])}
cpp2_ttc[2] = {'mean':np.mean(cpptraj2_en_data['TTC'][12:18]),'std':np.std(cpptraj2_en_data['TTC'][12:18])}
cpp2_ttc[3] = {'mean':np.mean(cpptraj2_en_data['TTC'][18:24]),'std':np.std(cpptraj2_en_data['TTC'][18:24])}
cpp2_ttc[4] = {'mean':np.mean(cpptraj2_en_data['TTC'][24:30]),'std':np.std(cpptraj2_en_data['TTC'][24:30])}
cpp2_ttc[5] = {'mean':np.mean(cpptraj2_en_data['TTC'][30:36]),'std':np.std(cpptraj2_en_data['TTC'][30:36])}

# %%
a=plt.figure()
plt.title('Time to Completion @ Stampede Ensemble mode, 9/10/2016\nEnsemble Size 80000 frames')
plt.ylabel('Time to Completion (secs)',fontsize=14)
n_groups=6
index=np.arange(n_groups)
bar_width=0.25
opacity=1.0
a1=plt.bar(index,[cpp2_ttc[0]['mean'],
                  cpp2_ttc[1]['mean'],
                  cpp2_ttc[2]['mean'],
                  cpp2_ttc[3]['mean'],
                  cpp2_ttc[4]['mean'],
                  cpp2_ttc[5]['mean']],
           bar_width,
           yerr=[cpp2_ttc[0]['std'],
                 cpp2_ttc[1]['std'],
                 cpp2_ttc[2]['std'],
                 cpp2_ttc[3]['std'],
                 cpp2_ttc[4]['std'],
                 cpp2_ttc[5]['std']],
        alpha=opacity,color='darkgreen')
a13=plt.bar(index,[cpp2_init[0]['mean']+cpp2_proc[0]['mean']+cpp2_write[0]['mean'],
                   cpp2_init[1]['mean']+cpp2_proc[1]['mean']+cpp2_write[1]['mean'],
                   cpp2_init[2]['mean']+cpp2_proc[2]['mean']+cpp2_write[2]['mean'],
                   cpp2_init[3]['mean']+cpp2_proc[3]['mean']+cpp2_write[3]['mean'],
                   cpp2_init[4]['mean']+cpp2_proc[4]['mean']+cpp2_write[4]['mean'],
                   cpp2_init[5]['mean']+cpp2_proc[5]['mean']+cpp2_write[5]['mean']],
                   bar_width,
             yerr=[cpp2_write[0]['std'],cpp2_write[1]['std'],cpp2_write[2]['std'],cpp2_write[3]['std'],cpp2_write[4]['std'],cpp2_write[5]['std']],
                   alpha=opacity,color='lightgreen')
a12=plt.bar(index,[cpp2_init[0]['mean']+cpp2_proc[0]['mean'],
                   cpp2_init[1]['mean']+cpp2_proc[1]['mean'],
                   cpp2_init[2]['mean']+cpp2_proc[2]['mean'],
                   cpp2_init[3]['mean']+cpp2_proc[3]['mean'],
                   cpp2_init[4]['mean']+cpp2_proc[4]['mean'],
                   cpp2_init[5]['mean']+cpp2_proc[5]['mean']],
                   bar_width,
             yerr=[cpp2_proc[0]['std'],cpp2_proc[1]['std'],cpp2_proc[2]['std'],cpp2_proc[3]['std'],cpp2_proc[4]['std'],cpp2_proc[5]['std']],
                   alpha=opacity,color='greenyellow')
a11=plt.bar(index,[cpp2_init[0]['mean'],
                   cpp2_init[1]['mean'],
                   cpp2_init[2]['mean'],
                   cpp2_init[3]['mean'],
                   cpp2_init[4]['mean'],
                   cpp2_init[5]['mean']],
            bar_width,
             yerr=[cpp2_init[0]['std'],
                   cpp2_init[1]['std'],
                   cpp2_init[2]['std'],
                   cpp2_init[3]['std'],
                   cpp2_init[4]['std'],
                   cpp2_init[5]['std']],
            alpha=opacity,color='lime')
a2=plt.bar(index+bar_width,[cpptraj2_rpen1,
                            cpptraj2_rpen2,
                            cpptraj2_rpen4,
                            cpptraj2_rpen8,
                            cpptraj2_rpen16,
                            cpptraj2_rpen32],
                bar_width,
                      yerr=[cpptraj2_rpen1_std,
                            cpptraj2_rpen2_std,
                            cpptraj2_rpen4_std,
                            cpptraj2_rpen8_std,
                            cpptraj2_rpen16_std,
                            cpptraj2_rpen32_std],
                            alpha=opacity,color='blue')
plt.xticks(index+bar_width,('1','2','4','8','16','32'))
plt.xlabel('Number of nodes')
lgd=plt.figlegend((a1,a11,a12,a13,a2),('CppTraj MPI','CppTraj MPI Init','CppTraj MPI Read & Exec','CppTraj MPI Write','RADICAL-Pilot'),loc='lower center',ncol=2,fontsize=10,borderaxespad=0.15)
a.subplots_adjust(bottom=0.22)
a.savefig('cpptraj_single_en_rp_vs_vanilla_80Kframes.png',dpi=800,bbox_extra_artists=(lgd,))
