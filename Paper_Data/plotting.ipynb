# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from textwrap import wrap
import json
import os

# %%
Stampede_startup=np.mean([18.865,21.2005,18.9489,18.813,19.0464,26.0466])
Stampede_startup_std=np.std([18.865,21.2005,18.9489,18.813,19.0464,26.0466])

StampedeY_startup_8=np.mean([])
StampedeY_startup_8_std=np.std([])

StampedeY_startup_16=np.mean([18.546,18.6155,])
StampedeY_startup_16_std=np.std([])

StampedeY_startup_32=np.mean([18.4803,19.0486,18.9608])
StampedeY_startup_32_std=np.std([18.4803,19.0486,18.9608])

# %%
Stampede_setup=np.mean([41.3166,33.5194,33.8765,55.2814,33.4078,33.2363])
Stampede_setup_std=np.std([41.3166,33.5194,33.8765,55.2814,33.4078,33.2363])

StampedeY_setup_8=np.mean([])
StampedeY_setup_8_std=np.std([])

StampedeY_setup_16=np.mean([115.8788,111.2982,])
StampedeY_setup_16_std=np.std([])

StampedeY_setup_32=np.mean([109.9705,146.2759,120.4977])
StampedeY_setup_32_std=np.std([109.9705,146.2759,120.4977])

# %%
Wrangler_startup=np.mean([32.2527,31.6556,31.9859,32.1798,34.3127,31.3348])
WranglerY_startup=np.mean([15.4973,16.025,16.1885,16.0132,15.9496,15.8779])
Wrangler_startup_std=np.std([32.2527,31.6556,31.9859,32.1798,34.3127,31.3348])
WranglerY_startup_std=np.std([15.4973,16.025,16.1885,16.0132,15.9496,15.8779])

# %%
Wrangler_setup=np.mean([32.2527,31.6556,31.9859,32.1798,34.3127,31.3348])
WranglerY_setup=np.mean([86.7343,86.9482,85.2831,85.4554,86.4079,88.9074])
Wrangler_setup_std=np.std([32.2527,31.6556,31.9859,32.1798,34.3127,31.3348])
WranglerY_setup_std=np.std([86.7343,86.9482,85.2831,85.4554,86.4079,88.9074])

# %%
b=plt.figure()
n_groups=2
index=np.arange(n_groups)
bar_width=0.30
opacity=1.0
plt.bar(index+0.25*bar_width,[Stampede_setup, Wrangler_setup],bar_width,yerr=[Stampede_setup_std,Wrangler_setup_std],alpha=opacity,color='darkgreen')
plt.bar(index+0.25*bar_width,[Stampede_startup, Wrangler_startup],bar_width,yerr=[Stampede_startup_std,Wrangler_startup_std],alpha=opacity,color='lightgreen')
plt.bar(index+1.25*bar_width,[StampedeY_setup,WranglerY_setup],bar_width,yerr=[StampedeY_setup_std,WranglerY_setup_std],alpha=opacity,color='blue')
plt.bar(index+1.25*bar_width,[StampedeY_startup,WranglerY_startup],bar_width,yerr=[StampedeY_startup_std,WranglerY_startup_std],alpha=opacity,color='cyan')
plt.xticks(index+1.25*bar_width,('Stampede','Wrangler'))
plt.ylim(ymax=150.0)
plt.xlabel('Selected Distributed Computation Resource')
plt.ylabel('Startup time (secs)')
plt.title('RADICAL-Pilot and RADICAL-Pilot-YARN Startup time Time Comparison')
plt.legend(('RP Setup','RP Startup','RP-YARN Setup','RP-YARN Startup'),fancybox=True,framealpha=0.5,prop={'size':9})
b.savefig('startup-rp-rpyarn-comp.png',dpi=800)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-5ffc3bce00b2> in <module>()
#       6 plt.bar(index+0.25*bar_width,[Stampede_setup, Wrangler_setup],bar_width,yerr=[Stampede_setup_std,Wrangler_setup_std],alpha=opacity,color='darkgreen')
#       7 plt.bar(index+0.25*bar_width,[Stampede_startup, Wrangler_startup],bar_width,yerr=[Stampede_startup_std,Wrangler_startup_std],alpha=opacity,color='lightgreen')
# ----> 8 plt.bar(index+1.25*bar_width,[StampedeY_setup,WranglerY_setup],bar_width,yerr=[StampedeY_setup_std,WranglerY_setup_std],alpha=opacity,color='blue')
#       9 plt.bar(index+1.25*bar_width,[StampedeY_startup,WranglerY_startup],bar_width,yerr=[StampedeY_startup_std,WranglerY_startup_std],alpha=opacity,color='cyan')
#      10 plt.xticks(index+1.25*bar_width,('Stampede','Wrangler'))
#
# NameError: name 'StampedeY_setup' is not defined

# %%
#Stampede 8 tasks ttcs
Stampede_time_small_8=np.mean([2145.54412007,2137.63672495,2229.51565909])
Stampede_time_medium_8=np.mean([2213.70678091,2147.27242804,2138.70977902])
Stampede_time_large_8=np.mean([2137.64313507,2131.87873387,2206.38733602])
StampedeY_time_small_8=np.mean([1723.27119398,1733.5453589,1724.09045601])
StampedeY_time_medium_8=np.mean([1734.21029592,1735.3958571,1737.93442488])
StampedeY_time_large_8=np.mean([1718.71537995,1715.78900099,1738.41648912])
StampedeS_time_small_8=np.mean([1571.23809004,1607.93889713,1612.394243])
StampedeS_time_medium_8=np.mean([1570.41904712,1589.76588392,1582.03352499])
StampedeS_time_large_8=np.mean([1622.29736805,1608.96517015,1631.1483469])

#Error Bars
Stampede_time_small_8_std=np.std([2145.54412007,2137.63672495,2229.51565909])
Stampede_time_medium_8_std=np.std([2213.70678091,2147.27242804,2138.70977902])
Stampede_time_large_8_std=np.std([2137.64313507,2131.87873387,2206.38733602])
StampedeY_time_small_8_std=np.std([1723.27119398,1733.5453589,1724.09045601])
StampedeY_time_medium_8_std=np.std([1734.21029592,1735.3958571,1737.93442488])
StampedeY_time_large_8_std=np.std([1718.71537995,1715.78900099,1738.41648912])
StampedeS_time_small_8_std=np.std([1571.23809004,1607.93889713,1612.394243])
StampedeS_time_medium_8_std=np.std([1570.41904712,1589.76588392,1582.03352499])
StampedeS_time_large_8_std=np.std([1622.29736805,1608.96517015,1631.1483469])

# %%
#Stampede 16 tasks ttcs
Stampede_time_small_16=np.mean([1221.28923011,1183.63156605,1220.72959614])
Stampede_time_medium_16=np.mean([1191.69664311,1162.15839291,1192.43594384])
Stampede_time_large_16=np.mean([1165.85112,1167.35577297,1162.25411582])
StampedeY_time_small_16=np.mean([987.688973904,1066.99679112,967.207538128])
StampedeY_time_medium_16=np.mean([980.556000948,1010.21886802,1019.55931401])
StampedeY_time_large_16=np.mean([1047.19151306,1042.51522613,1029.15395498])
StampedeS_time_small_16=np.mean([928.314900875,930.800843,967.870089054])
StampedeS_time_medium_16=np.mean([887.690189838,964.185465097,897.239539146])
StampedeS_time_large_16=np.mean([908.238212109,961.891016006,917.48016119])

#Error Bars
Stampede_time_small_16_std=np.std([1221.28923011,1183.63156605,1220.72959614])
Stampede_time_medium_16_std=np.std([1191.69664311,1162.15839291,1192.43594384])
Stampede_time_large_16_std=np.std([1165.85112,1167.35577297,1162.25411582])
StampedeY_time_small_16_std=np.std([987.688973904,1066.99679112,967.207538128])
StampedeY_time_medium_16_std=np.std([980.556000948,1010.21886802,1019.55931401])
StampedeY_time_large_16_std=np.std([1047.19151306,1042.51522613,1029.15395498])
StampedeS_time_small_16_std=np.std([928.314900875,930.800843,967.870089054])
StampedeS_time_medium_16_std=np.std([887.690189838,964.185465097,897.239539146])
StampedeS_time_large_16_std=np.std([908.238212109,961.891016006,917.48016119])

# %%
#Stampede 32 tasks ttcs
Stampede_time_small_32=np.mean([896.259181023,882.803158045,896.660805941])
Stampede_time_medium_32=np.mean([867.632007122,871.577993155,865.012584925])
Stampede_time_large_32=np.mean([937.848841906,960.252981901,873.237067938])
StampedeY_time_small_32=np.mean([576.099653959,645.488940001,578.568024874])
StampedeY_time_medium_32=np.mean([630.842726946,633.868588924,599.657902956])
StampedeY_time_large_32=np.mean([701.674252987,685.290445089,749.814280987])
StampedeS_time_small_32=np.mean([923.755445957,956.245986938,955.494695902])
StampedeS_time_medium_32=np.mean([927.234841108,924.904603004,928.693590879])
StampedeS_time_large_32=np.mean([939.74081707,949.304029226,923.430924892])

#Error Bars
Stampede_time_small_32_std=np.std([896.259181023,882.803158045,896.660805941])
Stampede_time_medium_32_std=np.std([867.632007122,871.577993155,865.012584925])
Stampede_time_large_32_std=np.std([937.848841906,960.252981901,873.237067938])
StampedeY_time_small_32_std=np.std([576.099653959,645.488940001,578.568024874])
StampedeY_time_medium_32_std=np.std([630.842726946,633.868588924,599.657902956])
StampedeY_time_large_32_std=np.std([701.674252987,685.290445089,749.814280987])
StampedeS_time_small_32_std=np.std([923.755445957,956.245986938,955.494695902])
StampedeS_time_medium_32_std=np.std([927.234841108,924.904603004,928.693590879])
StampedeS_time_large_32_std=np.std([939.74081707,949.304029226,923.430924892])

# %%
#Wrangler 8 tasks ttcs
Wrangler_time_small_8=np.mean([1509.75763988,1489.48768806,1531.8664999])
Wrangler_time_medium_8=np.mean([1485.52234507,1510.37437296,1522.61645484])
Wrangler_time_large_8=np.mean([1508.49888992,1489.49785399,1506.396873])
WranglerY_time_small_8=np.mean([1505.84960198,1579.40950608,1517.49286604])
WranglerY_time_medium_8=np.mean([1622.9932158,1529.28812814,1519.59566593])
WranglerY_time_large_8=np.mean([1560.92624092,1521.58122206,2067.66725993])

#Error Bars
Wrangler_time_small_8_std=np.std([1509.75763988,1489.48768806,1531.8664999])
Wrangler_time_medium_8_std=np.std([1485.52234507,1510.37437296,1522.61645484])
Wrangler_time_large_8_std=np.std([1508.49888992,1489.49785399,1506.396873])
WranglerY_time_small_8_std=np.std([1505.84960198,1579.40950608,1517.49286604])
WranglerY_time_medium_8_std=np.std([1622.9932158,1529.28812814,1519.59566593])
WranglerY_time_large_8_std=np.std([1560.92624092,1521.58122206,2067.66725993])

# %%
#Wrangler 16 tasks ttcs
Wrangler_time_small_16=np.mean([959.80213809,966.711568117,942.672577858])
Wrangler_time_medium_16=np.mean([966.113461971,1011.8970952,949.593145847])
Wrangler_time_large_16=np.mean([905.841525078,901.491403103,972.960112095])
WranglerY_time_small_16=np.mean([870.600597858,848.648193121,854.519306898])
WranglerY_time_medium_16=np.mean([871.803068161,882.785458088,847.346942902])
WranglerY_time_large_16=np.mean([840.363274097,878.792753935,841.203996181])

#Error Bars
Wrangler_time_small_16_std=np.std([959.80213809,966.711568117,942.672577858])
Wrangler_time_medium_16_std=np.std([966.113461971,1011.8970952,949.593145847])
Wrangler_time_large_16_std=np.std([905.841525078,901.491403103,972.960112095])
WranglerY_time_small_16_std=np.std([870.600597858,848.648193121,854.519306898])
WranglerY_time_medium_16_std=np.std([871.803068161,882.785458088,847.346942902])
WranglerY_time_large_16_std=np.std([840.363274097,878.792753935,841.203996181])

# %%
#Wrangler 32 tasks ttcs
Wrangler_time_small_32=np.mean([663.985900879,683.988374949,667.636712074])
Wrangler_time_medium_32=np.mean([657.932945013,675.298155069,673.550294161])
Wrangler_time_large_32=np.mean([640.345217943,638.115234852,628.021702051])
WranglerY_time_small_32=np.mean([510.741494179,510.556525946,531.348989964])
WranglerY_time_medium_32=np.mean([531.348989964,511.882702827,512.776201963])
WranglerY_time_large_32=np.mean([567.432689905,518.862347126,513.828785896])

#Error Bars
Wrangler_time_small_32_std=np.std([663.985900879,683.988374949,667.636712074])
Wrangler_time_medium_32_std=np.std([657.932945013,675.298155069,673.550294161])
Wrangler_time_large_32_std=np.std([640.345217943,638.115234852,628.021702051])
WranglerY_time_small_32_std=np.std([510.741494179,510.556525946,531.348989964])
WranglerY_time_medium_32_std=np.std([531.348989964,511.882702827,512.776201963])
WranglerY_time_large_32_std=np.std([567.432689905,518.862347126,513.828785896])

# %%
a=plt.figure()
plt.suptitle('K-Means Execution Time Comparison',y=1.06,fontsize=14)
plt.subplot(1,3,1)
n_groups=3
index=np.arange(n_groups)
bar_width=0.1
opacity=1.0
plt.bar(index,[Stampede_time_small_8,Stampede_time_small_16,Stampede_time_small_32],bar_width,yerr=[Stampede_time_small_8_std,Stampede_time_small_16_std,Stampede_time_small_32_std],alpha=opacity,color='darkgreen',label='RP Stampede')
plt.bar(index+bar_width,[StampedeY_time_small_8,StampedeY_time_small_16,StampedeY_time_small_32],bar_width,yerr=[StampedeY_time_small_8_std,StampedeY_time_small_16_std,StampedeY_time_small_32_std],alpha=opacity,color='blue',label='RP-YARN Stampede')
plt.bar(index+2*bar_width,[StampedeS_time_small_8,StampedeS_time_small_16,StampedeS_time_small_32],bar_width,yerr=[StampedeS_time_small_8_std,StampedeS_time_small_16_std,StampedeS_time_small_32_std],alpha=opacity,color='orange',label='RP-Spark Stampede')
plt.bar(index+3*bar_width,[Wrangler_time_small_8,Wrangler_time_small_16,Wrangler_time_small_32],bar_width,yerr=[Wrangler_time_small_8_std,Wrangler_time_small_16_std,Wrangler_time_small_32_std],alpha=opacity,color='cyan',label='RP Wrangler')
plt.bar(index+4*bar_width,[WranglerY_time_small_8,WranglerY_time_small_16,WranglerY_time_small_32],bar_width,yerr=[WranglerY_time_small_8_std,WranglerY_time_small_16_std,WranglerY_time_small_32_std],alpha=opacity,color='red',label='RP-YARN Wrangler')
plt.title('10,000 points'+'\n'+'5,000 clusters')
plt.xticks(index+3*bar_width,('8','16','32'))
plt.ylim(ymax=2900)
plt.ylabel('Time to Completion (secs)',fontsize=14)
plt.subplot(1,3,2)
n_groups=3
index=np.arange(n_groups)
bar_width=0.1
opacity=1.0
plt.bar(index,[Stampede_time_medium_8,Stampede_time_medium_16,Stampede_time_medium_32],bar_width,yerr=[Stampede_time_medium_8_std,Stampede_time_medium_16_std,Stampede_time_medium_32_std],alpha=opacity,color='darkgreen',label='RP Stampede')
plt.bar(index+bar_width,[StampedeY_time_medium_8,StampedeY_time_medium_16,StampedeY_time_medium_32],bar_width,yerr=[StampedeY_time_medium_8_std,StampedeY_time_medium_16_std,StampedeY_time_medium_32_std],alpha=opacity,color='blue',label='RP-YARN Stampede')
plt.bar(index+2*bar_width,[StampedeS_time_medium_8,StampedeS_time_medium_16,StampedeS_time_medium_32],bar_width,yerr=[StampedeS_time_medium_8_std,StampedeS_time_medium_16_std,StampedeS_time_medium_32_std],alpha=opacity,color='orange',label='RP-Spark Stampede')
plt.bar(index+3*bar_width,[Wrangler_time_medium_8,Wrangler_time_medium_16,Wrangler_time_medium_32],bar_width,yerr=[Wrangler_time_medium_8_std,Wrangler_time_medium_16_std,Wrangler_time_medium_32_std],alpha=opacity,color='cyan',label='RP Wrangler')
plt.bar(index+4*bar_width,[WranglerY_time_medium_8,WranglerY_time_medium_16,WranglerY_time_medium_32],bar_width,yerr=[WranglerY_time_medium_8_std,WranglerY_time_medium_16_std,WranglerY_time_medium_32_std],alpha=opacity,color='red',label='RP-YARN Wrangler')
plt.title('100,000 points'+'\n'+'500 clusters')
plt.xticks(index+3*bar_width,('8','16','32'))
plt.ylim(ymax=2900)
plt.subplot(1,3,3)
n_groups=3
index=np.arange(n_groups)
bar_width=0.1
opacity=1.0
b1=plt.bar(index,[Stampede_time_large_8,Stampede_time_large_16,Stampede_time_large_32],bar_width,yerr=[Stampede_time_large_8_std,Stampede_time_large_16_std,Stampede_time_large_32_std],alpha=opacity,color='darkgreen',label='RP-YARN Wrangler')
b2=plt.bar(index+bar_width,[StampedeY_time_large_8,StampedeY_time_large_16,StampedeY_time_large_32],bar_width,yerr=[StampedeY_time_large_8_std,StampedeY_time_large_16_std,StampedeY_time_large_32_std],alpha=opacity,color='blue',label='RP-YARN Stampede')
b3=plt.bar(index+2*bar_width,[StampedeS_time_large_8,StampedeS_time_large_16,StampedeS_time_large_32],bar_width,yerr=[StampedeS_time_large_8_std,StampedeS_time_large_16_std,StampedeS_time_large_32_std],alpha=opacity,color='orange',label='RP-Spark Stampede')
b4=plt.bar(index+3*bar_width,[Wrangler_time_large_8,Wrangler_time_large_16,Wrangler_time_large_32],bar_width,yerr=[Wrangler_time_large_8_std,Wrangler_time_large_16_std,Wrangler_time_large_32_std],alpha=opacity,color='cyan',label='RP Wrangler')
b5=plt.bar(index+4*bar_width,[WranglerY_time_large_8,WranglerY_time_large_16,WranglerY_time_large_32],bar_width,yerr=[WranglerY_time_large_8_std,WranglerY_time_large_16_std,WranglerY_time_large_32_std],alpha=opacity,color='red',label='RP-YARN Wrangler')
plt.xticks(index+3*bar_width,('8','16','32'))
plt.title('1,000,000 points'+'\n'+'50 clusters')
plt.ylim(ymax=2900)
lgd=plt.figlegend((b1,b2,b3,b4,b5),('RP on Stampede','RP-YARN on Stampede','RP-Spark on Stampede','RP on Wrangler','RP-YARN on Wrangler'),
              loc='lower center',mode="expand",ncol=3,fontsize=10,borderaxespad=0.11)
a.text(0.45,0.16,'Number of Tasks',ha='center',fontsize=14)
a.subplots_adjust(bottom=0.25)
a.savefig('kmeans-ttc-comp.png',dpi=800,bbox_extra_artists=(lgd,))

# %%
#Total time Speedup Calculation

##Stampede and Wrangler Small
sv_speed_1_small = Stampede_time_small_8/Stampede_time_small_8
sv_speed_2_small = Stampede_time_small_8/Stampede_time_small_16
sv_speed_3_small = Stampede_time_small_8/Stampede_time_small_32

sy_speed_1_small = StampedeY_time_small_8/StampedeY_time_small_8
sy_speed_2_small = StampedeY_time_small_8/StampedeY_time_small_16
sy_speed_3_small = StampedeY_time_small_8/StampedeY_time_small_32

wv_speed_1_small = Wrangler_time_small_8/Wrangler_time_small_8
wv_speed_2_small = Wrangler_time_small_8/Wrangler_time_small_16
wv_speed_3_small = Wrangler_time_small_8/Wrangler_time_small_32

wy_speed_1_small = WranglerY_time_small_8/WranglerY_time_small_8
wy_speed_2_small = WranglerY_time_small_8/WranglerY_time_small_16
wy_speed_3_small = WranglerY_time_small_8/WranglerY_time_small_32

##Stampede and Wrangler Medium
sv_speed_1_medium = Stampede_time_medium_8/Stampede_time_medium_8
sv_speed_2_medium = Stampede_time_medium_8/Stampede_time_medium_16
sv_speed_3_medium = Stampede_time_medium_8/Stampede_time_medium_32

sy_speed_1_medium = StampedeY_time_medium_8/StampedeY_time_medium_8
sy_speed_2_medium = StampedeY_time_medium_8/StampedeY_time_medium_16
sy_speed_3_medium = StampedeY_time_medium_8/StampedeY_time_medium_32

wv_speed_1_medium = Wrangler_time_medium_8/Wrangler_time_medium_8
wv_speed_2_medium = Wrangler_time_medium_8/Wrangler_time_medium_16
wv_speed_3_medium = Wrangler_time_medium_8/Wrangler_time_medium_32

wy_speed_1_medium = WranglerY_time_medium_8/WranglerY_time_medium_8
wy_speed_2_medium = WranglerY_time_medium_8/WranglerY_time_medium_16
wy_speed_3_medium = WranglerY_time_medium_8/WranglerY_time_medium_32

##Stampede and Wrangler Large
sv_speed_1_large = Stampede_time_large_8/Stampede_time_large_8
sv_speed_2_large = Stampede_time_large_8/Stampede_time_large_16
sv_speed_3_large = Stampede_time_large_8/Stampede_time_large_32

sy_speed_1_large = StampedeY_time_large_8/StampedeY_time_large_8
sy_speed_2_large = StampedeY_time_large_8/StampedeY_time_large_16
sy_speed_3_large = StampedeY_time_large_8/StampedeY_time_large_32

wv_speed_1_large = Wrangler_time_large_8/Wrangler_time_large_8
wv_speed_2_large = Wrangler_time_large_8/Wrangler_time_large_16
wv_speed_3_large = Wrangler_time_large_8/Wrangler_time_large_32

wy_speed_1_large = WranglerY_time_large_8/WranglerY_time_large_8
wy_speed_2_large = WranglerY_time_large_8/WranglerY_time_large_16
wy_speed_3_large = WranglerY_time_large_8/WranglerY_time_large_32

# %%
##Stampede and Wrangler Small
print sv_speed_1_small
print sv_speed_2_small
print sv_speed_3_small

print sy_speed_1_small
print sy_speed_2_small
print sy_speed_3_small

print wv_speed_1_small
print wv_speed_2_small
print wv_speed_3_small

print wy_speed_1_small
print wy_speed_2_small
print wy_speed_3_small
print ''
##Stampede and Wrangler Medium
print sv_speed_1_medium
print sv_speed_2_medium
print sv_speed_3_medium

print sy_speed_1_medium
print sy_speed_2_medium
print sy_speed_3_medium

print wv_speed_1_medium
print wv_speed_2_medium
print wv_speed_3_medium

print wy_speed_1_medium
print wy_speed_2_medium
print wy_speed_3_medium
print ''
##Stampede and Wrangler Large
print sv_speed_1_large
print sv_speed_2_large
print sv_speed_3_large

print sy_speed_1_large
print sy_speed_2_large
print sy_speed_3_large

print wv_speed_1_large
print wv_speed_2_large
print wv_speed_3_large

print wy_speed_1_large
print wy_speed_2_large
print wy_speed_3_large
# Out:
# 1.0
# 1.79628364553
# 2.43399490574
# 1.0
# 1.71445729189
# 2.87803125277
# 1.0
# 1.57923236041
# 2.24800909255
# 1.0
# 1.78833204821
# 2.96445485947
#
# 1.0
# 1.83281321947
# 2.49582697919
# 1.0
# 1.72988786672
# 2.79319167326
# 1.0
# 1.54341694821
# 2.25162201814
# 1.0
# 1.79553915355
# 3.00247641777
#
# 1.0
# 1.85266240667
# 2.33674388371
# 1.0
# 1.65859311374
# 2.4208965554
# 1.0
# 1.62011469714
# 2.36267284509
# 1.0
# 2.01150411435
# 3.21861011574

# %%
a=plt.figure()
plt.suptitle('K-Means TTC Speedup',y=1.0,fontsize=14)
plt.subplot(1,3,1)
plt.semilogx([8,16,32],[sv_speed_1_small,sv_speed_2_small,sv_speed_3_small],'-^g',[8,16,32],[sy_speed_1_small,sy_speed_2_small,sy_speed_3_small],'-^b',[8,16,32],[wv_speed_1_small,wv_speed_2_small,wv_speed_3_small],'-^y',[8,16,32],[wy_speed_1_small,wy_speed_2_small,wy_speed_3_small],'-^r',basex=2)
plt.ylim(ymin=0,ymax=4)
plt.xticks([4,8,16,32,64])
plt.subplot(1,3,2)
plt.semilogx([8,16,32],[sv_speed_1_medium,sv_speed_2_medium,sv_speed_3_medium],'-^g',[8,16,32],[sy_speed_1_medium,sy_speed_2_medium,sy_speed_3_medium],'-^b',[8,16,32],[wv_speed_1_medium,wv_speed_2_medium,wv_speed_3_medium],'-^y',[8,16,32],[wy_speed_1_medium,wy_speed_2_medium,wy_speed_3_medium],'-^r',basex=2)
plt.ylim(ymin=0,ymax=4)
plt.xticks([4,8,16,32,64])
plt.subplot(1,3,3)
plt.semilogx([8,16,32],[sv_speed_1_large,sv_speed_2_large,sv_speed_3_large],'-^g',[8,16,32],[sy_speed_1_large,sy_speed_2_large,sy_speed_3_large],'-^b',[8,16,32],[wv_speed_1_large,wv_speed_2_large,wv_speed_3_large],'-^y',[8,16,32],[wy_speed_1_large,wy_speed_2_large,wy_speed_3_large],'-^r',basex=2)
plt.ylim(ymin=0,ymax=4)
plt.xticks([4,8,16,32,64])
lgd = plt.figlegend((b1,b2,b3,b4),('RP on Stampede','RP-YARN on Stampede','RP on Wrangler','RP-YARN on Wrangler'),
              loc='lower center',mode="expand",ncol=3,fontsize=10,borderaxespad=0.11)
a.text(0.45,0.16,'Number of Tasks',ha='center',fontsize=14)
a.subplots_adjust(bottom=0.25)
a.savefig('kmeans-ttc-speedup.pdf',dpi=800,bbox_extra_artists=(lgd,))

# %%
pilot_file1=open('Stampede/vanilla_json/rp.session.RadicalExp.iparask.016822.0041.json')
pilot_file2=open('Stampede/vanilla_json/rp.session.RadicalExp.iparask.016822.0042.json')
pilot_file3=open('Stampede/vanilla_json/rp.session.RadicalExp.iparask.016822.0043.json')
pilot1=json.load(pilot_file1)
pilot2=json.load(pilot_file2)
pilot3=json.load(pilot_file3)
pilot_file1.close()
pilot_file2.close()
pilot_file3.close()
units_startup=list()
i=0
for elements in pilot1['unit']:
    for state in elements['statehistory']:
        if state['state']=='ExecutingPending':
            temp1=state['timestamp']
        elif state['state']=='Executing':
            temp2=state['timestamp']
    units_startup.append(temp2-temp1)

for elements in pilot2['unit']:
    for state in elements['statehistory']:
        if state['state']=='ExecutingPending':
            temp1=state['timestamp']
        elif state['state']=='Executing':
            temp2=state['timestamp']
    units_startup.append(temp2-temp1)

for elements in pilot3['unit']:
    for state in elements['statehistory']:
        if state['state']=='ExecutingPending':
            temp1=state['timestamp']
        elif state['state']=='Executing':
            temp2=state['timestamp']
    units_startup.append(temp2-temp1)
print units_startup.__len__()
mean_units_startup=np.mean(units_startup)
std_units_startup=np.std(units_startup)
# Out:
# 198

# %%
pilot_file1=open('Stampede/yarn_json/rp.session.RadicalExp.iparask.016823.0010.json')
pilot_file2=open('Stampede/yarn_json/rp.session.RadicalExp.iparask.016823.0011.json')
pilot_file3=open('Stampede/yarn_json/rp.session.RadicalExp.iparask.016823.0012.json')
pilot1=json.load(pilot_file1)
pilot2=json.load(pilot_file2)
pilot3=json.load(pilot_file3)
pilot_file1.close()
pilot_file2.close()
pilot_file3.close()
units_startup_yarn=list()
for elements in pilot1['unit']:
    for state in elements['statehistory']:
        if state['state']=='ExecutingPending':
            temp1=state['timestamp']
        elif state['state']=='Executing':
            temp2=state['timestamp']
    units_startup_yarn.append(temp2-temp1)

for elements in pilot2['unit']:
    for state in elements['statehistory']:
        if state['state']=='ExecutingPending':
            temp1=state['timestamp']
        elif state['state']=='Executing':
            temp2=state['timestamp']
    units_startup_yarn.append(temp2-temp1)

for elements in pilot3['unit']:
    for state in elements['statehistory']:
        if state['state']=='ExecutingPending':
            temp1=state['timestamp']
        elif state['state']=='Executing':
            temp2=state['timestamp']
    units_startup_yarn.append(temp2-temp1)
print units_startup_yarn.__len__()
mean_units_startup_yarn=np.mean(units_startup_yarn)
std_units_startup_yarn=np.std(units_startup_yarn)
# Out:
# 198

# %%
b=plt.figure()
n_groups=1
index=np.arange(n_groups)
bar_width=0.30
opacity=1.0
plt.bar(index+0.25*bar_width,[mean_units_startup],bar_width,yerr=[std_units_startup],alpha=opacity,color='darkgreen')
plt.bar(index+1.25*bar_width,[mean_units_startup_yarn],bar_width,yerr=[std_units_startup_yarn],alpha=opacity,color='blue')
plt.xticks(index+0.75*bar_width,('Vanilla','YAR'))
plt.ylim(ymax=30.0)
plt.xlabel('Selected Distributed Computation Resource')
plt.ylabel('Startup time (secs)')
plt.title('RADICAL-Pilot and RADICAL-Pilot-YARN Startup time Time Comparison')
plt.legend(('RP','RP-YARN'),fancybox=True,framealpha=0.5,prop={'size':9})
b.savefig('unit-startup-time.png',dpi=800)

# %%
stampede_vanilla = os.listdir('Stampede/Vanilla/')
stampede_yarn = os.listdir('Stampede/YARN/')
stampede_spark = os.listdir('Stampede/Spark/')
wrangler_vanilla = os.listdir('Wrangler/Vanilla/')
wrangler_yarn = os.listdir('Wrangler/YARN/')

# %%
def kmeans_exp_reader(filename):
    import csv
    exp_name = filename.split('.')[0]
    
    with open(filename,'rb') as open_file:
        data = csv.reader(open_file,delimiter=',')
    
        exp_data=dict()
        for row in data:
            exp_data[row[1]] = row[2:]
        
    mapper_iter1 = list()
    mapper_iter2 = list()
    reducer_iter1 = list()
    reducer_iter2 = list()
    
    detailed_data = {'FirstMapperStarted1': float(exp_data['Mapper-0-1'][3]),
                     'LastMapperEnded1'   : float(exp_data['Mapper-0-1'][5]),
                     'ReducerStarted1'    : float(exp_data['Reducer-0'][3]),
                     'ReducerEnded1'      : float(exp_data['Reducer-0'][5]),
                     'FirstMapperStarted2': float(exp_data['Mapper-1-1'][3]),
                     'LastMapperEnded2'   : float(exp_data['Mapper-1-1'][5]),
                     'ReducerStarted2'    : float(exp_data['Reducer-1'][3]),
                     'ReducerEnded2'      : float(exp_data['Reducer-1'][5]),
                     'AverMapRead'        : float(exp_data['Mapper-0-1'][6]),
                     'AverMapExec'        : float(exp_data['Mapper-0-1'][7]),
                     'AverMapWrite'       : float(exp_data['Mapper-0-1'][8]),
                     'AverRedRead'        : float(exp_data['Reducer-0'][6]),
                     'AverRedExec'        : float(exp_data['Reducer-0'][7]),
                     'AverRedWrite'       : float(exp_data['Reducer-0'][8]),
                    }
    mapread=list()
    mapexec=list()
    mapwrit=list()
    redread=list()
    redexec=list()
    redwrit=list()
    for key,value in exp_data.iteritems():
        if key.startswith('Mapper-0'):
            try:
                mapread.append(float(exp_data[key][6]))
                mapexec.append(float(exp_data[key][7]))
                mapwrit.append(float(exp_data[key][8]))
            except:
                print key,value
            mapper_iter1.append(float(value[4]) - float(value[3]))
            
            if value[3] < detailed_data['FirstMapperStarted1']:
                detailed_data['FirstMapperStarted1'] = float(value[3])
            
            if value[5] < detailed_data['LastMapperEnded1']:
                detailed_data['LastMapperEnded1'] = float(value[5])
        elif key.startswith('Mapper-1'):
            mapread.append(float(exp_data[key][6]))
            mapexec.append(float(exp_data[key][7]))
            mapwrit.append(float(exp_data[key][8]))
            mapper_iter2.append(float(value[4]) - float(value[3]))
            
            
            if value[3] < detailed_data['FirstMapperStarted2']:
                detailed_data['FirstMapperStarted2'] = float(value[3])
            
            if value[5] < detailed_data['LastMapperEnded2']:
                detailed_data['LastMapperEnded2'] = float(value[5])
                
        elif key.startswith('Reducer-0'):
            redread.append(float(exp_data[key][6]))
            redexec.append(float(exp_data[key][7]))
            redwrit.append(float(exp_data[key][8]))
            reducer_iter1.append(float(value[4]) - float(value[3]))
        elif key.startswith('Reducer-1'):
            redread.append(float(exp_data[key][6]))
            redexec.append(float(exp_data[key][7]))
            redwrit.append(float(exp_data[key][8]))
            reducer_iter2.append(float(value[4]) - float(value[3]))
                           
    detailed_data['AverMapRead']=np.mean(mapread)
    detailed_data['AverMapExec']=np.mean(mapexec)+detailed_data['AverMapRead']
    detailed_data['AverMapWrite']=np.mean(mapwrit)+detailed_data['AverMapExec']
    detailed_data['AverRedRead']=np.mean(redread)
    detailed_data['AverRedExec']=np.mean(redexec) + detailed_data['AverRedRead']
    detailed_data['AverRedWrite']=np.mean(redwrit) + detailed_data['AverRedExec']
            
    return exp_name,detailed_data,mapper_iter1,reducer_iter1,mapper_iter2,reducer_iter2

# %%
# Stampede Vanilla
sv10018,sv10018det,sv10018map1,sv10018red1,sv10018map2,sv10018red2 = kmeans_exp_reader('Stampede/Vanilla/k-means100K5H3d-run1-8.csv')
sv10028,sv10028det,sv10028map1,sv10028red1,sv10028map2,sv10028red2 = kmeans_exp_reader('Stampede/Vanilla/k-means100K5H3d-run2-8.csv')
sv10038,sv10038det,sv10038map1,sv10038red1,sv10038map2,sv10038red2 = kmeans_exp_reader('Stampede/Vanilla/k-means100K5H3d-run3-8.csv')

sv100116,sv100116det,sv100116map1,sv100116red1,sv100116map2,sv100116red2 = kmeans_exp_reader('Stampede/Vanilla/k-means100K5H3d-run1-16.csv')
sv100216,sv100216det,sv100216map1,sv100216red1,sv100216map2,sv100216red2 = kmeans_exp_reader('Stampede/Vanilla/k-means100K5H3d-run2-16.csv')
sv100316,sv100316det,sv100316map1,sv100316red1,sv100316map2,sv100316red2 = kmeans_exp_reader('Stampede/Vanilla/k-means100K5H3d-run3-16.csv')

sv100132,sv100132det,sv100132map1,sv100132red1,sv100132map2,sv100132red2 = kmeans_exp_reader('Stampede/Vanilla/k-means100K5H3d-run1-32.csv')
sv100232,sv100232det,sv100232map1,sv100232red1,sv100232map2,sv100232red2 = kmeans_exp_reader('Stampede/Vanilla/k-means100K5H3d-run2-32.csv')
sv100332,sv100332det,sv100332map1,sv100332red1,sv100332map2,sv100332red2 = kmeans_exp_reader('Stampede/Vanilla/k-means100K5H3d-run3-32.csv')

sv1018,sv1018det,sv1018map1,sv1018red1,sv1018map2,sv1018red2 = kmeans_exp_reader('Stampede/Vanilla/k-means10K5K3d-run1-8.csv')
sv1028,sv1028det,sv1028map1,sv1028red1,sv1028map2,sv1028red2 = kmeans_exp_reader('Stampede/Vanilla/k-means10K5K3d-run2-8.csv')
sv1038,sv1038det,sv1038map1,sv1038red1,sv1038map2,sv1038red2 = kmeans_exp_reader('Stampede/Vanilla/k-means10K5K3d-run3-8.csv')

sv10116,sv10116det,sv10116map1,sv10116red1,sv10116map2,sv10116red2 = kmeans_exp_reader('Stampede/Vanilla/k-means10K5K3d-run1-16.csv')
sv10216,sv10216det,sv10216map1,sv10216red1,sv10216map2,sv10216red2 = kmeans_exp_reader('Stampede/Vanilla/k-means10K5K3d-run2-16.csv')
sv10316,sv10316det,sv10316map1,sv10316red1,sv10316map2,sv10316red2 = kmeans_exp_reader('Stampede/Vanilla/k-means10K5K3d-run3-16.csv')

sv10132,sv10132det,sv10132map1,sv10132red1,sv10132map2,sv10132red2 = kmeans_exp_reader('Stampede/Vanilla/k-means10K5K3d-run1-32.csv')
sv10232,sv10232det,sv10232map1,sv10232red1,sv10232map2,sv10232red2 = kmeans_exp_reader('Stampede/Vanilla/k-means10K5K3d-run2-32.csv')
sv10332,sv10332det,sv10332map1,sv10332red1,sv10332map2,sv10332red2 = kmeans_exp_reader('Stampede/Vanilla/k-means10K5K3d-run3-32.csv')

sv118,sv118det,sv118map1,sv118red1,sv118map2,sv118red2 = kmeans_exp_reader('Stampede/Vanilla/k-means1M5D3d-run1-8.csv')
sv128,sv128det,sv128map1,sv128red1,sv128map2,sv128red2 = kmeans_exp_reader('Stampede/Vanilla/k-means1M5D3d-run2-8.csv')
sv138,sv138det,sv138map1,sv138red1,sv138map2,sv138red2 = kmeans_exp_reader('Stampede/Vanilla/k-means1M5D3d-run3-8.csv')

sv1116,sv1116det,sv1116map1,sv1116red1,sv1116map2,sv1116red2 = kmeans_exp_reader('Stampede/Vanilla/k-means1M5D3d-run1-16.csv')
sv1216,sv1216det,sv1216map1,sv1216red1,sv1216map2,sv1216red2 = kmeans_exp_reader('Stampede/Vanilla/k-means1M5D3d-run2-16.csv')
sv1316,sv1316det,sv1316map1,sv1316red1,sv1316map2,sv1316red2 = kmeans_exp_reader('Stampede/Vanilla/k-means1M5D3d-run3-16.csv')

sv1132,sv1132det,sv1132map1,sv1132red1,sv1132map2,sv1132red2 = kmeans_exp_reader('Stampede/Vanilla/k-means1M5D3d-run1-32.csv')
sv1232,sv1232det,sv1232map1,sv1232red1,sv1232map2,sv1232red2 = kmeans_exp_reader('Stampede/Vanilla/k-means1M5D3d-run2-32.csv')
sv1332,sv1332det,sv1332map1,sv1332red1,sv1332map2,sv1332red2 = kmeans_exp_reader('Stampede/Vanilla/k-means1M5D3d-run3-32.csv')

# %%
# Stampede YARN
sy10018,sy10018det,sy10018map1,sy10018red1,sy10018map2,sy10018red2 = kmeans_exp_reader('Stampede/YARN/k-means100K5H3d-run1-8.csv')
sy10028,sy10028det,sy10028map1,sy10028red1,sy10028map2,sy10028red2 = kmeans_exp_reader('Stampede/YARN/k-means100K5H3d-run2-8.csv')
sy10038,sy10038det,sy10038map1,sy10038red1,sy10038map2,sy10038red2 = kmeans_exp_reader('Stampede/YARN/k-means100K5H3d-run3-8.csv')

sy100116,sy100116det,sy100116map1,sy100116red1,sy100116map2,sy100116red2 = kmeans_exp_reader('Stampede/YARN/k-means100K5H3d-run1-16.csv')
sy100216,sy100216det,sy100216map1,sy100216red1,sy100216map2,sy100216red2 = kmeans_exp_reader('Stampede/YARN/k-means100K5H3d-run2-16.csv')
sy100316,sy100316det,sy100316map1,sy100316red1,sy100316map2,sy100316red2 = kmeans_exp_reader('Stampede/YARN/k-means100K5H3d-run3-16.csv')

sy100132,sy100132det,sy100132map1,sy100132red1,sy100132map2,sy100132red2 = kmeans_exp_reader('Stampede/YARN/k-means100K5H3d-run1-32.csv')
sy100232,sy100232det,sy100232map1,sy100232red1,sy100232map2,sy100232red2 = kmeans_exp_reader('Stampede/YARN/k-means100K5H3d-run2-32.csv')
sy100332,sy100332det,sy100332map1,sy100332red1,sy100332map2,sy100332red2 = kmeans_exp_reader('Stampede/YARN/k-means100K5H3d-run3-32.csv')

sy1018,sy1018det,sy1018map1,sy1018red1,sy1018map2,sy1018red2 = kmeans_exp_reader('Stampede/YARN/k-means10K5K3d-run1-8.csv')
sy1028,sy1028det,sy1028map1,sy1028red1,sy1028map2,sy1028red2 = kmeans_exp_reader('Stampede/YARN/k-means10K5K3d-run2-8.csv')
sy1038,sy1038det,sy1038map1,sy1038red1,sy1038map2,sy1038red2 = kmeans_exp_reader('Stampede/YARN/k-means10K5K3d-run3-8.csv')

sy10116,sy10116det,sy10116map1,sy10116red1,sy10116map2,sy10116red2 = kmeans_exp_reader('Stampede/YARN/k-means10K5K3d-run1-16.csv')
sy10216,sy10216det,sy10216map1,sy10216red1,sy10216map2,sy10216red2 = kmeans_exp_reader('Stampede/YARN/k-means10K5K3d-run2-16.csv')
sy10316,sy10316det,sy10316map1,sy10316red1,sy10316map2,sy10316red2 = kmeans_exp_reader('Stampede/YARN/k-means10K5K3d-run3-16.csv')

sy10132,sy10132det,sy10132map1,sy10132red1,sy10132map2,sy10132red2 = kmeans_exp_reader('Stampede/YARN/k-means10K5K3d-run1-32.csv')
sy10232,sy10232det,sy10232map1,sy10232red1,sy10232map2,sy10232red2 = kmeans_exp_reader('Stampede/YARN/k-means10K5K3d-run2-32.csv')
sy10332,sy10332det,sy10332map1,sy10332red1,sy10332map2,sy10332red2 = kmeans_exp_reader('Stampede/YARN/k-means10K5K3d-run3-32.csv')

sy118,sy118det,sy118map1,sy118red1,sy118map2,sy118red2 = kmeans_exp_reader('Stampede/YARN/k-means1M5D3d-run1-8.csv')
sy128,sy128det,sy128map1,sy128red1,sy128map2,sy128red2 = kmeans_exp_reader('Stampede/YARN/k-means1M5D3d-run2-8.csv')
sy138,sy138det,sy138map1,sy138red1,sy138map2,sy138red2 = kmeans_exp_reader('Stampede/YARN/k-means1M5D3d-run3-8.csv')

sy1116,sy1116det,sy1116map1,sy1116red1,sy1116map2,sy1116red2 = kmeans_exp_reader('Stampede/YARN/k-means1M5D3d-run1-16.csv')
sy1216,sy1216det,sy1216map1,sy1216red1,sy1216map2,sy1216red2 = kmeans_exp_reader('Stampede/YARN/k-means1M5D3d-run2-16.csv')
sy1316,sy1316det,sy1316map1,sy1316red1,sy1316map2,sy1316red2 = kmeans_exp_reader('Stampede/YARN/k-means1M5D3d-run3-16.csv')

sy1132,sy1132det,sy1132map1,sy1132red1,sy1132map2,sy1132red2 = kmeans_exp_reader('Stampede/YARN/k-means1M5D3d-run1-32.csv')
sy1232,sy1232det,sy1232map1,sy1232red1,sy1232map2,sy1232red2 = kmeans_exp_reader('Stampede/YARN/k-means1M5D3d-run2-32.csv')
sy1332,sy1332det,sy1332map1,sy1332red1,sy1332map2,sy1332red2 = kmeans_exp_reader('Stampede/YARN/k-means1M5D3d-run3-32.csv')

# %%
# Wrangler Vanilla
wv10018,wv10018det,wv10018map1,wv10018red1,wv10018map2,wv10018red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means100K5H3d-run1-8.csv')
wv10028,wv10028det,wv10028map1,wv10028red1,wv10028map2,wv10028red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means100K5H3d-run2-8.csv')
wv10038,wv10038det,wv10038map1,wv10038red1,wv10038map2,wv10038red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means100K5H3d-run3-8.csv')

wv100116,wv100116det,wv100116map1,wv100116red1,wv100116map2,wv100116red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means100K5H3d-run1-16.csv')
wv100216,wv100216det,wv100216map1,wv100216red1,wv100216map2,wv100216red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means100K5H3d-run2-16.csv')
wv100316,wv100316det,wv100316map1,wv100316red1,wv100316map2,wv100316red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means100K5H3d-run3-16.csv')

wv100132,wv100132det,wv100132map1,wv100132red1,wv100132map2,wv100132red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means100K5H3d-run1-32.csv')
wv100232,wv100232det,wv100232map1,wv100232red1,wv100232map2,wv100232red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means100K5H3d-run2-32.csv')
wv100332,wv100332det,wv100332map1,wv100332red1,wv100332map2,wv100332red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means100K5H3d-run3-32.csv')

wv1018,wv1018det,wv1018map1,wv1018red1,wv1018map2,wv1018red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means10K5K3d-run1-8.csv')
wv1028,wv1028det,wv1028map1,wv1028red1,wv1028map2,wv1028red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means10K5K3d-run2-8.csv')
wv1038,wv1038det,wv1038map1,wv1038red1,wv1038map2,wv1038red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means10K5K3d-run3-8.csv')

wv10116,wv10116det,wv10116map1,wv10116red1,wv10116map2,wv10116red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means10K5K3d-run1-16.csv')
wv10216,wv10216det,wv10216map1,wv10216red1,wv10216map2,wv10216red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means10K5K3d-run2-16.csv')
wv10316,wv10316det,wv10316map1,wv10316red1,wv10316map2,wv10316red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means10K5K3d-run3-16.csv')

wv10132,wv10132det,wv10132map1,wv10132red1,wv10132map2,wv10132red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means10K5K3d-run1-32.csv')
wv10232,wv10232det,wv10232map1,wv10232red1,wv10232map2,wv10232red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means10K5K3d-run2-32.csv')
wv10332,wv10332det,wv10332map1,wv10332red1,wv10332map2,wv10332red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means10K5K3d-run3-32.csv')

wv118,wv118det,wv118map1,wv118red1,wv118map2,wv118red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means1M5D3d-run1-8.csv')
wv128,wv128det,wv128map1,wv128red1,wv128map2,wv128red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means1M5D3d-run2-8.csv')
wv138,wv138det,wv138map1,wv138red1,wv138map2,wv138red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means1M5D3d-run3-8.csv')

wv1116,wv1116det,wv1116map1,wv1116red1,wv1116map2,wv1116red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means1M5D3d-run1-16.csv')
wv1216,wv1216det,wv1216map1,wv1216red1,wv1216map2,wv1216red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means1M5D3d-run2-16.csv')
wv1316,wv1316det,wv1316map1,wv1316red1,wv1316map2,wv1316red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means1M5D3d-run3-16.csv')

wv1132,wv1132det,wv1132map1,wv1132red1,wv1132map2,wv1132red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means1M5D3d-run1-32.csv')
wv1232,wv1232det,wv1232map1,wv1232red1,wv1232map2,wv1232red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means1M5D3d-run2-32.csv')
wv1332,wv1332det,wv1332map1,wv1332red1,wv1332map2,wv1332red2 = kmeans_exp_reader('Wrangler/Vanilla/k-means1M5D3d-run3-32.csv')

# %%
# Wrangler YARN
wy10018,wy10018det,wy10018map1,wy10018red1,wy10018map2,wy10018red2 = kmeans_exp_reader('Wrangler/YARN/k-means100K5H3d-run1-8.csv')
wy10028,wy10028det,wy10028map1,wy10028red1,wy10028map2,wy10028red2 = kmeans_exp_reader('Wrangler/YARN/k-means100K5H3d-run2-8.csv')
wy10038,wy10038det,wy10038map1,wy10038red1,wy10038map2,wy10038red2 = kmeans_exp_reader('Wrangler/YARN/k-means100K5H3d-run3-8.csv')

wy100116,wy100116det,wy100116map1,wy100116red1,wy100116map2,wy100116red2 = kmeans_exp_reader('Wrangler/YARN/k-means100K5H3d-run1-16.csv')
wy100216,wy100216det,wy100216map1,wy100216red1,wy100216map2,wy100216red2 = kmeans_exp_reader('Wrangler/YARN/k-means100K5H3d-run2-16.csv')
wy100316,wy100316det,wy100316map1,wy100316red1,wy100316map2,wy100316red2 = kmeans_exp_reader('Wrangler/YARN/k-means100K5H3d-run3-16.csv')

wy100132,wy100132det,wy100132map1,wy100132red1,wy100132map2,wy100132red2 = kmeans_exp_reader('Wrangler/YARN/k-means100K5H3d-run1-32.csv')
wy100232,wy100232det,wy100232map1,wy100232red1,wy100232map2,wy100232red2 = kmeans_exp_reader('Wrangler/YARN/k-means100K5H3d-run2-32.csv')
wy100332,wy100332det,wy100332map1,wy100332red1,wy100332map2,wy100332red2 = kmeans_exp_reader('Wrangler/YARN/k-means100K5H3d-run3-32.csv')

wy1018,wy1018det,wy1018map1,wy1018red1,wy1018map2,wy1018red2 = kmeans_exp_reader('Wrangler/YARN/k-means10K5K3d-run1-8.csv')
wy1028,wy1028det,wy1028map1,wy1028red1,wy1028map2,wy1028red2 = kmeans_exp_reader('Wrangler/YARN/k-means10K5K3d-run2-8.csv')
wy1038,wy1038det,wy1038map1,wy1038red1,wy1038map2,wy1038red2 = kmeans_exp_reader('Wrangler/YARN/k-means10K5K3d-run3-8.csv')

wy10116,wy10116det,wy10116map1,wy10116red1,wy10116map2,wy10116red2 = kmeans_exp_reader('Wrangler/YARN/k-means10K5K3d-run1-16.csv')
wy10216,wy10216det,wy10216map1,wy10216red1,wy10216map2,wy10216red2 = kmeans_exp_reader('Wrangler/YARN/k-means10K5K3d-run2-16.csv')
wy10316,wy10316det,wy10316map1,wy10316red1,wy10316map2,wy10316red2 = kmeans_exp_reader('Wrangler/YARN/k-means10K5K3d-run3-16.csv')

wy10132,wy10132det,wy10132map1,wy10132red1,wy10132map2,wy10132red2 = kmeans_exp_reader('Wrangler/YARN/k-means10K5K3d-run1-32.csv')
wy10232,wy10232det,wy10232map1,wy10232red1,wy10232map2,wy10232red2 = kmeans_exp_reader('Wrangler/YARN/k-means10K5K3d-run2-32.csv')
wy10332,wy10332det,wy10332map1,wy10332red1,wy10332map2,wy10332red2 = kmeans_exp_reader('Wrangler/YARN/k-means10K5K3d-run3-32.csv')

wy118,wy118det,wy118map1,wy118red1,wy118map2,wy118red2 = kmeans_exp_reader('Wrangler/YARN/k-means1M5D3d-run1-8.csv')
wy128,wy128det,wy128map1,wy128red1,wy128map2,wy128red2 = kmeans_exp_reader('Wrangler/YARN/k-means1M5D3d-run2-8.csv')
wy138,wy138det,wy138map1,wy138red1,wy138map2,wy138red2 = kmeans_exp_reader('Wrangler/YARN/k-means1M5D3d-run3-8.csv')

wy1116,wy1116det,wy1116map1,wy1116red1,wy1116map2,wy1116red2 = kmeans_exp_reader('Wrangler/YARN/k-means1M5D3d-run1-16.csv')
wy1216,wy1216det,wy1216map1,wy1216red1,wy1216map2,wy1216red2 = kmeans_exp_reader('Wrangler/YARN/k-means1M5D3d-run2-16.csv')
wy1316,wy1316det,wy1316map1,wy1316red1,wy1316map2,wy1316red2 = kmeans_exp_reader('Wrangler/YARN/k-means1M5D3d-run3-16.csv')

wy1132,wy1132det,wy1132map1,wy1132red1,wy1132map2,wy1132red2 = kmeans_exp_reader('Wrangler/YARN/k-means1M5D3d-run1-32.csv')
wy1332,wy1332det,wy1332map1,wy1332red1,wy1332map2,wy1332red2 = kmeans_exp_reader('Wrangler/YARN/k-means1M5D3d-run3-32.csv')
wy1232,wy1232det,wy1232map1,wy1232red1,wy1232map2,wy1232red2 = kmeans_exp_reader('Wrangler/YARN/k-means1M5D3d-run2-32.csv')

# %%
import pprint
print pprint.pprint(sv1018det)
print pprint.pprint(sv10116det)
print pprint.pprint(sv10132det)
# Out:
# {'AverMapExec': 1017.8241854375,
#  'AverMapRead': 0.011530624999999999,
#  'AverMapWrite': 1017.8406439375,
#  'AverRedExec': 2.5913280000000003,
#  'AverRedRead': 0.52868700000000002,
#  'AverRedWrite': 2.6023250000000004,
#  'FirstMapperStarted1': 11.8007090092,
#  'FirstMapperStarted2': 1169.655653,
#  'LastMapperEnded1': 961.283061028,
#  'LastMapperEnded2': 2205.65739107,
#  'ReducerEnded1': 1161.64449406,
#  'ReducerEnded2': 2229.51565909,
#  'ReducerStarted1': 1154.48870611,
#  'ReducerStarted2': 2221.14494205}
# None
# {'AverMapExec': 500.49730665625003,
#  'AverMapRead': 0.022793437499999999,
#  'AverMapWrite': 500.51159859375002,
#  'AverRedExec': 3.1117325000000005,
#  'AverRedRead': 1.0363125000000002,
#  'AverRedWrite': 3.1226040000000004,
#  'FirstMapperStarted1': 14.2771260738,
#  'FirstMapperStarted2': 629.050381184,
#  'LastMapperEnded1': 510.785340071,
#  'LastMapperEnded2': 1084.59820318,
#  'ReducerEnded1': 613.824799061,
#  'ReducerEnded2': 1220.72959614,
# ...

# %%
#Stamprede Vanilla 10K 5K detailed timing
sv_map1_10_8 = np.mean([sv1018det['LastMapperEnded1'],sv1028det['LastMapperEnded1'],sv1038det['LastMapperEnded1']])
sv_map1_10_8_std = np.std([sv1018det['LastMapperEnded1'],sv1028det['LastMapperEnded1'],sv1038det['LastMapperEnded1']])

sv_map1_10_16 = np.mean([sv10116det['LastMapperEnded1'],sv10216det['LastMapperEnded1'],sv10316det['LastMapperEnded1']])
sv_map1_10_16_std = np.std([sv10116det['LastMapperEnded1'],sv10216det['LastMapperEnded1'],sv10316det['LastMapperEnded1']])

sv_map1_10_32 = np.mean([sv10132det['LastMapperEnded1'],sv10232det['LastMapperEnded1'],sv10332det['LastMapperEnded1']])
sv_map1_10_32_std = np.std([sv10132det['LastMapperEnded1'],sv10232det['LastMapperEnded1'],sv10332det['LastMapperEnded1']])

sv_red1_10_8 = np.mean([sv1018det['ReducerEnded1'],sv1028det['ReducerEnded1'],sv1038det['ReducerEnded1']])
sv_red1_10_8_std = np.std([sv1018det['ReducerEnded1'],sv1028det['ReducerEnded1'],sv1038det['ReducerEnded1']])

sv_red1_10_16 = np.mean([sv10116det['ReducerEnded1'],sv10216det['ReducerEnded1'],sv10316det['ReducerEnded1']])
sv_red1_10_16_std = np.std([sv10116det['ReducerEnded1'],sv10216det['ReducerEnded1'],sv10316det['ReducerEnded1']])

sv_red1_10_32 = np.mean([sv10132det['ReducerEnded1'],sv10232det['ReducerEnded1'],sv10332det['ReducerEnded1']])
sv_red1_10_32_std = np.std([sv10132det['ReducerEnded1'],sv10232det['ReducerEnded1'],sv10332det['ReducerEnded1']])

sv_map2_10_8 = np.mean([sv1018det['LastMapperEnded2'],sv1028det['LastMapperEnded2'],sv1038det['LastMapperEnded2']])
sv_map2_10_8_std = np.std([sv1018det['LastMapperEnded2'],sv1028det['LastMapperEnded2'],sv1038det['LastMapperEnded2']])

sv_map2_10_16 = np.mean([sv10116det['LastMapperEnded2'],sv10216det['LastMapperEnded2'],sv10316det['LastMapperEnded2']])
sv_map2_10_16_std = np.std([sv10116det['LastMapperEnded2'],sv10216det['LastMapperEnded2'],sv10316det['LastMapperEnded2']])

sv_map2_10_32 = np.mean([sv10132det['LastMapperEnded2'],sv10232det['LastMapperEnded2'],sv10332det['LastMapperEnded2']])
sv_map2_10_32_std = np.std([sv10132det['LastMapperEnded2'],sv10232det['LastMapperEnded2'],sv10332det['LastMapperEnded2']])

sv_red2_10_8 = np.mean([sv1018det['ReducerEnded2'],sv1028det['ReducerEnded2'],sv1038det['ReducerEnded2']])
sv_red2_10_8_std = np.std([sv1018det['ReducerEnded2'],sv1028det['ReducerEnded2'],sv1038det['ReducerEnded2']])

sv_red2_10_16 = np.mean([sv10116det['ReducerEnded2'],sv10216det['ReducerEnded2'],sv10316det['ReducerEnded2']])
sv_red2_10_16_std = np.std([sv10116det['ReducerEnded2'],sv10216det['ReducerEnded2'],sv10316det['ReducerEnded2']])

sv_red2_10_32 = np.mean([sv10132det['ReducerEnded2'],sv10232det['ReducerEnded2'],sv10332det['ReducerEnded2']])
sv_red2_10_32_std = np.std([sv10132det['ReducerEnded2'],sv10232det['ReducerEnded2'],sv10332det['ReducerEnded2']])

# %%
#Stampede Vanilla 100K 500 detailed timing
sv_map1_100_8 = np.mean([sv10018det['LastMapperEnded1'],sv10028det['LastMapperEnded1'],sv10038det['LastMapperEnded1']])
sv_map1_100_8_std = np.std([sv10018det['LastMapperEnded1'],sv10028det['LastMapperEnded1'],sv10038det['LastMapperEnded1']])

sv_map1_100_16 = np.mean([sv100116det['LastMapperEnded1'],sv100216det['LastMapperEnded1'],sv100316det['LastMapperEnded1']])
sv_map1_100_16_std = np.std([sv100116det['LastMapperEnded1'],sv100216det['LastMapperEnded1'],sv100316det['LastMapperEnded1']])

sv_map1_100_32 = np.mean([sv100132det['LastMapperEnded1'],sv100232det['LastMapperEnded1'],sv100332det['LastMapperEnded1']])
sv_map1_100_32_std = np.std([sv100132det['LastMapperEnded1'],sv100232det['LastMapperEnded1'],sv100332det['LastMapperEnded1']])

sv_red1_100_8 = np.mean([sv10018det['ReducerEnded1'],sv10028det['ReducerEnded1'],sv10038det['ReducerEnded1']])
sv_red1_100_8_std = np.std([sv10018det['ReducerEnded1'],sv10028det['ReducerEnded1'],sv10038det['ReducerEnded1']])

sv_red1_100_16 = np.mean([sv100116det['ReducerEnded1'],sv100216det['ReducerEnded1'],sv100316det['ReducerEnded1']])
sv_red1_100_16_std = np.std([sv100116det['ReducerEnded1'],sv100216det['ReducerEnded1'],sv100316det['ReducerEnded1']])

sv_red1_100_32 = np.mean([sv100132det['ReducerEnded1'],sv100232det['ReducerEnded1'],sv100332det['ReducerEnded1']])
sv_red1_100_32_std = np.std([sv100132det['ReducerEnded1'],sv100232det['ReducerEnded1'],sv100332det['ReducerEnded1']])

sv_map2_100_8 = np.mean([sv10018det['LastMapperEnded2'],sv10028det['LastMapperEnded2'],sv10038det['LastMapperEnded2']])
sv_map2_100_8_std = np.std([sv10018det['LastMapperEnded2'],sv10028det['LastMapperEnded2'],sv10038det['LastMapperEnded2']])

sv_map2_100_16 = np.mean([sv100116det['LastMapperEnded2'],sv100216det['LastMapperEnded2'],sv100316det['LastMapperEnded2']])
sv_map2_100_16_std = np.std([sv100116det['LastMapperEnded2'],sv100216det['LastMapperEnded2'],sv100316det['LastMapperEnded2']])

sv_map2_100_32 = np.mean([sv100132det['LastMapperEnded2'],sv100232det['LastMapperEnded2'],sv100332det['LastMapperEnded2']])
sv_map2_100_32_std = np.std([sv100132det['LastMapperEnded2'],sv100232det['LastMapperEnded2'],sv100332det['LastMapperEnded2']])

sv_red2_100_8 = np.mean([sv10018det['ReducerEnded2'],sv10028det['ReducerEnded2'],sv10038det['ReducerEnded2']])
sv_red2_100_8_std = np.std([sv10018det['ReducerEnded2'],sv10028det['ReducerEnded2'],sv10038det['ReducerEnded2']])

sv_red2_100_16 = np.mean([sv100116det['ReducerEnded2'],sv100216det['ReducerEnded2'],sv100316det['ReducerEnded2']])
sv_red2_100_16_std = np.std([sv100116det['ReducerEnded2'],sv100216det['ReducerEnded2'],sv100316det['ReducerEnded2']])

sv_red2_100_32 = np.mean([sv100132det['ReducerEnded2'],sv100232det['ReducerEnded2'],sv100332det['ReducerEnded2']])
sv_red2_100_32_std = np.std([sv100132det['ReducerEnded2'],sv100232det['ReducerEnded2'],sv100332det['ReducerEnded2']])

# %%
#Stamprede Vanilla 1M 50K detailed timing
sv_map1_1_8 = np.mean([sv118det['LastMapperEnded1'],sv128det['LastMapperEnded1'],sv138det['LastMapperEnded1']])
sv_map1_1_8_std = np.std([sv118det['LastMapperEnded1'],sv128det['LastMapperEnded1'],sv138det['LastMapperEnded1']])

sv_map1_1_16 = np.mean([sv1116det['LastMapperEnded1'],sv1216det['LastMapperEnded1'],sv1316det['LastMapperEnded1']])
sv_map1_1_16_std = np.std([sv1116det['LastMapperEnded1'],sv1216det['LastMapperEnded1'],sv1316det['LastMapperEnded1']])

sv_map1_1_32 = np.mean([sv1132det['LastMapperEnded1'],sv1232det['LastMapperEnded1'],sv1332det['LastMapperEnded1']])
sv_map1_1_32_std = np.std([sv1132det['LastMapperEnded1'],sv1232det['LastMapperEnded1'],sv1332det['LastMapperEnded1']])

sv_red1_1_8 = np.mean([sv118det['ReducerEnded1'],sv128det['ReducerEnded1'],sv138det['ReducerEnded1']])
sv_red1_1_8_std = np.std([sv118det['ReducerEnded1'],sv128det['ReducerEnded1'],sv138det['ReducerEnded1']])

sv_red1_1_16 = np.mean([sv1116det['ReducerEnded1'],sv1216det['ReducerEnded1'],sv1316det['ReducerEnded1']])
sv_red1_1_16_std = np.std([sv1116det['ReducerEnded1'],sv1216det['ReducerEnded1'],sv1316det['ReducerEnded1']])

sv_red1_1_32 = np.mean([sv1132det['ReducerEnded1'],sv1232det['ReducerEnded1'],sv1332det['ReducerEnded1']])
sv_red1_1_32_std = np.std([sv1132det['ReducerEnded1'],sv1232det['ReducerEnded1'],sv1332det['ReducerEnded1']])

sv_map2_1_8 = np.mean([sv118det['LastMapperEnded2'],sv128det['LastMapperEnded2'],sv138det['LastMapperEnded2']])
sv_map2_1_8_std = np.std([sv118det['LastMapperEnded2'],sv128det['LastMapperEnded2'],sv138det['LastMapperEnded2']])

sv_map2_1_16 = np.mean([sv1116det['LastMapperEnded2'],sv1216det['LastMapperEnded2'],sv1316det['LastMapperEnded2']])
sv_map2_1_16_std = np.std([sv1116det['LastMapperEnded2'],sv1216det['LastMapperEnded2'],sv1316det['LastMapperEnded2']])

sv_map2_1_32 = np.mean([sv1132det['LastMapperEnded2'],sv1232det['LastMapperEnded2'],sv1332det['LastMapperEnded2']])
sv_map2_1_32_std = np.std([sv1132det['LastMapperEnded2'],sv1232det['LastMapperEnded2'],sv1332det['LastMapperEnded2']])

sv_red2_1_8 = np.mean([sv118det['ReducerEnded2'],sv128det['ReducerEnded2'],sv138det['ReducerEnded2']])
sv_red2_1_8_std = np.std([sv118det['ReducerEnded2'],sv128det['ReducerEnded2'],sv138det['ReducerEnded2']])

sv_red2_1_16 = np.mean([sv1116det['ReducerEnded2'],sv1216det['ReducerEnded2'],sv1316det['ReducerEnded2']])
sv_red2_1_16_std = np.std([sv1116det['ReducerEnded2'],sv1216det['ReducerEnded2'],sv1316det['ReducerEnded2']])

sv_red2_1_32 = np.mean([sv1132det['ReducerEnded2'],sv1232det['ReducerEnded2'],sv1332det['ReducerEnded2']])
sv_red2_1_32_std = np.std([sv1132det['ReducerEnded2'],sv1232det['ReducerEnded2'],sv1332det['ReducerEnded2']])

# %%
#Stampede YARN 10K 5K detailed timing
sy_map1_10_8 = np.mean([sy1018det['LastMapperEnded1'],sy1028det['LastMapperEnded1'],sy1038det['LastMapperEnded1']])
sy_map1_10_8_std = np.std([sy1018det['LastMapperEnded1'],sy1028det['LastMapperEnded1'],sy1038det['LastMapperEnded1']])

sy_map1_10_16 = np.mean([sy10116det['LastMapperEnded1'],sy10216det['LastMapperEnded1'],sy10316det['LastMapperEnded1']])
sy_map1_10_16_std = np.std([sy10116det['LastMapperEnded1'],sy10216det['LastMapperEnded1'],sy10316det['LastMapperEnded1']])

sy_map1_10_32 = np.mean([sy10132det['LastMapperEnded1'],sy10232det['LastMapperEnded1'],sy10332det['LastMapperEnded1']])
sy_map1_10_32_std = np.std([sy10132det['LastMapperEnded1'],sy10232det['LastMapperEnded1'],sy10332det['LastMapperEnded1']])

sy_red1_10_8 = np.mean([sy1018det['ReducerEnded1'],sy1028det['ReducerEnded1'],sy1038det['ReducerEnded1']])
sy_red1_10_8_std = np.std([sy1018det['ReducerEnded1'],sy1028det['ReducerEnded1'],sy1038det['ReducerEnded1']])

sy_red1_10_16 = np.mean([sy10116det['ReducerEnded1'],sy10216det['ReducerEnded1'],sy10316det['ReducerEnded1']])
sy_red1_10_16_std = np.std([sy10116det['ReducerEnded1'],sy10216det['ReducerEnded1'],sy10316det['ReducerEnded1']])

sy_red1_10_32 = np.mean([sy10132det['ReducerEnded1'],sy10232det['ReducerEnded1'],sy10332det['ReducerEnded1']])
sy_red1_10_32_std = np.std([sy10132det['ReducerEnded1'],sy10232det['ReducerEnded1'],sy10332det['ReducerEnded1']])

sy_map2_10_8 = np.mean([sy1018det['LastMapperEnded2'],sy1028det['LastMapperEnded2'],sy1038det['LastMapperEnded2']])
sy_map2_10_8_std = np.std([sy1018det['LastMapperEnded2'],sy1028det['LastMapperEnded2'],sy1038det['LastMapperEnded2']])

sy_map2_10_16 = np.mean([sy10116det['LastMapperEnded2'],sy10216det['LastMapperEnded2'],sy10316det['LastMapperEnded2']])
sy_map2_10_16_std = np.std([sy10116det['LastMapperEnded2'],sy10216det['LastMapperEnded2'],sy10316det['LastMapperEnded2']])

sy_map2_10_32 = np.mean([sy10132det['LastMapperEnded2'],sy10232det['LastMapperEnded2'],sy10332det['LastMapperEnded2']])
sy_map2_10_32_std = np.std([sy10132det['LastMapperEnded2'],sy10232det['LastMapperEnded2'],sy10332det['LastMapperEnded2']])

sy_red2_10_8 = np.mean([sy1018det['ReducerEnded2'],sy1028det['ReducerEnded2'],sy1038det['ReducerEnded2']])
sy_red2_10_8_std = np.std([sy1018det['ReducerEnded2'],sy1028det['ReducerEnded2'],sy1038det['ReducerEnded2']])

sy_red2_10_16 = np.mean([sy10116det['ReducerEnded2'],sy10216det['ReducerEnded2'],sy10316det['ReducerEnded2']])
sy_red2_10_16_std = np.std([sy10116det['ReducerEnded2'],sy10216det['ReducerEnded2'],sy10316det['ReducerEnded2']])

sy_red2_10_32 = np.mean([sy10132det['ReducerEnded2'],sy10232det['ReducerEnded2'],sy10332det['ReducerEnded2']])
sy_red2_10_32_std = np.std([sy10132det['ReducerEnded2'],sy10232det['ReducerEnded2'],sy10332det['ReducerEnded2']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-61884eff2481> in <module>()
#       1 #Stampede YARN 10K 5K detailed timing
# ----> 2 sy_map1_10_8 = np.mean([sy1018det['LastMapperEnded1'],sy1028det['LastMapperEnded1'],sy1038det['LastMapperEnded1']])
#       3 sy_map1_10_8_std = np.std([sy1018det['LastMapperEnded1'],sy1028det['LastMapperEnded1'],sy1038det['LastMapperEnded1']])
#       4
#       5 sy_map1_10_16 = np.mean([sy10116det['LastMapperEnded1'],sy10216det['LastMapperEnded1'],sy10316det['LastMapperEnded1']])
#
# NameError: name 'sy1018det' is not defined

# %%
#Stampede YARN 100K 500 detailed timing
sy_map1_100_8 = np.mean([sy10018det['LastMapperEnded1'],sy10028det['LastMapperEnded1'],sy10038det['LastMapperEnded1']])
sy_map1_100_8_std = np.std([sy10018det['LastMapperEnded1'],sy10028det['LastMapperEnded1'],sy10038det['LastMapperEnded1']])

sy_map1_100_16 = np.mean([sy100116det['LastMapperEnded1'],sy100216det['LastMapperEnded1'],sy100316det['LastMapperEnded1']])
sy_map1_100_16_std = np.std([sy100116det['LastMapperEnded1'],sy100216det['LastMapperEnded1'],sy100316det['LastMapperEnded1']])

sy_map1_100_32 = np.mean([sy100132det['LastMapperEnded1'],sy100232det['LastMapperEnded1'],sy100332det['LastMapperEnded1']])
sy_map1_100_32_std = np.std([sy100132det['LastMapperEnded1'],sy100232det['LastMapperEnded1'],sy100332det['LastMapperEnded1']])

sy_red1_100_8 = np.mean([sy10018det['ReducerEnded1'],sy10028det['ReducerEnded1'],sy10038det['ReducerEnded1']])
sy_red1_100_8_std = np.std([sy10018det['ReducerEnded1'],sy10028det['ReducerEnded1'],sy10038det['ReducerEnded1']])

sy_red1_100_16 = np.mean([sy100116det['ReducerEnded1'],sy100216det['ReducerEnded1'],sy100316det['ReducerEnded1']])
sy_red1_100_16_std = np.std([sy100116det['ReducerEnded1'],sy100216det['ReducerEnded1'],sy100316det['ReducerEnded1']])

sy_red1_100_32 = np.mean([sy100132det['ReducerEnded1'],sy100232det['ReducerEnded1'],sy100332det['ReducerEnded1']])
sy_red1_100_32_std = np.std([sy100132det['ReducerEnded1'],sy100232det['ReducerEnded1'],sy100332det['ReducerEnded1']])

sy_map2_100_8 = np.mean([sy10018det['LastMapperEnded2'],sy10028det['LastMapperEnded2'],sy10038det['LastMapperEnded2']])
sy_map2_100_8_std = np.std([sy10018det['LastMapperEnded2'],sy10028det['LastMapperEnded2'],sy10038det['LastMapperEnded2']])

sy_map2_100_16 = np.mean([sy100116det['LastMapperEnded2'],sy100216det['LastMapperEnded2'],sy100316det['LastMapperEnded2']])
sy_map2_100_16_std = np.std([sy100116det['LastMapperEnded2'],sy100216det['LastMapperEnded2'],sy100316det['LastMapperEnded2']])

sy_map2_100_32 = np.mean([sy100132det['LastMapperEnded2'],sy100232det['LastMapperEnded2'],sy100332det['LastMapperEnded2']])
sy_map2_100_32_std = np.std([sy100132det['LastMapperEnded2'],sy100232det['LastMapperEnded2'],sy100332det['LastMapperEnded2']])

sy_red2_100_8 = np.mean([sy10018det['ReducerEnded2'],sy10028det['ReducerEnded2'],sy10038det['ReducerEnded2']])
sy_red2_100_8_std = np.std([sy10018det['ReducerEnded2'],sy10028det['ReducerEnded2'],sy10038det['ReducerEnded2']])

sy_red2_100_16 = np.mean([sy100116det['ReducerEnded2'],sy100216det['ReducerEnded2'],sy100316det['ReducerEnded2']])
sy_red2_100_16_std = np.std([sy100116det['ReducerEnded2'],sy100216det['ReducerEnded2'],sy100316det['ReducerEnded2']])

sy_red2_100_32 = np.mean([sy100132det['ReducerEnded2'],sy100232det['ReducerEnded2'],sy100332det['ReducerEnded2']])
sy_red2_100_32_std = np.std([sy100132det['ReducerEnded2'],sy100232det['ReducerEnded2'],sy100332det['ReducerEnded2']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-6c351670b814> in <module>()
#       3 sy_map1_100_8_std = np.std([sy10018det['LastMapperEnded1'],sy10028det['LastMapperEnded1'],sy10038det['LastMapperEnded1']])
#       4
# ----> 5 sy_map1_100_16 = np.mean([sy100116det['LastMapperEnded1'],sy100216det['LastMapperEnded1'],sy100316det['LastMapperEnded1']])
#       6 sy_map1_100_16_std = np.std([sy100116det['LastMapperEnded1'],sy100216det['LastMapperEnded1'],sy100316det['LastMapperEnded1']])
#       7
#
# NameError: name 'sy100116det' is not defined

# %%
#Stamprede YARN 1M 50K detailed timing
sy_map1_1_8 = np.mean([sy118det['LastMapperEnded1'],sy128det['LastMapperEnded1'],sy138det['LastMapperEnded1']])
sy_map1_1_8_std = np.std([sy118det['LastMapperEnded1'],sy128det['LastMapperEnded1'],sy138det['LastMapperEnded1']])

sy_map1_1_16 = np.mean([sy1116det['LastMapperEnded1'],sy1216det['LastMapperEnded1'],sy1316det['LastMapperEnded1']])
sy_map1_1_16_std = np.std([sy1116det['LastMapperEnded1'],sy1216det['LastMapperEnded1'],sy1316det['LastMapperEnded1']])

sy_map1_1_32 = np.mean([sy1132det['LastMapperEnded1'],sy1232det['LastMapperEnded1'],sy1332det['LastMapperEnded1']])
sy_map1_1_32_std = np.std([sy1132det['LastMapperEnded1'],sy1232det['LastMapperEnded1'],sy1332det['LastMapperEnded1']])

sy_red1_1_8 = np.mean([sy118det['ReducerEnded1'],sy128det['ReducerEnded1'],sy138det['ReducerEnded1']])
sy_red1_1_8_std = np.std([sy118det['ReducerEnded1'],sy128det['ReducerEnded1'],sy138det['ReducerEnded1']])

sy_red1_1_16 = np.mean([sy1116det['ReducerEnded1'],sy1216det['ReducerEnded1'],sy1316det['ReducerEnded1']])
sy_red1_1_16_std = np.std([sy1116det['ReducerEnded1'],sy1216det['ReducerEnded1'],sy1316det['ReducerEnded1']])

sy_red1_1_32 = np.mean([sy1132det['ReducerEnded1'],sy1232det['ReducerEnded1'],sy1332det['ReducerEnded1']])
sy_red1_1_32_std = np.std([sy1132det['ReducerEnded1'],sy1232det['ReducerEnded1'],sy1332det['ReducerEnded1']])

sy_map2_1_8 = np.mean([sy118det['LastMapperEnded2'],sy128det['LastMapperEnded2'],sy138det['LastMapperEnded2']])
sy_map2_1_8_std = np.std([sy118det['LastMapperEnded2'],sy128det['LastMapperEnded2'],sy138det['LastMapperEnded2']])

sy_map2_1_16 = np.mean([sy1116det['LastMapperEnded2'],sy1216det['LastMapperEnded2'],sy1316det['LastMapperEnded2']])
sy_map2_1_16_std = np.std([sy1116det['LastMapperEnded2'],sy1216det['LastMapperEnded2'],sy1316det['LastMapperEnded2']])

sy_map2_1_32 = np.mean([sy1132det['LastMapperEnded2'],sy1232det['LastMapperEnded2'],sy1332det['LastMapperEnded2']])
sy_map2_1_32_std = np.std([sy1132det['LastMapperEnded2'],sy1232det['LastMapperEnded2'],sy1332det['LastMapperEnded2']])

sy_red2_1_8 = np.mean([sy118det['ReducerEnded2'],sy128det['ReducerEnded2'],sy138det['ReducerEnded2']])
sy_red2_1_8_std = np.std([sy118det['ReducerEnded2'],sy128det['ReducerEnded2'],sy138det['ReducerEnded2']])

sy_red2_1_16 = np.mean([sy1116det['ReducerEnded2'],sy1216det['ReducerEnded2'],sy1316det['ReducerEnded2']])
sy_red2_1_16_std = np.std([sy1116det['ReducerEnded2'],sy1216det['ReducerEnded2'],sy1316det['ReducerEnded2']])

sy_red2_1_32 = np.mean([sy1132det['ReducerEnded2'],sy1232det['ReducerEnded2'],sy1332det['ReducerEnded2']])
sy_red2_1_32_std = np.std([sy1132det['ReducerEnded2'],sy1232det['ReducerEnded2'],sy1332det['ReducerEnded2']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-d6ff3c6e7f6d> in <module>()
#       1 #Stamprede YARN 1M 50K detailed timing
# ----> 2 sy_map1_1_8 = np.mean([sy118det['LastMapperEnded1'],sy128det['LastMapperEnded1'],sy138det['LastMapperEnded1']])
#       3 sy_map1_1_8_std = np.std([sy118det['LastMapperEnded1'],sy128det['LastMapperEnded1'],sy138det['LastMapperEnded1']])
#       4
#       5 sy_map1_1_16 = np.mean([sy1116det['LastMapperEnded1'],sy1216det['LastMapperEnded1'],sy1316det['LastMapperEnded1']])
#
# NameError: name 'sy118det' is not defined

# %%
#Wrangler Vanilla 10K 5K detailed timing
wv_map1_10_8 = np.mean([wv1018det['LastMapperEnded1'],wv1028det['LastMapperEnded1'],wv1038det['LastMapperEnded1']])
wv_map1_10_8_std = np.std([wv1018det['LastMapperEnded1'],wv1028det['LastMapperEnded1'],wv1038det['LastMapperEnded1']])

wv_map1_10_16 = np.mean([wv10116det['LastMapperEnded1'],wv10216det['LastMapperEnded1'],wv10316det['LastMapperEnded1']])
wv_map1_10_16_std = np.std([wv10116det['LastMapperEnded1'],wv10216det['LastMapperEnded1'],wv10316det['LastMapperEnded1']])

wv_map1_10_32 = np.mean([wv10132det['LastMapperEnded1'],wv10232det['LastMapperEnded1'],wv10332det['LastMapperEnded1']])
wv_map1_10_32_std = np.std([wv10132det['LastMapperEnded1'],wv10232det['LastMapperEnded1'],wv10332det['LastMapperEnded1']])

wv_red1_10_8 = np.mean([wv1018det['ReducerEnded1'],wv1028det['ReducerEnded1'],wv1038det['ReducerEnded1']])
wv_red1_10_8_std = np.std([wv1018det['ReducerEnded1'],wv1028det['ReducerEnded1'],wv1038det['ReducerEnded1']])

wv_red1_10_16 = np.mean([wv10116det['ReducerEnded1'],wv10216det['ReducerEnded1'],wv10316det['ReducerEnded1']])
wv_red1_10_16_std = np.std([wv10116det['ReducerEnded1'],wv10216det['ReducerEnded1'],wv10316det['ReducerEnded1']])

wv_red1_10_32 = np.mean([wv10132det['ReducerEnded1'],wv10232det['ReducerEnded1'],wv10332det['ReducerEnded1']])
wv_red1_10_32_std = np.std([wv10132det['ReducerEnded1'],wv10232det['ReducerEnded1'],wv10332det['ReducerEnded1']])

wv_map2_10_8 = np.mean([wv1018det['LastMapperEnded2'],wv1028det['LastMapperEnded2'],wv1038det['LastMapperEnded2']])
wv_map2_10_8_std = np.std([wv1018det['LastMapperEnded2'],wv1028det['LastMapperEnded2'],wv1038det['LastMapperEnded2']])

wv_map2_10_16 = np.mean([wv10116det['LastMapperEnded2'],wv10216det['LastMapperEnded2'],wv10316det['LastMapperEnded2']])
wv_map2_10_16_std = np.std([wv10116det['LastMapperEnded2'],wv10216det['LastMapperEnded2'],wv10316det['LastMapperEnded2']])

wv_map2_10_32 = np.mean([wv10132det['LastMapperEnded2'],wv10232det['LastMapperEnded2'],wv10332det['LastMapperEnded2']])
wv_map2_10_32_std = np.std([wv10132det['LastMapperEnded2'],wv10232det['LastMapperEnded2'],wv10332det['LastMapperEnded2']])

wv_red2_10_8 = np.mean([wv1018det['ReducerEnded2'],wv1028det['ReducerEnded2'],wv1038det['ReducerEnded2']])
wv_red2_10_8_std = np.std([wv1018det['ReducerEnded2'],wv1028det['ReducerEnded2'],wv1038det['ReducerEnded2']])

wv_red2_10_16 = np.mean([wv10116det['ReducerEnded2'],wv10216det['ReducerEnded2'],wv10316det['ReducerEnded2']])
wv_red2_10_16_std = np.std([wv10116det['ReducerEnded2'],wv10216det['ReducerEnded2'],wv10316det['ReducerEnded2']])

wv_red2_10_32 = np.mean([wv10132det['ReducerEnded2'],wv10232det['ReducerEnded2'],wv10332det['ReducerEnded2']])
wv_red2_10_32_std = np.std([wv10132det['ReducerEnded2'],wv10232det['ReducerEnded2'],wv10332det['ReducerEnded2']])

# %%
#Wrangler Vanilla 100K 500 detailed timing
wv_map1_100_8 = np.mean([wv10018det['LastMapperEnded1'],wv10028det['LastMapperEnded1'],wv10038det['LastMapperEnded1']])
wv_map1_100_8_std = np.std([wv10018det['LastMapperEnded1'],wv10028det['LastMapperEnded1'],wv10038det['LastMapperEnded1']])

wv_map1_100_16 = np.mean([wv100116det['LastMapperEnded1'],wv100216det['LastMapperEnded1'],wv100316det['LastMapperEnded1']])
wv_map1_100_16_std = np.std([wv100116det['LastMapperEnded1'],wv100216det['LastMapperEnded1'],wv100316det['LastMapperEnded1']])

wv_map1_100_32 = np.mean([wv100132det['LastMapperEnded1'],wv100232det['LastMapperEnded1'],wv100332det['LastMapperEnded1']])
wv_map1_100_32_std = np.std([wv100132det['LastMapperEnded1'],wv100232det['LastMapperEnded1'],wv100332det['LastMapperEnded1']])

wv_red1_100_8 = np.mean([wv10018det['ReducerEnded1'],wv10028det['ReducerEnded1'],wv10038det['ReducerEnded1']])
wv_red1_100_8_std = np.std([wv10018det['ReducerEnded1'],wv10028det['ReducerEnded1'],wv10038det['ReducerEnded1']])

wv_red1_100_16 = np.mean([wv100116det['ReducerEnded1'],wv100216det['ReducerEnded1'],wv100316det['ReducerEnded1']])
wv_red1_100_16_std = np.std([wv100116det['ReducerEnded1'],wv100216det['ReducerEnded1'],wv100316det['ReducerEnded1']])

wv_red1_100_32 = np.mean([wv100132det['ReducerEnded1'],wv100232det['ReducerEnded1'],wv100332det['ReducerEnded1']])
wv_red1_100_32_std = np.std([wv100132det['ReducerEnded1'],wv100232det['ReducerEnded1'],wv100332det['ReducerEnded1']])

wv_map2_100_8 = np.mean([wv10018det['LastMapperEnded2'],wv10028det['LastMapperEnded2'],wv10038det['LastMapperEnded2']])
wv_map2_100_8_std = np.std([wv10018det['LastMapperEnded2'],wv10028det['LastMapperEnded2'],wv10038det['LastMapperEnded2']])

wv_map2_100_16 = np.mean([wv100116det['LastMapperEnded2'],wv100216det['LastMapperEnded2'],wv100316det['LastMapperEnded2']])
wv_map2_100_16_std = np.std([wv100116det['LastMapperEnded2'],wv100216det['LastMapperEnded2'],wv100316det['LastMapperEnded2']])

wv_map2_100_32 = np.mean([wv100132det['LastMapperEnded2'],wv100232det['LastMapperEnded2'],wv100332det['LastMapperEnded2']])
wv_map2_100_32_std = np.std([wv100132det['LastMapperEnded2'],wv100232det['LastMapperEnded2'],wv100332det['LastMapperEnded2']])

wv_red2_100_8 = np.mean([wv10018det['ReducerEnded2'],wv10028det['ReducerEnded2'],wv10038det['ReducerEnded2']])
wv_red2_100_8_std = np.std([wv10018det['ReducerEnded2'],wv10028det['ReducerEnded2'],wv10038det['ReducerEnded2']])

wv_red2_100_16 = np.mean([wv100116det['ReducerEnded2'],wv100216det['ReducerEnded2'],wv100316det['ReducerEnded2']])
wv_red2_100_16_std = np.std([wv100116det['ReducerEnded2'],wv100216det['ReducerEnded2'],wv100316det['ReducerEnded2']])

wv_red2_100_32 = np.mean([wv100132det['ReducerEnded2'],wv100232det['ReducerEnded2'],wv100332det['ReducerEnded2']])
wv_red2_100_32_std = np.std([wv100132det['ReducerEnded2'],wv100232det['ReducerEnded2'],wv100332det['ReducerEnded2']])

# %%
#Wrangler Vanilla 1M 50K detailed timing
wv_map1_1_8 = np.mean([wv118det['LastMapperEnded1'],wv128det['LastMapperEnded1'],wv138det['LastMapperEnded1']])
wv_map1_1_8_std = np.std([wv118det['LastMapperEnded1'],wv128det['LastMapperEnded1'],wv138det['LastMapperEnded1']])

wv_map1_1_16 = np.mean([wv1116det['LastMapperEnded1'],wv1216det['LastMapperEnded1'],wv1316det['LastMapperEnded1']])
wv_map1_1_16_std = np.std([wv1116det['LastMapperEnded1'],wv1216det['LastMapperEnded1'],wv1316det['LastMapperEnded1']])

wv_map1_1_32 = np.mean([wv1132det['LastMapperEnded1'],wv1232det['LastMapperEnded1'],wv1332det['LastMapperEnded1']])
wv_map1_1_32_std = np.std([wv1132det['LastMapperEnded1'],wv1232det['LastMapperEnded1'],wv1332det['LastMapperEnded1']])

wv_red1_1_8 = np.mean([wv118det['ReducerEnded1'],wv128det['ReducerEnded1'],wv138det['ReducerEnded1']])
wv_red1_1_8_std = np.std([wv118det['ReducerEnded1'],wv128det['ReducerEnded1'],wv138det['ReducerEnded1']])

wv_red1_1_16 = np.mean([wv1116det['ReducerEnded1'],wv1216det['ReducerEnded1'],wv1316det['ReducerEnded1']])
wv_red1_1_16_std = np.std([wv1116det['ReducerEnded1'],wv1216det['ReducerEnded1'],wv1316det['ReducerEnded1']])

wv_red1_1_32 = np.mean([wv1132det['ReducerEnded1'],wv1232det['ReducerEnded1'],wv1332det['ReducerEnded1']])
wv_red1_1_32_std = np.std([wv1132det['ReducerEnded1'],wv1232det['ReducerEnded1'],wv1332det['ReducerEnded1']])

wv_map2_1_8 = np.mean([wv118det['LastMapperEnded2'],wv128det['LastMapperEnded2'],wv138det['LastMapperEnded2']])
wv_map2_1_8_std = np.std([wv118det['LastMapperEnded2'],wv128det['LastMapperEnded2'],wv138det['LastMapperEnded2']])

wv_map2_1_16 = np.mean([wv1116det['LastMapperEnded2'],wv1216det['LastMapperEnded2'],wv1316det['LastMapperEnded2']])
wv_map2_1_16_std = np.std([wv1116det['LastMapperEnded2'],wv1216det['LastMapperEnded2'],wv1316det['LastMapperEnded2']])

wv_map2_1_32 = np.mean([wv1132det['LastMapperEnded2'],wv1232det['LastMapperEnded2'],wv1332det['LastMapperEnded2']])
wv_map2_1_32_std = np.std([wv1132det['LastMapperEnded2'],wv1232det['LastMapperEnded2'],wv1332det['LastMapperEnded2']])

wv_red2_1_8 = np.mean([wv118det['ReducerEnded2'],wv128det['ReducerEnded2'],wv138det['ReducerEnded2']])
wv_red2_1_8_std = np.std([wv118det['ReducerEnded2'],wv128det['ReducerEnded2'],wv138det['ReducerEnded2']])

wv_red2_1_16 = np.mean([wv1116det['ReducerEnded2'],wv1216det['ReducerEnded2'],wv1316det['ReducerEnded2']])
wv_red2_1_16_std = np.std([wv1116det['ReducerEnded2'],wv1216det['ReducerEnded2'],wv1316det['ReducerEnded2']])

wv_red2_1_32 = np.mean([wv1132det['ReducerEnded2'],wv1232det['ReducerEnded2'],wv1332det['ReducerEnded2']])
wv_red2_1_32_std = np.std([wv1132det['ReducerEnded2'],wv1232det['ReducerEnded2'],wv1332det['ReducerEnded2']])

# %%
#Wrangler YARN 10K 5K detailed timing
wy_map1_10_8 = np.mean([wy1018det['LastMapperEnded1'],wy1028det['LastMapperEnded1'],wy1038det['LastMapperEnded1']])
wy_map1_10_8_std = np.std([wy1018det['LastMapperEnded1'],wy1028det['LastMapperEnded1'],wy1038det['LastMapperEnded1']])

wy_map1_10_16 = np.mean([wy10116det['LastMapperEnded1'],wy10216det['LastMapperEnded1'],wy10316det['LastMapperEnded1']])
wy_map1_10_16_std = np.std([wy10116det['LastMapperEnded1'],wy10216det['LastMapperEnded1'],wy10316det['LastMapperEnded1']])

wy_map1_10_32 = np.mean([wy10132det['LastMapperEnded1'],wy10232det['LastMapperEnded1'],wy10332det['LastMapperEnded1']])
wy_map1_10_32_std = np.std([wy10132det['LastMapperEnded1'],wy10232det['LastMapperEnded1'],wy10332det['LastMapperEnded1']])

wy_red1_10_8 = np.mean([wy1018det['ReducerEnded1'],wy1028det['ReducerEnded1'],wy1038det['ReducerEnded1']])
wy_red1_10_8_std = np.std([wy1018det['ReducerEnded1'],wy1028det['ReducerEnded1'],wy1038det['ReducerEnded1']])

wy_red1_10_16 = np.mean([wy10116det['ReducerEnded1'],wy10216det['ReducerEnded1'],wy10316det['ReducerEnded1']])
wy_red1_10_16_std = np.std([wy10116det['ReducerEnded1'],wy10216det['ReducerEnded1'],wy10316det['ReducerEnded1']])

wy_red1_10_32 = np.mean([wy10132det['ReducerEnded1'],wy10232det['ReducerEnded1'],wy10332det['ReducerEnded1']])
wy_red1_10_32_std = np.std([wy10132det['ReducerEnded1'],wy10232det['ReducerEnded1'],wy10332det['ReducerEnded1']])

wy_map2_10_8 = np.mean([wy1018det['LastMapperEnded2'],wy1028det['LastMapperEnded2'],wy1038det['LastMapperEnded2']])
wy_map2_10_8_std = np.std([wy1018det['LastMapperEnded2'],wy1028det['LastMapperEnded2'],wy1038det['LastMapperEnded2']])

wy_map2_10_16 = np.mean([wy10116det['LastMapperEnded2'],wy10216det['LastMapperEnded2'],wy10316det['LastMapperEnded2']])
wy_map2_10_16_std = np.std([wy10116det['LastMapperEnded2'],wy10216det['LastMapperEnded2'],wy10316det['LastMapperEnded2']])

wy_map2_10_32 = np.mean([wy10132det['LastMapperEnded2'],wy10232det['LastMapperEnded2'],wy10332det['LastMapperEnded2']])
wy_map2_10_32_std = np.std([wy10132det['LastMapperEnded2'],wy10232det['LastMapperEnded2'],wy10332det['LastMapperEnded2']])

wy_red2_10_8 = np.mean([wy1018det['ReducerEnded2'],wy1028det['ReducerEnded2'],wy1038det['ReducerEnded2']])
wy_red2_10_8_std = np.std([wy1018det['ReducerEnded2'],wy1028det['ReducerEnded2'],wy1038det['ReducerEnded2']])

wy_red2_10_16 = np.mean([wy10116det['ReducerEnded2'],wy10216det['ReducerEnded2'],wy10316det['ReducerEnded2']])
wy_red2_10_16_std = np.std([wy10116det['ReducerEnded2'],wy10216det['ReducerEnded2'],wy10316det['ReducerEnded2']])

wy_red2_10_32 = np.mean([wy10132det['ReducerEnded2'],wy10232det['ReducerEnded2'],wy10332det['ReducerEnded2']])
wy_red2_10_32_std = np.std([wy10132det['ReducerEnded2'],wy10232det['ReducerEnded2'],wy10332det['ReducerEnded2']])

# %%
#Wrangler YARN 100K 500 detailed timing
wy_map1_100_8 = np.mean([wy10018det['LastMapperEnded1'],wy10028det['LastMapperEnded1'],wy10038det['LastMapperEnded1']])
wy_map1_100_8_std = np.std([wy10018det['LastMapperEnded1'],wy10028det['LastMapperEnded1'],wy10038det['LastMapperEnded1']])

wy_map1_100_16 = np.mean([wy100116det['LastMapperEnded1'],wy100216det['LastMapperEnded1'],wy100316det['LastMapperEnded1']])
wy_map1_100_16_std = np.std([wy100116det['LastMapperEnded1'],wy100216det['LastMapperEnded1'],wy100316det['LastMapperEnded1']])

wy_map1_100_32 = np.mean([wy100132det['LastMapperEnded1'],wy100232det['LastMapperEnded1'],wy100332det['LastMapperEnded1']])
wy_map1_100_32_std = np.std([wy100132det['LastMapperEnded1'],wy100232det['LastMapperEnded1'],wy100332det['LastMapperEnded1']])

wy_red1_100_8 = np.mean([wy10018det['ReducerEnded1'],wy10028det['ReducerEnded1'],wy10038det['ReducerEnded1']])
wy_red1_100_8_std = np.std([wy10018det['ReducerEnded1'],wy10028det['ReducerEnded1'],wy10038det['ReducerEnded1']])

wy_red1_100_16 = np.mean([wy100116det['ReducerEnded1'],wy100216det['ReducerEnded1'],wy100316det['ReducerEnded1']])
wy_red1_100_16_std = np.std([wy100116det['ReducerEnded1'],wy100216det['ReducerEnded1'],wy100316det['ReducerEnded1']])

wy_red1_100_32 = np.mean([wy100132det['ReducerEnded1'],wy100232det['ReducerEnded1'],wy100332det['ReducerEnded1']])
wy_red1_100_32_std = np.std([wy100132det['ReducerEnded1'],wy100232det['ReducerEnded1'],wy100332det['ReducerEnded1']])

wy_map2_100_8 = np.mean([wy10018det['LastMapperEnded2'],wy10028det['LastMapperEnded2'],wy10038det['LastMapperEnded2']])
wy_map2_100_8_std = np.std([wy10018det['LastMapperEnded2'],wy10028det['LastMapperEnded2'],wy10038det['LastMapperEnded2']])

wy_map2_100_16 = np.mean([wy100116det['LastMapperEnded2'],wy100216det['LastMapperEnded2'],wy100316det['LastMapperEnded2']])
wy_map2_100_16_std = np.std([wy100116det['LastMapperEnded2'],wy100216det['LastMapperEnded2'],wy100316det['LastMapperEnded2']])

wy_map2_100_32 = np.mean([wy100132det['LastMapperEnded2'],wy100232det['LastMapperEnded2'],wy100332det['LastMapperEnded2']])
wy_map2_100_32_std = np.std([wy100132det['LastMapperEnded2'],wy100232det['LastMapperEnded2'],wy100332det['LastMapperEnded2']])

wy_red2_100_8 = np.mean([wy10018det['ReducerEnded2'],wy10028det['ReducerEnded2'],wy10038det['ReducerEnded2']])
wy_red2_100_8_std = np.std([wy10018det['ReducerEnded2'],wy10028det['ReducerEnded2'],wy10038det['ReducerEnded2']])

wy_red2_100_16 = np.mean([wy100116det['ReducerEnded2'],wy100216det['ReducerEnded2'],wy100316det['ReducerEnded2']])
wy_red2_100_16_std = np.std([wy100116det['ReducerEnded2'],wy100216det['ReducerEnded2'],wy100316det['ReducerEnded2']])

wy_red2_100_32 = np.mean([wy100132det['ReducerEnded2'],wy100232det['ReducerEnded2'],wy100332det['ReducerEnded2']])
wy_red2_100_32_std = np.std([wy100132det['ReducerEnded2'],wy100232det['ReducerEnded2'],wy100332det['ReducerEnded2']])

# %%
#Wrangler YARN 1M 50K detailed timing
wy_map1_1_8 = np.mean([wy118det['LastMapperEnded1'],wy128det['LastMapperEnded1'],wy138det['LastMapperEnded1']])
wy_map1_1_8_std = np.std([wy118det['LastMapperEnded1'],wy128det['LastMapperEnded1'],wy138det['LastMapperEnded1']])

wy_map1_1_16 = np.mean([wy1116det['LastMapperEnded1'],wy1216det['LastMapperEnded1'],wy1316det['LastMapperEnded1']])
wy_map1_1_16_std = np.std([wy1116det['LastMapperEnded1'],wy1216det['LastMapperEnded1'],wy1316det['LastMapperEnded1']])

wy_map1_1_32 = np.mean([wy1132det['LastMapperEnded1'],wy1232det['LastMapperEnded1'],wy1332det['LastMapperEnded1']])
wy_map1_1_32_std = np.std([wy1132det['LastMapperEnded1'],wy1232det['LastMapperEnded1'],wy1332det['LastMapperEnded1']])

wy_red1_1_8 = np.mean([wy118det['ReducerEnded1'],wy128det['ReducerEnded1'],wy138det['ReducerEnded1']])
wy_red1_1_8_std = np.std([wy118det['ReducerEnded1'],wy128det['ReducerEnded1'],wy138det['ReducerEnded1']])

wy_red1_1_16 = np.mean([wy1116det['ReducerEnded1'],wy1216det['ReducerEnded1'],wy1316det['ReducerEnded1']])
wy_red1_1_16_std = np.std([wy1116det['ReducerEnded1'],wy1216det['ReducerEnded1'],wy1316det['ReducerEnded1']])

wy_red1_1_32 = np.mean([wy1132det['ReducerEnded1'],wy1232det['ReducerEnded1'],wy1332det['ReducerEnded1']])
wy_red1_1_32_std = np.std([wy1132det['ReducerEnded1'],wy1232det['ReducerEnded1'],wy1332det['ReducerEnded1']])

wy_map2_1_8 = np.mean([wy118det['LastMapperEnded2'],wy128det['LastMapperEnded2'],wy138det['LastMapperEnded2']])
wy_map2_1_8_std = np.std([wy118det['LastMapperEnded2'],wy128det['LastMapperEnded2'],wy138det['LastMapperEnded2']])

wy_map2_1_16 = np.mean([wy1116det['LastMapperEnded2'],wy1216det['LastMapperEnded2'],wy1316det['LastMapperEnded2']])
wy_map2_1_16_std = np.std([wy1116det['LastMapperEnded2'],wy1216det['LastMapperEnded2'],wy1316det['LastMapperEnded2']])

wy_map2_1_32 = np.mean([wy1132det['LastMapperEnded2'],wy1232det['LastMapperEnded2'],wy1332det['LastMapperEnded2']])
wy_map2_1_32_std = np.std([wy1132det['LastMapperEnded2'],wy1232det['LastMapperEnded2'],wy1332det['LastMapperEnded2']])

wy_red2_1_8 = np.mean([wy118det['ReducerEnded2'],wy128det['ReducerEnded2'],wy138det['ReducerEnded2']])
wy_red2_1_8_std = np.std([wy118det['ReducerEnded2'],wy128det['ReducerEnded2'],wy138det['ReducerEnded2']])

wy_red2_1_16 = np.mean([wy1116det['ReducerEnded2'],wy1216det['ReducerEnded2'],wy1316det['ReducerEnded2']])
wy_red2_1_16_std = np.std([wy1116det['ReducerEnded2'],wy1216det['ReducerEnded2'],wy1316det['ReducerEnded2']])

wy_red2_1_32 = np.mean([wy1132det['ReducerEnded2'],wy1232det['ReducerEnded2'],wy1332det['ReducerEnded2']])
wy_red2_1_32_std = np.std([wy1132det['ReducerEnded2'],wy1232det['ReducerEnded2'],wy1332det['ReducerEnded2']])

# %%
a=plt.figure()
plt.suptitle('K-Means Execution Time Comparison',y=1.06,fontsize=14)
plt.subplot(1,3,1)
n_groups=3
index=np.arange(n_groups)
bar_width=0.1
opacity=1.0

plt.bar(index,[sv_red2_10_8,sv_red2_10_16,sv_red2_10_32],bar_width,yerr=[sv_red2_10_8_std,sv_red2_10_16_std,sv_red2_10_32_std],alpha=opacity,color='lightgreen',label='RP Stampede')
plt.bar(index,[sv_map2_10_8,sv_map2_10_16,sv_map2_10_32],bar_width,yerr=[sv_map2_10_8_std,sv_map2_10_16_std,sv_map2_10_32_std],alpha=opacity,color='green',label='RP Stampede')
plt.bar(index,[sv_red1_10_8,sv_red1_10_16,sv_red1_10_32],bar_width,yerr=[sv_red1_10_8_std,sv_red1_10_16_std,sv_red1_10_32_std],alpha=opacity,color='lightgreen',label='RP Stampede')
plt.bar(index,[sv_map1_10_8,sv_map1_10_16,sv_map1_10_32],bar_width,yerr=[sv_map1_10_8_std,sv_map1_10_16_std,sv_map1_10_32_std],alpha=opacity,color='green',label='RP Stampede')
plt.bar(index+bar_width,[sy_red2_10_8,sy_red2_10_16,sy_red2_10_32],bar_width,yerr=[sy_red2_10_8_std,sy_red2_10_16_std,sy_red2_10_32_std],alpha=opacity,color='blue',label='RP-YARN Stampede')
plt.bar(index+bar_width,[sy_map2_10_8,sy_map2_10_16,sy_map2_10_32],bar_width,yerr=[sy_map2_10_8_std,sy_map2_10_16_std,sy_map2_10_32_std],alpha=opacity,color='cyan',label='RP-YARN Stampede')
plt.bar(index+bar_width,[sy_red1_10_8,sy_red1_10_16,sy_red1_10_32],bar_width,yerr=[sy_red1_10_8_std,sy_red1_10_16_std,sy_red1_10_32_std],alpha=opacity,color='blue',label='RP-YARN Stampede')
plt.bar(index+bar_width,[sy_map1_10_8,sy_map1_10_16,sy_map1_10_32],bar_width,yerr=[sy_map1_10_8_std,sy_map1_10_16_std,sy_map1_10_32_std],alpha=opacity,color='cyan',label='RP-YARN Stampede')
plt.bar(index+2*bar_width,[wv_red2_10_8,wv_red2_10_16,wv_red2_10_32],bar_width,yerr=[wv_red2_10_8_std,wv_red2_10_16_std,wv_red2_10_32_std],alpha=opacity,color='yellow',label='RP Wrangler')
plt.bar(index+2*bar_width,[wv_map2_10_8,wv_map2_10_16,wv_map2_10_32],bar_width,yerr=[wv_map2_10_8_std,wv_map2_10_16_std,wv_map2_10_32_std],alpha=opacity,color='orange',label='RP Wrangler')
plt.bar(index+2*bar_width,[wv_red1_10_8,wv_red1_10_16,wv_red1_10_32],bar_width,yerr=[wv_red1_10_8_std,wv_red1_10_16_std,wv_red1_10_32_std],alpha=opacity,color='yellow',label='RP Wrangler')
plt.bar(index+2*bar_width,[wv_map1_10_8,wv_map1_10_16,wv_map1_10_32],bar_width,yerr=[wv_map1_10_8_std,wv_map1_10_16_std,wv_map1_10_32_std],alpha=opacity,color='orange',label='RP Wrangler')
plt.bar(index+3*bar_width,[wy_red2_10_8,wy_red2_10_16,wy_red2_10_32],bar_width,yerr=[wy_red2_10_8_std,wy_red2_10_16_std,wy_red2_10_32_std],alpha=opacity,color='darkred',label='RP-YARN Wrangler')
plt.bar(index+3*bar_width,[wy_map2_10_8,wy_map2_10_16,wy_map2_10_32],bar_width,yerr=[wy_map2_10_8_std,wy_map2_10_16_std,wy_map2_10_32_std],alpha=opacity,color='red',label='RP-YARN Wrangler')
plt.bar(index+3*bar_width,[wy_red1_10_8,wy_red1_10_16,wy_red1_10_32],bar_width,yerr=[wy_red1_10_8_std,wy_red1_10_16_std,wy_red1_10_32_std],alpha=opacity,color='darkred',label='RP-YARN Wrangler')
plt.bar(index+3*bar_width,[wy_map1_10_8,wy_map1_10_16,wy_map1_10_32],bar_width,yerr=[wy_map1_10_8_std,wy_map1_10_16_std,wy_map1_10_32_std],alpha=opacity,color='red',label='RP-YARN Wrangler')

plt.title('10,000 points'+'\n'+'5,000 clusters')
plt.xticks(index+3*bar_width,('8','16','32'))
plt.ylim(ymax=2300)
plt.ylabel('Time to Completion (secs)',fontsize=14)
plt.subplot(1,3,2)
n_groups=3
index=np.arange(n_groups)
bar_width=0.1
opacity=1.0

plt.bar(index,[sv_red2_100_8,sv_red2_100_16,sv_red2_100_32],bar_width,yerr=[sv_red2_100_8_std,sv_red2_100_16_std,sv_red2_100_32_std],alpha=opacity,color='lightgreen',label='RP Stampede')
plt.bar(index,[sv_map2_100_8,sv_map2_100_16,sv_map2_100_32],bar_width,yerr=[sv_map2_100_8_std,sv_map2_100_16_std,sv_map2_100_32_std],alpha=opacity,color='green',label='RP Stampede')
plt.bar(index,[sv_red1_100_8,sv_red1_100_16,sv_red1_100_32],bar_width,yerr=[sv_red1_100_8_std,sv_red1_100_16_std,sv_red1_100_32_std],alpha=opacity,color='lightgreen',label='RP Stampede')
plt.bar(index,[sv_map1_100_8,sv_map1_100_16,sv_map1_100_32],bar_width,yerr=[sv_map1_100_8_std,sv_map1_100_16_std,sv_map1_100_32_std],alpha=opacity,color='green',label='RP Stampede')
plt.bar(index+bar_width,[sy_red2_100_8,sy_red2_100_16,sy_red2_100_32],bar_width,yerr=[sy_red2_100_8_std,sy_red2_100_16_std,sy_red2_100_32_std],alpha=opacity,color='blue',label='RP-YARN Stampede')
plt.bar(index+bar_width,[sy_map2_100_8,sy_map2_100_16,sy_map2_100_32],bar_width,yerr=[sy_map2_100_8_std,sy_map2_100_16_std,sy_map2_100_32_std],alpha=opacity,color='cyan',label='RP-YARN Stampede')
plt.bar(index+bar_width,[sy_red1_100_8,sy_red1_100_16,sy_red1_100_32],bar_width,yerr=[sy_red1_100_8_std,sy_red1_100_16_std,sy_red1_100_32_std],alpha=opacity,color='blue',label='RP-YARN Stampede')
plt.bar(index+bar_width,[sy_map1_100_8,sy_map1_100_16,sy_map1_100_32],bar_width,yerr=[sy_map1_100_8_std,sy_map1_100_16_std,sy_map1_100_32_std],alpha=opacity,color='cyan',label='RP-YARN Stampede')
plt.bar(index+2*bar_width,[wv_red2_100_8,wv_red2_100_16,wv_red2_100_32],bar_width,yerr=[wv_red2_100_8_std,wv_red2_100_16_std,wv_red2_100_32_std],alpha=opacity,color='yellow',label='RP Wrangler')
plt.bar(index+2*bar_width,[wv_map2_100_8,wv_map2_100_16,wv_map2_100_32],bar_width,yerr=[wv_map2_100_8_std,wv_map2_100_16_std,wv_map2_100_32_std],alpha=opacity,color='orange',label='RP Wrangler')
plt.bar(index+2*bar_width,[wv_red1_100_8,wv_red1_100_16,wv_red1_100_32],bar_width,yerr=[wv_red1_100_8_std,wv_red1_100_16_std,wv_red1_100_32_std],alpha=opacity,color='yellow',label='RP Wrangler')
plt.bar(index+2*bar_width,[wv_map1_100_8,wv_map1_100_16,wv_map1_100_32],bar_width,yerr=[wv_map1_100_8_std,wv_map1_100_16_std,wv_map1_100_32_std],alpha=opacity,color='orange',label='RP Wrangler')
plt.bar(index+3*bar_width,[wy_red2_100_8,wy_red2_100_16,wy_red2_100_32],bar_width,yerr=[wy_red2_100_8_std,wy_red2_100_16_std,wy_red2_100_32_std],alpha=opacity,color='darkred',label='RP-YARN Wrangler')
plt.bar(index+3*bar_width,[wy_map2_100_8,wy_map2_100_16,wy_map2_100_32],bar_width,yerr=[wy_map2_100_8_std,wy_map2_100_16_std,wy_map2_100_32_std],alpha=opacity,color='red',label='RP-YARN Wrangler')
plt.bar(index+3*bar_width,[wy_red1_100_8,wy_red1_100_16,wy_red1_100_32],bar_width,yerr=[wy_red1_100_8_std,wy_red1_100_16_std,wy_red1_100_32_std],alpha=opacity,color='darkred',label='RP-YARN Wrangler')
plt.bar(index+3*bar_width,[wy_map1_100_8,wy_map1_100_16,wy_map1_100_32],bar_width,yerr=[wy_map1_100_8_std,wy_map1_100_16_std,wy_map1_100_32_std],alpha=opacity,color='red',label='RP-YARN Wrangler')

plt.title('100,000 points'+'\n'+'500 clusters')
plt.xticks(index+3*bar_width,('8','16','32'))
plt.ylim(ymax=2300)
plt.subplot(1,3,3)
n_groups=3
index=np.arange(n_groups)
bar_width=0.1
opacity=1.0

plt.bar(index,[sv_red2_1_8,sv_red2_1_16,sv_red2_1_32],bar_width,yerr=[sv_red2_1_8_std,sv_red2_1_16_std,sv_red2_1_32_std],alpha=opacity,color='lightgreen',label='RP Stampede')
b1=plt.bar(index,[sv_map2_1_8,sv_map2_1_16,sv_map2_1_32],bar_width,yerr=[sv_map2_1_8_std,sv_map2_1_16_std,sv_map2_1_32_std],alpha=opacity,color='green',label='RP Stampede')
plt.bar(index,[sv_red1_1_8,sv_red1_1_16,sv_red1_1_32],bar_width,yerr=[sv_red1_1_8_std,sv_red1_1_16_std,sv_red1_1_32_std],alpha=opacity,color='lightgreen',label='RP Stampede')
plt.bar(index,[sv_map1_1_8,sv_map1_1_16,sv_map1_1_32],bar_width,yerr=[sv_map1_1_8_std,sv_map1_1_16_std,sv_map1_1_32_std],alpha=opacity,color='green',label='RP Stampede')
plt.bar(index+bar_width,[sy_red2_1_8,sy_red2_1_16,sy_red2_1_32],bar_width,yerr=[sy_red2_1_8_std,sy_red2_1_16_std,sy_red2_1_32_std],alpha=opacity,color='blue',label='RP-YARN Stampede')
b2=plt.bar(index+bar_width,[sy_map2_1_8,sy_map2_1_16,sy_map2_1_32],bar_width,yerr=[sy_map2_1_8_std,sy_map2_1_16_std,sy_map2_1_32_std],alpha=opacity,color='cyan',label='RP-YARN Stampede')
plt.bar(index+bar_width,[sy_red1_1_8,sy_red1_1_16,sy_red1_1_32],bar_width,yerr=[sy_red1_1_8_std,sy_red1_1_16_std,sy_red1_1_32_std],alpha=opacity,color='blue',label='RP-YARN Stampede')
plt.bar(index+bar_width,[sy_map1_1_8,sy_map1_1_16,sy_map1_1_32],bar_width,yerr=[sy_map1_1_8_std,sy_map1_1_16_std,sy_map1_1_32_std],alpha=opacity,color='cyan',label='RP-YARN Stampede')
plt.bar(index+2*bar_width,[wv_red2_1_8,wv_red2_1_16,wv_red2_1_32],bar_width,yerr=[wv_red2_1_8_std,wv_red2_1_16_std,wv_red2_1_32_std],alpha=opacity,color='yellow',label='RP Wrangler')
b3=plt.bar(index+2*bar_width,[wv_map2_1_8,wv_map2_1_16,wv_map2_1_32],bar_width,yerr=[wv_map2_1_8_std,wv_map2_1_16_std,wv_map2_1_32_std],alpha=opacity,color='orange',label='RP Wrangler')
plt.bar(index+2*bar_width,[wv_red1_1_8,wv_red1_1_16,wv_red1_1_32],bar_width,yerr=[wv_red1_1_8_std,wv_red1_1_16_std,wv_red1_1_32_std],alpha=opacity,color='yellow',label='RP Wrangler')
plt.bar(index+2*bar_width,[wv_map1_1_8,wv_map1_1_16,wv_map1_1_32],bar_width,yerr=[wv_map1_1_8_std,wv_map1_1_16_std,wv_map1_1_32_std],alpha=opacity,color='orange',label='RP Wrangler')
plt.bar(index+3*bar_width,[wy_red2_1_8,wy_red2_1_16,wy_red2_1_32],bar_width,yerr=[wy_red2_1_8_std,wy_red2_1_16_std,wy_red2_1_32_std],alpha=opacity,color='darkred',label='RP-YARN Wrangler')
b4=plt.bar(index+3*bar_width,[wy_map2_1_8,wy_map2_1_16,wy_map2_1_32],bar_width,yerr=[wy_map2_1_8_std,wy_map2_1_16_std,wy_map2_1_32_std],alpha=opacity,color='red',label='RP-YARN Wrangler')
plt.bar(index+3*bar_width,[wy_red1_1_8,wy_red1_1_16,wy_red1_1_32],bar_width,yerr=[wy_red1_1_8_std,wy_red1_1_16_std,wy_red1_1_32_std],alpha=opacity,color='darkred',label='RP-YARN Wrangler')
plt.bar(index+3*bar_width,[wy_map1_1_8,wy_map1_1_16,wy_map1_1_32],bar_width,yerr=[wy_map1_1_8_std,wy_map1_1_16_std,wy_map1_1_32_std],alpha=opacity,color='red',label='RP-YARN Wrangler')

plt.title('1,000,000 points'+'\n'+'50 clusters')
plt.xticks(index+3*bar_width,('8','16','32'))
plt.ylim(ymax=2300)

lgd=plt.figlegend((b1,b2,b3,b4),('RP on Stampede','RP-YARN on Stampede','RP on Wrangler','RP-YARN on Wrangler'),
              loc='lower center',mode="expand",ncol=3,fontsize=10,borderaxespad=0.11)
a.text(0.45,0.16,'Number of Tasks',ha='center',fontsize=14)
a.subplots_adjust(bottom=0.25)
a.savefig('kmeans-ttc-comp-detailed.pdf',dpi=800,bbox_extra_artists=(lgd,))

# %%
# Stampede Vanilla
SV1008MapMean = np.mean(sv10018map1+sv10018map2+sv10028map1+sv10028map2+sv10038map1+sv10038map2)
SV10016MapMean = np.mean(sv100116map1+sv100116map2+sv100216map1+sv100216map2+sv100316map1+sv100316map2)
SV10032MapMean = np.mean(sv100132map1+sv100132map2+sv100232map1+sv100232map2+sv100332map1+sv100332map2)
SV108MapMean = np.mean(sv1018map1+sv1018map2+sv1028map1+sv1028map2+sv1038map1+sv1038map2)
SV1016MapMean = np.mean(sv10116map1+sv10116map2+sv10216map1+sv10216map2+sv10316map1+sv10316map2)
SV1032MapMean = np.mean(sv10132map1+sv10132map2+sv10232map1+sv10232map2+sv10332map1+sv10332map2)
SV18MapMean = np.mean(sv118map1+sv118map2+sv128map1+sv128map2+sv138map1+sv138map2)
SV116MapMean = np.mean(sv1116map1+sv1116map2+sv1216map1+sv1216map2+sv1316map1+sv1316map2)
SV132MapMean = np.mean(sv1132map1+sv1132map2+sv1232map1+sv1232map2+sv1332map1+sv1332map2)

SV1008MapStd = np.std(sv10018map1+sv10018map2+sv10028map1+sv10028map2+sv10038map1+sv10038map2)
SV10016MapStd = np.std(sv100116map1+sv100116map2+sv100216map1+sv100216map2+sv100316map1+sv100316map2)
SV10032MapStd = np.std(sv100132map1+sv100132map2+sv100232map1+sv100232map2+sv100332map1+sv100332map2)
SV108MapStd = np.std(sv1018map1+sv1018map2+sv1028map1+sv1028map2+sv1038map1+sv1038map2)
SV1016MapStd = np.std(sv10116map1+sv10116map2+sv10216map1+sv10216map2+sv10316map1+sv10316map2)
SV1032MapStd = np.std(sv10132map1+sv10132map2+sv10232map1+sv10232map2+sv10332map1+sv10332map2)
SV18MapStd = np.std(sv118map1+sv118map2+sv128map1+sv128map2+sv138map1+sv138map2)
SV116MapStd = np.std(sv1116map1+sv1116map2+sv1216map1+sv1216map2+sv1316map1+sv1316map2)
SV132MapStd = np.std(sv1132map1+sv1132map2+sv1232map1+sv1232map2+sv1332map1+sv1332map2)

# %%
# Stampede YARN
SY1008MapMean = np.mean(sy10018map1+sy10018map2+sy10028map1+sy10028map2+sy10038map1+sy10038map2)
SY10016MapMean = np.mean(sy100116map1+sy100116map2+sy100216map1+sy100216map2+sy100316map1+sy100316map2)
SY10032MapMean = np.mean(sy100132map1+sy100132map2+sy100232map1+sy100232map2+sy100332map1+sy100332map2)
SY108MapMean = np.mean(sy1018map1+sy1018map2+sy1028map1+sy1028map2+sy1038map1+sy1038map2)
SY1016MapMean = np.mean(sy10116map1+sy10116map2+sy10216map1+sy10216map2+sy10316map1+sy10316map2)
SY1032MapMean = np.mean(sy10132map1+sy10132map2+sy10232map1+sy10232map2+sy10332map1+sy10332map2)
SY18MapMean = np.mean(sy118map1+sy118map2+sy128map1+sy128map2+sy138map1+sy138map2)
SY116MapMean = np.mean(sy1116map1+sy1116map2+sy1216map1+sy1216map2+sy1316map1+sy1316map2)
SY132MapMean = np.mean(sy1132map1+sy1132map2+sy1232map1+sy1232map2+sy1332map1+sy1332map2)

SY1008MapStd = np.std(sy10018map1+sy10018map2+sy10028map1+sy10028map2+sy10038map1+sy10038map2)
SY10016MapStd = np.std(sy100116map1+sy100116map2+sy100216map1+sy100216map2+sy100316map1+sy100316map2)
SY10032MapStd = np.std(sy100132map1+sy100132map2+sy100232map1+sy100232map2+sy100332map1+sy100332map2)
SY108MapStd = np.std(sy1018map1+sy1018map2+sy1028map1+sy1028map2+sy1038map1+sy1038map2)
SY1016MapStd = np.std(sy10116map1+sy10116map2+sy10216map1+sy10216map2+sy10316map1+sy10316map2)
SY1032MapStd = np.std(sy10132map1+sy10132map2+sy10232map1+sy10232map2+sy10332map1+sy10332map2)
SY18MapStd = np.std(sy118map1+sy118map2+sy128map1+sy128map2+sy138map1+sy138map2)
SY116MapStd = np.std(sy1116map1+sy1116map2+sy1216map1+sy1216map2+sy1316map1+sy1316map2)
SY132MapStd = np.std(sy1132map1+sy1132map2+sy1232map1+sy1232map2+sy1332map1+sy1332map2)

# %%
# Wrangler Vanilla
WV1008MapMean = np.mean(wv10018map1+wv10018map2+wv10028map1+wv10028map2+wv10038map1+wv10038map2)
WV10016MapMean = np.mean(wv100116map1+wv100116map2+wv100216map1+wv100216map2+wv100316map1+wv100316map2)
WV10032MapMean = np.mean(wv100132map1+wv100132map2+wv100232map1+wv100232map2+wv100332map1+wv100332map2)
WV108MapMean = np.mean(wv1018map1+wv1018map2+wv1028map1+wv1028map2+wv1038map1+wv1038map2)
WV1016MapMean = np.mean(wv10116map1+wv10116map2+wv10216map1+wv10216map2+wv10316map1+wv10316map2)
WV1032MapMean = np.mean(wv10132map1+wv10132map2+wv10232map1+wv10232map2+wv10332map1+wv10332map2)
WV18MapMean = np.mean(wv118map1+wv118map2+wv128map1+wv128map2+wv138map1+wv138map2)
WV116MapMean = np.mean(wv1116map1+wv1116map2+wv1216map1+wv1216map2+wv1316map1+wv1316map2)
WV132MapMean = np.mean(wv1132map1+wv1132map2+wv1232map1+wv1232map2+wv1332map1+wv1332map2)

WV1008MapStd = np.std(wv10018map1+wv10018map2+wv10028map1+wv10028map2+wv10038map1+wv10038map2)
WV10016MapStd = np.std(wv100116map1+wv100116map2+wv100216map1+wv100216map2+wv100316map1+wv100316map2)
WV10032MapStd = np.std(wv100132map1+wv100132map2+wv100232map1+wv100232map2+wv100332map1+wv100332map2)
WV108MapStd = np.std(wv1018map1+wv1018map2+wv1028map1+wv1028map2+wv1038map1+wv1038map2)
WV1016MapStd = np.std(wv10116map1+wv10116map2+wv10216map1+wv10216map2+wv10316map1+wv10316map2)
WV1032MapStd = np.std(wv10132map1+wv10132map2+wv10232map1+wv10232map2+wv10332map1+wv10332map2)
WV18MapStd = np.std(wv118map1+wv118map2+wv128map1+wv128map2+wv138map1+wv138map2)
WV116MapStd = np.std(wv1116map1+wv1116map2+wv1216map1+wv1216map2+wv1316map1+wv1316map2)
WV132MapStd = np.std(wv1132map1+wv1132map2+wv1232map1+wv1232map2+wv1332map1+wv1332map2)

# %%
# Wrangler YARN
WY1008MapMean = np.mean(wy10018map1+wy10018map2+wy10028map1+wy10028map2+wy10038map1+wy10038map2)
WY10016MapMean = np.mean(wy100116map1+wy100116map2+wy100216map1+wy100216map2+wy100316map1+wy100316map2)
WY10032MapMean = np.mean(wy100132map1+wy100132map2+wy100232map1+wy100232map2+wy100332map1+wy100332map2)
WY108MapMean = np.mean(wy1018map1+wy1018map2+wy1028map1+wy1028map2+wy1038map1+wy1038map2)
WY1016MapMean = np.mean(wy10116map1+wy10116map2+wy10216map1+wy10216map2+wy10316map1+wy10316map2)
WY1032MapMean = np.mean(wy10132map1+wy10132map2+wy10232map1+wy10232map2+wy10332map1+wy10332map2)
WY18MapMean = np.mean(wy118map1+wy118map2+wy128map1+wy128map2+wy138map1+wy138map2)
WY116MapMean = np.mean(wy1116map1+wy1116map2+wy1216map1+wy1216map2+wy1316map1+wy1316map2)
WY132MapMean = np.mean(wy1132map1+wy1132map2+wy1232map1+wy1232map2+wy1332map1+wy1332map2)

WY1008MapStd = np.std(wy10018map1+wy10018map2+wy10028map1+wy10028map2+wy10038map1+wy10038map2)
WY10016MapStd = np.std(wy100116map1+wy100116map2+wy100216map1+wy100216map2+wy100316map1+wy100316map2)
WY10032MapStd = np.std(wy100132map1+wy100132map2+wy100232map1+wy100232map2+wy100332map1+wy100332map2)
WY108MapStd = np.std(wy1018map1+wy1018map2+wy1028map1+wy1028map2+wy1038map1+wy1038map2)
WY1016MapStd = np.std(wy10116map1+wy10116map2+wy10216map1+wy10216map2+wy10316map1+wy10316map2)
WY1032MapStd = np.std(wy10132map1+wy10132map2+wy10232map1+wy10232map2+wy10332map1+wy10332map2)
WY18MapStd = np.std(wy118map1+wy118map2+wy128map1+wy128map2+wy138map1+wy138map2)
WY116MapStd = np.std(wy1116map1+wy1116map2+wy1216map1+wy1216map2+wy1316map1+wy1316map2)
WY132MapStd = np.std(wy1132map1+wy1132map2+wy1232map1+wy1232map2+wy1332map1+wy1332map2)

# %%
a=plt.figure()
plt.suptitle('K-Means Map Execution Time Comparison',y=1.06,fontsize=14)
plt.subplot(1,3,1)
n_groups=3
index=np.arange(n_groups)
bar_width=0.1
opacity=1.0
plt.bar(index,[SV108MapMean,SV1016MapMean,SV1032MapMean],bar_width,yerr=[SV108MapStd,SV1016MapStd,SV1032MapStd],alpha=opacity,color='darkgreen',ecolor='darkgreen',label='RP Stampede')
plt.bar(index+bar_width,[SY108MapMean,SY1016MapMean,SY1032MapMean],bar_width,yerr=[SY108MapStd,SY1016MapStd,SY1032MapStd],alpha=opacity,color='blue',ecolor='blue',label='RP-YARN Stampede')
plt.bar(index+2*bar_width,[WV108MapMean,WV1016MapMean,WV1032MapMean],bar_width,yerr=[WV108MapStd,WV1016MapStd,WV1032MapStd],alpha=opacity,color='cyan',ecolor='cyan',label='RP Wrangler')
plt.bar(index+3*bar_width,[WY108MapMean,WY1016MapMean,WY1032MapMean],bar_width,yerr=[WY108MapStd,WY1016MapStd,WY1032MapStd],alpha=opacity,color='red',ecolor='red',label='RP-YARN Wrangler')
plt.title('10,000 points'+'\n'+'5,000 clusters')
plt.xticks(index+2*bar_width,('8','16','32'))
plt.ylim(ymax=1100)
plt.ylabel('Map Average Time (secs)',fontsize=14)
plt.subplot(1,3,2)
n_groups=3
index=np.arange(n_groups)
bar_width=0.1
opacity=1.0
plt.bar(index,[SV1008MapMean,SV10016MapMean,SV10032MapMean],bar_width,yerr=[SV1008MapStd,SV10016MapStd,SV10032MapStd],alpha=opacity,color='darkgreen',ecolor='darkgreen',label='RP Stampede')
plt.bar(index+bar_width,[SY1008MapMean,SY10016MapMean,SY10032MapMean],bar_width,yerr=[SY1008MapStd,SY10016MapStd,SY10032MapStd],alpha=opacity,color='blue',ecolor='blue',label='RP-YARN Stampede')
plt.bar(index+2*bar_width,[WV1008MapMean,WV10016MapMean,WV10032MapMean],bar_width,yerr=[WV1008MapStd,WV10016MapStd,WV10032MapStd],alpha=opacity,color='cyan',ecolor='cyan',label='RP Wrangler')
plt.bar(index+3*bar_width,[WY1008MapMean,WY10016MapMean,WY10032MapMean],bar_width,yerr=[WY1008MapStd,WY10016MapStd,WY10032MapStd],alpha=opacity,color='red',ecolor='red',label='RP-YARN Wrangler')
plt.title('100,000 points'+'\n'+'500 clusters')
plt.xticks(index+2*bar_width,('8','16','32'))
plt.ylim(ymax=1100)
plt.subplot(1,3,3)
n_groups=3
index=np.arange(n_groups)
bar_width=0.1
opacity=1.0
b1 = plt.bar(index,[SV18MapMean,SV116MapMean,SV132MapMean],bar_width,yerr=[SV18MapStd,SV116MapStd,SV132MapStd],alpha=opacity,color='darkgreen',ecolor='darkgreen',label='RP Stampede')
b2 = plt.bar(index+bar_width,[SY18MapMean,SY116MapMean,SY132MapMean],bar_width,yerr=[SY18MapStd,SY116MapStd,SY132MapStd],alpha=opacity,color='blue',ecolor='blue',label='RP-YARN Stampede')
b3 = plt.bar(index+2*bar_width,[WV18MapMean,WV116MapMean,WV132MapMean],bar_width,yerr=[WV18MapStd,WV116MapStd,WV132MapStd],alpha=opacity,color='cyan',ecolor='cyan',label='RP Wrangler')
b4 = plt.bar(index+3*bar_width,[WY18MapMean,WY116MapMean,WY132MapMean],bar_width,yerr=[WY18MapStd,WY116MapStd,WY132MapStd],alpha=opacity,color='red',ecolor='red',label='RP-YARN Wrangler')
plt.xticks(index+2*bar_width,('8','16','32'))
plt.title('1,000,000 points'+'\n'+'50 clusters')
plt.ylim(ymax=1100)
lgd=plt.figlegend((b1,b2,b3,b4),('RP on Stampede','RP-YARN on Stampede','RP on Wrangler','RP-YARN on Wrangler'),
              loc='lower center',mode="expand",ncol=3,fontsize=10,borderaxespad=0.11)
a.text(0.45,0.16,'Number of Tasks',ha='center',fontsize=14)
a.subplots_adjust(bottom=0.25)
a.savefig('kmeans-maptime-comp.pdf',dpi=800,bbox_extra_artists=(lgd,))

# %%
#Map Seedup

##Stampede and Wrangler Small
sv_map_speed_small_1 = SV108MapMean/SV108MapMean
sv_map_speed_small_2 = SV108MapMean/SV1016MapMean
sv_map_speed_small_3 = SV108MapMean/SV1032MapMean

sy_map_speed_small_1 = SY108MapMean/SY108MapMean
sy_map_speed_small_2 = SY108MapMean/SY1016MapMean
sy_map_speed_small_3 = SY108MapMean/SY1032MapMean

wv_map_speed_small_1 = WV108MapMean/WV108MapMean
wv_map_speed_small_2 = WV108MapMean/WV1016MapMean
wv_map_speed_small_3 = WV108MapMean/WV1032MapMean

wy_map_speed_small_1 = WY108MapMean/WY108MapMean
wy_map_speed_small_2 = WY108MapMean/WY1016MapMean
wy_map_speed_small_3 = WY108MapMean/WY1032MapMean

##Stampede and Wrangler Medium
sv_map_speed_medium_1 = SV1008MapMean/SV1008MapMean
sv_map_speed_medium_2 = SV1008MapMean/SV10016MapMean
sv_map_speed_medium_3 = SV1008MapMean/SV10032MapMean

sy_map_speed_medium_1 = SY1008MapMean/SY1008MapMean
sy_map_speed_medium_2 = SY1008MapMean/SY10016MapMean
sy_map_speed_medium_3 = SY1008MapMean/SY10032MapMean

wv_map_speed_medium_1 = WV1008MapMean/WV1008MapMean
wv_map_speed_medium_2 = WV1008MapMean/WV10016MapMean
wv_map_speed_medium_3 = WV1008MapMean/WV10032MapMean

wy_map_speed_medium_1 = WY1008MapMean/WY1008MapMean
wy_map_speed_medium_2 = WY1008MapMean/WY10016MapMean
wy_map_speed_medium_3 = WY1008MapMean/WY10032MapMean

##Stampede and Wrangler Large
sv_map_speed_large_1 = SV18MapMean/SV18MapMean
sv_map_speed_large_2 = SV18MapMean/SV116MapMean
sv_map_speed_large_3 = SV18MapMean/SV132MapMean

sy_map_speed_large_1 = SY18MapMean/SY18MapMean
sy_map_speed_large_2 = SY18MapMean/SY116MapMean
sy_map_speed_large_3 = SY18MapMean/SY132MapMean

wv_map_speed_large_1 = WV18MapMean/WV18MapMean
wv_map_speed_large_2 = WV18MapMean/WV116MapMean
wv_map_speed_large_3 = WV18MapMean/WV132MapMean

wy_map_speed_large_1 = WY18MapMean/WY18MapMean
wy_map_speed_large_2 = WY18MapMean/WY116MapMean
wy_map_speed_large_3 = WY18MapMean/WY132MapMean

# %%
print sv_map_speed_small_1
print sv_map_speed_small_2
print sv_map_speed_small_3

print sy_map_speed_small_1
print sy_map_speed_small_2
print sy_map_speed_small_3

print wv_map_speed_small_1
print wv_map_speed_small_2
print wv_map_speed_small_3

print wy_map_speed_small_1
print wy_map_speed_small_2
print wy_map_speed_small_3
print ''
print sv_map_speed_medium_1
print sv_map_speed_medium_2
print sv_map_speed_medium_3

print sy_map_speed_medium_1
print sy_map_speed_medium_2
print sy_map_speed_medium_3

print wv_map_speed_medium_1
print wv_map_speed_medium_2
print wv_map_speed_medium_3

print wy_map_speed_medium_1
print wy_map_speed_medium_2
print wy_map_speed_medium_3
print ''
print sv_map_speed_large_1
print sv_map_speed_large_2
print sv_map_speed_large_3

print sy_map_speed_large_1
print sy_map_speed_large_2
print sy_map_speed_large_3

print wv_map_speed_large_1
print wv_map_speed_large_2
print wv_map_speed_large_3

print wy_map_speed_large_1
print wy_map_speed_large_2
print wy_map_speed_large_3
# Out:
# 1.0
# 2.01241443879
# 2.82975285488
# 1.0
# 1.91076976962
# 3.75439178176
# 1.0
# 1.69172177426
# 2.71913457125
# 1.0
# 1.96117538053
# 3.68766042856
#
# 1.0
# 1.99365060303
# 2.87032746121
# 1.0
# 1.91972867331
# 3.71295333913
# 1.0
# 1.68904607926
# 2.70705245565
# 1.0
# 1.97235773812
# 3.68952464189
#
# 1.0
# 2.02005271676
# 2.83468603627
# 1.0
# 1.84579150282
# 3.14682083954
# 1.0
# 1.73003753538
# 2.80516937715
# 1.0
# 1.98055926887
# 3.65753954042

# %%
help(plt.legend)
# Out:
# Help on function legend in module matplotlib.pyplot:
#
# legend(*args, **kwargs)
#     Places a legend on the axes.
#
#     To make a legend for lines which already exist on the axes
#     (via plot for instance), simply call this function with an iterable
#     of strings, one for each legend item. For example::
#
#         ax.plot([1, 2, 3])
#         ax.legend(['A simple line'])
#
#     However, in order to keep the "label" and the legend element
#     instance together, it is preferable to specify the label either at
#     artist creation, or by calling the
#     :meth:`~matplotlib.artist.Artist.set_label` method on the artist::
#
#         line, = ax.plot([1, 2, 3], label='Inline label')
#         # Overwrite the label by calling the method.
#         line.set_label('Label via method')
#         ax.legend()
#
#     Specific lines can be excluded from the automatic legend element
#     selection by defining a label starting with an underscore.
# ...

# %%
a=plt.figure()
plt.suptitle('K-Means Map Time Speedup',fontsize=14)
plt.subplot(1,3,1)
plt.semilogx([8,16,32],[sv_map_speed_small_1,sv_map_speed_small_2,sv_map_speed_small_3],'-^g',[8,16,32],[sy_map_speed_small_1,sy_map_speed_small_2,sy_map_speed_small_3],'-^b',[8,16,32],[wv_map_speed_small_1,wv_map_speed_small_2,wv_map_speed_small_3],'-^y',[8,16,32],[wy_map_speed_small_1,wy_map_speed_small_2,wy_map_speed_small_3],'-^r',basex=2)
plt.ylim(ymin=0,ymax=4)
plt.xticks([4,8,16,32,64])
plt.subplot(1,3,2)
plt.semilogx([8,16,32],[sv_map_speed_medium_1,sv_map_speed_medium_2,sv_map_speed_medium_3],'-^g',[8,16,32],[sy_map_speed_medium_1,sy_map_speed_medium_2,sy_map_speed_medium_3],'-^b',[8,16,32],[wv_map_speed_medium_1,wv_map_speed_medium_2,wv_map_speed_medium_3],'-^y',[8,16,32],[wy_map_speed_medium_1,wy_map_speed_medium_2,wy_map_speed_medium_3],'-^r',basex=2)
plt.ylim(ymin=0,ymax=4)
plt.xticks([4,8,16,32,64])
plt.subplot(1,3,3)
b1,b2,b3,b4 = plt.semilogx([8,16,32],[sv_map_speed_large_1,sv_map_speed_large_2,sv_map_speed_large_3],'-^g',[8,16,32],[sy_map_speed_large_1,sy_map_speed_large_2,sy_map_speed_large_3],'-^b',[8,16,32],[wv_map_speed_large_1,wv_map_speed_large_2,wv_map_speed_large_3],'-^y',[8,16,32],[wy_map_speed_large_1,wy_map_speed_large_2,wy_map_speed_large_3],'-^r',basex=2)
plt.ylim(ymin=0,ymax=4)
plt.xticks([4,8,16,32,64])
lgd = plt.figlegend((b1,b2,b3,b4),('RP on Stampede','RP-YARN on Stampede','RP on Wrangler','RP-YARN on Wrangler'),
              loc='lower center',mode="expand",ncol=3,fontsize=10,borderaxespad=0.11)
a.text(0.45,0.16,'Number of Tasks',ha='center',fontsize=14)
a.subplots_adjust(bottom=0.25)
a.savefig('kmeans-map-speedup.pdf',dpi=800,bbox_extra_artists=(lgd,))

# %%
# Stampede Vanilla
SV1008RedMean = np.mean(sv10018red1+sv10018red2+sv10028red1+sv10028red2+sv10038red1+sv10038red2)
SV10016RedMean = np.mean(sv100116red1+sv100116red2+sv100216red1+sv100216red2+sv100316red1+sv100316red2)
SV10032RedMean = np.mean(sv100132red1+sv100132red2+sv100232red1+sv100232red2+sv100332red1+sv100332red2)
SV108RedMean = np.mean(sv1018red1+sv1018red2+sv1028red1+sv1028red2+sv1038red1+sv1038red2)
SV1016RedMean = np.mean(sv10116red1+sv10116red2+sv10216red1+sv10216red2+sv10316red1+sv10316red2)
SV1032RedMean = np.mean(sv10132red1+sv10132red2+sv10232red1+sv10232red2+sv10332red1+sv10332red2)
SV18RedMean = np.mean(sv118red1+sv118red2+sv128red1+sv128red2+sv138red1+sv138red2)
SV116RedMean = np.mean(sv1116red1+sv1116red2+sv1216red1+sv1216red2+sv1316red1+sv1316red2)
SV132RedMean = np.mean(sv1132red1+sv1132red2+sv1232red1+sv1232red2+sv1332red1+sv1332red2)

SV1008RedStd = np.std(sv10018red1+sv10018red2+sv10028red1+sv10028red2+sv10038red1+sv10038red2)
SV10016RedStd = np.std(sv100116red1+sv100116red2+sv100216red1+sv100216red2+sv100316red1+sv100316red2)
SV10032RedStd = np.std(sv100132red1+sv100132red2+sv100232red1+sv100232red2+sv100332red1+sv100332red2)
SV108RedStd = np.std(sv1018red1+sv1018red2+sv1028red1+sv1028red2+sv1038red1+sv1038red2)
SV1016RedStd = np.std(sv10116red1+sv10116red2+sv10216red1+sv10216red2+sv10316red1+sv10316red2)
SV1032RedStd = np.std(sv10132red1+sv10132red2+sv10232red1+sv10232red2+sv10332red1+sv10332red2)
SV18RedStd = np.std(sv118red1+sv118red2+sv128red1+sv128red2+sv138red1+sv138red2)
SV116RedStd = np.std(sv1116red1+sv1116red2+sv1216red1+sv1216red2+sv1316red1+sv1316red2)
SV132RedStd = np.std(sv1132red1+sv1132red2+sv1232red1+sv1232red2+sv1332red1+sv1332red2)

# Stampede YARN
SY1008RedMean = np.mean(sy10018red1+sy10018red2+sy10028red1+sy10028red2+sy10038red1+sy10038red2)
SY10016RedMean = np.mean(sy100116red1+sy100116red2+sy100216red1+sy100216red2+sy100316red1+sy100316red2)
SY10032RedMean = np.mean(sy100132red1+sy100132red2+sy100232red1+sy100232red2+sy100332red1+sy100332red2)
SY108RedMean = np.mean(sy1018red1+sy1018red2+sy1028red1+sy1028red2+sy1038red1+sy1038red2)
SY1016RedMean = np.mean(sy10116red1+sy10116red2+sy10216red1+sy10216red2+sy10316red1+sy10316red2)
SY1032RedMean = np.mean(sy10132red1+sy10132red2+sy10232red1+sy10232red2+sy10332red1+sy10332red2)
SY18RedMean = np.mean(sy118red1+sy118red2+sy128red1+sy128red2+sy138red1+sy138red2)
SY116RedMean = np.mean(sy1116red1+sy1116red2+sy1216red1+sy1216red2+sy1316red1+sy1316red2)
SY132RedMean = np.mean(sy1132red1+sy1132red2+sy1232red1+sy1232red2+sy1332red1+sy1332red2)

SY1008RedStd = np.std(sy10018red1+sy10018red2+sy10028red1+sy10028red2+sy10038red1+sy10038red2)
SY10016RedStd = np.std(sy100116red1+sy100116red2+sy100216red1+sy100216red2+sy100316red1+sy100316red2)
SY10032RedStd = np.std(sy100132red1+sy100132red2+sy100232red1+sy100232red2+sy100332red1+sy100332red2)
SY108RedStd = np.std(sy1018red1+sy1018red2+sy1028red1+sy1028red2+sy1038red1+sy1038red2)
SY1016RedStd = np.std(sy10116red1+sy10116red2+sy10216red1+sy10216red2+sy10316red1+sy10316red2)
SY1032RedStd = np.std(sy10132red1+sy10132red2+sy10232red1+sy10232red2+sy10332red1+sy10332red2)
SY18RedStd = np.std(sy118red1+sy118red2+sy128red1+sy128red2+sy138red1+sy138red2)
SY116RedStd = np.std(sy1116red1+sy1116red2+sy1216red1+sy1216red2+sy1316red1+sy1316red2)
SY132RedStd = np.std(sy1132red1+sy1132red2+sy1232red1+sy1232red2+sy1332red1+sy1332red2)

# Wrangler Vanilla
WV1008RedMean = np.mean(wv10018red1+wv10018red2+wv10028red1+wv10028red2+wv10038red1+wv10038red2)
WV10016RedMean = np.mean(wv100116red1+wv100116red2+wv100216red1+wv100216red2+wv100316red1+wv100316red2)
WV10032RedMean = np.mean(wv100132red1+wv100132red2+wv100232red1+wv100232red2+wv100332red1+wv100332red2)
WV108RedMean = np.mean(wv1018red1+wv1018red2+wv1028red1+wv1028red2+wv1038red1+wv1038red2)
WV1016RedMean = np.mean(wv10116red1+wv10116red2+wv10216red1+wv10216red2+wv10316red1+wv10316red2)
WV1032RedMean = np.mean(wv10132red1+wv10132red2+wv10232red1+wv10232red2+wv10332red1+wv10332red2)
WV18RedMean = np.mean(wv118red1+wv118red2+wv128red1+wv128red2+wv138red1+wv138red2)
WV116RedMean = np.mean(wv1116red1+wv1116red2+wv1216red1+wv1216red2+wv1316red1+wv1316red2)
WV132RedMean = np.mean(wv1132red1+wv1132red2+wv1232red1+wv1232red2+wv1332red1+wv1332red2)

WV1008RedStd = np.std(wv10018red1+wv10018red2+wv10028red1+wv10028red2+wv10038red1+wv10038red2)
WV10016RedStd = np.std(wv100116red1+wv100116red2+wv100216red1+wv100216red2+wv100316red1+wv100316red2)
WV10032RedStd = np.std(wv100132red1+wv100132red2+wv100232red1+wv100232red2+wv100332red1+wv100332red2)
WV108RedStd = np.std(wv1018red1+wv1018red2+wv1028red1+wv1028red2+wv1038red1+wv1038red2)
WV1016RedStd = np.std(wv10116red1+wv10116red2+wv10216red1+wv10216red2+wv10316red1+wv10316red2)
WV1032RedStd = np.std(wv10132red1+wv10132red2+wv10232red1+wv10232red2+wv10332red1+wv10332red2)
WV18RedStd = np.std(wv118red1+wv118red2+wv128red1+wv128red2+wv138red1+wv138red2)
WV116RedStd = np.std(wv1116red1+wv1116red2+wv1216red1+wv1216red2+wv1316red1+wv1316red2)
WV132RedStd = np.std(wv1132red1+wv1132red2+wv1232red1+wv1232red2+wv1332red1+wv1332red2)

# Wrangler YARN
WY1008RedMean = np.mean(wy10018red1+wy10018red2+wy10028red1+wy10028red2+wy10038red1+wy10038red2)
WY10016RedMean = np.mean(wy100116red1+wy100116red2+wy100216red1+wy100216red2+wy100316red1+wy100316red2)
WY10032RedMean = np.mean(wy100132red1+wy100132red2+wy100232red1+wy100232red2+wy100332red1+wy100332red2)
WY108RedMean = np.mean(wy1018red1+wy1018red2+wy1028red1+wy1028red2+wy1038red1+wy1038red2)
WY1016RedMean = np.mean(wy10116red1+wy10116red2+wy10216red1+wy10216red2+wy10316red1+wy10316red2)
WY1032RedMean = np.mean(wy10132red1+wy10132red2+wy10232red1+wy10232red2+wy10332red1+wy10332red2)
WY18RedMean = np.mean(wy118red1+wy118red2+wy128red1+wy128red2+wy138red1+wy138red2)
WY116RedMean = np.mean(wy1116red1+wy1116red2+wy1216red1+wy1216red2+wy1316red1+wy1316red2)
WY132RedMean = np.mean(wy1132red1+wy1132red2+wy1232red1+wy1232red2+wy1332red1+wy1332red2)

WY1008RedStd = np.std(wy10018red1+wy10018red2+wy10028red1+wy10028red2+wy10038red1+wy10038red2)
WY10016RedStd = np.std(wy100116red1+wy100116red2+wy100216red1+wy100216red2+wy100316red1+wy100316red2)
WY10032RedStd = np.std(wy100132red1+wy100132red2+wy100232red1+wy100232red2+wy100332red1+wy100332red2)
WY108RedStd = np.std(wy1018red1+wy1018red2+wy1028red1+wy1028red2+wy1038red1+wy1038red2)
WY1016RedStd = np.std(wy10116red1+wy10116red2+wy10216red1+wy10216red2+wy10316red1+wy10316red2)
WY1032RedStd = np.std(wy10132red1+wy10132red2+wy10232red1+wy10232red2+wy10332red1+wy10332red2)
WY18RedStd = np.std(wy118red1+wy118red2+wy128red1+wy128red2+wy138red1+wy138red2)
WY116RedStd = np.std(wy1116red1+wy1116red2+wy1216red1+wy1216red2+wy1316red1+wy1316red2)
WY132RedStd = np.std(wy1132red1+wy1132red2+wy1232red1+wy1232red2+wy1332red1+wy1332red2)

# %%
a=plt.figure()
plt.suptitle('K-Means Reduce Execution Time Comparison',y=1.06,fontsize=14)
plt.subplot(1,3,1)
n_groups=3
index=np.arange(n_groups)
bar_width=0.1
opacity=1.0
plt.bar(index,[SV108RedMean,SV1016RedMean,SV1032RedMean],bar_width,yerr=[SV108RedStd,SV1016RedStd,SV1032RedStd],alpha=opacity,color='darkgreen',ecolor='darkgreen',label='RP Stampede')
plt.bar(index+bar_width,[SY108RedMean,SY1016RedMean,SY1032RedMean],bar_width,yerr=[SY108RedStd,SY1016RedStd,SY1032RedStd],alpha=opacity,color='blue',ecolor='blue',label='RP-YARN Stampede')
plt.bar(index+2*bar_width,[WV108RedMean,WV1016RedMean,WV1032RedMean],bar_width,yerr=[WV108RedStd,WV1016RedStd,WV1032RedStd],alpha=opacity,color='cyan',ecolor='cyan',label='RP Wrangler')
plt.bar(index+3*bar_width,[WY108RedMean,WY1016RedMean,WY1032RedMean],bar_width,yerr=[WY108RedStd,WY1016RedStd,WY1032RedStd],alpha=opacity,color='red',ecolor='red',label='RP-YARN Wrangler')
plt.title('10,000 points'+'\n'+'5,000 clusters')
plt.xticks(index+2*bar_width,('8','16','32'))
plt.ylim(ymax=20)
plt.ylabel('Red Average Time (secs)',fontsize=14)
plt.subplot(1,3,2)
n_groups=3
index=np.arange(n_groups)
bar_width=0.1
opacity=1.0
plt.bar(index,[SV1008RedMean,SV10016RedMean,SV10032RedMean],bar_width,yerr=[SV1008RedStd,SV10016RedStd,SV10032RedStd],alpha=opacity,color='darkgreen',ecolor='darkgreen',label='RP Stampede')
plt.bar(index+bar_width,[SY1008RedMean,SY10016RedMean,SY10032RedMean],bar_width,yerr=[SY1008RedStd,SY10016RedStd,SY10032RedStd],alpha=opacity,color='blue',ecolor='blue',label='RP-YARN Stampede')
plt.bar(index+2*bar_width,[WV1008RedMean,WV10016RedMean,WV10032RedMean],bar_width,yerr=[WV1008RedStd,WV10016RedStd,WV10032RedStd],alpha=opacity,color='cyan',ecolor='cyan',label='RP Wrangler')
plt.bar(index+3*bar_width,[WY1008RedMean,WY10016RedMean,WY10032RedMean],bar_width,yerr=[WY1008RedStd,WY10016RedStd,WY10032RedStd],alpha=opacity,color='red',ecolor='red',label='RP-YARN Wrangler')
plt.title('100,000 points'+'\n'+'500 clusters')
plt.xticks(index+2*bar_width,('8','16','32'))
plt.ylim(ymax=20)
plt.subplot(1,3,3)
n_groups=3
index=np.arange(n_groups)
bar_width=0.1
opacity=1.0
b1 = plt.bar(index,[SV18RedMean,SV116RedMean,SV132RedMean],bar_width,yerr=[SV18RedStd,SV116RedStd,SV132RedStd],alpha=opacity,color='darkgreen',ecolor='darkgreen',label='RP Stampede')
b2 = plt.bar(index+bar_width,[SY18RedMean,SY116RedMean,SY132RedMean],bar_width,yerr=[SY18RedStd,SY116RedStd,SY132RedStd],alpha=opacity,color='blue',ecolor='blue',label='RP-YARN Stampede')
b3 = plt.bar(index+2*bar_width,[WV18RedMean,WV116RedMean,WV132RedMean],bar_width,yerr=[WV18RedStd,WV116RedStd,WV132RedStd],alpha=opacity,color='cyan',ecolor='cyan',label='RP Wrangler')
b4 = plt.bar(index+3*bar_width,[WY18RedMean,WY116RedMean,WY132RedMean],bar_width,yerr=[WY18RedStd,WY116RedStd,WY132RedStd],alpha=opacity,color='red',ecolor='red',label='RP-YARN Wrangler')
plt.xticks(index+2*bar_width,('8','16','32'))
plt.title('1,000,000 points'+'\n'+'50 clusters')
plt.ylim(ymax=30)
lgd=plt.figlegend((b1,b2,b3,b4),('RP on Stampede','RP-YARN on Stampede','RP on Wrangler','RP-YARN on Wrangler'),
              loc='lower center',mode="expand",ncol=3,fontsize=10,borderaxespad=0.11)
a.text(0.45,0.16,'Number of Tasks',ha='center',fontsize=14)
a.subplots_adjust(bottom=0.25)
a.savefig('kmeans-redtime-comp.pdf',dpi=800,bbox_extra_artists=(lgd,))

# %%
# Stampede Vanilla
SVRedRead1008  =np.mean([sv10018det['AverRedRead'],sv10028det['AverRedRead'],sv10038det['AverRedRead']])
SVRedRead10016 =np.mean([sv100116det['AverRedRead'],sv100216det['AverRedRead'],sv100316det['AverRedRead']])
SVRedRead10032 =np.mean([sv100132det['AverRedRead'],sv100232det['AverRedRead'],sv100332det['AverRedRead']])
SVRedRead108   =np.mean([sv1018det['AverRedRead'],sv1028det['AverRedRead'],sv1038det['AverRedRead']])
SVRedRead1016  =np.mean([sv10116det['AverRedRead'],sv10216det['AverRedRead'],sv10316det['AverRedRead']])
SVRedRead1032  =np.mean([sv10132det['AverRedRead'],sv10232det['AverRedRead'],sv10332det['AverRedRead']])
SVRedRead18    =np.mean([sv118det['AverRedRead'],sv128det['AverRedRead'],sv138det['AverRedRead']])
SVRedRead116   =np.mean([sv1116det['AverRedRead'],sv1216det['AverRedRead'],sv1316det['AverRedRead']])
SVRedRead132   =np.mean([sv1132det['AverRedRead'],sv1232det['AverRedRead'],sv1332det['AverRedRead']])
SVRedExec1008  =np.mean([sv10018det['AverRedExec'],sv10028det['AverRedExec'],sv10038det['AverRedExec']])
SVRedExec10016 =np.mean([sv100116det['AverRedExec'],sv100216det['AverRedExec'],sv100316det['AverRedExec']])
SVRedExec10032 =np.mean([sv100132det['AverRedExec'],sv100232det['AverRedExec'],sv100332det['AverRedExec']])
SVRedExec108   =np.mean([sv1018det['AverRedExec'],sv1028det['AverRedExec'],sv1038det['AverRedExec']])
SVRedExec1016  =np.mean([sv10116det['AverRedExec'],sv10216det['AverRedExec'],sv10316det['AverRedExec']])
SVRedExec1032  =np.mean([sv10132det['AverRedExec'],sv10232det['AverRedExec'],sv10332det['AverRedExec']])
SVRedExec18    =np.mean([sv118det['AverRedExec'],sv128det['AverRedExec'],sv138det['AverRedExec']])
SVRedExec116   =np.mean([sv1116det['AverRedExec'],sv1216det['AverRedExec'],sv1316det['AverRedExec']])
SVRedExec132   =np.mean([sv1132det['AverRedExec'],sv1232det['AverRedExec'],sv1332det['AverRedExec']])
SVRedWrit1008  =np.mean([sv10018det['AverRedWrite'],sv10028det['AverRedWrite'],sv10038det['AverRedWrite']])
SVRedWrit10016 =np.mean([sv100116det['AverRedWrite'],sv100216det['AverRedWrite'],sv100316det['AverRedWrite']])
SVRedWrit10032 =np.mean([sv100132det['AverRedWrite'],sv100232det['AverRedWrite'],sv100332det['AverRedWrite']])
SVRedWrit108   =np.mean([sv1018det['AverRedWrite'],sv1028det['AverRedWrite'],sv1038det['AverRedWrite']])
SVRedWrit1016  =np.mean([sv10116det['AverRedWrite'],sv10216det['AverRedWrite'],sv10316det['AverRedWrite']])
SVRedWrit1032  =np.mean([sv10132det['AverRedWrite'],sv10232det['AverRedWrite'],sv10332det['AverRedWrite']])
SVRedWrit18    =np.mean([sv118det['AverRedWrite'],sv128det['AverRedWrite'],sv138det['AverRedWrite']])
SVRedWrit116   =np.mean([sv1116det['AverRedWrite'],sv1216det['AverRedWrite'],sv1316det['AverRedWrite']])
SVRedWrit132   =np.mean([sv1132det['AverRedWrite'],sv1232det['AverRedWrite'],sv1332det['AverRedWrite']])

# %%
print sv10116det['AverRedWrite'],sv10216det['AverRedWrite'],sv10316det['AverRedWrite']
# Out:
# 3.122604 3.1493015 3.4011635

# %%
# Wrangler Vanilla
WVRedRead1008  =np.mean([wv10018det['AverRedRead'],wv10028det['AverRedRead'],wv10038det['AverRedRead']])
WVRedRead10016 =np.mean([wv100116det['AverRedRead'],wv100216det['AverRedRead'],wv100316det['AverRedRead']])
WVRedRead10032 =np.mean([wv100132det['AverRedRead'],wv100232det['AverRedRead'],wv100332det['AverRedRead']])
WVRedRead108   =np.mean([wv1018det['AverRedRead'],wv1028det['AverRedRead'],wv1038det['AverRedRead']])
WVRedRead1016  =np.mean([wv10116det['AverRedRead'],wv10216det['AverRedRead'],wv10316det['AverRedRead']])
WVRedRead1032  =np.mean([wv10132det['AverRedRead'],wv10232det['AverRedRead'],wv10332det['AverRedRead']])
WVRedRead18    =np.mean([wv118det['AverRedRead'],wv128det['AverRedRead'],wv138det['AverRedRead']])
WVRedRead116   =np.mean([wv1116det['AverRedRead'],wv1216det['AverRedRead'],wv1316det['AverRedRead']])
WVRedRead132   =np.mean([wv1132det['AverRedRead'],wv1232det['AverRedRead'],wv1332det['AverRedRead']])
WVRedExec1008  =np.mean([wv10018det['AverRedExec'],wv10028det['AverRedExec'],wv10038det['AverRedExec']])
WVRedExec10016 =np.mean([wv100116det['AverRedExec'],wv100216det['AverRedExec'],wv100316det['AverRedExec']])
WVRedExec10032 =np.mean([wv100132det['AverRedExec'],wv100232det['AverRedExec'],wv100332det['AverRedExec']])
WVRedExec108   =np.mean([wv1018det['AverRedExec'],wv1028det['AverRedExec'],wv1038det['AverRedExec']])
WVRedExec1016  =np.mean([wv10116det['AverRedExec'],wv10216det['AverRedExec'],wv10316det['AverRedExec']])
WVRedExec1032  =np.mean([wv10132det['AverRedExec'],wv10232det['AverRedExec'],wv10332det['AverRedExec']])
WVRedExec18    =np.mean([wv118det['AverRedExec'],wv128det['AverRedExec'],wv138det['AverRedExec']])
WVRedExec116   =np.mean([wv1116det['AverRedExec'],wv1216det['AverRedExec'],wv1316det['AverRedExec']])
WVRedExec132   =np.mean([wv1132det['AverRedExec'],wv1232det['AverRedExec'],wv1332det['AverRedExec']])
WVRedWrit1008  =np.mean([wv10018det['AverRedWrite'],wv10028det['AverRedWrite'],wv10038det['AverRedWrite']])
WVRedWrit10016 =np.mean([wv100116det['AverRedWrite'],wv100216det['AverRedWrite'],wv100316det['AverRedWrite']])
WVRedWrit10032 =np.mean([wv100132det['AverRedWrite'],wv100232det['AverRedWrite'],wv100332det['AverRedWrite']])
WVRedWrit108   =np.mean([wv1018det['AverRedWrite'],wv1028det['AverRedWrite'],wv1038det['AverRedWrite']])
WVRedWrit1016  =np.mean([wv10116det['AverRedWrite'],wv10216det['AverRedWrite'],wv10316det['AverRedWrite']])
WVRedWrit1032  =np.mean([wv10132det['AverRedWrite'],wv10232det['AverRedWrite'],wv10332det['AverRedWrite']])
WVRedWrit18    =np.mean([wv118det['AverRedWrite'],wv128det['AverRedWrite'],wv138det['AverRedWrite']])
WVRedWrit116   =np.mean([wv1116det['AverRedWrite'],wv1216det['AverRedWrite'],wv1316det['AverRedWrite']])
WVRedWrit132   =np.mean([wv1132det['AverRedWrite'],wv1232det['AverRedWrite'],wv1332det['AverRedWrite']])

# %%
# Wrangler YARN
WYRedRead1008  =np.mean([wy10018det['AverRedRead'],wy10028det['AverRedRead'],wy10038det['AverRedRead']])
WYRedRead10016 =np.mean([wy100116det['AverRedRead'],wy100216det['AverRedRead'],wy100316det['AverRedRead']])
WYRedRead10032 =np.mean([wy100132det['AverRedRead'],wy100232det['AverRedRead'],wy100332det['AverRedRead']])
WYRedRead108   =np.mean([wy1018det['AverRedRead'],wy1028det['AverRedRead'],wy1038det['AverRedRead']])
WYRedRead1016  =np.mean([wy10116det['AverRedRead'],wy10216det['AverRedRead'],wy10316det['AverRedRead']])
WYRedRead1032  =np.mean([wy10132det['AverRedRead'],wy10232det['AverRedRead'],wy10332det['AverRedRead']])
WYRedRead18    =np.mean([wy118det['AverRedRead'],wy128det['AverRedRead'],wy138det['AverRedRead']])
WYRedRead116   =np.mean([wy1116det['AverRedRead'],wy1216det['AverRedRead'],wy1316det['AverRedRead']])
WYRedRead132   =np.mean([wy1132det['AverRedRead'],wy1232det['AverRedRead'],wy1332det['AverRedRead']])
WYRedExec1008  =np.mean([wy10018det['AverRedExec'],wy10028det['AverRedExec'],wy10038det['AverRedExec']])
WYRedExec10016 =np.mean([wy100116det['AverRedExec'],wy100216det['AverRedExec'],wy100316det['AverRedExec']])
WYRedExec10032 =np.mean([wy100132det['AverRedExec'],wy100232det['AverRedExec'],wy100332det['AverRedExec']])
WYRedExec108   =np.mean([wy1018det['AverRedExec'],wy1028det['AverRedExec'],wy1038det['AverRedExec']])
WYRedExec1016  =np.mean([wy10116det['AverRedExec'],wy10216det['AverRedExec'],wy10316det['AverRedExec']])
WYRedExec1032  =np.mean([wy10132det['AverRedExec'],wy10232det['AverRedExec'],wy10332det['AverRedExec']])
WYRedExec18    =np.mean([wy118det['AverRedExec'],wy128det['AverRedExec'],wy138det['AverRedExec']])
WYRedExec116   =np.mean([wy1116det['AverRedExec'],wy1216det['AverRedExec'],wy1316det['AverRedExec']])
WYRedExec132   =np.mean([wy1132det['AverRedExec'],wy1232det['AverRedExec'],wy1332det['AverRedExec']])
WYRedWrit1008  =np.mean([wy10018det['AverRedWrite'],wy10028det['AverRedWrite'],wy10038det['AverRedWrite']])
WYRedWrit10016 =np.mean([wy100116det['AverRedWrite'],wy100216det['AverRedWrite'],wy100316det['AverRedWrite']])
WYRedWrit10032 =np.mean([wy100132det['AverRedWrite'],wy100232det['AverRedWrite'],wy100332det['AverRedWrite']])
WYRedWrit108   =np.mean([wy1018det['AverRedWrite'],wy1028det['AverRedWrite'],wy1038det['AverRedWrite']])
WYRedWrit1016  =np.mean([wy10116det['AverRedWrite'],wy10216det['AverRedWrite'],wy10316det['AverRedWrite']])
WYRedWrit1032  =np.mean([wy10132det['AverRedWrite'],wy10232det['AverRedWrite'],wy10332det['AverRedWrite']])
WYRedWrit18    =np.mean([wy118det['AverRedWrite'],wy128det['AverRedWrite'],wy138det['AverRedWrite']])
WYRedWrit116   =np.mean([wy1116det['AverRedWrite'],wy1216det['AverRedWrite'],wy1316det['AverRedWrite']])
WYRedWrit132   =np.mean([wy1132det['AverRedWrite'],wy1232det['AverRedWrite'],wy1332det['AverRedWrite']])

# %%
a=plt.figure()
plt.suptitle('K-Means Reduce Time Detailed',y=1.06,fontsize=14)
plt.subplot(1,3,1)
n_groups=3
index=np.arange(n_groups)
bar_width=0.1
opacity=1.0

plt.bar(index,[SVRedWrit108,SVRedWrit1016,SVRedWrit1032],bar_width,yerr=[0,0,0],alpha=opacity,color='lightgreen',label='RP Stampede')
plt.bar(index,[SVRedExec108,SVRedExec1016,SVRedExec1032],bar_width,yerr=[0,0,0],alpha=opacity,color='green',label='RP Stampede')
plt.bar(index,[SVRedRead108,SVRedRead1016,SVRedRead1032],bar_width,yerr=[0,0,0],alpha=opacity,color='lightgreen',label='RP Stampede')
plt.bar(index+bar_width,[0,0,0],bar_width,yerr=[0,0,0],alpha=opacity,color='blue',label='RP-YARN Stampede')
plt.bar(index+bar_width,[0,0,0],bar_width,yerr=[0,0,0],alpha=opacity,color='cyan',label='RP-YARN Stampede')
plt.bar(index+bar_width,[0,0,0],bar_width,yerr=[0,0,0],alpha=opacity,color='blue',label='RP-YARN Stampede')
plt.bar(index+2*bar_width,[WVRedWrit108,WVRedWrit1016,WVRedWrit1032],bar_width,yerr=[0,0,0],alpha=opacity,color='yellow',label='RP Wrangler')
plt.bar(index+2*bar_width,[WVRedExec108,WVRedExec1016,WVRedExec1032],bar_width,yerr=[0,0,0],alpha=opacity,color='orange',label='RP Wrangler')
plt.bar(index+2*bar_width,[WVRedRead108,WVRedRead1016,WVRedRead1032],bar_width,yerr=[0,0,0],alpha=opacity,color='yellow',label='RP Wrangler')
plt.bar(index+3*bar_width,[WYRedWrit108,WYRedWrit1016,WYRedWrit1032],bar_width,yerr=[0,0,0],alpha=opacity,color='darkred',label='RP-YARN Wrangler')
plt.bar(index+3*bar_width,[WYRedExec108,WYRedExec1016,WYRedExec1032],bar_width,yerr=[0,0,0],alpha=opacity,color='red',label='RP-YARN Wrangler')
plt.bar(index+3*bar_width,[WYRedRead108,WYRedRead1016,WYRedRead1032],bar_width,yerr=[0,0,0],alpha=opacity,color='darkred',label='RP-YARN Wrangler')

plt.title('10,000 points'+'\n'+'5,000 clusters')
plt.xticks(index+3*bar_width,('8','16','32'))
plt.ylim(ymax=5)
plt.ylabel('Time (secs)',fontsize=14)
plt.subplot(1,3,2)
n_groups=3
index=np.arange(n_groups)
bar_width=0.1
opacity=1.0

plt.bar(index,[SVRedWrit1008,SVRedWrit10016,SVRedWrit10032],bar_width,yerr=[0,0,0],alpha=opacity,color='lightgreen',label='RP Stampede')
plt.bar(index,[SVRedExec1008,SVRedExec10016,SVRedExec10032],bar_width,yerr=[0,0,0],alpha=opacity,color='green',label='RP Stampede')
plt.bar(index,[SVRedRead1008,SVRedRead10016,SVRedRead10032],bar_width,yerr=[0,0,0],alpha=opacity,color='lightgreen',label='RP Stampede')
plt.bar(index+bar_width,[0,0,0],bar_width,yerr=[0,0,0],alpha=opacity,color='blue',label='RP-YARN Stampede')
plt.bar(index+bar_width,[0,0,0],bar_width,yerr=[0,0,0],alpha=opacity,color='cyan',label='RP-YARN Stampede')
plt.bar(index+bar_width,[0,0,0],bar_width,yerr=[0,0,0],alpha=opacity,color='blue',label='RP-YARN Stampede')
plt.bar(index+2*bar_width,[WVRedWrit1008,WVRedWrit10016,WVRedWrit10032],bar_width,yerr=[0,0,0],alpha=opacity,color='yellow',label='RP Wrangler')
plt.bar(index+2*bar_width,[WVRedExec1008,WVRedExec10016,WVRedExec10032],bar_width,yerr=[0,0,0],alpha=opacity,color='orange',label='RP Wrangler')
plt.bar(index+2*bar_width,[WVRedRead1008,WVRedRead10016,WVRedRead10032],bar_width,yerr=[0,0,0],alpha=opacity,color='yellow',label='RP Wrangler')
plt.bar(index+3*bar_width,[WYRedWrit1008,WYRedWrit10016,WYRedWrit10032],bar_width,yerr=[0,0,0],alpha=opacity,color='darkred',label='RP-YARN Wrangler')
plt.bar(index+3*bar_width,[WYRedExec1008,WYRedExec10016,WYRedExec10032],bar_width,yerr=[0,0,0],alpha=opacity,color='red',label='RP-YARN Wrangler')
plt.bar(index+3*bar_width,[WYRedRead1008,WYRedRead10016,WYRedRead10032],bar_width,yerr=[0,0,0],alpha=opacity,color='darkred',label='RP-YARN Wrangler')

plt.title('100,000 points'+'\n'+'500 clusters')
plt.xticks(index+3*bar_width,('8','16','32'))
plt.ylim(ymax=1)

plt.subplot(1,3,3)
n_groups=3
index=np.arange(n_groups)
bar_width=0.1
opacity=1.0

b1 = plt.bar(index,[SVRedWrit18,SVRedWrit116,SVRedWrit132],bar_width,yerr=[0,0,0],alpha=opacity,color='lightgreen',label='RP Stampede')
plt.bar(index,[SVRedExec18,SVRedExec116,SVRedExec132],bar_width,yerr=[0,0,0],alpha=opacity,color='green',label='RP Stampede')
plt.bar(index,[SVRedRead18,SVRedRead116,SVRedRead132],bar_width,yerr=[0,0,0],alpha=opacity,color='lightgreen',label='RP Stampede')
b2 = plt.bar(index+bar_width,[0,0,0],bar_width,yerr=[0,0,0],alpha=opacity,color='blue',label='RP-YARN Stampede')
plt.bar(index+bar_width,[0,0,0],bar_width,yerr=[0,0,0],alpha=opacity,color='cyan',label='RP-YARN Stampede')
plt.bar(index+bar_width,[0,0,0],bar_width,yerr=[0,0,0],alpha=opacity,color='blue',label='RP-YARN Stampede')
b3 = plt.bar(index+2*bar_width,[WVRedWrit18,WVRedWrit116,WVRedWrit132],bar_width,yerr=[0,0,0],alpha=opacity,color='yellow',label='RP Wrangler')
plt.bar(index+2*bar_width,[WVRedExec18,WVRedExec116,WVRedExec132],bar_width,yerr=[0,0,0],alpha=opacity,color='orange',label='RP Wrangler')
plt.bar(index+2*bar_width,[WVRedRead18,WVRedRead116,WVRedRead132],bar_width,yerr=[0,0,0],alpha=opacity,color='yellow',label='RP Wrangler')
b4 = plt.bar(index+3*bar_width,[WYRedWrit18,WYRedWrit116,WYRedWrit132],bar_width,yerr=[0,0,0],alpha=opacity,color='darkred',label='RP-YARN Wrangler')
plt.bar(index+3*bar_width,[WYRedExec18,WYRedExec116,WYRedExec132],bar_width,yerr=[0,0,0],alpha=opacity,color='red',label='RP-YARN Wrangler')
plt.bar(index+3*bar_width,[WYRedRead18,WYRedRead116,WYRedRead132],bar_width,yerr=[0,0,0],alpha=opacity,color='darkred',label='RP-YARN Wrangler')

plt.title('1,000,000 points'+'\n'+'50 clusters')
plt.xticks(index+3*bar_width,('8','16','32'))
plt.ylim(ymax=1)

lgd=plt.figlegend((b1,b2,b3,b4),('RP on Stampede','RP-YARN on Stampede','RP on Wrangler','RP-YARN on Wrangler'),
              loc='lower center',mode="expand",ncol=3,fontsize=10,borderaxespad=0.11)
a.text(0.45,0.16,'Number of Tasks',ha='center',fontsize=14)
a.subplots_adjust(bottom=0.25)
a.savefig('kmeans-red-comp-detailed.pdf',dpi=800,bbox_extra_artists=(lgd,))

# %%
print WYRedWrit132,WYRedExec132,WYRedRead132
print WYRedWrit10032,WYRedExec10032,WYRedRead10032
# Out:
# 0.829491833333 0.824578 0.671676833333
# 0.829491833333 0.824578 0.671676833333

# %%
# Stampede Vanilla
SVMapRead1008  =np.mean([sv10018det['AverMapRead'],sv10028det['AverMapRead'],sv10038det['AverMapRead']])
SVMapRead10016 =np.mean([sv100116det['AverMapRead'],sv100216det['AverMapRead'],sv100316det['AverMapRead']])
SVMapRead10032 =np.mean([sv100132det['AverMapRead'],sv100232det['AverMapRead'],sv100332det['AverMapRead']])
SVMapRead108   =np.mean([sv1018det['AverMapRead'],sv1028det['AverMapRead'],sv1038det['AverMapRead']])
SVMapRead1016  =np.mean([sv10116det['AverMapRead'],sv10216det['AverMapRead'],sv10316det['AverMapRead']])
SVMapRead1032  =np.mean([sv10132det['AverMapRead'],sv10232det['AverMapRead'],sv10332det['AverMapRead']])
SVMapRead18    =np.mean([sv118det['AverMapRead'],sv128det['AverMapRead'],sv138det['AverMapRead']])
SVMapRead116   =np.mean([sv1116det['AverMapRead'],sv1216det['AverMapRead'],sv1316det['AverMapRead']])
SVMapRead132   =np.mean([sv1132det['AverMapRead'],sv1232det['AverMapRead'],sv1332det['AverMapRead']])
SVMapExec1008  =np.mean([sv10018det['AverMapExec'],sv10028det['AverMapExec'],sv10038det['AverMapExec']])
SVMapExec10016 =np.mean([sv100116det['AverMapExec'],sv100216det['AverMapExec'],sv100316det['AverMapExec']])
SVMapExec10032 =np.mean([sv100132det['AverMapExec'],sv100232det['AverMapExec'],sv100332det['AverMapExec']])
SVMapExec108   =np.mean([sv1018det['AverMapExec'],sv1028det['AverMapExec'],sv1038det['AverMapExec']])
SVMapExec1016  =np.mean([sv10116det['AverMapExec'],sv10216det['AverMapExec'],sv10316det['AverMapExec']])
SVMapExec1032  =np.mean([sv10132det['AverMapExec'],sv10232det['AverMapExec'],sv10332det['AverMapExec']])
SVMapExec18    =np.mean([sv118det['AverMapExec'],sv128det['AverMapExec'],sv138det['AverMapExec']])
SVMapExec116   =np.mean([sv1116det['AverMapExec'],sv1216det['AverMapExec'],sv1316det['AverMapExec']])
SVMapExec132   =np.mean([sv1132det['AverMapExec'],sv1232det['AverMapExec'],sv1332det['AverMapExec']])
SVMapWrit1008  =np.mean([sv10018det['AverMapWrite'],sv10028det['AverMapWrite'],sv10038det['AverMapWrite']])
SVMapWrit10016 =np.mean([sv100116det['AverMapWrite'],sv100216det['AverMapWrite'],sv100316det['AverMapWrite']])
SVMapWrit10032 =np.mean([sv100132det['AverMapWrite'],sv100232det['AverMapWrite'],sv100332det['AverMapWrite']])
SVMapWrit108   =np.mean([sv1018det['AverMapWrite'],sv1028det['AverMapWrite'],sv1038det['AverMapWrite']])
SVMapWrit1016  =np.mean([sv10116det['AverMapWrite'],sv10216det['AverMapWrite'],sv10316det['AverMapWrite']])
SVMapWrit1032  =np.mean([sv10132det['AverMapWrite'],sv10232det['AverMapWrite'],sv10332det['AverMapWrite']])
SVMapWrit18    =np.mean([sv118det['AverMapWrite'],sv128det['AverMapWrite'],sv138det['AverMapWrite']])
SVMapWrit116   =np.mean([sv1116det['AverMapWrite'],sv1216det['AverMapWrite'],sv1316det['AverMapWrite']])
SVMapWrit132   =np.mean([sv1132det['AverMapWrite'],sv1232det['AverMapWrite'],sv1332det['AverMapWrite']])

# %%
# Wrangler Vanilla
WVMapRead1008  =np.mean([wv10018det['AverMapRead'],wv10028det['AverMapRead'],wv10038det['AverMapRead']])
WVMapRead10016 =np.mean([wv100116det['AverMapRead'],wv100216det['AverMapRead'],wv100316det['AverMapRead']])
WVMapRead10032 =np.mean([wv100132det['AverMapRead'],wv100232det['AverMapRead'],wv100332det['AverMapRead']])
WVMapRead108   =np.mean([wv1018det['AverMapRead'],wv1028det['AverMapRead'],wv1038det['AverMapRead']])
WVMapRead1016  =np.mean([wv10116det['AverMapRead'],wv10216det['AverMapRead'],wv10316det['AverMapRead']])
WVMapRead1032  =np.mean([wv10132det['AverMapRead'],wv10232det['AverMapRead'],wv10332det['AverMapRead']])
WVMapRead18    =np.mean([wv118det['AverMapRead'],wv128det['AverMapRead'],wv138det['AverMapRead']])
WVMapRead116   =np.mean([wv1116det['AverMapRead'],wv1216det['AverMapRead'],wv1316det['AverMapRead']])
WVMapRead132   =np.mean([wv1132det['AverMapRead'],wv1232det['AverMapRead'],wv1332det['AverMapRead']])
WVMapExec1008  =np.mean([wv10018det['AverMapExec'],wv10028det['AverMapExec'],wv10038det['AverMapExec']])
WVMapExec10016 =np.mean([wv100116det['AverMapExec'],wv100216det['AverMapExec'],wv100316det['AverMapExec']])
WVMapExec10032 =np.mean([wv100132det['AverMapExec'],wv100232det['AverMapExec'],wv100332det['AverMapExec']])
WVMapExec108   =np.mean([wv1018det['AverMapExec'],wv1028det['AverMapExec'],wv1038det['AverMapExec']])
WVMapExec1016  =np.mean([wv10116det['AverMapExec'],wv10216det['AverMapExec'],wv10316det['AverMapExec']])
WVMapExec1032  =np.mean([wv10132det['AverMapExec'],wv10232det['AverMapExec'],wv10332det['AverMapExec']])
WVMapExec18    =np.mean([wv118det['AverMapExec'],wv128det['AverMapExec'],wv138det['AverMapExec']])
WVMapExec116   =np.mean([wv1116det['AverMapExec'],wv1216det['AverMapExec'],wv1316det['AverMapExec']])
WVMapExec132   =np.mean([wv1132det['AverMapExec'],wv1232det['AverMapExec'],wv1332det['AverMapExec']])
WVMapWrit1008  =np.mean([wv10018det['AverMapWrite'],wv10028det['AverMapWrite'],wv10038det['AverMapWrite']])
WVMapWrit10016 =np.mean([wv100116det['AverMapWrite'],wv100216det['AverMapWrite'],wv100316det['AverMapWrite']])
WVMapWrit10032 =np.mean([wv100132det['AverMapWrite'],wv100232det['AverMapWrite'],wv100332det['AverMapWrite']])
WVMapWrit108   =np.mean([wv1018det['AverMapWrite'],wv1028det['AverMapWrite'],wv1038det['AverMapWrite']])
WVMapWrit1016  =np.mean([wv10116det['AverMapWrite'],wv10216det['AverMapWrite'],wv10316det['AverMapWrite']])
WVMapWrit1032  =np.mean([wv10132det['AverMapWrite'],wv10232det['AverMapWrite'],wv10332det['AverMapWrite']])
WVMapWrit18    =np.mean([wv118det['AverMapWrite'],wv128det['AverMapWrite'],wv138det['AverMapWrite']])
WVMapWrit116   =np.mean([wv1116det['AverMapWrite'],wv1216det['AverMapWrite'],wv1316det['AverMapWrite']])
WVMapWrit132   =np.mean([wv1132det['AverMapWrite'],wv1232det['AverMapWrite'],wv1332det['AverMapWrite']])

# %%
# Wrangler YARN
WYMapRead1008  =np.mean([wy10018det['AverMapRead'],wy10028det['AverMapRead'],wy10038det['AverMapRead']])
WYMapRead10016 =np.mean([wy100116det['AverMapRead'],wy100216det['AverMapRead'],wy100316det['AverMapRead']])
WYMapRead10032 =np.mean([wy100132det['AverMapRead'],wy100232det['AverMapRead'],wy100332det['AverMapRead']])
WYMapRead108   =np.mean([wy1018det['AverMapRead'],wy1028det['AverMapRead'],wy1038det['AverMapRead']])
WYMapRead1016  =np.mean([wy10116det['AverMapRead'],wy10216det['AverMapRead'],wy10316det['AverMapRead']])
WYMapRead1032  =np.mean([wy10132det['AverMapRead'],wy10232det['AverMapRead'],wy10332det['AverMapRead']])
WYMapRead18    =np.mean([wy118det['AverMapRead'],wy128det['AverMapRead'],wy138det['AverMapRead']])
WYMapRead116   =np.mean([wy1116det['AverMapRead'],wy1216det['AverMapRead'],wy1316det['AverMapRead']])
WYMapRead132   =np.mean([wy1132det['AverMapRead'],wy1232det['AverMapRead'],wy1332det['AverMapRead']])
WYMapExec1008  =np.mean([wy10018det['AverMapExec'],wy10028det['AverMapExec'],wy10038det['AverMapExec']])
WYMapExec10016 =np.mean([wy100116det['AverMapExec'],wy100216det['AverMapExec'],wy100316det['AverMapExec']])
WYMapExec10032 =np.mean([wy100132det['AverMapExec'],wy100232det['AverMapExec'],wy100332det['AverMapExec']])
WYMapExec108   =np.mean([wy1018det['AverMapExec'],wy1028det['AverMapExec'],wy1038det['AverMapExec']])
WYMapExec1016  =np.mean([wy10116det['AverMapExec'],wy10216det['AverMapExec'],wy10316det['AverMapExec']])
WYMapExec1032  =np.mean([wy10132det['AverMapExec'],wy10232det['AverMapExec'],wy10332det['AverMapExec']])
WYMapExec18    =np.mean([wy118det['AverMapExec'],wy128det['AverMapExec'],wy138det['AverMapExec']])
WYMapExec116   =np.mean([wy1116det['AverMapExec'],wy1216det['AverMapExec'],wy1316det['AverMapExec']])
WYMapExec132   =np.mean([wy1132det['AverMapExec'],wy1232det['AverMapExec'],wy1332det['AverMapExec']])
WYMapWrit1008  =np.mean([wy10018det['AverMapWrite'],wy10028det['AverMapWrite'],wy10038det['AverMapWrite']])
WYMapWrit10016 =np.mean([wy100116det['AverMapWrite'],wy100216det['AverMapWrite'],wy100316det['AverMapWrite']])
WYMapWrit10032 =np.mean([wy100132det['AverMapWrite'],wy100232det['AverMapWrite'],wy100332det['AverMapWrite']])
WYMapWrit108   =np.mean([wy1018det['AverMapWrite'],wy1028det['AverMapWrite'],wy1038det['AverMapWrite']])
WYMapWrit1016  =np.mean([wy10116det['AverMapWrite'],wy10216det['AverMapWrite'],wy10316det['AverMapWrite']])
WYMapWrit1032  =np.mean([wy10132det['AverMapWrite'],wy10232det['AverMapWrite'],wy10332det['AverMapWrite']])
WYMapWrit18    =np.mean([wy118det['AverMapWrite'],wy128det['AverMapWrite'],wy138det['AverMapWrite']])
WYMapWrit116   =np.mean([wy1116det['AverMapWrite'],wy1216det['AverMapWrite'],wy1316det['AverMapWrite']])
WYMapWrit132   =np.mean([wy1132det['AverMapWrite'],wy1232det['AverMapWrite'],wy1332det['AverMapWrite']])

# %%
a=plt.figure()
plt.suptitle('K-Means Map Time Detailed',y=1.06,fontsize=14)
plt.subplot(1,3,1)
n_groups=3
index=np.arange(n_groups)
bar_width=0.1
opacity=1.0

plt.bar(index,[SVMapWrit108,SVMapWrit1016,SVMapWrit1032],bar_width,yerr=[0,0,0],alpha=opacity,color='lightgreen',label='RP Stampede')
plt.bar(index,[SVMapExec108,SVMapExec1016,SVMapExec1032],bar_width,yerr=[0,0,0],alpha=opacity,color='green',label='RP Stampede')
plt.bar(index,[SVMapRead108,SVMapRead1016,SVMapRead1032],bar_width,yerr=[0,0,0],alpha=opacity,color='lightgreen',label='RP Stampede')
plt.bar(index+bar_width,[0,0,0],bar_width,yerr=[0,0,0],alpha=opacity,color='blue',label='RP-YARN Stampede')
plt.bar(index+bar_width,[0,0,0],bar_width,yerr=[0,0,0],alpha=opacity,color='cyan',label='RP-YARN Stampede')
plt.bar(index+bar_width,[0,0,0],bar_width,yerr=[0,0,0],alpha=opacity,color='blue',label='RP-YARN Stampede')
plt.bar(index+2*bar_width,[WVMapWrit108,WVMapWrit1016,WVMapWrit1032],bar_width,yerr=[0,0,0],alpha=opacity,color='yellow',label='RP Wrangler')
plt.bar(index+2*bar_width,[WVMapExec108,WVMapExec1016,WVMapExec1032],bar_width,yerr=[0,0,0],alpha=opacity,color='orange',label='RP Wrangler')
plt.bar(index+2*bar_width,[WVMapRead108,WVMapRead1016,WVMapRead1032],bar_width,yerr=[0,0,0],alpha=opacity,color='yellow',label='RP Wrangler')
plt.bar(index+3*bar_width,[WYMapWrit108,WYMapWrit1016,WYMapWrit1032],bar_width,yerr=[0,0,0],alpha=opacity,color='darkred',label='RP-YARN Wrangler')
plt.bar(index+3*bar_width,[WYMapExec108,WYMapExec1016,WYMapExec1032],bar_width,yerr=[0,0,0],alpha=opacity,color='red',label='RP-YARN Wrangler')
plt.bar(index+3*bar_width,[WYMapRead108,WYMapRead1016,WYMapRead1032],bar_width,yerr=[0,0,0],alpha=opacity,color='darkred',label='RP-YARN Wrangler')

plt.title('10,000 points'+'\n'+'5,000 clusters')
plt.xticks(index+3*bar_width,('8','16','32'))
plt.ylim(ymax=1100)
plt.ylabel('Time (secs)',fontsize=14)
plt.subplot(1,3,2)
n_groups=3
index=np.arange(n_groups)
bar_width=0.1
opacity=1.0

plt.bar(index,[SVMapWrit1008,SVMapWrit10016,SVMapWrit10032],bar_width,yerr=[0,0,0],alpha=opacity,color='lightgreen',label='RP Stampede')
plt.bar(index,[SVMapExec1008,SVMapExec10016,SVMapExec10032],bar_width,yerr=[0,0,0],alpha=opacity,color='green',label='RP Stampede')
plt.bar(index,[SVMapRead1008,SVMapRead10016,SVMapRead10032],bar_width,yerr=[0,0,0],alpha=opacity,color='lightgreen',label='RP Stampede')
plt.bar(index+bar_width,[0,0,0],bar_width,yerr=[0,0,0],alpha=opacity,color='blue',label='RP-YARN Stampede')
plt.bar(index+bar_width,[0,0,0],bar_width,yerr=[0,0,0],alpha=opacity,color='cyan',label='RP-YARN Stampede')
plt.bar(index+bar_width,[0,0,0],bar_width,yerr=[0,0,0],alpha=opacity,color='blue',label='RP-YARN Stampede')
plt.bar(index+2*bar_width,[WVMapWrit1008,WVMapWrit10016,WVMapWrit10032],bar_width,yerr=[0,0,0],alpha=opacity,color='yellow',label='RP Wrangler')
plt.bar(index+2*bar_width,[WVMapExec1008,WVMapExec10016,WVMapExec10032],bar_width,yerr=[0,0,0],alpha=opacity,color='orange',label='RP Wrangler')
plt.bar(index+2*bar_width,[WVMapRead1008,WVMapRead10016,WVMapRead10032],bar_width,yerr=[0,0,0],alpha=opacity,color='yellow',label='RP Wrangler')
plt.bar(index+3*bar_width,[WYMapWrit1008,WYMapWrit10016,WYMapWrit10032],bar_width,yerr=[0,0,0],alpha=opacity,color='darkred',label='RP-YARN Wrangler')
plt.bar(index+3*bar_width,[WYMapExec1008,WYMapExec10016,WYMapExec10032],bar_width,yerr=[0,0,0],alpha=opacity,color='red',label='RP-YARN Wrangler')
plt.bar(index+3*bar_width,[WYMapRead1008,WYMapRead10016,WYMapRead10032],bar_width,yerr=[0,0,0],alpha=opacity,color='darkred',label='RP-YARN Wrangler')

plt.title('100,000 points'+'\n'+'500 clusters')
plt.xticks(index+3*bar_width,('8','16','32'))
plt.ylim(ymax=1100)
plt.ylabel('Time (secs)',fontsize=14)

plt.subplot(1,3,3)
n_groups=3
index=np.arange(n_groups)
bar_width=0.1
opacity=1.0

b1 = plt.bar(index,[SVMapWrit18,SVMapWrit116,SVMapWrit132],bar_width,yerr=[0,0,0],alpha=opacity,color='lightgreen',label='RP Stampede')
plt.bar(index,[SVMapExec18,SVMapExec116,SVMapExec132],bar_width,yerr=[0,0,0],alpha=opacity,color='green',label='RP Stampede')
plt.bar(index,[SVMapRead18,SVMapRead116,SVMapRead132],bar_width,yerr=[0,0,0],alpha=opacity,color='lightgreen',label='RP Stampede')
b2 = plt.bar(index+bar_width,[0,0,0],bar_width,yerr=[0,0,0],alpha=opacity,color='blue',label='RP-YARN Stampede')
plt.bar(index+bar_width,[0,0,0],bar_width,yerr=[0,0,0],alpha=opacity,color='cyan',label='RP-YARN Stampede')
plt.bar(index+bar_width,[0,0,0],bar_width,yerr=[0,0,0],alpha=opacity,color='blue',label='RP-YARN Stampede')
b3 = plt.bar(index+2*bar_width,[WVMapWrit18,WVMapWrit116,WVMapWrit132],bar_width,yerr=[0,0,0],alpha=opacity,color='yellow',label='RP Wrangler')
plt.bar(index+2*bar_width,[WVMapExec18,WVMapExec116,WVMapExec132],bar_width,yerr=[0,0,0],alpha=opacity,color='orange',label='RP Wrangler')
plt.bar(index+2*bar_width,[WVMapRead18,WVMapRead116,WVMapRead132],bar_width,yerr=[0,0,0],alpha=opacity,color='yellow',label='RP Wrangler')
b4 = plt.bar(index+3*bar_width,[WYMapWrit18,WYMapWrit116,WYMapWrit132],bar_width,yerr=[0,0,0],alpha=opacity,color='darkred',label='RP-YARN Wrangler')
plt.bar(index+3*bar_width,[WYMapExec18,WYMapExec116,WYMapExec132],bar_width,yerr=[0,0,0],alpha=opacity,color='red',label='RP-YARN Wrangler')
plt.bar(index+3*bar_width,[WYMapRead18,WYMapRead116,WYMapRead132],bar_width,yerr=[0,0,0],alpha=opacity,color='darkred',label='RP-YARN Wrangler')

plt.title('1,000,000 points'+'\n'+'50 clusters')
plt.xticks(index+3*bar_width,('8','16','32'))
plt.ylim(ymax=1100)
plt.ylabel('Time (secs)',fontsize=14)

lgd=plt.figlegend((b1,b2,b3,b4),('RP on Stampede','RP-YARN on Stampede','RP on Wrangler','RP-YARN on Wrangler'),
              loc='lower center',mode="expand",ncol=3,fontsize=10,borderaxespad=0.11)
a.text(0.45,0.16,'Number of Tasks',ha='center',fontsize=14)
a.subplots_adjust(bottom=0.25)
a.savefig('kmeans-map-comp-detailed.pdf',dpi=800,bbox_extra_artists=(lgd,))
