# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
def CsvToMaxCu(csvfile):
    csv_data = list()
    for row in csvfile:
        if row[0].startswith('unit.'):
            csv_data.append(float(row[-2]))
    csvdata=np.array(csv_data)
    return csvdata.max()

# %%
#Stampede CA RADICAL-Pilot Vanilla
st_van_ca_short_16_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_16_ca_short_1.csv')))
st_van_ca_short_16_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_16_ca_short_2.csv')))
st_van_ca_short_16_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_16_ca_short_3.csv')))
st_van_ca_short_32_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_32_ca_short_1.csv')))
st_van_ca_short_32_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_32_ca_short_2.csv')))
st_van_ca_short_32_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_32_ca_short_3.csv')))
st_van_ca_short_64_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_64_ca_short_1.csv')))
st_van_ca_short_64_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_64_ca_short_2.csv')))
st_van_ca_short_64_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_64_ca_short_3.csv')))
st_van_ca_short_128_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_128_ca_short_1.csv')))
st_van_ca_short_128_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_128_ca_short_2.csv')))
st_van_ca_short_128_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_128_ca_short_3.csv')))

st_van_ca_med_16_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_16_ca_med_1.csv')))
st_van_ca_med_16_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_16_ca_med_2.csv')))
st_van_ca_med_16_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_16_ca_med_3.csv')))
st_van_ca_med_32_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_32_ca_med_1.csv')))
st_van_ca_med_32_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_32_ca_med_2.csv')))
st_van_ca_med_32_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_32_ca_med_3.csv')))
st_van_ca_med_64_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_64_ca_med_1.csv')))
st_van_ca_med_64_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_64_ca_med_2.csv')))
st_van_ca_med_64_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_64_ca_med_3.csv')))
st_van_ca_med_128_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_128_ca_med_1.csv')))
st_van_ca_med_128_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_128_ca_med_2.csv')))
st_van_ca_med_128_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_128_ca_med_3.csv')))

st_van_ca_long_16_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_16_ca_long_1.csv')))
st_van_ca_long_16_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_16_ca_long_2.csv')))
st_van_ca_long_16_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_16_ca_long_3.csv')))
st_van_ca_long_32_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_32_ca_long_1.csv')))
st_van_ca_long_32_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_32_ca_long_2.csv')))
st_van_ca_long_32_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_32_ca_long_3.csv')))
st_van_ca_long_64_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_64_ca_long_1.csv')))
st_van_ca_long_64_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_64_ca_long_2.csv')))
st_van_ca_long_64_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_64_ca_long_3.csv')))
st_van_ca_long_128_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_128_ca_long_1.csv')))
st_van_ca_long_128_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_128_ca_long_2.csv')))
st_van_ca_long_128_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_128_ca_long_3.csv')))

st_val_ca_short_16_mean = np.mean([st_van_ca_short_16_1,st_van_ca_short_16_2,st_van_ca_short_16_3])
st_val_ca_short_32_mean = np.mean([st_van_ca_short_32_1,st_van_ca_short_32_2,st_van_ca_short_32_3])
st_val_ca_short_64_mean = np.mean([st_van_ca_short_64_1,st_van_ca_short_64_2,st_van_ca_short_64_3])
st_val_ca_short_128_mean = np.mean([st_van_ca_short_128_1,st_van_ca_short_128_2,st_van_ca_short_128_3])

st_val_ca_med_16_mean = np.mean([st_van_ca_med_16_1,st_van_ca_med_16_2,st_van_ca_med_16_3])
st_val_ca_med_32_mean = np.mean([st_van_ca_med_32_1,st_van_ca_med_32_2,st_van_ca_med_32_3])
st_val_ca_med_64_mean = np.mean([st_van_ca_med_64_1,st_van_ca_med_64_2,st_van_ca_med_64_3])
st_val_ca_med_128_mean = np.mean([st_van_ca_med_128_1,st_van_ca_med_128_2,st_van_ca_med_128_3])

st_val_ca_long_16_mean = np.mean([st_van_ca_long_16_1,st_van_ca_long_16_2,st_van_ca_long_16_3])
st_val_ca_long_32_mean = np.mean([st_van_ca_long_32_1,st_van_ca_long_32_2,st_van_ca_long_32_3])
st_val_ca_long_64_mean = np.mean([st_van_ca_long_64_1,st_van_ca_long_64_2,st_van_ca_long_64_3])
st_val_ca_long_128_mean = np.mean([st_van_ca_long_128_1,st_van_ca_long_128_2,st_van_ca_long_128_3])

st_val_ca_short_16_std = np.std([st_van_ca_short_16_1,st_van_ca_short_16_2,st_van_ca_short_16_3])
st_val_ca_short_32_std = np.std([st_van_ca_short_32_1,st_van_ca_short_32_2,st_van_ca_short_32_3])
st_val_ca_short_64_std = np.std([st_van_ca_short_64_1,st_van_ca_short_64_2,st_van_ca_short_64_3])
st_val_ca_short_128_std = np.std([st_van_ca_short_128_1,st_van_ca_short_128_2,st_van_ca_short_128_3])

st_val_ca_med_16_std = np.std([st_van_ca_med_16_1,st_van_ca_med_16_2,st_van_ca_med_16_3])
st_val_ca_med_32_std = np.std([st_van_ca_med_32_1,st_van_ca_med_32_2,st_van_ca_med_32_3])
st_val_ca_med_64_std = np.std([st_van_ca_med_64_1,st_van_ca_med_64_2,st_van_ca_med_64_3])
st_val_ca_med_128_std = np.std([st_van_ca_med_128_1,st_van_ca_med_128_2,st_van_ca_med_128_3])

st_val_ca_long_16_std = np.std([st_van_ca_long_16_1,st_van_ca_long_16_2,st_van_ca_long_16_3])
st_val_ca_long_32_std = np.std([st_van_ca_long_32_1,st_van_ca_long_32_2,st_van_ca_long_32_3])
st_val_ca_long_64_std = np.std([st_van_ca_long_64_1,st_van_ca_long_64_2,st_van_ca_long_64_3])
st_val_ca_long_128_std = np.std([st_van_ca_long_128_1,st_van_ca_long_128_2,st_van_ca_long_128_3])

# %%
#Stampede HA RADICAL-Pilot Vanilla
st_van_ha_short_16_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_16_ha_short_1.csv')))
st_van_ha_short_16_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_16_ha_short_2.csv')))
st_van_ha_short_16_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_16_ha_short_3.csv')))
st_van_ha_short_32_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_32_ha_short_1.csv')))
st_van_ha_short_32_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_32_ha_short_2.csv')))
st_van_ha_short_32_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_32_ha_short_3.csv')))
st_van_ha_short_64_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_64_ha_short_1.csv')))
st_van_ha_short_64_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_64_ha_short_2.csv')))
st_van_ha_short_64_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_64_ha_short_3.csv')))
st_van_ha_short_128_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_128_ha_short_1.csv')))
st_van_ha_short_128_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_128_ha_short_2.csv')))
st_van_ha_short_128_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_128_ha_short_3.csv')))

st_van_ha_med_16_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_16_ha_med_1.csv')))
st_van_ha_med_16_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_16_ha_med_2.csv')))
st_van_ha_med_16_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_16_ha_med_3.csv')))
st_van_ha_med_32_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_32_ha_med_1.csv')))
st_van_ha_med_32_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_32_ha_med_2.csv')))
st_van_ha_med_32_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_32_ha_med_3.csv')))
st_van_ha_med_64_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_64_ha_med_1.csv')))
st_van_ha_med_64_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_64_ha_med_2.csv')))
st_van_ha_med_64_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_64_ha_med_3.csv')))
st_van_ha_med_128_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_128_ha_med_1.csv')))
st_van_ha_med_128_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_128_ha_med_2.csv')))
st_van_ha_med_128_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_128_ha_med_3.csv')))

st_van_ha_long_16_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_16_ha_long_1.csv')))
st_van_ha_long_16_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_16_ha_long_2.csv')))
st_van_ha_long_16_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_16_ha_long_3.csv')))
st_van_ha_long_32_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_32_ha_long_1.csv')))
st_van_ha_long_32_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_32_ha_long_2.csv')))
st_van_ha_long_32_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_32_ha_long_3.csv')))
st_van_ha_long_64_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_64_ha_long_1.csv')))
st_van_ha_long_64_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_64_ha_long_2.csv')))
st_van_ha_long_64_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_64_ha_long_3.csv')))
st_van_ha_long_128_1 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_128_ha_long_1.csv')))
st_van_ha_long_128_2 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_128_ha_long_2.csv')))
st_van_ha_long_128_3 = CsvToMaxCu(csv.reader(open('Vanilla/Stampede/haus_rp_128_ha_long_3.csv')))

st_val_ha_short_16_mean = np.mean([st_van_ha_short_16_1,st_van_ha_short_16_2,st_van_ha_short_16_3])
st_val_ha_short_32_mean = np.mean([st_van_ha_short_32_1,st_van_ha_short_32_2,st_van_ha_short_32_3])
st_val_ha_short_64_mean = np.mean([st_van_ha_short_64_1,st_van_ha_short_64_2,st_van_ha_short_64_3])
st_val_ha_short_128_mean = np.mean([st_van_ha_short_128_1,st_van_ha_short_128_2,st_van_ha_short_128_3])

st_val_ha_med_16_mean = np.mean([st_van_ha_med_16_1,st_van_ha_med_16_2,st_van_ha_med_16_3])
st_val_ha_med_32_mean = np.mean([st_van_ha_med_32_1,st_van_ha_med_32_2,st_van_ha_med_32_3])
st_val_ha_med_64_mean = np.mean([st_van_ha_med_64_1,st_van_ha_med_64_2,st_van_ha_med_64_3])
st_val_ha_med_128_mean = np.mean([st_van_ha_med_128_1,st_van_ha_med_128_2,st_van_ha_med_128_3])

st_val_ha_long_16_mean = np.mean([st_van_ha_long_16_1,st_van_ha_long_16_2,st_van_ha_long_16_3])
st_val_ha_long_32_mean = np.mean([st_van_ha_long_32_1,st_van_ha_long_32_2,st_van_ha_long_32_3])
st_val_ha_long_64_mean = np.mean([st_van_ha_long_64_1,st_van_ha_long_64_2,st_van_ha_long_64_3])
st_val_ha_long_128_mean = np.mean([st_van_ha_long_128_1,st_van_ha_long_128_2,st_van_ha_long_128_3])

st_val_ha_short_16_std = np.std([st_van_ha_short_16_1,st_van_ha_short_16_2,st_van_ha_short_16_3])
st_val_ha_short_32_std = np.std([st_van_ha_short_32_1,st_van_ha_short_32_2,st_van_ha_short_32_3])
st_val_ha_short_64_std = np.std([st_van_ha_short_64_1,st_van_ha_short_64_2,st_van_ha_short_64_3])
st_val_ha_short_128_std = np.std([st_van_ha_short_128_1,st_van_ha_short_128_2,st_van_ha_short_128_3])

st_val_ha_med_16_std = np.std([st_van_ha_med_16_1,st_van_ha_med_16_2,st_van_ha_med_16_3])
st_val_ha_med_32_std = np.std([st_van_ha_med_32_1,st_van_ha_med_32_2,st_van_ha_med_32_3])
st_val_ha_med_64_std = np.std([st_van_ha_med_64_1,st_van_ha_med_64_2,st_van_ha_med_64_3])
st_val_ha_med_128_std = np.std([st_van_ha_med_128_1,st_van_ha_med_128_2,st_van_ha_med_128_3])

st_val_ha_long_16_std = np.std([st_van_ha_long_16_1,st_van_ha_long_16_2,st_van_ha_long_16_3])
st_val_ha_long_32_std = np.std([st_van_ha_long_32_1,st_van_ha_long_32_2,st_van_ha_long_32_3])
st_val_ha_long_64_std = np.std([st_van_ha_long_64_1,st_van_ha_long_64_2,st_van_ha_long_64_3])
st_val_ha_long_128_std = np.std([st_van_ha_long_128_1,st_van_ha_long_128_2,st_van_ha_long_128_3])

# %%
#Stampede CA RADICAL-Spark
st_sp_ca_short_16_mean = np.mean([36,35,34])
st_sp_ca_short_32_mean = np.mean([28,25,26])
st_sp_ca_short_64_mean = np.mean([26,27,29])
st_sp_ca_short_128_mean = np.mean([29,29,30])

st_sp_ca_med_16_mean = np.mean([56,65,56])
st_sp_ca_med_32_mean = np.mean([42,43,45])
st_sp_ca_med_64_mean = np.mean([45,44,40])
st_sp_ca_med_128_mean = np.mean([43,39,43])

st_sp_ca_long_16_mean = np.mean([122,117,118])
st_sp_ca_long_32_mean = np.mean([89,88,86])
st_sp_ca_long_64_mean = np.mean([81,78,84])
st_sp_ca_long_128_mean = np.mean([91,96,104])

st_sp_ca_short_16_std = np.std([36,35,34])
st_sp_ca_short_32_std = np.std([28,25,26])
st_sp_ca_short_64_std = np.std([26,27,29])
st_sp_ca_short_128_std = np.std([29,29,30])

st_sp_ca_med_16_std = np.std([56,65,56])
st_sp_ca_med_32_std = np.std([42,43,45])
st_sp_ca_med_64_std = np.std([45,44,40])
st_sp_ca_med_128_std = np.std([43,39,43])

st_sp_ca_long_16_std = np.std([122,117,118])
st_sp_ca_long_32_std = np.std([89,88,86])
st_sp_ca_long_64_std = np.std([81,78,84])
st_sp_ca_long_128_std = np.std([91,96,104])

# %%
#Stampede HA RADICAL-Spark
st_sp_ha_short_16_mean = np.mean([431,424,424])
st_sp_ha_short_32_mean = np.mean([268,278,274])
st_sp_ha_short_64_mean = np.mean([219,213,225])
st_sp_ha_short_128_mean = np.mean([244,247,237])

st_sp_ha_med_16_mean = np.mean([962,1130,1044])
st_sp_ha_med_32_mean = np.mean([757,631,793])
st_sp_ha_med_64_mean = np.mean([592,606,589])
st_sp_ha_med_128_mean = np.mean([0,0,0])

st_sp_ha_long_16_mean = np.mean([0,0,0])
st_sp_ha_long_32_mean = np.mean([0,0,0])
st_sp_ha_long_64_mean = np.mean([0,0,0])
st_sp_ha_long_128_mean = np.mean([0,0,0])

st_sp_ha_short_16_std = np.std([431,424,424])
st_sp_ha_short_32_std = np.std([268,278,274])
st_sp_ha_short_64_std = np.std([219,213,225])
st_sp_ha_short_128_std = np.std([244,247,237])

st_sp_ha_med_16_std = np.std([962,1130,1044])
st_sp_ha_med_32_std = np.std([757,631,793])
st_sp_ha_med_64_std = np.std([592,606,589])
st_sp_ha_med_128_std = np.std([0,0,0])

st_sp_ha_long_16_std = np.std([0,0,0])
st_sp_ha_long_32_std = np.std([0,0,0])
st_sp_ha_long_64_std = np.std([0,0,0])
st_sp_ha_long_128_std = np.std([0,0,0])

# %%
a=plt.figure()
plt.suptitle('Time to Completion @ Stampede,CA atoms,136 tasks')
plt.ylabel('Time to Completion (secs)',fontsize=14)
plt.subplot(3, 1, 1)
plt.text(2.5,290,'Short Trajectory')
n_groups=4
index=np.arange(n_groups)
bar_width=0.25
opacity=1.0
a1=plt.bar(index,[st_val_ca_short_16_mean, 
                  st_val_ca_short_32_mean, 
                  st_val_ca_short_64_mean, 
                  st_val_ca_short_128_mean],
           bar_width,
           yerr=[st_val_ca_short_16_std, 
                 st_val_ca_short_32_std, 
                 st_val_ca_short_64_std, 
                 st_val_ca_short_128_std],
           alpha=opacity,color='blue')
b1 = plt.bar(index+bar_width,[st_sp_ca_short_16_mean, 
                              st_sp_ca_short_32_mean, 
                              st_sp_ca_short_64_mean, 
                              st_sp_ca_short_128_mean],
             bar_width,
             yerr=[st_sp_ca_short_16_std, 
                   st_sp_ca_short_32_std, 
                   st_sp_ca_short_64_std, 
                   st_sp_ca_short_128_std],
             alpha=opacity,color='orange')
plt.xticks(index+bar_width,('','','',''))
plt.ylim(ymax=350)
a.subplots_adjust(bottom=0.30)

plt.subplot(3, 1, 2)
plt.text(2.5,290,'Medium Trajectory')
n_groups=4
index=np.arange(n_groups)
bar_width=0.25
opacity=1.0
a1=plt.bar(index,[st_val_ca_med_16_mean, 
                  st_val_ca_med_32_mean, 
                  st_val_ca_med_64_mean, 
                  st_val_ca_med_128_mean],
           bar_width,
           yerr=[st_val_ca_med_16_std, 
                 st_val_ca_med_32_std, 
                 st_val_ca_med_64_std, 
                 st_val_ca_med_128_std],
           alpha=opacity,color='blue')
b1 = plt.bar(index+bar_width,[st_sp_ca_med_16_mean, 
                              st_sp_ca_med_32_mean, 
                              st_sp_ca_med_64_mean, 
                              st_sp_ca_med_128_mean],
             bar_width,
             yerr=[st_sp_ca_med_16_std, 
                   st_sp_ca_med_32_std, 
                   st_sp_ca_med_64_std, 
                   st_sp_ca_med_128_std],
             alpha=opacity,color='orange')
plt.xticks(index+bar_width,('','','',''))
plt.ylim(ymax=350)
a.subplots_adjust(bottom=0.30)

plt.subplot(3, 1, 3)
plt.text(2.5,290,'Long Trajectory')
n_groups=4
index=np.arange(n_groups)
bar_width=0.25
opacity=1.0
a1=plt.bar(index,[st_val_ca_long_16_mean, 
                  st_val_ca_long_32_mean, 
                  st_val_ca_long_64_mean, 
                  st_val_ca_long_128_mean],
           bar_width,
           yerr=[st_val_ca_long_16_std, 
                 st_val_ca_long_32_std, 
                 st_val_ca_long_64_std, 
                 st_val_ca_long_128_std],
           alpha=opacity,color='blue')
b1 = plt.bar(index+bar_width,[st_sp_ca_long_16_mean, 
                              st_sp_ca_long_32_mean, 
                              st_sp_ca_long_64_mean, 
                              st_sp_ca_long_128_mean],
             bar_width,
             yerr=[st_sp_ca_long_16_std, 
                   st_sp_ca_long_32_std, 
                   st_sp_ca_long_64_std, 
                   st_sp_ca_long_128_std],
             alpha=opacity,color='orange')
plt.xticks(index+bar_width,('16','32','64','128'))
plt.xlabel('Number of cores')
plt.ylim(ymax=350)
lgd=plt.figlegend((a1,b1),('RADICAL-Pilot Vanilla','RADICAL-Pilot SPark'),
              loc='lower center',ncol=2,fontsize=10,borderaxespad=0.15)
a.subplots_adjust(bottom=0.15)
a.savefig('haus_ca_stampede.pdf',bbox_extra_artists=(lgd,))

a=plt.figure()
plt.suptitle('Time to Completion @ Stampede,HA atoms,136 tasks')
plt.ylabel('Time to Completion (secs)',fontsize=14)
plt.subplot(3, 1, 1)
plt.text(2.5,2600,'Short Trajectory')
n_groups=4
index=np.arange(n_groups)
bar_width=0.25
opacity=1.0
a1=plt.bar(index,[st_val_ha_short_16_mean, 
                  st_val_ha_short_32_mean, 
                  st_val_ha_short_64_mean, 
                  st_val_ha_short_128_mean],
           bar_width,
           yerr=[st_val_ha_short_16_std, 
                 st_val_ha_short_32_std, 
                 st_val_ha_short_64_std, 
                 st_val_ha_short_128_std],
           alpha=opacity,color='blue')
b1 = plt.bar(index+bar_width,[st_sp_ha_short_16_mean, 
                              st_sp_ha_short_32_mean, 
                              st_sp_ha_short_64_mean, 
                              st_sp_ha_short_128_mean],
             bar_width,
             yerr=[st_sp_ha_short_16_std, 
                   st_sp_ha_short_32_std, 
                   st_sp_ha_short_64_std, 
                   st_sp_ha_short_128_std],
             alpha=opacity,color='orange')
plt.xticks(index+bar_width,('','','',''))
plt.ylim(ymax=3000)
a.subplots_adjust(bottom=0.30)

plt.subplot(3, 1, 2)
plt.text(2.5,2600,'Medium Trajectory')
n_groups=4
index=np.arange(n_groups)
bar_width=0.25
opacity=1.0
a1=plt.bar(index,[st_val_ha_med_16_mean, 
                  st_val_ha_med_32_mean, 
                  st_val_ha_med_64_mean, 
                  st_val_ha_med_128_mean],
           bar_width,
           yerr=[st_val_ha_med_16_std, 
                 st_val_ha_med_32_std, 
                 st_val_ha_med_64_std, 
                 st_val_ha_med_128_std],
           alpha=opacity,color='blue')
b1 = plt.bar(index+bar_width,[st_sp_ha_med_16_mean, 
                              st_sp_ha_med_32_mean, 
                              st_sp_ha_med_64_mean, 
                              st_sp_ha_med_128_mean],
             bar_width,
             yerr=[st_sp_ha_med_16_std, 
                   st_sp_ha_med_32_std, 
                   st_sp_ha_med_64_std, 
                   st_sp_ha_med_128_std],
             alpha=opacity,color='orange')
plt.xticks(index+bar_width,('','','',''))
plt.ylim(ymax=3000)
a.subplots_adjust(bottom=0.30)

plt.subplot(3, 1, 3)
plt.text(2.5,2600,'Long Trajectory')
n_groups=4
index=np.arange(n_groups)
bar_width=0.25
opacity=1.0
a1=plt.bar(index,[st_val_ha_long_16_mean, 
                  st_val_ha_long_32_mean, 
                  st_val_ha_long_64_mean, 
                  st_val_ha_long_128_mean],
           bar_width,
           yerr=[st_val_ha_long_16_std, 
                 st_val_ha_long_32_std, 
                 st_val_ha_long_64_std, 
                 st_val_ha_long_128_std],
           alpha=opacity,color='blue')
b1 = plt.bar(index+bar_width,[st_sp_ha_long_16_mean, 
                              st_sp_ha_long_32_mean, 
                              st_sp_ha_long_64_mean, 
                              st_sp_ha_long_128_mean],
             bar_width,
             yerr=[st_sp_ha_long_16_std, 
                   st_sp_ha_long_32_std, 
                   st_sp_ha_long_64_std, 
                   st_sp_ha_long_128_std],
             alpha=opacity,color='orange')
plt.xticks(index+bar_width,('16','32','64','128'))
plt.xlabel('Number of cores')
plt.ylim(ymax=3000)
lgd=plt.figlegend((a1,b1),('RADICAL-Pilot Vanilla','RADICAL-Pilot SPark'),
              loc='lower center',ncol=2,fontsize=10,borderaxespad=0.15)
a.subplots_adjust(bottom=0.15)
a.savefig('haus_ha_stampede.pdf',bbox_extra_artists=(lgd,))

# %%
#Comet CA RADICAL-Pilot Vanilla
co_van_ca_short_24_1 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_ca_short_24_1.csv')))
co_van_ca_short_24_2 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_ca_short_24_2.csv')))
co_van_ca_short_24_3 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_ca_short_24_3.csv')))
co_van_ca_short_48_1 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_ca_short_48_1.csv')))
co_van_ca_short_48_2 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_ca_short_48_2.csv')))
co_van_ca_short_48_3 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_ca_short_48_3.csv')))
co_van_ca_short_96_1 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_ca_short_96_1.csv')))
co_van_ca_short_96_2 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_ca_short_96_2.csv')))
co_van_ca_short_96_3 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_ca_short_96_3.csv')))
co_van_ca_short_144_1 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_ca_short_144_1.csv')))
co_van_ca_short_144_2 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_ca_short_144_2.csv')))
co_van_ca_short_144_3 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_ca
co_val_ha_med_48_mean = np.mean([co_van_ha_med_48_1,co_van_ha_med_48_2,co_van_ha_med_48_3])
co_val_ha_med_96_mean = np.mean([co_van_ha_med_96_1,co_van_ha_med_96_2,co_van_ha_med_96_3])
co_val_ha_med_144_mean = np.mean([co_van_ha_med_144_1,co_van_ha_med_144_2,co_van_ha_med_144_3])

co_val_ha_long_24_mean = np.mean([co_van_ha_long_24_1,co_van_ha_long_24_2,co_van_ha_long_24_3])
co_val_ha_long_48_mean = np.mean([co_van_ha_long_48_1,co_van_ha_long_48_2,co_van_ha_long_48_3])
co_val_ha_long_96_mean = np.mean([co_van_ha_long_96_1,co_van_ha_long_96_2,co_van_ha_long_96_3])
co_val_ha_long_144_mean = np.mean([co_van_ha_long_144_1,co_van_ha_long_144_2,co_van_ha_long_144_3])

co_val_ha_short_24_std = np.std([co_van_ha_short_24_1,co_van_ha_short_24_2,co_van_ha_short_24_3])
co_val_ha_short_48_std = np.std([co_van_ha_short_48_1,co_van_ha_short_48_2,co_van_ha_short_48_3])
co_val_ha_short_96_std = np.std([co_van_ha_short_96_1,co_van_ha_short_96_2,co_van_ha_short_96_3])
co_val_ha_short_144_std = np.std([co_van_ha_short_144_1,co_van_ha_short_144_2,co_van_ha_short_144_3])

co_val_ha_med_24_std = np.std([co_van_ha_med_24_1,co_van_ha_med_24_2,co_van_ha_med_24_3])
co_val_ha_med_48_std = np.std([co_van_ha_med_48_1,co_van_ha_med_48_2,co_van_ha_med_48_3])
co_val_ha_med_96_std = np.std([co_van_ha_med_96_1,co_van_ha_med_96_2,co_van_ha_med_96_3])
co_val_ha_med_144_std = np.std([co_van_ha_med_144_1,co_van_ha_med_144_2,co_van_ha_med_144_3])

co_val_ha_long_24_std = np.std([co_van_ha_long_24_1,co_van_ha_long_24_2,co_van_ha_long_24_3])
co_val_ha_long_48_std = np.std([co_van_ha_long_48_1,co_van_ha_long_48_2,co_van_ha_long_48_3])
co_val_ha_long_96_std = np.std([co_van_ha_long_96_1,co_van_ha_long_96_2,co_van_ha_long_96_3])
co_val_ha_long_144_std = np.std([co_van_ha_long_144_1,co_van_ha_long_144_2,co_van_ha_long_144_3])

# %%
#Comet AA RADICAL-Pilot Vanilla
co_van_aa_short_24_1 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_aa_short_24_1.csv')))
co_van_aa_short_24_2 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_aa_short_24_2.csv')))
co_van_aa_short_24_3 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_aa_short_24_3.csv')))
co_van_aa_short_48_1 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_aa_short_48_1.csv')))
co_van_aa_short_48_2 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_aa_short_48_2.csv')))
co_van_aa_short_48_3 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_aa_short_48_3.csv')))
co_van_aa_short_96_1 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_aa_short_96_1.csv')))
co_van_aa_short_96_2 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_aa_short_96_2.csv')))
co_van_aa_short_96_3 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_aa_short_96_3.csv')))
co_van_aa_short_144_1 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_aa_short_144_1.csv')))
co_van_aa_short_144_2 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_aa_short_144_2.csv')))
co_van_aa_short_144_3 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_aa_short_144_3.csv')))

co_van_aa_med_24_1 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_aa_med_24_1.csv')))
co_van_aa_med_24_2 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_aa_med_24_2.csv')))
co_van_aa_med_24_3 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_aa_med_24_3.csv')))
co_van_aa_med_48_1 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_aa_med_48_1.csv')))
co_van_aa_med_48_2 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_aa_med_48_2.csv')))
co_van_aa_med_48_3 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_aa_med_48_3.csv')))
co_van_aa_med_96_1 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_aa_med_96_1.csv')))
co_van_aa_med_96_2 = CsvToMaxCu(csv.reader(open('Vanilla/Comet/rpco_haus_aa_med
co_val_aa_med_144_std = np.std([co_van_aa_med_144_1,co_van_aa_med_144_2,co_van_aa_med_144_3])

co_val_aa_long_24_std = np.std([co_van_aa_long_24_1,co_van_aa_long_24_2,co_van_aa_long_24_3])
co_val_aa_long_48_std = np.std([co_van_aa_long_48_1,co_van_aa_long_48_2,co_van_aa_long_48_3])
co_val_aa_long_96_std = np.std([co_van_aa_long_96_1,co_van_aa_long_96_2,co_van_aa_long_96_3])
co_val_aa_long_144_std = np.std([co_van_aa_long_144_1,co_van_aa_long_144_2,co_van_aa_long_144_3])

# %%
#Comet CA RADICAL-Spark
co_sp_ca_short_24_mean = np.mean([24,23,26])
co_sp_ca_short_48_mean = np.mean([17,13,12])
co_sp_ca_short_96_mean = np.mean([24,23,21])
co_sp_ca_short_144_mean = np.mean([21,17,15])

co_sp_ca_med_24_mean = np.mean([41,44,38])
co_sp_ca_med_48_mean = np.mean([30,45,26])
co_sp_ca_med_96_mean = np.mean([18,18,18])
co_sp_ca_med_144_mean = np.mean([17,22,19])

co_sp_ca_long_24_mean = np.mean([96,84,82])
co_sp_ca_long_48_mean = np.mean([55,55,97])
co_sp_ca_long_96_mean = np.mean([52,49,47])
co_sp_ca_long_144_mean = np.mean([50,37,41])

co_sp_ca_short_24_std = np.std([24,23,26])
co_sp_ca_short_48_std = np.std([17,13,12])
co_sp_ca_short_96_std = np.std([24,23,21])
co_sp_ca_short_144_std = np.std([21,17,15])

co_sp_ca_med_24_std = np.std([41,44,38])
co_sp_ca_med_48_std = np.std([30,45,26])
co_sp_ca_med_96_std = np.std([18,18,18])
co_sp_ca_med_144_std = np.std([17,22,19])

co_sp_ca_long_24_std = np.std([96,84,82])
co_sp_ca_long_48_std = np.std([55,55,97])
co_sp_ca_long_96_std = np.std([52,49,47])
co_sp_ca_long_144_std = np.std([50,37,41])

# %%
#Comet HA RADICAL-Spark
co_sp_ha_short_24_mean = np.mean([239,234,241])
co_sp_ha_short_48_mean = np.mean([138,139,138])
co_sp_ha_short_96_mean = np.mean([108,97,98])
co_sp_ha_short_144_mean = np.mean([88,91,90])

co_sp_ha_med_24_mean = np.mean([645,687,584])
co_sp_ha_med_48_mean = np.mean([468,330,523])
co_sp_ha_med_96_mean = np.mean([342,316,289])
co_sp_ha_med_144_mean = np.mean([338,301,262])

co_sp_ha_long_24_mean = np.mean([0,0,0])
co_sp_ha_long_48_mean = np.mean([0,0,0])
co_sp_ha_long_96_mean = np.mean([0,0,0])
co_sp_ha_long_144_mean = np.mean([0,0,0])

co_sp_ha_short_24_std = np.std([239,234,241])
co_sp_ha_short_48_std = np.std([138,139,138])
co_sp_ha_short_96_std = np.std([108,97,98])
co_sp_ha_short_144_std = np.std([88,91,90])

co_sp_ha_med_24_std = np.std([645,687,584])
co_sp_ha_med_48_std = np.std([468,330,523])
co_sp_ha_med_96_std = np.std([342,316,289])
co_sp_ha_med_144_std = np.std([338,301,262])

co_sp_ha_long_24_std = np.std([0,0,0])
co_sp_ha_long_48_std = np.std([0,0,0])
co_sp_ha_long_96_std = np.std([0,0,0])
co_sp_ha_long_144_std = np.std([0,0,0])

# %%
#Comet AA RADICAL-Spark
co_sp_aa_short_24_mean = np.mean([866,565,667])
co_sp_aa_short_48_mean = np.mean([430,444,341])
co_sp_aa_short_96_mean = np.mean([268,253,256])
co_sp_aa_short_144_mean = np.mean([297,266,283])

co_sp_aa_med_24_mean = np.mean([0,0,0])
co_sp_aa_med_48_mean = np.mean([0,0,0])
co_sp_aa_med_96_mean = np.mean([0,0,0])
co_sp_aa_med_144_mean = np.mean([0,0,0])

co_sp_aa_long_24_mean = np.mean([0,0,0])
co_sp_aa_long_48_mean = np.mean([0,0,0])
co_sp_aa_long_96_mean = np.mean([0,0,0])
co_sp_aa_long_144_mean = np.mean([0,0,0])

co_sp_aa_short_24_std = np.std([866,565,667])
co_sp_aa_short_48_std = np.std([430,444,341])
co_sp_aa_short_96_std = np.std([268,253,256])
co_sp_aa_short_144_std = np.std([297,266,283])

co_sp_aa_med_24_std = np.std([0,0,0])
co_sp_aa_med_48_std = np.std([0,0,0])
co_sp_aa_med_96_std = np.std([0,0,0])
co_sp_aa_med_144_std = np.std([0,0,0])

co_sp_aa_long_24_std = np.std([0,0,0])
co_sp_aa_long_48_std = np.std([0,0,0])
co_sp_aa_long_96_std = np.std([0,0,0])
co_sp_aa_long_144_std = np.std([0,0,0])

# %%
a=plt.figure()
plt.suptitle('Time to Completion @ Comet,CA atoms,136 tasks',fontsize=14)
plt.ylabel('Time to Completion (secs)',fontsize=14)
n_groups=4
index=np.arange(n_groups)
bar_width=0.25
opacity=1.0
plt.subplot(3, 1, 1)
plt.text(2.5,80,'Short Trajectory')
a1=plt.bar(index,[co_val_ca_short_24_mean,co_val_ca_short_48_mean,co_val_ca_short_96_mean,co_val_ca_short_144_mean],
               bar_width,
         yerr=[co_val_ca_short_24_std,co_val_ca_short_48_std,co_val_ca_short_96_std,co_val_ca_short_144_std],
           alpha=opacity,color='blue')
b1=plt.bar(index+bar_width,[co_sp_ca_short_24_mean,co_sp_ca_short_48_mean,co_sp_ca_short_96_mean,co_sp_ca_short_144_mean],
            bar_width,
      yerr=[co_sp_ca_short_24_std,co_sp_ca_short_48_std,co_sp_ca_short_96_std,co_sp_ca_short_144_std],
            alpha=opacity,color='orange')
plt.xticks(index+bar_width,('24','48','96','144'))
plt.ylim(ymax=100)
a.subplots_adjust(bottom=0.30)
plt.subplot(3, 1, 2)
plt.text(2.5,80,'Medium Trajectory')
plt.bar(index,[co_val_ca_med_24_mean,co_val_ca_med_48_mean,co_val_ca_med_96_mean,co_val_ca_med_144_mean],
               bar_width,
         yerr=[co_val_ca_med_24_std,co_val_ca_med_48_std,co_val_ca_med_96_std,co_val_ca_med_144_std],
           alpha=opacity,color='blue')
plt.bar(index+bar_width,[co_sp_ca_med_24_mean,co_sp_ca_med_48_mean,co_sp_ca_med_96_mean,co_sp_ca_med_144_mean],
            bar_width,
      yerr=[co_sp_ca_med_24_std,co_sp_ca_med_48_std,co_sp_ca_med_96_std,co_sp_ca_med_144_std],
            alpha=opacity,color='orange')
plt.xticks(index+bar_width,('24','48','96','144'))
plt.ylim(ymax=100)
a.subplots_adjust(bottom=0.30)
plt.subplot(3, 1, 3)
plt.text(2.5,80,'Long Trajectory')
plt.bar(index,[co_val_ca_long_24_mean,co_val_ca_long_48_mean,co_val_ca_long_96_mean,co_val_ca_long_144_mean],
               bar_width,
         yerr=[co_val_ca_long_24_std,co_val_ca_long_48_std,co_val_ca_long_96_std,co_val_ca_long_144_std],
           alpha=opacity,color='blue')
plt.bar(index+bar_width,[co_sp_ca_long_24_mean,co_sp_ca_long_48_mean,co_sp_ca_long_96_mean,co_sp_ca_long_144_mean],
            bar_width,
      yerr=[co_sp_ca_long_24_std,co_sp_ca_long_48_std,co_sp_ca_long_96_std,co_sp_ca_long_144_std],
            alpha=opacity,color='orange')
plt.xticks(index+bar_width,('24','48','96','144'))
plt.xlabel('Number of cores',fontsize=14)
lgd=plt.figlegend((a1,b1),('RADICAL-Pilot Vanilla','RADICAL-Pilot SPark'),
              loc='lower center',ncol=2,fontsize=10,borderaxespad=0.15)
a.subplots_adjust(bottom=0.20)
plt.ylim(ymax=100)
a.savefig('haus_ca_comet.pdf',bbox_extra_artists=(lgd,))

a=plt.figure()
plt.suptitle('Time to Completion @ Comet,HA atoms,136 tasks',fontsize=14)
plt.subplot(3, 1, 1)
plt.text(2.5,550,'Short Trajectory')
a1=plt.bar(index,[co_val_ha_short_24_mean,co_val_ha_short_48_mean,co_val_ha_short_96_mean,co_val_ha_short_144_mean],
               bar_width,
         yerr=[co_val_ha_short_24_std,co_val_ha_short_48_std,co_val_ha_short_96_std,co_val_ha_short_144_std],
           alpha=opacity,color='blue')
b1=plt.bar(index+bar_width,[co_sp_ha_short_24_mean,co_sp_ha_short_48_mean,co_sp_ha_short_96_mean,co_sp_ha_short_144_mean],
            bar_width,
      yerr=[co_sp_ha_short_24_std,co_sp_ha_short_48_std,co_sp_ha_short_96_std,co_sp_ha_short_144_std],
            alpha=opacity,color='orange')
plt.xticks(index+bar_width,('24','48','96','144'))
plt.ylim(ymax=700)
a.subplots_adjust(bottom=0.30)
plt.subplot(3, 1, 2)
plt.text(2.5,550,'Medium Trajectory')
plt.bar(index,[co_val_ha_med_24_mean,co_val_ha_med_48_mean,co_val_ha_med_96_mean,co_val_ha_med_144_mean],
               bar_width,
         yerr=[co_val_ha_med_24_std,co_val_ha_med_48_std,co_val_ha_med_96_std,co_val_ha_med_144_std],
           alpha=opacity,color='blue')
plt.bar(index+bar_width,[co_sp_ha_med_24_mean,co_sp_ha_med_48_mean,co_sp_ha_med_96_mean,co_sp_ha_med_144_mean],
            bar_width,
      yerr=[co_sp_ha_med_24_std,co_sp_ha_med_48_std,co_sp_ha_med_96_std,co_sp_ha_med_144_std],
            alpha=opacity,color='orange')
plt.xticks(index+bar_width,('24','48','96','144'))
plt.ylim(ymax=700)
a.subplots_adjust(bottom=0.30)
plt.subplot(3, 1, 3)
plt.text(2.5,550,'Long Trajectory')
plt.bar(index,[co_val_ha_long_24_mean,co_val_ha_long_48_mean,co_val_ha_long_96_mean,co_val_ha_long_144_mean],
               bar_width,
         yerr=[co_val_ha_long_24_std,co_val_ha_long_48_std,co_val_ha_long_96_std,co_val_ha_long_144_std],
           alpha=opacity,color='blue')
plt.bar(index+bar_width,[co_sp_ha_long_24_mean,co_sp_ha_long_48_mean,co_sp_ha_long_96_mean,co_sp_ha_long_144_mean],
            bar_width,
      yerr=[co_sp_ha_long_24_std,co_sp_ha_long_48_std,co_sp_ha_long_96_std,co_sp_ha_long_144_std],
            alpha=opacity,color='orange')
plt.xticks(index+bar_width,('24','48','96','144'))
plt.ylim(ymax=700)
plt.xlabel('Number of cores',fontsize=14)
lgd=plt.figlegend((a1,b1),('RADICAL-Pilot Vanilla','RADICAL-Pilot SPark'),
              loc='lower center',ncol=2,fontsize=10,borderaxespad=0.15)
a.subplots_adjust(bottom=0.20)
a.savefig('haus_ha_comet.pdf',bbox_extra_artists=(lgd,))

a=plt.figure()
plt.suptitle('Time to Completion @ Comet,AA atoms,136 tasks',fontsize=14)
plt.subplot(3, 1, 1)
plt.text(2.5,650,'Short Trajectory')
plt.bar(index,[co_val_aa_short_24_mean,co_val_aa_short_48_mean,co_val_aa_short_96_mean,co_val_aa_short_144_mean],
               bar_width,
         yerr=[co_val_aa_short_24_std,co_val_aa_short_48_std,co_val_aa_short_96_std,co_val_aa_short_144_std],
           alpha=opacity,color='blue')
plt.bar(index+bar_width,[co_sp_aa_short_24_mean,co_sp_aa_short_48_mean,co_sp_aa_short_96_mean,co_sp_aa_short_144_mean],
            bar_width,
      yerr=[co_sp_aa_short_24_std,co_sp_aa_short_48_std,co_sp_aa_short_96_std,co_sp_aa_short_144_std],
            alpha=opacity,color='orange')
plt.xticks(index+bar_width,('24','48','96','144'))
plt.ylim(ymax=900)
a.subplots_adjust(bottom=0.30)
plt.subplot(3, 1, 2)
plt.text(2.5,650,'Medium Trajectory')
plt.bar(index,[co_val_aa_med_24_mean,co_val_aa_med_48_mean,co_val_aa_med_96_mean,co_val_aa_med_144_mean],
               bar_width,
         yerr=[co_val_aa_med_24_std,co_val_aa_med_48_std,co_val_aa_med_96_std,co_val_aa_med_144_std],
           alpha=opacity,color='blue')
plt.bar(index+bar_width,[co_sp_aa_med_24_mean,co_sp_aa_med_48_mean,co_sp_aa_med_96_mean,co_sp_aa_med_144_mean],
            bar_width,
      yerr=[co_sp_aa_med_24_std,co_sp_aa_med_48_std,co_sp_aa_med_96_std,co_sp_aa_med_144_std],
            alpha=opacity,color='orange')
plt.xticks(index+bar_width,('24','48','96','144'))
plt.ylim(ymax=900)
a.subplots_adjust(bottom=0.15)
plt.subplot(3, 1, 3)
plt.text(2.5,650,'Long Trajectory')
a1=plt.bar(index,[co_val_aa_long_24_mean,co_val_aa_long_48_mean,co_val_aa_long_96_mean,co_val_aa_long_144_mean],
               bar_width,
         yerr=[co_val_aa_long_24_std,co_val_aa_long_48_std,co_val_aa_long_96_std,co_val_aa_long_144_std],
           alpha=opacity,color='blue')
b1=plt.bar(index+bar_width,[co_sp_aa_long_24_mean,co_sp_aa_long_48_mean,co_sp_aa_long_96_mean,co_sp_aa_long_144_mean],
            bar_width,
      yerr=[co_sp_aa_long_24_std,co_sp_aa_long_48_std,co_sp_aa_long_96_std,co_sp_aa_long_144_std],
            alpha=opacity,color='orange')
plt.xticks(index+bar_width,('24','48','96','144'))
plt.ylim(ymax=900)
plt.xlabel('Number of cores',fontsize=14)
lgd=plt.figlegend((a1,b1),('RADICAL-Pilot Vanilla','RADICAL-Pilot SPark'),
              loc='lower center',ncol=2,fontsize=10,borderaxespad=0.15)
a.subplots_adjust(bottom=0.20)
a.savefig('haus_aa_comet.pdf',bbox_extra_artists=(lgd,))
