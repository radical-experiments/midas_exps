# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
#Stampede CA RADICAL-Pilot Vanilla
st_van_ca_short_16_1
st_van_ca_short_16_2
st_van_ca_short_16_3
st_van_ca_short_32_1
st_van_ca_short_32_2
st_van_ca_short_32_3
st_van_ca_short_64_1
st_van_ca_short_64_2
st_van_ca_short_64_3
st_van_ca_short_128_1
st_van_ca_short_128_2
st_van_ca_short_128_3

st_van_ca_med_16_1
st_van_ca_med_16_2
st_van_ca_med_16_3
st_van_ca_med_32_1
st_van_ca_med_32_2
st_van_ca_med_32_3
st_van_ca_med_64_1
st_van_ca_med_64_2
st_van_ca_med_64_3
st_van_ca_med_128_1
st_van_ca_med_128_2
st_van_ca_med_128_3

st_van_ca_long_16_1
st_van_ca_long_16_2
st_van_ca_long_16_3
st_van_ca_long_32_1
st_van_ca_long_32_2
st_van_ca_long_32_3
st_van_ca_long_64_1
st_van_ca_long_64_2
st_van_ca_long_64_3
st_van_ca_long_128_1
st_van_ca_long_128_2
st_van_ca_long_128_3

st_val_ca_short_16_mean = np.mean()
st_val_ca_short_32_mean = np.mean()
st_val_ca_short_64_mean = np.mean()
st_val_ca_short_128_mean = np.mean()

st_val_ca_med_16_mean = np.mean()
st_val_ca_med_32_mean = np.mean()
st_val_ca_med_64_mean = np.mean()
st_val_ca_med_128_mean = np.mean()

st_val_ca_long_16_mean = np.mean()
st_val_ca_long_32_mean = np.mean()
st_val_ca_long_64_mean = np.mean()
st_val_ca_long_128_mean = np.mean()

st_val_ca_short_16_std = np.std()
st_val_ca_short_32_std = np.std()
st_val_ca_short_64_std = np.std()
st_val_ca_short_128_std = np.std()

st_val_ca_med_16_std = np.std()
st_val_ca_med_32_std = np.std()
st_val_ca_med_64_std = np.std()
st_val_ca_med_128_std = np.std()

st_val_ca_long_16_std = np.std()
st_val_ca_long_32_std = np.std()
st_val_ca_long_64_std = np.std()
st_val_ca_long_128_std = np.std()

# %%
#Stampede CA RADICAL-Spark
st_sp_ca_short_16_mean = np.mean()
st_sp_ca_short_32_mean = np.mean()
st_sp_ca_short_64_mean = np.mean()
st_sp_ca_short_128_mean = np.mean()

st_sp_ca_med_16_mean = np.mean()
st_sp_ca_med_32_mean = np.mean()
st_sp_ca_med_64_mean = np.mean()
st_sp_ca_med_128_mean = np.mean()

st_sp_ca_long_16_mean = np.mean()
st_sp_ca_long_32_mean = np.mean()
st_sp_ca_long_64_mean = np.mean()
st_sp_ca_long_128_mean = np.mean()

st_sp_ca_short_16_std = np.std()
st_sp_ca_short_32_std = np.std()
st_sp_ca_short_64_std = np.std()
st_sp_ca_short_128_std = np.std()

st_sp_ca_med_16_std = np.std()
st_sp_ca_med_32_std = np.std()
st_sp_ca_med_64_std = np.std()
st_sp_ca_med_128_std = np.std()

st_sp_ca_long_16_std = np.std()
st_sp_ca_long_32_std = np.std()
st_sp_ca_long_64_std = np.std()
st_sp_ca_long_128_std = np.std()

# %%
a=plt.figure()
plt.title('Time to Completion @ Stampede,CA atoms,136 tasks')
plt.ylabel('Time to Completion (secs)',fontsize=14)
plt.subplot(3, 1, 1)
n_groups=4
index=np.arange(n_groups)
bar_width=0.25
opacity=1.0
a1=plt.bar(index,[st_val_ca_short_16_mean, 
                  st_val_ca_short_32_mean, 
                  st_val_ca_short_64_mean, 
                  st_val_ca_short_128_mean],
           bar_width,
           yerr=[st_val_ca_short_16_std, 
                 st_val_ca_short_32_std, 
                 st_val_ca_short_64_std, 
                 st_val_ca_short_128_std],
           alpha=opacity,color='darkgreen')
b1 = plt.bar(index+bar_width,[st_sp_ca_short_16_mean, 
                              st_sp_ca_short_32_mean, 
                              st_sp_ca_short_64_mean, 
                              st_sp_ca_short_128_mean],
             bar_width,
             yerr=[st_sp_ca_short_16_std, 
                   st_sp_ca_short_32_std, 
                   st_sp_ca_short_64_std, 
                   st_sp_ca_short_128_std],
             alpha=opacity,color='red')
plt.xticks(index+bar_width,('16','32','64','128'))
plt.xlabel('Number of cores')
a.subplots_adjust(bottom=0.30)
plt.ylim(ymax=2400)

plt.subplot(3, 1, 2)
n_groups=4
index=np.arange(n_groups)
bar_width=0.25
opacity=1.0
a1=plt.bar(index,[st_val_ca_med_16_mean, 
                  st_val_ca_med_32_mean, 
                  st_val_ca_med_64_mean, 
                  st_val_ca_med_128_mean],
           bar_width,
           yerr=[st_val_ca_med_16_std, 
                 st_val_ca_med_32_std, 
                 st_val_ca_med_64_std, 
                 st_val_ca_med_128_std],
           alpha=opacity,color='darkgreen')
b1 = plt.bar(index+bar_width,[st_sp_ca_med_16_mean, 
                              st_sp_ca_med_32_mean, 
                              st_sp_ca_med_64_mean, 
                              st_sp_ca_med_128_mean],
             bar_width,
             yerr=[st_sp_ca_med_16_std, 
                   st_sp_ca_med_32_std, 
                   st_sp_ca_med_64_std, 
                   st_sp_ca_med_128_std],
             alpha=opacity,color='red')
plt.xticks(index+bar_width,('16','32','64','128'))
plt.xlabel('Number of cores')
a.subplots_adjust(bottom=0.30)
plt.ylim(ymax=2400)

plt.subplot(3, 1, 3)
n_groups=4
index=np.arange(n_groups)
bar_width=0.25
opacity=1.0
a1=plt.bar(index,[st_val_ca_long_16_mean, 
                  st_val_ca_long_32_mean, 
                  st_val_ca_long_64_mean, 
                  st_val_ca_long_128_mean],
           bar_width,
           yerr=[st_val_ca_long_16_std, 
                 st_val_ca_long_32_std, 
                 st_val_ca_long_64_std, 
                 st_val_ca_long_128_std],
           alpha=opacity,color='darkgreen')
b1 = plt.bar(index+bar_width,[st_sp_ca_long_16_mean, 
                              st_sp_ca_long_32_mean, 
                              st_sp_ca_long_64_mean, 
                              st_sp_ca_long_128_mean],
             bar_width,
             yerr=[st_sp_ca_long_16_std, 
                   st_sp_ca_long_32_std, 
                   st_sp_ca_long_64_std, 
                   st_sp_ca_long_128_std],
             alpha=opacity,color='red')
plt.xticks(index+bar_width,('16','32','64','128'))
plt.xlabel('Number of cores')
lgd=plt.figlegend((a1,b1),('RADICAL-Pilot Vanilla','RADICAL-Pilot SPark'),
              loc='lower center',ncol=2,fontsize=10,borderaxespad=0.15)
a.subplots_adjust(bottom=0.30)
plt.ylim(ymax=2400)
a.savefig('haus_ca.pdf',bbox_extra_artists=(lgd,))
