# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm
import csv
import pandas as pd

blues = cm.get_cmap(plt.get_cmap('Blues'))
greens = cm.get_cmap(plt.get_cmap('Greens'))
reds = cm.get_cmap(plt.get_cmap('Reds'))
oranges = cm.get_cmap(plt.get_cmap('Greens_r'))
greys = cm.get_cmap(plt.get_cmap('Greys'))

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
RPW131_64 = [pd.DataFrame.from_csv('Vanilla/Wrangler/WraRPalO_131Kn_64_1024_%d.csv'%i) for i in range(1,4)]
RPW131_256 = [pd.DataFrame.from_csv('Vanilla/Wrangler/WraRPalO_131Kn_256_1024_%d.csv'%i) for i in range(1,4)]
RPW262_64 = [pd.DataFrame.from_csv('Vanilla/Wrangler/WraRPalO_262Kn_64_1024_%d.csv'%i) for i in range(1,4)]
RPW262_256 = [pd.DataFrame.from_csv('Vanilla/Wrangler/WraRPalO_262Kn_256_1024_%d.csv'%i) for i in range(1,4)]
RPW524_64 = [pd.DataFrame.from_csv('Vanilla/Wrangler/WraRPalO_524Kn_64_1024_%d.csv'%i) for i in range(1,4)]
RPW524_256 = [pd.DataFrame.from_csv('Vanilla/Wrangler/WraRPalO_524Kn_256_1024_%d.csv'%i) for i in range(1,4)]

# %%
ExecutionTimesSummations = pd.DataFrame(columns=['Atoms','Run','Cores','TimeToAgent','StagingIn','Scheduling','ExecutionTime','StagingOut'])

for i in range(3):
    ExecutionTimesSummations.loc[len(ExecutionTimesSummations)]=[131,i,64,RPW131_64[i]['AgentStagingInput'].mean(),
                                                                 (RPW131_64[i]['AllocatingPending']-RPW131_64[i]['AgentStagingInput']).mean(),
                                                                 (RPW131_64[i]['Executing']-RPW131_64[i]['AllocatingPending']).mean(),
                                                                 (RPW131_64[i]['AgentStagingOutputPending']-RPW131_64[i]['Executing']).mean(),
                                                                 (RPW131_64[i]['PendingOutputStaging']-RPW131_64[i]['AgentStagingOutputPending']).mean()]
    

for i in range(3):
    ExecutionTimesSummations.loc[len(ExecutionTimesSummations)]=[131,i,256,RPW131_256[i]['AgentStagingInput'].mean(),
                                                                 (RPW131_256[i]['AllocatingPending']-RPW131_256[i]['AgentStagingInput']).mean(),
                                                                 (RPW131_256[i]['Executing']-RPW131_256[i]['AllocatingPending']).mean(),
                                                                 (RPW131_256[i]['AgentStagingOutputPending']-RPW131_256[i]['Executing']).mean(),
                                                                 (RPW131_256[i]['PendingOutputStaging']-RPW131_256[i]['AgentStagingOutputPending']).mean()]
    

for i in range(3):
    ExecutionTimesSummations.loc[len(ExecutionTimesSummations)]=[262,i,64,RPW262_64[i]['AgentStagingInput'].mean(),
                                                                 (RPW262_64[i]['AllocatingPending']-RPW262_64[i]['AgentStagingInput']).mean(),
                                                                 (RPW262_64[i]['Executing']-RPW262_64[i]['AllocatingPending']).mean(),
                                                                 (RPW262_64[i]['AgentStagingOutputPending']-RPW262_64[i]['Executing']).mean(),
                                                                 (RPW262_64[i]['PendingOutputStaging']-RPW262_64[i]['AgentStagingOutputPending']).mean()]
    

for i in range(3):
    ExecutionTimesSummations.loc[len(ExecutionTimesSummations)]=[262,i,256,RPW262_256[i]['AgentStagingInput'].mean(),
                                                                 (RPW262_256[i]['AllocatingPending']-RPW262_256[i]['AgentStagingInput']).mean(),
                                                                 (RPW262_256[i]['Executing']-RPW262_256[i]['AllocatingPending']).mean(),
                                                                 (RPW262_256[i]['AgentStagingOutputPending']-RPW262_256[i]['Executing']).mean(),
                                                                 (RPW262_256[i]['PendingOutputStaging']-RPW262_256[i]['AgentStagingOutputPending']).mean()]
    

for i in range(3):
    ExecutionTimesSummations.loc[len(ExecutionTimesSummations)]=[524,i,64,RPW524_64[i]['AgentStagingInput'].mean(),
                                                                 (RPW524_64[i]['AllocatingPending']-RPW524_64[i]['AgentStagingInput']).mean(),
                                                                 (RPW524_64[i]['Executing']-RPW524_64[i]['AllocatingPending']).mean(),
                                                                 (RPW524_64[i]['AgentStagingOutputPending']-RPW524_64[i]['Executing']).mean(),
                                                                 (RPW524_64[i]['PendingOutputStaging']-RPW524_64[i]['AgentStagingOutputPending']).mean()]
    

for i in range(3):
    ExecutionTimesSummations.loc[len(ExecutionTimesSummations)]=[524,i,256,RPW524_256[i]['AgentStagingInput'].mean(),
                                                                 (RPW524_256[i]['AllocatingPending']-RPW524_256[i]['AgentStagingInput']).mean(),
                                                                 (RPW524_256[i]['Executing']-RPW524_256[i]['AllocatingPending']).mean(),
                                                                 (RPW524_256[i]['AgentStagingOutputPending']-RPW524_256[i]['Executing']).mean(),
                                                                 (RPW524_256[i]['PendingOutputStaging']-RPW524_256[i]['AgentStagingOutputPending']).mean()]

# %%
ExecutionTimesSummations
# Out:
#     Atoms  Run  Cores  TimeToAgent  StagingIn  Scheduling  ExecutionTime  \
# 0   131.0  0.0   64.0   185.431809   0.005302    0.006177       0.731087
# 1   131.0  1.0   64.0   186.259083   0.007078    0.007330       0.729223
# 2   131.0  2.0   64.0   185.166250   0.004682    0.006958       0.715281
# 3   131.0  0.0  256.0   186.202260   0.007901    0.007564       0.737088
# 4   131.0  1.0  256.0   185.800793   0.004608    0.007100       0.727106
# 5   131.0  2.0  256.0   190.811166   0.005589    0.007818       0.718532
# 6   262.0  0.0   64.0   185.952046   0.005778    0.005202       1.333929
# 7   262.0  1.0   64.0   187.747580   0.008311    0.009413       1.324555
# 8   262.0  2.0   64.0   185.839934   0.005773    0.006004       1.331860
# 9   262.0  0.0  256.0   186.023766   0.008632    0.010286       1.335139
# 10  262.0  1.0  256.0   186.131282   0.005788    0.006931       1.312424
# 11  262.0  2.0  256.0   187.237704   0.008753    0.007776       1.331096
# ...
