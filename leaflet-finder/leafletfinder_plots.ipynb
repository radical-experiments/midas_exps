# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
stampede_frame1_128c_1809w_1_128 = open('Vanilla/Iteration3/reports/stampede_frame1_128c_1809w_1-128.csv')
stampede_frame1_128c_1809w_2_128 = open('Vanilla/Iteration3/reports/stampede_frame1_128c_1809w_2-128.csv')
stampede_frame1_128c_1809w_3_128 = open('Vanilla/Iteration3/reports/stampede_frame1_128c_1809w_3-128.csv')
stampede_frame1_16c_1809w_1_16 = open('Vanilla/Iteration3/reports/stampede_frame1_16c_1809w_1-16.csv')
stampede_frame1_16c_1809w_2_16 = open('Vanilla/Iteration3/reports/stampede_frame1_16c_1809w_2-16.csv')
stampede_frame1_16c_1809w_3_16 = open('Vanilla/Iteration3/reports/stampede_frame1_16c_1809w_3-16.csv')
stampede_frame1_32c_1809w_1_32 = open('Vanilla/Iteration3/reports/stampede_frame1_32c_1809w_1-32.csv')
stampede_frame1_32c_1809w_2_32 = open('Vanilla/Iteration3/reports/stampede_frame1_32c_1809w_2-32.csv')
stampede_frame1_32c_1809w_3_32 = open('Vanilla/Iteration3/reports/stampede_frame1_32c_1809w_3-32.csv')
stampede_frame1_64c_1809w_1_64 = open('Vanilla/Iteration3/reports/stampede_frame1_64c_1809w_1-64.csv')
stampede_frame1_64c_1809w_2_64 = open('Vanilla/Iteration3/reports/stampede_frame1_64c_1809w_2-64.csv')
stampede_frame1_64c_1809w_3_64 = open('Vanilla/Iteration3/reports/stampede_frame1_64c_1809w_3-64.csv')



leaflet_128c_1809w_1_128 = csv.reader(stampede_frame1_128c_1809w_1_128)
leaflet_128c_1809w_2_128 = csv.reader(stampede_frame1_128c_1809w_2_128)
leaflet_128c_1809w_3_128 = csv.reader(stampede_frame1_128c_1809w_3_128)
leaflet_16c_1809w_1_16 = csv.reader(stampede_frame1_16c_1809w_1_16)
leaflet_16c_1809w_2_16 = csv.reader(stampede_frame1_16c_1809w_2_16)
leaflet_16c_1809w_3_16 = csv.reader(stampede_frame1_16c_1809w_3_16)
leaflet_32c_1809w_1_32 = csv.reader(stampede_frame1_32c_1809w_1_32)
leaflet_32c_1809w_2_32 = csv.reader(stampede_frame1_32c_1809w_2_32)
leaflet_32c_1809w_3_32 = csv.reader(stampede_frame1_32c_1809w_3_32)
leaflet_64c_1809w_1_64 = csv.reader(stampede_frame1_64c_1809w_1_64)
leaflet_64c_1809w_2_64 = csv.reader(stampede_frame1_64c_1809w_2_64)
leaflet_64c_1809w_3_64 = csv.reader(stampede_frame1_64c_1809w_3_64)

# %%
leaflet_128_1_dist = list()
for row in leaflet_128c_1809w_1_128:
    if row[1].startswith('Euclidean'):
        leaflet_128_1_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_128_1_con = float(row[-1])
        
leaflet_128_2_dist = list()
for row in leaflet_128c_1809w_2_128:
    if row[1].startswith('Euclidean'):
        leaflet_128_2_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_128_2_con = float(row[-1])

leaflet_128_3_dist = list()
for row in leaflet_128c_1809w_3_128:
    if row[1].startswith('Euclidean'):
        leaflet_128_3_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_128_3_con = float(row[-1])
        
leaflet_64_1_dist = list()
for row in leaflet_64c_1809w_1_64:
    if row[1].startswith('Euclidean'):
        leaflet_64_1_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_64_1_con = float(row[-1])

leaflet_64_2_dist = list()
for row in leaflet_64c_1809w_2_64:
    if row[1].startswith('Euclidean'):
        leaflet_64_2_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_64_2_con = float(row[-1])

leaflet_64_3_dist = list()
for row in leaflet_64c_1809w_3_64:
    if row[1].startswith('Euclidean'):
        leaflet_64_3_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_64_3_con = float(row[-1])


leaflet_32_1_dist = list()
for row in leaflet_32c_1809w_1_32:
    if row[1].startswith('Euclidean'):
        leaflet_32_1_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_32_1_con = float(row[-1])
        
leaflet_32_2_dist = list()
for row in leaflet_32c_1809w_2_32:
    if row[1].startswith('Euclidean'):
        leaflet_32_2_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_32_2_con = float(row[-1])

leaflet_32_3_dist = list()
for row in leaflet_32c_1809w_3_32:
    if row[1].startswith('Euclidean'):
        leaflet_32_3_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_32_3_con = float(row[-1])

leaflet_16_1_dist = list()
for row in leaflet_16c_1809w_1_16:
    if row[1].startswith('Euclidean'):
        leaflet_16_1_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_16_1_con = float(row[-1])
        
leaflet_16_2_dist = list()
for row in leaflet_16c_1809w_2_16:
    if row[1].startswith('Euclidean'):
        leaflet_16_2_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_16_2_con = float(row[-1])

leaflet_16_3_dist = list()
for row in leaflet_16c_1809w_3_16:
    if row[1].startswith('Euclidean'):
        leaflet_16_3_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_16_3_con = float(row[-1])

# %%
print leaflet_64_1_dist
# Out:
# [203.872479916, 198.331706047, 199.471091032, 196.261132002, 198.450484037, 198.419720888, 199.422571898, 199.505461931, 195.17523694, 196.272031069, 37.3195300102, 36.2519230843, 38.3767149448, 37.3191890717, 38.3796789646, 36.2779569626, 36.2783808708, 53.4766440392, 37.343957901, 37.3422448635, 86.8206670284, 87.9719259739, 90.0862150192, 89.0401520729, 89.0380969048, 85.7332010269, 87.9157788754, 87.8638749123, 71.6494688988, 84.6707649231, 157.925181866, 159.053543091, 157.936668873, 160.14745307, 161.335241079, 161.340775013, 162.413112879, 161.366174936, 161.390938997, 162.438658953, 226.424851894, 226.45007205, 227.512554884, 227.524203062, 224.221937895, 226.470788002, 44.7598779202, 45.9172589779, 233.088914871, 228.789448977, 205.939821959, 204.938951969, 44.8038699627, 47.0872528553, 45.9612350464, 30.1188049316, 44.8335199356, 43.7103440762, 47.110820055, 38.4987530708, 128.334044933, 127.203645945, 128.342375994, 127.22840786, 205.996404886, 129.388495922, 131.554606915
# ...

# %%
leaflet_128_dist = np.mean([np.max(leaflet_128_1_dist),np.max(leaflet_128_2_dist),np.max(leaflet_128_3_dist)])
leaflet_128_con = np.mean([leaflet_128_1_con,leaflet_128_2_con,leaflet_128_3_con])
leaflet_64_dist = np.mean([np.max(leaflet_64_1_dist),np.max(leaflet_64_2_dist),np.max(leaflet_64_3_dist)])
leaflet_64_con = np.mean([leaflet_64_1_con,leaflet_64_2_con,leaflet_64_3_con])
leaflet_32_dist = np.mean([np.max(leaflet_32_1_dist),np.max(leaflet_32_2_dist),np.max(leaflet_32_3_dist)])
leaflet_32_con = np.mean([leaflet_32_1_con,leaflet_32_2_con,leaflet_32_3_con])
leaflet_16_dist = np.mean([np.max(leaflet_16_1_dist),np.max(leaflet_16_2_dist),np.max(leaflet_16_3_dist)])
leaflet_16_con = np.mean([leaflet_16_1_con,leaflet_16_2_con,leaflet_16_3_con])

# %%
leaflet_spark_16_dist = 284
leaflet_spark_16_con = 2285
leaflet_spark_32_dist = 285
leaflet_spark_32_con = 2325
leaflet_spark_64_dist = 122
leaflet_spark_64_con = 1435
leaflet_spark_128_dist = 120
leaflet_spark_128_con = 1457
leaflet_spark_256_dist = 121
leaflet_spark_256_con = 1845

# %%
-

# %%
dir(a)
# Out:
# ['_Figure__remove_ax',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__getstate__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_agg_filter',
#  '_alpha',
#  '_animated',
#  '_axobservers',
#  '_axstack',
#  '_cachedRenderer',
#  '_clipon',
#  '_clippath',
#  '_contains',
#  '_dpi',
#  '_gci',
#  '_get_axes',
#  '_get_dpi',
#  '_gid',
#  '_hold',
#  '_label',
#  '_make_key',
#  '_mouseover',
#  '_oid',
#  '_path_effects',
#  '_picker',
#  '_propobservers',
#  '_rasterized',
#  '_remove_method',
#  '_repr_html_',
#  '_set_artist_props',
#  '_set_dpi',
#  '_set_gc_clip',
#  '_sketch',
#  '_snap',
#  '_stale',
#  '_suptitle',
#  '_tight',
#  '_tight_parameters',
#  '_transform',
#  '_transformSet',
#  '_url',
#  '_visible',
#  'add_axes',
# ...

# %%
leaflet_256_1_dist = list()
for row in leaflet_256c_5398w_1_256:
    if row[1].startswith('Euclidean'):
        leaflet_256_1_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_256_1_con = float(row[-1])
        
leaflet_256_2_dist = list()
for row in leaflet_256c_5398w_2_256:
    if row[1].startswith('Euclidean'):
        leaflet_256_2_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_256_2_con = float(row[-1])

leaflet_256_3_dist = list()
for row in leaflet_256c_5398w_3_256:
    if row[1].startswith('Euclidean'):
        leaflet_256_3_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_256_3_con = float(row[-1])

leaflet_128_1_dist = list()
for row in leaflet_128c_5398w_1_128:
    if row[1].startswith('Euclidean'):
        leaflet_128_1_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_128_1_con = float(row[-1])
        
leaflet_128_2_dist = list()
for row in leaflet_128c_5398w_2_128:
    if row[1].startswith('Euclidean'):
        leaflet_128_2_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_128_2_con = float(row[-1])

leaflet_128_3_dist = list()
for row in leaflet_128c_5398w_3_128:
    if row[1].startswith('Euclidean'):
        leaflet_128_3_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_128_3_con = float(row[-1])
        
leaflet_64_1_dist = list()
for row in leaflet_64c_5398w_1_64:
    if row[1].startswith('Euclidean'):
        leaflet_64_1_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_64_1_con = float(row[-1])

leaflet_64_2_dist = list()
for row in leaflet_64c_5398w_2_64:
    if row[1].startswith('Euclidean'):
        leaflet_64_2_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_64_2_con = float(row[-1])

leaflet_64_3_dist = list()
for row in leaflet_64c_5398w_3_64:
    if row[1].startswith('Euclidean'):
        leaflet_64_3_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_64_3_con = float(row[-1])


leaflet_32_1_dist = list()
for row in leaflet_32c_5398w_1_32:
    if row[1].startswith('Euclidean'):
        leaflet_32_1_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_32_1_con = float(row[-1])
        
leaflet_32_2_dist = list()
for row in leaflet_32c_5398w_2_32:
    if row[1].startswith('Euclidean'):
        leaflet_32_2_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_32_2_con = float(row[-1])

leaflet_32_3_dist = list()
for row in leaflet_32c_5398w_3_32:
    if row[1].startswith('Euclidean'):
        leaflet_32_3_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_32_3_con = float(row[-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-19f02826af97> in <module>()
#       1 leaflet_256_1_dist = list()
# ----> 2 for row in leaflet_256c_5398w_1_256:
#       3     if row[1].startswith('Euclidean'):
#       4         leaflet_256_1_dist.append(float(row[-1]))
#       5     elif row[1].startswith('ConnComp'):
#
# NameError: name 'leaflet_256c_5398w_1_256' is not defined

# %%
leaflet_256_dist = np.mean([np.max(leaflet_256_1_dist),np.max(leaflet_256_2_dist),np.max(leaflet_256_3_dist)])
leaflet_256_con = np.mean([leaflet_256_1_con,leaflet_256_2_con,leaflet_256_3_con])
leaflet_128_dist = np.mean([np.max(leaflet_128_1_dist),np.max(leaflet_128_2_dist),np.max(leaflet_128_3_dist)])
leaflet_128_con = np.mean([leaflet_128_1_con,leaflet_128_2_con,leaflet_128_3_con])
leaflet_32_dist = np.mean([np.max(leaflet_64_1_dist),np.max(leaflet_64_2_dist),np.max(leaflet_64_3_dist)])
leaflet_64_con = np.mean([leaflet_64_1_con,leaflet_64_2_con,leaflet_64_3_con])
leaflet_32_dist = np.mean([np.max(leaflet_32_1_dist),np.max(leaflet_32_2_dist),np.max(leaflet_32_3_dist)])
leaflet_32_con = np.mean([leaflet_32_1_con,leaflet_32_2_con,leaflet_32_3_con])

# %%
leaflet_spark_32_dist = np.mean([2356,2486,2370])
leaflet_spark_32_con = np.mean([54,56,54])+leaflet_spark_32_dist
leaflet_spark_64_dist = np.mean([1201,1291,1250])
leaflet_spark_64_con = np.mean([54,55,54])+leaflet_spark_64_dist
leaflet_spark_128_dist = np.mean([545,524,540])
leaflet_spark_128_con = np.mean([54,55,54])+leaflet_spark_128_dist
leaflet_spark_256_dist = np.mean([348,350,325])
leaflet_spark_256_con = np.mean([55,54,53])+leaflet_spark_256_dist

# %%
-

# %%
comet_frame1_5398w_1_48 = open('Vanilla/Iteration4/leaflet1co-192.csv')
comet_frame1_5398w_2_48 = open('Vanilla/Iteration4/leaflet2co-192.csv')
comet_frame1_5398w_3_48 = open('Vanilla/Iteration4/leaflet3co-192.csv')
comet_frame1_5398w_1_96 = open('Vanilla/Iteration4/leaflet1co-384.csv')
comet_frame1_5398w_2_96 = open('Vanilla/Iteration4/leaflet2co-384.csv')
comet_frame1_5398w_3_96 = open('Vanilla/Iteration4/leaflet3co-384.csv')
comet_frame1_5398w_1_192 = open('Vanilla/Iteration4/leaflet1co-768.csv')
comet_frame1_5398w_2_192 = open('Vanilla/Iteration4/leaflet2co-768.csv')
comet_frame1_5398w_3_192 = open('Vanilla/Iteration4/leaflet3co-768.csv')
comet_frame1_5398w_1_384 = open('Vanilla/Iteration4/leaflet1co-1536.csv')
comet_frame1_5398w_2_384 = open('Vanilla/Iteration4/leaflet2co-1536.csv')
comet_frame1_5398w_3_384 = open('Vanilla/Iteration4/leaflet3co-1536.csv')

leaflet_5398w_1_48 = csv.reader(comet_frame1_5398w_1_48)
leaflet_5398w_2_48 = csv.reader(comet_frame1_5398w_2_48)
leaflet_5398w_3_48 = csv.reader(comet_frame1_5398w_3_48)
leaflet_5398w_1_96 = csv.reader(comet_frame1_5398w_1_96)
leaflet_5398w_2_96 = csv.reader(comet_frame1_5398w_2_96)
leaflet_5398w_3_96 = csv.reader(comet_frame1_5398w_3_96)
leaflet_5398w_1_192 = csv.reader(comet_frame1_5398w_1_192)
leaflet_5398w_2_192 = csv.reader(comet_frame1_5398w_2_192)
leaflet_5398w_3_192 = csv.reader(comet_frame1_5398w_3_192)
leaflet_5398w_1_384 = csv.reader(comet_frame1_5398w_1_384)
leaflet_5398w_2_384 = csv.reader(comet_frame1_5398w_2_384)
leaflet_5398w_3_384 = csv.reader(comet_frame1_5398w_3_384)

# %%
leaflet_384_1_dist = list()
for row in leaflet_5398w_1_384:
    if row[1].startswith('Euclidean'):
        leaflet_384_1_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_384_1_con = float(row[-1])
        
leaflet_384_2_dist = list()
for row in leaflet_5398w_2_384:
    if row[1].startswith('Euclidean'):
        leaflet_384_2_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_384_2_con = float(row[-1])

leaflet_384_3_dist = list()
for row in leaflet_5398w_3_384:
    if row[1].startswith('Euclidean'):
        leaflet_384_3_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_384_3_con = float(row[-1])

leaflet_192_1_dist = list()
for row in leaflet_5398w_1_192:
    if row[1].startswith('Euclidean'):
        leaflet_192_1_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_192_1_con = float(row[-1])
        
leaflet_192_2_dist = list()
for row in leaflet_5398w_2_192:
    if row[1].startswith('Euclidean'):
        leaflet_192_2_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_192_2_con = float(row[-1])

leaflet_192_3_dist = list()
for row in leaflet_5398w_3_192:
    if row[1].startswith('Euclidean'):
        leaflet_192_3_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_192_3_con = float(row[-1])
        
leaflet_96_1_dist = list()
for row in leaflet_5398w_1_96:
    if row[1].startswith('Euclidean'):
        leaflet_96_1_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_96_1_con = float(row[-1])

leaflet_96_2_dist = list()
for row in leaflet_5398w_2_96:
    if row[1].startswith('Euclidean'):
        leaflet_96_2_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_96_2_con = float(row[-1])

leaflet_96_3_dist = list()
for row in leaflet_5398w_3_96:
    if row[1].startswith('Euclidean'):
        leaflet_96_3_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_96_3_con = float(row[-1])


leaflet_48_1_dist = list()
for row in leaflet_5398w_1_48:
    if row[1].startswith('Euclidean'):
        leaflet_48_1_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_48_1_con = float(row[-1])
        
leaflet_48_2_dist = list()
for row in leaflet_5398w_2_48:
    if row[1].startswith('Euclidean'):
        leaflet_48_2_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_48_2_con = float(row[-1])

leaflet_48_3_dist = list()
for row in leaflet_5398w_3_48:
    if row[1].startswith('Euclidean'):
        leaflet_48_3_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        leaflet_48_3_con = float(row[-1])

# %%
leaflet_384_dist = np.mean([np.max(leaflet_384_1_dist),np.max(leaflet_384_2_dist),np.max(leaflet_384_3_dist)])
leaflet_384_con = np.mean([leaflet_384_1_con,leaflet_384_2_con,leaflet_384_3_con])
leaflet_192_dist = np.mean([np.max(leaflet_192_1_dist),np.max(leaflet_192_2_dist),np.max(leaflet_192_3_dist)])
leaflet_192_con = np.mean([leaflet_192_1_con,leaflet_192_2_con,leaflet_192_3_con])
leaflet_96_dist = np.mean([np.max(leaflet_96_1_dist),np.max(leaflet_96_2_dist),np.max(leaflet_96_3_dist)])
leaflet_96_con = np.mean([leaflet_96_1_con,leaflet_96_2_con,leaflet_96_3_con])
leaflet_48_dist = np.mean([np.max(leaflet_48_1_dist),np.max(leaflet_48_2_dist),np.max(leaflet_48_3_dist)])
leaflet_48_con = np.mean([leaflet_48_1_con,leaflet_48_2_con,leaflet_48_3_con])

leaflet_384_dist_std = np.std([np.max(leaflet_384_1_dist),np.max(leaflet_384_2_dist),np.max(leaflet_384_3_dist)])
leaflet_384_con_std = np.std([leaflet_384_1_con,leaflet_384_2_con,leaflet_384_3_con])
leaflet_192_dist_std = np.std([np.max(leaflet_192_1_dist),np.max(leaflet_192_2_dist),np.max(leaflet_192_3_dist)])
leaflet_192_con_std = np.std([leaflet_192_1_con,leaflet_192_2_con,leaflet_192_3_con])
leaflet_96_dist_std = np.std([np.max(leaflet_96_1_dist),np.max(leaflet_96_2_dist),np.max(leaflet_96_3_dist)])
leaflet_96_con_std = np.std([leaflet_96_1_con,leaflet_96_2_con,leaflet_96_3_con])
leaflet_48_dist_std = np.std([np.max(leaflet_48_1_dist),np.max(leaflet_48_2_dist),np.max(leaflet_48_3_dist)])
leaflet_48_con_std = np.std([leaflet_48_1_con,leaflet_48_2_con,leaflet_48_3_con])

# %%
leaflet_spark_48_dist = np.mean([1421,1355,1392])
leaflet_spark_48_con = np.mean([54,53,54])+leaflet_spark_48_dist
leaflet_spark_96_dist = np.mean([757,756,712])
leaflet_spark_96_con = np.mean([54,54,54])+leaflet_spark_96_dist
leaflet_spark_192_dist = np.mean([417,393,396])
leaflet_spark_192_con = np.mean([53,54,54])+leaflet_spark_192_dist
leaflet_spark_384_dist = np.mean([393,370,367])
leaflet_spark_384_con = np.mean([54,53,53])+leaflet_spark_384_dist

leaflet_spark_48_dist_std = np.std([1421,1355,1392])
leaflet_spark_48_con_std = np.std([54,53,54])
leaflet_spark_96_dist_std = np.std([757,756,712])
leaflet_spark_96_con_std = np.std([54,54,54])
leaflet_spark_192_dist_std = np.std([417,393,396])
leaflet_spark_192_con_std = np.std([53,54,54])
leaflet_spark_384_dist_std = np.std([393,370,367])
leaflet_spark_384_con_std = np.std([54,53,53])

# %%
-

# %%
leaflet_spark_r21_48_dist = np.mean([1842,1841,1720])
leaflet_spark_r21_48_con = np.mean([55,56,55])+leaflet_spark_r21_48_dist
leaflet_spark_r21_96_dist = np.mean([754,797,781])
leaflet_spark_r21_96_con = np.mean([54,54,55])+leaflet_spark_r21_96_dist
leaflet_spark_r21_192_dist = np.mean([393,408,388])
leaflet_spark_r21_192_con = np.mean([54,54,54])+leaflet_spark_r21_192_dist
leaflet_spark_r21_384_dist = np.mean([273,458,419])
leaflet_spark_r21_384_con = np.mean([54,54,54])+leaflet_spark_r21_384_dist

leaflet_spark_r21_48_dist_std = np.std([1842,1841,1720])
leaflet_spark_r21_48_con_std = np.std([55,56,55])
leaflet_spark_r21_96_dist_std = np.std([754,797,781])
leaflet_spark_r21_96_con_std = np.std([54,54,55])
leaflet_spark_r21_192_dist_std = np.std([393,408,388])
leaflet_spark_r21_192_con_std = np.std([54,54,54])
leaflet_spark_r21_384_dist_std = np.std([273,458,419])
leaflet_spark_r21_384_con_std = np.std([54,54,54])

# %%
a=plt.figure()
plt.title('Time to Completion @ Comet,~145k atoms')
plt.ylabel('Time to Completion (secs)',fontsize=14)
n_groups=4
index=np.arange(n_groups)
bar_width=0.25
opacity=1.0
a1=plt.bar(index,[leaflet_48_con,leaflet_96_con,leaflet_192_con,leaflet_384_con],bar_width,alpha=opacity,color='darkgreen')
a2=plt.bar(index,[leaflet_48_dist,leaflet_96_dist,leaflet_192_dist,leaflet_384_dist],bar_width,alpha=opacity,color='blue')
b1 = plt.bar(index+bar_width,[leaflet_spark_48_con,leaflet_spark_96_con,leaflet_spark_192_con,leaflet_spark_384_con],bar_width,alpha=opacity,color='orange')
b2 = plt.bar(index+bar_width,[leaflet_spark_48_dist,leaflet_spark_96_dist,leaflet_spark_192_dist,leaflet_spark_384_dist],bar_width,alpha=opacity,color='red')
c1 = plt.bar(index+2*bar_width,[leaflet_spark_r21_48_con,leaflet_spark_r21_96_con,leaflet_spark_r21_192_con,leaflet_spark_r21_384_con],bar_width,alpha=opacity,color='black')
c2 = plt.bar(index+2*bar_width,[leaflet_spark_r21_48_dist,leaflet_spark_r21_96_dist,leaflet_spark_r21_192_dist,leaflet_spark_r21_384_dist],bar_width,alpha=opacity,color='grey')
plt.xticks(index+1.5*bar_width,('48','96','192','384'))
plt.xlabel('Number of cores')
lgd=plt.figlegend((a1,a2,b1,b2,c1,c2),('RADICAL-Pilot Conn Comp','RADICAL-Pilot Adj Matrix Calc','RADICAL-Pilot-Spark Conn Comp','RADICAL-Pilot-Spark Adj Matrix Calc','RADICAL-Pilot-Spark Conn Comp Ratio 2:1','RADICAL-Pilot-Spark Adj Matrix Calc Ratio 2:1'),
              loc='lower center',ncol=2,fontsize=9,borderaxespad=0.15)
a.subplots_adjust(bottom=0.30)
plt.ylim(ymax=2000)
a.savefig('leafletfinder_rp_spark_comet_ratio21.png',dpi=800,bbox_extra_artists=(lgd,))

# %%
leaflet_spark_win_impl_48_dist = np.mean([1371,1285,1262])
leaflet_spark_win_impl_48_con = np.mean([57,57,57])+leaflet_spark_win_impl_48_dist
leaflet_spark_win_impl_96_dist = np.mean([709,822,661])
leaflet_spark_win_impl_96_con = np.mean([57,57,57])+leaflet_spark_win_impl_96_dist
leaflet_spark_win_impl_192_dist = np.mean([368,373,357])
leaflet_spark_win_impl_192_con = np.mean([57,56,57])+leaflet_spark_win_impl_192_dist
leaflet_spark_win_impl_384_dist = np.mean([203,201,198])
leaflet_spark_win_impl_384_con = np.mean([56,56,57])+leaflet_spark_win_impl_384_dist

leaflet_spark_win_impl_48_dist_std = np.std([1371,1285,1262])
leaflet_spark_win_impl_48_con_std = np.std([57,57,57])
leaflet_spark_win_impl_96_dist_std = np.std([709,822,661])
leaflet_spark_win_impl_96_con_std = np.std([57,57,57])
leaflet_spark_win_impl_192_dist_std = np.std([368,373,357])
leaflet_spark_win_impl_192_con_std = np.std([57,56,57])
leaflet_spark_win_impl_384_dist_std = np.std([203,201,198])
leaflet_spark_win_impl_384_con_std = np.std([56,56,57])

# %%
a=plt.figure()
plt.title('Time to Completion @ Comet,~145k atoms')
plt.ylabel('Time to Completion (secs)',fontsize=14)
n_groups=4
index=np.arange(n_groups)
bar_width=0.20
opacity=1.0
a1=plt.bar(index,[leaflet_48_con,
                  leaflet_96_con,
                  leaflet_192_con,
                  leaflet_384_con],
                  bar_width,
            yerr=[leaflet_48_con_std,
                  leaflet_96_con_std,
                  leaflet_192_con_std,
                  leaflet_384_con_std],
           alpha=opacity,color='darkgreen')
a2=plt.bar(index,[leaflet_48_dist,
                  leaflet_96_dist,
                  leaflet_192_dist,
                  leaflet_384_dist],
                  bar_width,
            yerr=[leaflet_48_dist_std,
                  leaflet_96_dist_std,
                  leaflet_192_dist_std,
                  leaflet_384_dist_std],
                  alpha=opacity,color='blue')
b1 = plt.bar(index+bar_width,[leaflet_spark_48_con,
                              leaflet_spark_96_con,
                              leaflet_spark_192_con,
                              leaflet_spark_384_con],
                              bar_width,
                        yerr=[leaflet_spark_48_con_std,
                              leaflet_spark_96_con_std,
                              leaflet_spark_192_con_std,
                              leaflet_spark_384_con_std],
                              alpha=opacity,color='orange')
b2 = plt.bar(index+bar_width,[leaflet_spark_48_dist,
                              leaflet_spark_96_dist,
                              leaflet_spark_192_dist,
                              leaflet_spark_384_dist],
                              bar_width,
                        yerr=[leaflet_spark_48_dist_std,
                              leaflet_spark_96_dist_std,
                              leaflet_spark_192_dist_std,
                              leaflet_spark_384_dist_std],
                              alpha=opacity,color='red')
c1 = plt.bar(index+2*bar_width,[leaflet_spark_r21_48_con,
                                leaflet_spark_r21_96_con,
                                leaflet_spark_r21_192_con,
                                leaflet_spark_r21_384_con],
                                bar_width,
                          yerr=[leaflet_spark_r21_48_con_std,
                                leaflet_spark_r21_96_con_std,
                                leaflet_spark_r21_192_con_std,
                                leaflet_spark_r21_384_con_std],
                                alpha=opacity,color='black')
c2 = plt.bar(index+2*bar_width,[leaflet_spark_r21_48_dist,
                                leaflet_spark_r21_96_dist,
                                leaflet_spark_r21_192_dist,
                                leaflet_spark_r21_384_dist],
                                bar_width,
                          yerr=[leaflet_spark_r21_48_dist_std,
                                leaflet_spark_r21_96_dist_std,
                                leaflet_spark_r21_192_dist_std,
                                leaflet_spark_r21_384_dist_std],
                                alpha=opacity,color='grey')
d1 = plt.bar(index+3*bar_width,[leaflet_spark_win_impl_48_con,
                                leaflet_spark_win_impl_96_con,
                                leaflet_spark_win_impl_192_con,
                                leaflet_spark_win_impl_384_con],bar_width,
                          yerr=[leaflet_spark_win_impl_48_con_std,
                                leaflet_spark_win_impl_96_con_std,
                                leaflet_spark_win_impl_192_con_std,
                                leaflet_spark_win_impl_384_con_std],
                                alpha=opacity,color='cyan')
d2 = plt.bar(index+3*bar_width,[leaflet_spark_win_impl_48_dist,
                                leaflet_spark_win_impl_96_dist,
                                leaflet_spark_win_impl_192_dist,
                                leaflet_spark_win_impl_384_dist],
                                bar_width,
                          yerr=[leaflet_spark_win_impl_48_dist_std,
                                leaflet_spark_win_impl_96_dist_std,
                                leaflet_spark_win_impl_192_dist_std,
                                leaflet_spark_win_impl_384_dist_std],
                                alpha=opacity,color='lightcyan')
plt.xticks(index+2*bar_width,('48','96','192','384'))
plt.xlabel('Number of cores')
lgd=plt.figlegend((a1,a2,b1,b2,c1,c2,d1,d2),
    ('RADICAL-Pilot Conn Comp','RADICAL-Pilot Adj Matrix Calc',\
     'RADICAL-Pilot-Spark Conn Comp','RADICAL-Pilot-Spark Adj Matrix Calc',\
     'RADICAL-Pilot-Spark Conn Comp Ratio 2:1','RADICAL-Pilot-Spark Adj Matrix Calc Ratio 2:1',\
     'RADICAL-Pilot-Spark Conn Comp Window','RADICAL-Pilot-Spark Adj Matrix Calc Window'),
              loc='lower center',ncol=2,fontsize=8.5,borderaxespad=0.15)
a.subplots_adjust(bottom=0.30)
plt.ylim(ymax=2000)
a.savefig('leafletfinder_rp_spark_comet_win.pdf',bbox_extra_artists=(lgd,))

# %%
comet_similar_spark_48_1=open('Vanilla/Iteration5/lf_48_1-192.csv')
comet_similar_spark_48_2=open('Vanilla/Iteration5/lf_48_2-192.csv')
comet_similar_spark_48_3=open('Vanilla/Iteration5/lf_48_3-192.csv')
comet_similar_spark_96_1=open('Vanilla/Iteration5/lf_96_1-384.csv')
comet_similar_spark_96_2=open('Vanilla/Iteration5/lf_96_2-384.csv')
comet_similar_spark_96_3=open('Vanilla/Iteration5/lf_96_3-384.csv')
comet_similar_spark_192_1=open('Vanilla/Iteration5/lf_192_1-768.csv')
comet_similar_spark_192_2=open('Vanilla/Iteration5/lf_192_2-768.csv')
comet_similar_spark_192_3=open('Vanilla/Iteration5/lf_192_3-768.csv')
comet_similar_spark_384_1=open('Vanilla/Iteration5/lf_384_1-1536.csv')
comet_similar_spark_384_2=open('Vanilla/Iteration5/lf_384_2-1536.csv')
comet_similar_spark_384_3=open('Vanilla/Iteration5/lf_384_3-1536.csv')

leaflet_similar_spark_48_1 = csv.reader(comet_similar_spark_48_1)
leaflet_similar_spark_48_2 = csv.reader(comet_similar_spark_48_2)
leaflet_similar_spark_48_3 = csv.reader(comet_similar_spark_48_3)
leaflet_similar_spark_96_1 = csv.reader(comet_similar_spark_96_1)
leaflet_similar_spark_96_2 = csv.reader(comet_similar_spark_96_2)
leaflet_similar_spark_96_3 = csv.reader(comet_similar_spark_96_3)
leaflet_similar_spark_192_1 = csv.reader(comet_similar_spark_192_1)
leaflet_similar_spark_192_2 = csv.reader(comet_similar_spark_192_2)
leaflet_similar_spark_192_3 = csv.reader(comet_similar_spark_192_3)
leaflet_similar_spark_384_1 = csv.reader(comet_similar_spark_384_1)
leaflet_similar_spark_384_2 = csv.reader(comet_similar_spark_384_2)
leaflet_similar_spark_384_3 = csv.reader(comet_similar_spark_384_3)

# %%
lf_48_1_dist = list()
for row in leaflet_similar_spark_48_1:
    if row[1].startswith('Euclidean'):
        lf_48_1_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lf_48_1_con = float(row[-1])
        
lf_48_2_dist = list()
for row in leaflet_similar_spark_48_2:
    if row[1].startswith('Euclidean'):
        lf_48_2_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lf_48_2_con = float(row[-1])

lf_48_3_dist = list()
for row in leaflet_similar_spark_48_3:
    if row[1].startswith('Euclidean'):
        lf_48_3_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lf_48_3_con = float(row[-1])

lf_96_1_dist = list()
for row in leaflet_similar_spark_96_1:
    if row[1].startswith('Euclidean'):
        lf_96_1_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lf_96_1_con = float(row[-1])

lf_96_2_dist = list()
for row in leaflet_similar_spark_96_2:
    if row[1].startswith('Euclidean'):
        lf_96_2_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lf_96_2_con = float(row[-1])

lf_96_3_dist = list()
for row in leaflet_similar_spark_96_3:
    if row[1].startswith('Euclidean'):
        lf_96_3_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lf_96_3_con = float(row[-1])

lf_192_1_dist = list()
for row in leaflet_similar_spark_192_1:
    if row[1].startswith('Euclidean'):
        lf_192_1_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lf_192_1_con = float(row[-1])
        
lf_192_2_dist = list()
for row in leaflet_similar_spark_192_2:
    if row[1].startswith('Euclidean'):
        lf_192_2_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lf_192_2_con = float(row[-1])

lf_192_3_dist = list()
for row in leaflet_similar_spark_192_3:
    if row[1].startswith('Euclidean'):
        lf_192_3_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lf_192_3_con = float(row[-1])
        
lf_384_1_dist = list()
for row in leaflet_similar_spark_384_1:
    if row[1].startswith('Euclidean'):
        lf_384_1_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lf_384_1_con = float(row[-1])
        
lf_384_2_dist = list()
for row in leaflet_similar_spark_384_2:
    if row[1].startswith('Euclidean'):
        lf_384_2_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lf_384_2_con = float(row[-1])

lf_384_3_dist = list()
for row in leaflet_similar_spark_384_3:
    if row[1].startswith('Euclidean'):
        lf_384_3_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lf_384_3_con = float(row[-1])

# %%
lf_48_dist = np.mean([np.max(lf_48_1_dist),np.max(lf_48_2_dist),np.max(lf_48_3_dist)])
lf_48_con  = np.mean([lf_48_1_con,lf_48_2_con,lf_48_3_con])
lf_96_dist = np.mean([np.max(lf_96_1_dist),np.max(lf_96_2_dist),np.max(lf_96_3_dist)])
lf_96_con  = np.mean([lf_96_1_con,lf_96_2_con,lf_96_3_con])
lf_192_dist = np.mean([np.max(lf_192_1_dist),np.max(lf_192_2_dist),np.max(lf_192_3_dist)])
lf_192_con  = np.mean([lf_192_1_con,lf_192_2_con,lf_192_3_con])
lf_384_dist = np.mean([np.max(lf_384_1_dist),np.max(lf_384_2_dist),np.max(lf_384_3_dist)])
lf_384_con  = np.mean([lf_384_1_con,lf_384_2_con,lf_384_3_con])

# %%
a=plt.figure()
plt.title('Time to Completion @ Comet,~145k atoms')
plt.ylabel('Time to Completion (secs)',fontsize=14)
n_groups=4
index=np.arange(n_groups)
bar_width=0.25
opacity=1.0
a1=plt.bar(index,[lf_48_con,lf_96_con,lf_192_con,lf_384_con],bar_width,alpha=opacity,color='darkgreen')
a2=plt.bar(index,[lf_48_dist,lf_96_dist,lf_192_dist,lf_384_dist],bar_width,alpha=opacity,color='blue')
b1 = plt.bar(index+bar_width,[leaflet_spark_48_con,leaflet_spark_96_con,leaflet_spark_192_con,leaflet_spark_384_con],bar_width,alpha=opacity,color='orange')
b2 = plt.bar(index+bar_width,[leaflet_spark_48_dist,leaflet_spark_96_dist,leaflet_spark_192_dist,leaflet_spark_384_dist],bar_width,alpha=opacity,color='red')
plt.xticks(index+bar_width,('48','96','192','384'))
plt.xlabel('Number of cores')
lgd=plt.figlegend((a1,a2,b1,b2),('RADICAL-Pilot Conn Comp','RADICAL-Pilot Adj Matrix Calc','RADICAL-Pilot-Spark Conn Comp','RADICAL-Pilot-Spark Adj Matrix Calc'),
              loc='lower center',ncol=2,fontsize=9,borderaxespad=0.15)
a.subplots_adjust(bottom=0.2)
plt.ylim(ymax=3000)
a.savefig('leafletfinder_rp_spark_comet_samealgo.png',dpi=800,bbox_extra_artists=(lgd,))

# %%
#:Leaflet Finder Comet 1 core per task. Somewhat strong scaling. Vanilla RADICAL-Pilot
lfrp_1on1_21_1 = open('Vanilla/Iteration6/lfrp_1on1_21_1-96.csv')
lfrp_1on1_21_2 = open('Vanilla/Iteration6/lfrp_1on1_21_2-96.csv')
lfrp_1on1_21_3 = open('Vanilla/Iteration6/lfrp_1on1_21_3-96.csv')
lfrp_1on1_45_1 = open('Vanilla/Iteration6/lfrp_1on1_45_1-192.csv')
lfrp_1on1_45_2 = open('Vanilla/Iteration6/lfrp_1on1_45_2-192.csv')
lfrp_1on1_45_3 = open('Vanilla/Iteration6/lfrp_1on1_45_3-192.csv')
lfrp_1on1_171_1 = open('Vanilla/Iteration6/lfrp_1on1_171_1-696.csv')
lfrp_1on1_171_2 = open('Vanilla/Iteration6/lfrp_1on1_171_2-696.csv')
lfrp_1on1_171_3 = open('Vanilla/Iteration6/lfrp_1on1_171_3-696.csv')
lfrp_1on1_378_1 = open('Vanilla/Iteration4/leaflet1co-1536.csv')
lfrp_1on1_378_2 = open('Vanilla/Iteration4/leaflet2co-1536.csv')
lfrp_1on1_378_3 = open('Vanilla/Iteration4/leaflet3co-1536.csv')

leaflet_rp_1on1_21_1 = csv.reader(lfrp_1on1_21_1)
leaflet_rp_1on1_21_2 = csv.reader(lfrp_1on1_21_2)
leaflet_rp_1on1_21_3 = csv.reader(lfrp_1on1_21_3)
leaflet_rp_1on1_45_1 = csv.reader(lfrp_1on1_45_1)
leaflet_rp_1on1_45_2 = csv.reader(lfrp_1on1_45_2)
leaflet_rp_1on1_45_3 = csv.reader(lfrp_1on1_45_3)
leaflet_rp_1on1_171_1 = csv.reader(lfrp_1on1_171_1)
leaflet_rp_1on1_171_2 = csv.reader(lfrp_1on1_171_2)
leaflet_rp_1on1_171_3 = csv.reader(lfrp_1on1_171_3)
leaflet_rp_1on1_378_1 = csv.reader(lfrp_1on1_378_1)
leaflet_rp_1on1_378_2 = csv.reader(lfrp_1on1_378_2)
leaflet_rp_1on1_378_3 = csv.reader(lfrp_1on1_378_3)

# %%
lfrp_11_21_1_dist = list()
for row in leaflet_rp_1on1_21_1:
    if row[1].startswith('Euclidean'):
        lfrp_11_21_1_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lfrp_11_21_1_con = float(row[-1])
        
lfrp_11_21_2_dist = list()
for row in leaflet_rp_1on1_21_2:
    if row[1].startswith('Euclidean'):
        lfrp_11_21_2_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lfrp_11_21_2_con = float(row[-1])

lfrp_11_21_3_dist = list()
for row in leaflet_rp_1on1_21_3:
    if row[1].startswith('Euclidean'):
        lfrp_11_21_3_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lfrp_11_21_3_con = float(row[-1])

lfrp_11_45_1_dist = list()
for row in leaflet_rp_1on1_45_1:
    if row[1].startswith('Euclidean'):
        lfrp_11_45_1_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lfrp_11_45_1_con = float(row[-1])

lfrp_11_45_2_dist = list()
for row in leaflet_rp_1on1_45_2:
    if row[1].startswith('Euclidean'):
        lfrp_11_45_2_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lfrp_11_45_2_con = float(row[-1])

lfrp_11_45_3_dist = list()
for row in leaflet_rp_1on1_45_3:
    if row[1].startswith('Euclidean'):
        lfrp_11_45_3_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lfrp_11_45_3_con = float(row[-1])

lfrp_11_171_1_dist = list()
for row in leaflet_rp_1on1_171_1:
    if row[1].startswith('Euclidean'):
        lfrp_11_171_1_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lfrp_11_171_1_con = float(row[-1])
        
lfrp_11_171_2_dist = list()
for row in leaflet_rp_1on1_171_2:
    if row[1].startswith('Euclidean'):
        lfrp_11_171_2_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lfrp_11_171_2_con = float(row[-1])

lfrp_11_171_3_dist = list()
for row in leaflet_rp_1on1_171_3:
    if row[1].startswith('Euclidean'):
        lfrp_11_171_3_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lfrp_11_171_3_con = float(row[-1])
        
lfrp_11_378_1_dist = list()
for row in leaflet_rp_1on1_378_1:
    if row[1].startswith('Euclidean'):
        lfrp_11_378_1_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lfrp_11_378_1_con = float(row[-1])
        
lfrp_11_378_2_dist = list()
for row in leaflet_rp_1on1_378_2:
    if row[1].startswith('Euclidean'):
        lfrp_11_378_2_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lfrp_11_378_2_con = float(row[-1])

lfrp_11_378_3_dist = list()
for row in leaflet_rp_1on1_378_3:
    if row[1].startswith('Euclidean'):
        lfrp_11_378_3_dist.append(float(row[-1]))
    elif row[1].startswith('ConnComp'):
        lfrp_11_378_3_con = float(row[-1])

# %%
lfrp_11_21_dist = np.mean([np.max(lfrp_11_21_1_dist),np.max(lfrp_11_21_2_dist),np.max(lfrp_11_21_3_dist)])
lfrp_11_21_con = np.mean([lfrp_11_21_1_con,lfrp_11_21_2_con,lfrp_11_21_3_con])
lfrp_11_45_dist = np.mean([np.max(lfrp_11_45_1_dist),np.max(lfrp_11_45_2_dist),np.max(lfrp_11_45_3_dist)])
lfrp_11_45_con = np.mean([lfrp_11_45_1_con,lfrp_11_45_2_con,lfrp_11_45_3_con])
lfrp_11_171_dist = np.mean([np.max(lfrp_11_171_1_dist),np.max(lfrp_11_171_2_dist),np.max(lfrp_11_171_3_dist)])
lfrp_11_171_con = np.mean([lfrp_11_171_1_con,lfrp_11_171_2_con,lfrp_11_171_3_con])
lfrp_11_378_dist = np.mean([np.max(lfrp_11_378_1_dist),np.max(lfrp_11_378_2_dist),np.max(lfrp_11_378_3_dist)])
lfrp_11_378_con = np.mean([lfrp_11_378_1_con,lfrp_11_378_2_con,lfrp_11_378_3_con])

lfrp_11_21_dist_std = np.std([np.max(lfrp_11_21_1_dist),np.max(lfrp_11_21_2_dist),np.max(lfrp_11_21_3_dist)])
lfrp_11_21_con_std = np.std([lfrp_11_21_1_con,lfrp_11_21_2_con,lfrp_11_21_3_con])
lfrp_11_45_dist_std = np.std([np.max(lfrp_11_45_1_dist),np.max(lfrp_11_45_2_dist),np.max(lfrp_11_45_3_dist)])
lfrp_11_45_con_std = np.std([lfrp_11_45_1_con,lfrp_11_45_2_con,lfrp_11_45_3_con])
lfrp_11_171_dist_std = np.std([np.max(lfrp_11_171_1_dist),np.max(lfrp_11_171_2_dist),np.max(lfrp_11_171_3_dist)])
lfrp_11_171_con_std = np.std([lfrp_11_171_1_con,lfrp_11_171_2_con,lfrp_11_171_3_con])
lfrp_11_378_dist_std = np.std([np.max(lfrp_11_378_1_dist),np.max(lfrp_11_378_2_dist),np.max(lfrp_11_378_3_dist)])
lfrp_11_378_con_std = np.std([lfrp_11_378_1_con,lfrp_11_378_2_con,lfrp_11_378_3_con])

# %%
lfsp_11_21_dist = np.mean([3436,3216,3642])
lfsp_11_21_con = np.mean([57,57,56]) + lfsp_11_21_dist
lfsp_11_45_dist = np.mean([1503,1460,1556])
lfsp_11_45_con = np.mean([57,57,57]) + lfsp_11_45_dist
lfsp_11_171_dist = np.mean([426,444,433])
lfsp_11_171_con = np.mean([56,57,56]) + lfsp_11_171_dist
lfsp_11_378_dist = np.mean([209,208,207])
lfsp_11_378_con = np.mean([57,57,57]) + lfsp_11_378_dist
lfsp_11_1485_dist = np.mean([139,72,129])
lfsp_11_1485_con = np.mean([57,56,57]) + lfsp_11_1485_dist

lfsp_11_21_dist_std = np.std([3436,3216,3642])
lfsp_11_21_con_std = np.std([57,57,56])
lfsp_11_45_dist_std = np.std([1503,1460,1556])
lfsp_11_45_con_std = np.std([57,57,57])
lfsp_11_171_dist_std = np.std([426,444,433])
lfsp_11_171_con_std = np.std([56,57,5])
lfsp_11_378_dist_std = np.std([209,208,207])
lfsp_11_378_con_std = np.std([57,57,57])
lfsp_11_1485_dist_std = np.std([139,72,129])
lfsp_11_1485_con_std = np.std([57,56,57])

# %%
a=plt.figure()
plt.title('Time to Completion @ Comet,~145k atoms')
plt.ylabel('Time to Completion (secs)',fontsize=14)
n_groups=5
index=np.arange(n_groups)
bar_width=0.25
opacity=1.0
a1=plt.bar(index,[lfrp_11_21_con,
                  lfrp_11_45_con,
                  lfrp_11_171_con,
                  lfrp_11_378_con,0],
                  bar_width,
            yerr=[lfrp_11_21_con_std,
                  lfrp_11_45_con_std,
                  lfrp_11_171_con_std,
                  lfrp_11_378_con_std,0],
           alpha=opacity,color='darkgreen')
a2=plt.bar(index,[lfrp_11_21_dist,
                  lfrp_11_45_dist,
                  lfrp_11_171_dist,
                  lfrp_11_378_dist,0],
                  bar_width,
            yerr=[lfrp_11_21_dist_std,
                  lfrp_11_45_dist_std,
                  lfrp_11_171_dist_std,
                  lfrp_11_378_dist_std,0],
                  alpha=opacity,color='blue')
b1 = plt.bar(index+bar_width,[lfsp_11_21_con,
                              lfsp_11_45_con,
                              lfsp_11_171_con,
                              lfsp_11_378_con,
                              lfsp_11_1485_con],
                              bar_width,
                        yerr=[lfsp_11_21_con_std,
                              lfsp_11_45_con_std,
                              lfsp_11_171_con_std,
                              lfsp_11_378_con_std,
                              lfsp_11_1485_con_std],
                              alpha=opacity,color='orange')
b2 = plt.bar(index+bar_width,[lfsp_11_21_dist,
                              lfsp_11_45_dist,
                              lfsp_11_171_dist,
                              lfsp_11_378_dist,
                              lfsp_11_1485_dist],
                              bar_width,
                        yerr=[lfsp_11_21_dist_std,
                              lfsp_11_45_dist_std,
                              lfsp_11_171_dist_std,
                              lfsp_11_378_dist_std,
                              lfsp_11_1485_dist_std],
                              alpha=opacity,color='red')
plt.xticks(index+bar_width,('21','45','171','378','1485'))
plt.xlabel('Number of Tasks/Cores')
lgd=plt.figlegend((a1,a2,b1,b2),('RADICAL-Pilot Conn Comp','RADICAL-Pilot Adj Matrix Calc','RADICAL-Pilot-Spark Conn Comp','RADICAL-Pilot-Spark Adj Matrix Calc'),
              loc='lower center',ncol=2,fontsize=9,borderaxespad=0.15)
a.subplots_adjust(bottom=0.2)
plt.ylim(ymax=3600)
a.savefig('leafletfinder_rp_spark_comet_strongscaling.pdf',bbox_extra_artists=(lgd,))

# %%
print lfrp_11_21_dist
print lfrp_11_45_dist
print lfrp_11_171_dist
print lfrp_11_378_dist

print lfsp_11_21_dist
print lfsp_11_45_dist
print lfsp_11_171_dist
print lfsp_11_378_dist
# Out:
# 2494.8873113
# 1110.14394243
# 498.560687701
# 339.834630649
# 3431.33333333
# 1506.33333333
# 434.333333333
# 208.0

# %%
a=plt.figure()
plt.title('Adj Matrix Execution time @ Comet,~145k atoms')
plt.ylabel('Time (secs, log scale)',fontsize=14)
plt.xlabel('Number of Atoms per Task/Core (log scale)')
plt.grid(True,which="both")
y1 = [lfrp_11_378_dist,lfrp_11_171_dist,lfrp_11_45_dist,lfrp_11_21_dist]
y2 = [lfsp_11_378_dist,lfsp_11_171_dist,lfsp_11_45_dist,lfsp_11_21_dist]
x = [5398,8097,16194,24291]
plt.loglog(x,y1,'*-b',label='RP Vanilla',basex=2,basey=2)
plt.loglog(x,y2,'*-r',label='RP Spark',basex=2,basey=2)
plt.legend(loc='upper left')
a.savefig('adj_exec_time_log_comp.pdf')
