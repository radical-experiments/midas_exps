# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm
import csv
import pandas as pd

blues = cm.get_cmap(plt.get_cmap('Blues'))
greens = cm.get_cmap(plt.get_cmap('Greens'))
reds = cm.get_cmap(plt.get_cmap('Reds'))
oranges = cm.get_cmap(plt.get_cmap('Oranges'))
purples = cm.get_cmap(plt.get_cmap('Purples'))
greys = cm.get_cmap(plt.get_cmap('Greys'))

#from IPython.core.display import display, HTML
#display(HTML("<style>.container { width:100% !important; }</style>"))
import warnings
warnings.filterwarnings('ignore')

# %%
lfWbroad = pd.DataFrame.from_csv('mpi4py/Wrangler/LFBroad_mpi4py.csv')
lfWcoll  = pd.DataFrame.from_csv('mpi4py/Wrangler/LFColl_mpi4py.csv')
lfWparcc = pd.DataFrame.from_csv('mpi4py/Wrangler/LFParCC_mpi4py.csv')
lfWbtree = pd.DataFrame.from_csv('mpi4py/Wrangler/LFBTree_mpi4py.csv')

# %%
lfWb131 = lfWbroad[lfWbroad['Atoms']==131072]
lfWb131 = lfWb131[lfWb131['Type']=='total'].reset_index(drop=['index'])
lfWb131.drop(['Atoms','Type'],inplace=True,axis=1)
lfWb131Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfWb131[i:i+10]['Duration'].mean()
    std = lfWb131[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfWb131Means.loc[len(lfWb131Means)] = [lfWb131['Cores'][i],mean,std,np.divide(basic,mean)]
    
lfWb262 = lfWbroad[lfWbroad['Atoms']==262144]
lfWb262 = lfWb262[lfWb262['Type']=='total'].reset_index(drop=['index'])
lfWb262.drop(['Atoms','Type'],inplace=True,axis=1)
lfWb262Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfWb262[i:i+10]['Duration'].mean()
    std = lfWb262[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfWb262Means.loc[len(lfWb262Means)] = [lfWb262['Cores'][i],mean,std,np.divide(basic,mean)]
lfWb262Means

lfWb524 = lfWbroad[lfWbroad['Atoms']==524288]
lfWb524 = lfWb524[lfWb524['Type']=='total'].reset_index(drop=['index'])
lfWb524.drop(['Atoms','Type'],inplace=True,axis=1)
lfWb524Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfWb524[i:i+10]['Duration'].mean()
    std = lfWb524[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfWb524Means.loc[len(lfWb524Means)] = [lfWb524['Cores'][i],mean,std,np.divide(basic,mean)]

# %%
lfWc131 = lfWcoll[lfWcoll['Atoms']==131072]
lfWc131 = lfWc131[lfWc131['Type']=='total'].reset_index(drop=['index'])
lfWc131.drop(['Atoms','Type'],inplace=True,axis=1)
lfWc131Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfWc131[i:i+10]['Duration'].mean()
    std = lfWc131[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfWc131Means.loc[len(lfWc131Means)] = [lfWc131['Cores'][i],mean,std,np.divide(basic,mean)]
    
lfWc262 = lfWcoll[lfWcoll['Atoms']==262144]
lfWc262 = lfWc262[lfWc262['Type']=='total'].reset_index(drop=['index'])
lfWc262.drop(['Atoms','Type'],inplace=True,axis=1)
lfWc262Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfWc262[i:i+10]['Duration'].mean()
    std = lfWc262[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfWc262Means.loc[len(lfWc262Means)] = [lfWc262['Cores'][i],mean,std,np.divide(basic,mean)]
lfWc262Means

lfWc524 = lfWcoll[lfWcoll['Atoms']==524288]
lfWc524 = lfWc524[lfWc524['Type']=='total'].reset_index(drop=['index'])
lfWc524.drop(['Atoms','Type'],inplace=True,axis=1)
lfWc524Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfWc524[i:i+10]['Duration'].mean()
    std = lfWc524[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfWc524Means.loc[len(lfWc524Means)] = [lfWc524['Cores'][i],mean,std,np.divide(basic,mean)]

# %%
lfWpc131 = lfWparcc[lfWparcc['Atoms']==131072]
lfWpc131 = lfWpc131[lfWpc131['Type']=='total'].reset_index(drop=['index'])
lfWpc131.drop(['Atoms','Type'],inplace=True,axis=1)
lfWpc131Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfWpc131[i:i+10]['Duration'].mean()
    std = lfWpc131[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfWpc131Means.loc[len(lfWpc131Means)] = [lfWpc131['Cores'][i],mean,std,np.divide(basic,mean)]
    
lfWpc262 = lfWparcc[lfWparcc['Atoms']==262144]
lfWpc262 = lfWpc262[lfWpc262['Type']=='total'].reset_index(drop=['index'])
lfWpc262.drop(['Atoms','Type'],inplace=True,axis=1)
lfWpc262Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfWpc262[i:i+10]['Duration'].mean()
    std = lfWpc262[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfWpc262Means.loc[len(lfWpc262Means)] = [lfWpc262['Cores'][i],mean,std,np.divide(basic,mean)]

lfWpc524 = lfWparcc[lfWparcc['Atoms']==524288]
lfWpc524 = lfWpc524[lfWpc524['Type']=='total'].reset_index(drop=['index'])
lfWpc524.drop(['Atoms','Type'],inplace=True,axis=1)
lfWpc524Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfWpc524[i:i+10]['Duration'].mean()
    std = lfWpc524[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfWpc524Means.loc[len(lfWpc524Means)] = [lfWpc524['Cores'][i],mean,std,np.divide(basic,mean)]

# %%
lfWbt131 = lfWbtree[lfWbtree['Atoms']==131072]
lfWbt131 = lfWbt131[lfWbt131['Type']=='total'].reset_index(drop=['index'])
lfWbt131.drop(['Atoms','Type'],inplace=True,axis=1)
lfWbt131Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfWbt131[i:i+10]['Duration'].mean()
    std = lfWbt131[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfWbt131Means.loc[len(lfWbt131Means)] = [lfWbt131['Cores'][i],mean,std,np.divide(basic,mean)]
    
lfWbt262 = lfWbtree[lfWbtree['Atoms']==262144]
lfWbt262 = lfWbt262[lfWbt262['Type']=='total'].reset_index(drop=['index'])
lfWbt262.drop(['Atoms','Type'],inplace=True,axis=1)
lfWbt262Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfWbt262[i:i+10]['Duration'].mean()
    std = lfWbt262[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfWbt262Means.loc[len(lfWbt262Means)] = [lfWbt262['Cores'][i],mean,std,np.divide(basic,mean)]

lfWbt524 = lfWbtree[lfWbtree['Atoms']==524288]
lfWbt524 = lfWbt524[lfWbt524['Type']=='total'].reset_index(drop=['index'])
lfWbt524.drop(['Atoms','Type'],inplace=True,axis=1)
lfWbt524Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfWbt524[i:i+10]['Duration'].mean()
    std = lfWbt524[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfWbt524Means.loc[len(lfWbt524Means)] = [lfWbt524['Cores'][i],mean,std,np.divide(basic,mean)]

# %%
lfCbroad = pd.DataFrame.from_csv('mpi4py/Comet/LFBroad_mpi4py.csv')
lfCcoll  = pd.DataFrame.from_csv('mpi4py/Comet/LFColl_mpi4py.csv')
lfCparcc = pd.DataFrame.from_csv('mpi4py/Comet/LFParCC_mpi4py.csv')
lfCbtree = pd.DataFrame.from_csv('mpi4py/Comet/LFBTree_mpi4py.csv')

# %%
lfCb131 = lfCbroad[lfCbroad['Atoms']==131072]
lfCb131 = lfCb131[lfCb131['Type']=='total'].reset_index(drop=['index'])
lfCb131.drop(['Atoms','Type'],inplace=True,axis=1)
lfCb131Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfCb131[i:i+10]['Duration'].mean()
    std = lfCb131[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfCb131Means.loc[len(lfCb131Means)] = [lfCb131['Cores'][i],mean,std,np.divide(basic,mean)]
    
lfCb262 = lfCbroad[lfCbroad['Atoms']==262144]
lfCb262 = lfCb262[lfCb262['Type']=='total'].reset_index(drop=['index'])
lfCb262.drop(['Atoms','Type'],inplace=True,axis=1)
lfCb262Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfCb262[i:i+10]['Duration'].mean()
    std = lfCb262[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfCb262Means.loc[len(lfCb262Means)] = [lfCb262['Cores'][i],mean,std,np.divide(basic,mean)]
lfCb262Means

lfCb524 = lfCbroad[lfCbroad['Atoms']==524288]
lfCb524 = lfCb524[lfCb524['Type']=='total'].reset_index(drop=['index'])
lfCb524.drop(['Atoms','Type'],inplace=True,axis=1)
lfCb524Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfCb524[i:i+10]['Duration'].mean()
    std = lfCb524[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfCb524Means.loc[len(lfCb524Means)] = [lfCb524['Cores'][i],mean,std,np.divide(basic,mean)]

# %%
lfCc131 = lfCcoll[lfCcoll['Atoms']==131072]
lfCc131 = lfCc131[lfCc131['Type']=='total'].reset_index(drop=['index'])
lfCc131.drop(['Atoms','Type'],inplace=True,axis=1)
lfCc131Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfCc131[i:i+10]['Duration'].mean()
    std = lfCc131[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfCc131Means.loc[len(lfCc131Means)] = [lfCc131['Cores'][i],mean,std,np.divide(basic,mean)]
    
lfCc262 = lfCcoll[lfCcoll['Atoms']==262144]
lfCc262 = lfCc262[lfCc262['Type']=='total'].reset_index(drop=['index'])
lfCc262.drop(['Atoms','Type'],inplace=True,axis=1)
lfCc262Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfCc262[i:i+10]['Duration'].mean()
    std = lfCc262[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfCc262Means.loc[len(lfCc262Means)] = [lfCc262['Cores'][i],mean,std,np.divide(basic,mean)]
lfCc262Means

lfCc524 = lfCcoll[lfCcoll['Atoms']==524288]
lfCc524 = lfCc524[lfCc524['Type']=='total'].reset_index(drop=['index'])
lfCc524.drop(['Atoms','Type'],inplace=True,axis=1)
lfCc524Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfCc524[i:i+10]['Duration'].mean()
    std = lfCc524[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfCc524Means.loc[len(lfCc524Means)] = [lfCc524['Cores'][i],mean,std,np.divide(basic,mean)]

# %%
lfCpc131 = lfCparcc[lfCparcc['Atoms']==131072]
lfCpc131 = lfCpc131[lfCpc131['Type']=='total'].reset_index(drop=['index'])
lfCpc131.drop(['Atoms','Type'],inplace=True,axis=1)
lfCpc131Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfCpc131[i:i+10]['Duration'].mean()
    std = lfCpc131[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfCpc131Means.loc[len(lfCpc131Means)] = [lfCpc131['Cores'][i],mean,std,np.divide(basic,mean)]
    
lfCpc262 = lfCparcc[lfCparcc['Atoms']==262144]
lfCpc262 = lfCpc262[lfCpc262['Type']=='total'].reset_index(drop=['index'])
lfCpc262.drop(['Atoms','Type'],inplace=True,axis=1)
lfCpc262Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfCpc262[i:i+10]['Duration'].mean()
    std = lfCpc262[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfCpc262Means.loc[len(lfCpc262Means)] = [lfCpc262['Cores'][i],mean,std,np.divide(basic,mean)]

lfCpc524 = lfCparcc[lfCparcc['Atoms']==524288]
lfCpc524 = lfCpc524[lfCpc524['Type']=='total'].reset_index(drop=['index'])
lfCpc524.drop(['Atoms','Type'],inplace=True,axis=1)
lfCpc524Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfCpc524[i:i+10]['Duration'].mean()
    std = lfCpc524[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfCpc524Means.loc[len(lfCpc524Means)] = [lfCpc524['Cores'][i],mean,std,np.divide(basic,mean)]

# %%
lfCbt131 = lfCbtree[lfCbtree['Atoms']==131072]
lfCbt131 = lfCbt131[lfCbt131['Type']=='total'].reset_index(drop=['index'])
lfCbt131.drop(['Atoms','Type'],inplace=True,axis=1)
lfCbt131Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfCbt131[i:i+10]['Duration'].mean()
    std = lfCbt131[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfCbt131Means.loc[len(lfCbt131Means)] = [lfCbt131['Cores'][i],mean,std,np.divide(basic,mean)]
    
lfCbt262 = lfCbtree[lfCbtree['Atoms']==262144]
lfCbt262 = lfCbt262[lfCbt262['Type']=='total'].reset_index(drop=['index'])
lfCbt262.drop(['Atoms','Type'],inplace=True,axis=1)
lfCbt262Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfCbt262[i:i+10]['Duration'].mean()
    std = lfCbt262[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfCbt262Means.loc[len(lfCbt262Means)] = [lfCbt262['Cores'][i],mean,std,np.divide(basic,mean)]

lfCbt524 = lfCbtree[lfCbtree['Atoms']==524288]
lfCbt524 = lfCbt524[lfCbt524['Type']=='total'].reset_index(drop=['index'])
lfCbt524.drop(['Atoms','Type'],inplace=True,axis=1)
lfCbt524Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfCbt524[i:i+10]['Duration'].mean()
    std = lfCbt524[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfCbt524Means.loc[len(lfCbt524Means)] = [lfCbt524['Cores'][i],mean,std,np.divide(basic,mean)]

# %%
fig,axes = plt.subplots(nrows=2,ncols=4,sharex=True,sharey=True,gridspec_kw={'wspace':0.05, 'hspace':0.07})
fig.set_size_inches(12,5)
width = 0.2

lfCb131Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfCb131Means['Std'].values.transpose().tolist(),ax=axes[0,0],width=width,color=[reds(150)],legend=False,position=1.5,log=1)
lfCb262Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfCb262Means['Std'].values.transpose().tolist(),ax=axes[0,0],width=width,color=[greens(150)],legend=False,position=.5)
lfCb524Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfCb524Means['Std'].values.transpose().tolist(),ax=axes[0,0],width=width,color=[blues(150)],legend=False,position=-.5)

lfCc131Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfCc131Means['Std'].values.transpose().tolist(),ax=axes[0,1],width=width,color=[reds(150)],legend=False,position=1.5)
lfCc262Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfCc262Means['Std'].values.transpose().tolist(),ax=axes[0,1],width=width,color=[greens(150)],legend=False,position=.5)
lfCc524Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfCc524Means['Std'].values.transpose().tolist(),ax=axes[0,1],width=width,color=[blues(150)],legend=False,position=-.5)

lfCpc131Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfCpc131Means['Std'].values.transpose().tolist(),ax=axes[0,2],width=width,color=[reds(150)],legend=False,position=1.5)
lfCpc262Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfCpc262Means['Std'].values.transpose().tolist(),ax=axes[0,2],width=width,color=[greens(150)],legend=False,position=.5)
lfCpc524Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfCpc524Means['Std'].values.transpose().tolist(),ax=axes[0,2],width=width,color=[blues(150)],legend=False,position=-.5)
                                                                                                                                   
lfCbt131Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfCbt131Means['Std'].values.transpose().tolist(),ax=axes[0,3],width=width,color=[reds(150)],legend=False,position=1.5)
lfCbt262Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfCbt262Means['Std'].values.transpose().tolist(),ax=axes[0,3],width=width,color=[greens(150)],legend=False,position=.5)
lfCbt524Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfCbt524Means['Std'].values.transpose().tolist(),ax=axes[0,3],width=width,color=[blues(150)],legend=False,position=-.5)

lfWb131Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfWb131Means['Std'].values.transpose().tolist(),ax=axes[1,0],width=width,color=[reds(150)],legend=False,position=1.5,log=1)
lfWb262Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfWb262Means['Std'].values.transpose().tolist(),ax=axes[1,0],width=width,color=[greens(150)],legend=False,position=.5)
lfWb524Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfWb524Means['Std'].values.transpose().tolist(),ax=axes[1,0],width=width,color=[blues(150)],legend=False,position=-.5)

lfWc131Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfWc131Means['Std'].values.transpose().tolist(),ax=axes[1,1],width=width,color=[reds(150)],legend=False,position=1.5)
lfWc262Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfWc262Means['Std'].values.transpose().tolist(),ax=axes[1,1],width=width,color=[greens(150)],legend=False,position=.5)
lfWc524Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfWc524Means['Std'].values.transpose().tolist(),ax=axes[1,1],width=width,color=[blues(150)],legend=False,position=-.5)

lfWpc131Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfWpc131Means['Std'].values.transpose().tolist(),ax=axes[1,2],width=width,color=[reds(150)],legend=False,position=1.5)
lfWpc262Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfWpc262Means['Std'].values.transpose().tolist(),ax=axes[1,2],width=width,color=[greens(150)],legend=False,position=.5)
lfWpc524Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfWpc524Means['Std'].values.transpose().tolist(),ax=axes[1,2],width=width,color=[blues(150)],legend=False,position=-.5)
                                                                                                                                   
lfWbt131Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfWbt131Means['Std'].values.transpose().tolist(),ax=axes[1,3],width=width,color=[reds(150)],legend=False,position=1.5)
lfWbt262Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfWbt262Means['Std'].values.transpose().tolist(),ax=axes[1,3],width=width,color=[greens(150)],legend=False,position=.5)
lfWbt524Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfWbt524Means['Std'].values.transpose().tolist(),ax=axes[1,3],width=width,color=[blues(150)],legend=False,position=-.5)

axes[0,0].set_title('Broadcast & 1-D Partitioning', fontsize=10)
axes[0,1].set_title('Task API & 2-D Partitioning', fontsize=10)
axes[0,2].set_title('Parallel Connected Components', fontsize=10)
axes[0,3].set_title('Tree-Search & \nParallel-Connected Components', fontsize=10)
axes[1,0].set_xticklabels(['32','64','128','256'], fontsize=12,rotation=0)
axes[1,1].set_xticklabels(['32','64','128','256'], fontsize=12,rotation=0)
axes[1,2].set_xticklabels(['32','64','128','256'], fontsize=12,rotation=0)
axes[1,3].set_xticklabels(['32','64','128','256'], fontsize=12,rotation=0)

axes[0,0].grid('on',which='both',linestyle=':')
axes[0,1].grid('on',which='both',linestyle=':')
axes[0,2].grid('on',which='both',linestyle=':')
axes[0,3].grid('on',which='both',linestyle=':')
axes[1,0].grid('on',which='both',linestyle=':')
axes[1,1].grid('on',which='both',linestyle=':')
axes[1,2].grid('on',which='both',linestyle=':')
axes[1,3].grid('on',which='both',linestyle=':')
axes[1,0].set_xlabel('',fontsize=12)
axes[1,1].set_xlabel('',fontsize=12)
axes[1,2].set_xlabel('',fontsize=12)
axes[1,3].set_xlabel('',fontsize=12)
axes[1,0].set_ylim([1,12000])
axes[1,0].set_yticks([1,10,100,1000,10000])
axes[0,0].set_yticklabels(['1','10','100','1000','10000'])
axes[0,3].text(4.25,1000, 'Comet',fontsize=14,bbox={'facecolor':'grey', 'alpha':0, 'pad':8},horizontalalignment='left',verticalalignment='top',rotation=270)
axes[1,3].text(4.25,1000, 'Wrangler',fontsize=14,bbox={'facecolor':'grey', 'alpha':0, 'pad':8},horizontalalignment='left',verticalalignment='top',rotation=270)
axes[1,0].text(-2.5,500000, 'Runtime',fontsize=14,bbox={'facecolor':'grey', 'alpha':0, 'pad':8},horizontalalignment='left',verticalalignment='top',rotation=90)
axes[1,2].text(-2.5,.1, 'Number of Cores',fontsize=14,bbox={'facecolor':'grey', 'alpha':0, 'pad':8},horizontalalignment='left',verticalalignment='top',rotation=0)
axes[0,0].set_xlim([-.55,4.0])
#axes[1,0].set_yticks([1,2,3,4,5,6,7])

#axes[1,0].set_ylabel('Speedup', fontsize=12)
#axes[1,1].set_xlabel('Number of Cores', fontsize=12)
axes[0,3].legend(['131k','262k','524k','4M'],fontsize=12,bbox_to_anchor=(0., -1.75, -2,0), loc='lower center',ncol=4, borderaxespad=0.)
#fig.savefig('All4approachesWith4M_logscale.pdf',dpi=800,bbox_inches='tight',pad_inches=0)

# %%
fig,axes = plt.subplots(nrows=2,ncols=4,sharex=True,sharey=True,gridspec_kw={'wspace':0.05, 'hspace':0.07})
fig.set_size_inches(12,5)
width = 0.2

lfCb131Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[0,0],color=[reds(150)],legend=False,marker='*')
lfCb262Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[0,0],color=[greens(150)],legend=False,marker='*')
lfCb524Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[0,0],color=[blues(150)],legend=False,marker='*')

lfCc131Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[0,1],color=[reds(150)],legend=False,marker='*')
lfCc262Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[0,1],color=[greens(150)],legend=False,marker='*')
lfCc524Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[0,1],color=[blues(150)],legend=False,marker='*')

lfCpc131Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[0,2],color=[reds(150)],legend=False,marker='*')
lfCpc262Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[0,2],color=[greens(150)],legend=False,marker='*')
lfCpc524Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[0,2],color=[blues(150)],legend=False,marker='*')

lfCbt131Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[0,3],color=[reds(150)],legend=False,marker='*')
lfCbt262Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[0,3],color=[greens(150)],legend=False,marker='*')
lfCbt524Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[0,3],color=[blues(150)],legend=False,marker='*')

lfWb131Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[1,0],color=[reds(150)],legend=False,marker='*')
lfWb262Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[1,0],color=[greens(150)],legend=False,marker='*')
lfWb524Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[1,0],color=[blues(150)],legend=False,marker='*')

lfWc131Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[1,1],color=[reds(150)],legend=False,marker='*')
lfWc262Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[1,1],color=[greens(150)],legend=False,marker='*')
lfWc524Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[1,1],color=[blues(150)],legend=False,marker='*')

lfWpc131Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[1,2],color=[reds(150)],legend=False,marker='*')
lfWpc262Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[1,2],color=[greens(150)],legend=False,marker='*')
lfWpc524Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[1,2],color=[blues(150)],legend=False,marker='*')

lfWbt131Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[1,3],color=[reds(150)],legend=False,marker='*')
lfWbt262Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[1,3],color=[greens(150)],legend=False,marker='*')
lfWbt524Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[1,3],color=[blues(150)],legend=False,marker='*')

axes[0,0].set_title('Broadcast & 1-D Partitioning', fontsize=10)
axes[0,1].set_title('Task API & 2-D Partitioning', fontsize=10)
axes[0,2].set_title('Parallel Connected Components', fontsize=10)
axes[0,3].set_title('Tree-Search & \nParallel-Connected Components', fontsize=10)
axes[1,0].set_xscale('log',basex=2)
axes[1,0].set_xticks([32,64,128,256])
axes[1,0].set_xticklabels(['32','64','128','256'], fontsize=12,rotation=0)
axes[1,1].set_xticklabels(['32','64','128','256'], fontsize=12,rotation=0)
axes[1,2].set_xticklabels(['32','64','128','256'], fontsize=12,rotation=0)
axes[1,3].set_xticklabels(['32','64','128','256'], fontsize=12,rotation=0)
axes[1,0].set_yscale('log',basey=2)
axes[1,0].set_yticks([1,2,4,8])
axes[0,0].set_yticks([1,2,4,8])
axes[0,0].set_yticklabels(['1','2','4','8'], fontsize=12,rotation=0)
axes[1,0].set_yticklabels(['1','2','4','8'], fontsize=12,rotation=0)
axes[0,0].grid('on',which='both',linestyle=':')
axes[0,1].grid('on',which='both',linestyle=':')
axes[0,2].grid('on',which='both',linestyle=':')
axes[0,3].grid('on',which='both',linestyle=':')
axes[1,0].grid('on',which='both',linestyle=':')
axes[1,1].grid('on',which='both',linestyle=':')
axes[1,2].grid('on',which='both',linestyle=':')
axes[1,3].grid('on',which='both',linestyle=':')
axes[1,0].set_xlabel('',fontsize=12)
axes[1,1].set_xlabel('',fontsize=12)
axes[1,2].set_xlabel('',fontsize=12)
axes[1,3].set_xlabel('',fontsize=12)
axes[0,3].text(290,4, 'Wrangler',fontsize=14,bbox={'facecolor':'grey', 'alpha':0, 'pad':8},horizontalalignment='left',verticalalignment='top',rotation=270)
axes[1,3].text(290,4, 'Wrangler',fontsize=14,bbox={'facecolor':'grey', 'alpha':0, 'pad':8},horizontalalignment='left',verticalalignment='top',rotation=270)
axes[1,0].text(16,10, 'Speedup',fontsize=14,bbox={'facecolor':'grey', 'alpha':0, 'pad':8},horizontalalignment='left',verticalalignment='top',rotation=90)
axes[1,2].text(12,0.5,'Number of Cores',fontsize=14,bbox={'facecolor':'grey', 'alpha':0, 'pad':8},horizontalalignment='left',verticalalignment='top',rotation=0)
#axes[0,0].set_xlim([-.55,4.0])
#axes[1,0].set_yticks([1,2,3,4,5,6,7])

#axes[1,0].set_ylabel('Speedup', fontsize=12)
#axes[1,1].set_xlabel('Number of Cores', fontsize=12)
axes[0,3].legend(['131k','262k','524k','4M'],fontsize=12,bbox_to_anchor=(0., -1.85, -2,0), loc='lower center',ncol=4, borderaxespad=0.)
#fig.savefig('All4approachesWith4M_logscale.png',dpi=800,bbox_inches='tight',pad_inches=0)
