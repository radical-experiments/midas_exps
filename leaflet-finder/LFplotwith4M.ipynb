# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm
import csv
import pandas as pd

blues = cm.get_cmap(plt.get_cmap('Blues'))
greens = cm.get_cmap(plt.get_cmap('Greens'))
reds = cm.get_cmap(plt.get_cmap('Reds'))
oranges = cm.get_cmap(plt.get_cmap('Oranges'))
purples = cm.get_cmap(plt.get_cmap('Purples'))
greys = cm.get_cmap(plt.get_cmap('Greys'))

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import warnings
warnings.filterwarnings('ignore')
# Out:
# <style>.container { width:100% !important; }</style>

# %%
tidy_wrangler = pd.read_csv('tidy_lf_wrangler.csv')
tidy_wrangler_std = pd.read_csv('tidy_lf_wranglerSTD.csv')

tidy_tree_wrangler = pd.read_csv('tidy_lf_tree_wrangler.csv')
tidy_tree_wranglerSTD = pd.read_csv('tidy_lf_tree_wranglerSTD.csv')

# %%
#131
Sp1meansW = pd.DataFrame(columns=['Cores','Spark Total Time','Speedup'])
Sp1meansW.loc[1] = np.array([tidy_wrangler['Cores'][59],tidy_wrangler['Time'][59],tidy_wrangler['Time'][59]/tidy_wrangler['Time'][59]])
Sp1meansW.loc[2] = np.array([tidy_wrangler['Cores'][60],tidy_wrangler['Time'][60],tidy_wrangler['Time'][59]/tidy_wrangler['Time'][60]])
Sp1meansW.loc[3] = np.array([tidy_wrangler['Cores'][61],tidy_wrangler['Time'][61],tidy_wrangler['Time'][59]/tidy_wrangler['Time'][61]])
Sp1meansW.loc[4] = np.array([tidy_wrangler['Cores'][62],tidy_wrangler['Time'][62],tidy_wrangler['Time'][59]/tidy_wrangler['Time'][62]])
#262
Sp1meansW.loc[5] = np.array([tidy_wrangler['Cores'][75],tidy_wrangler['Time'][75],tidy_wrangler['Time'][75]/tidy_wrangler['Time'][75]])
Sp1meansW.loc[6] = np.array([tidy_wrangler['Cores'][76],tidy_wrangler['Time'][76],tidy_wrangler['Time'][75]/tidy_wrangler['Time'][76]])
Sp1meansW.loc[7] = np.array([tidy_wrangler['Cores'][77],tidy_wrangler['Time'][77],tidy_wrangler['Time'][75]/tidy_wrangler['Time'][77]])
Sp1meansW.loc[8] = np.array([tidy_wrangler['Cores'][78],tidy_wrangler['Time'][78],tidy_wrangler['Time'][75]/tidy_wrangler['Time'][78]])

Sp1meansW.loc[9]  = np.array([tidy_wrangler['Cores'][91],tidy_wrangler['Time'][91],tidy_wrangler['Time'][91]/tidy_wrangler['Time'][91]])
Sp1meansW.loc[10] = np.array([tidy_wrangler['Cores'][92],tidy_wrangler['Time'][92],tidy_wrangler['Time'][91]/tidy_wrangler['Time'][92]])
Sp1meansW.loc[11] = np.array([tidy_wrangler['Cores'][93],tidy_wrangler['Time'][93],tidy_wrangler['Time'][91]/tidy_wrangler['Time'][93]])
Sp1meansW.loc[12] = np.array([tidy_wrangler['Cores'][94],tidy_wrangler['Time'][94],tidy_wrangler['Time'][91]/tidy_wrangler['Time'][94]])

Sp1stdW = pd.DataFrame(columns=['Cores','Spark Total Time','Speedup'])
#131
Sp1stdW.loc[1] = np.array([tidy_wrangler_std['Cores'][59],tidy_wrangler_std['Time'][59],tidy_wrangler_std['Time'][59]/tidy_wrangler_std['Time'][59]])
Sp1stdW.loc[2] = np.array([tidy_wrangler_std['Cores'][60],tidy_wrangler_std['Time'][60],tidy_wrangler_std['Time'][59]/tidy_wrangler_std['Time'][60]])
Sp1stdW.loc[3] = np.array([tidy_wrangler_std['Cores'][61],tidy_wrangler_std['Time'][61],tidy_wrangler_std['Time'][59]/tidy_wrangler_std['Time'][61]])
Sp1stdW.loc[4] = np.array([tidy_wrangler_std['Cores'][62],tidy_wrangler_std['Time'][62],tidy_wrangler_std['Time'][59]/tidy_wrangler_std['Time'][62]])
#262
Sp1stdW.loc[5] = np.array([tidy_wrangler_std['Cores'][75],tidy_wrangler_std['Time'][75],tidy_wrangler_std['Time'][75]/tidy_wrangler_std['Time'][75]])
Sp1stdW.loc[6] = np.array([tidy_wrangler_std['Cores'][76],tidy_wrangler_std['Time'][76],tidy_wrangler_std['Time'][75]/tidy_wrangler_std['Time'][76]])
Sp1stdW.loc[7] = np.array([tidy_wrangler_std['Cores'][77],tidy_wrangler_std['Time'][77],tidy_wrangler_std['Time'][75]/tidy_wrangler_std['Time'][77]])
Sp1stdW.loc[8] = np.array([tidy_wrangler_std['Cores'][78],tidy_wrangler_std['Time'][78],tidy_wrangler_std['Time'][75]/tidy_wrangler_std['Time'][78]])

Sp1stdW.loc[9]  = np.array([tidy_wrangler_std['Cores'][91],tidy_wrangler_std['Time'][91],tidy_wrangler_std['Time'][91]/tidy_wrangler_std['Time'][91]])
Sp1stdW.loc[10] = np.array([tidy_wrangler_std['Cores'][92],tidy_wrangler_std['Time'][92],tidy_wrangler_std['Time'][91]/tidy_wrangler_std['Time'][92]])
Sp1stdW.loc[11] = np.array([tidy_wrangler_std['Cores'][93],tidy_wrangler_std['Time'][93],tidy_wrangler_std['Time'][91]/tidy_wrangler_std['Time'][93]])
Sp1stdW.loc[12] = np.array([tidy_wrangler_std['Cores'][94],tidy_wrangler_std['Time'][94],tidy_wrangler_std['Time'][91]/tidy_wrangler_std['Time'][94]])

# %%
D1meansW = pd.DataFrame(columns=['Cores','Dask Overhead','Dask Edge Disc','Dask ConnComp','Dask Total Time','Speedup'])
#131
D1meansW.loc[1] = np.array([tidy_wrangler['Cores'][191],tidy_wrangler['Time'][191],tidy_wrangler['Time'][195],tidy_wrangler['Time'][199],tidy_wrangler['Time'][203],tidy_wrangler['Time'][195]/tidy_wrangler['Time'][195]])
D1meansW.loc[2] = np.array([tidy_wrangler['Cores'][192],tidy_wrangler['Time'][192],tidy_wrangler['Time'][196],tidy_wrangler['Time'][200],tidy_wrangler['Time'][204],tidy_wrangler['Time'][195]/tidy_wrangler['Time'][196]])
D1meansW.loc[3] = np.array([tidy_wrangler['Cores'][193],tidy_wrangler['Time'][193],tidy_wrangler['Time'][197],tidy_wrangler['Time'][201],tidy_wrangler['Time'][205],tidy_wrangler['Time'][195]/tidy_wrangler['Time'][197]])
D1meansW.loc[4] = np.array([tidy_wrangler['Cores'][194],tidy_wrangler['Time'][194],tidy_wrangler['Time'][198],tidy_wrangler['Time'][202],tidy_wrangler['Time'][206],tidy_wrangler['Time'][195]/tidy_wrangler['Time'][198]])
#262
D1meansW.loc[5] = np.array([tidy_wrangler['Cores'][207],tidy_wrangler['Time'][207],tidy_wrangler['Time'][211],tidy_wrangler['Time'][215],tidy_wrangler['Time'][219],tidy_wrangler['Time'][211]/tidy_wrangler['Time'][211]])
D1meansW.loc[6] = np.array([tidy_wrangler['Cores'][208],tidy_wrangler['Time'][208],tidy_wrangler['Time'][212],tidy_wrangler['Time'][216],tidy_wrangler['Time'][220],tidy_wrangler['Time'][211]/tidy_wrangler['Time'][212]])
D1meansW.loc[7] = np.array([tidy_wrangler['Cores'][209],tidy_wrangler['Time'][209],tidy_wrangler['Time'][213],tidy_wrangler['Time'][217],tidy_wrangler['Time'][221],tidy_wrangler['Time'][211]/tidy_wrangler['Time'][213]])
D1meansW.loc[8] = np.array([tidy_wrangler['Cores'][210],tidy_wrangler['Time'][210],tidy_wrangler['Time'][214],tidy_wrangler['Time'][218],tidy_wrangler['Time'][222],tidy_wrangler['Time'][211]/tidy_wrangler['Time'][214]])

D1stdW = pd.DataFrame(columns=['Cores','Dask Overhead','Dask Edge Disc','Dask ConnComp','Dask Total Time','Speedup'])
#131
D1stdW.loc[1] = np.array([tidy_wrangler_std['Cores'][191],tidy_wrangler_std['Time'][191],tidy_wrangler_std['Time'][195],tidy_wrangler_std['Time'][199],tidy_wrangler_std['Time'][203],tidy_wrangler_std['Time'][195]/tidy_wrangler_std['Time'][195]])
D1stdW.loc[2] = np.array([tidy_wrangler_std['Cores'][192],tidy_wrangler_std['Time'][192],tidy_wrangler_std['Time'][196],tidy_wrangler_std['Time'][200],tidy_wrangler_std['Time'][204],tidy_wrangler_std['Time'][195]/tidy_wrangler_std['Time'][196]])
D1stdW.loc[3] = np.array([tidy_wrangler_std['Cores'][193],tidy_wrangler_std['Time'][193],tidy_wrangler_std['Time'][197],tidy_wrangler_std['Time'][201],tidy_wrangler_std['Time'][205],tidy_wrangler_std['Time'][195]/tidy_wrangler_std['Time'][197]])
D1stdW.loc[4] = np.array([tidy_wrangler_std['Cores'][194],tidy_wrangler_std['Time'][194],tidy_wrangler_std['Time'][198],tidy_wrangler_std['Time'][202],tidy_wrangler_std['Time'][206],tidy_wrangler_std['Time'][195]/tidy_wrangler_std['Time'][198]])

#262
D1stdW.loc[5] = np.array([tidy_wrangler_std['Cores'][207],tidy_wrangler_std['Time'][207],tidy_wrangler_std['Time'][211],tidy_wrangler_std['Time'][215],tidy_wrangler_std['Time'][219],tidy_wrangler_std['Time'][211]/tidy_wrangler_std['Time'][211]])
D1stdW.loc[6] = np.array([tidy_wrangler_std['Cores'][208],tidy_wrangler_std['Time'][208],tidy_wrangler_std['Time'][212],tidy_wrangler_std['Time'][216],tidy_wrangler_std['Time'][220],tidy_wrangler_std['Time'][211]/tidy_wrangler_std['Time'][212]])
D1stdW.loc[7] = np.array([tidy_wrangler_std['Cores'][209],tidy_wrangler_std['Time'][209],tidy_wrangler_std['Time'][213],tidy_wrangler_std['Time'][217],tidy_wrangler_std['Time'][221],tidy_wrangler_std['Time'][211]/tidy_wrangler_std['Time'][213]])
D1stdW.loc[8] = np.array([tidy_wrangler_std['Cores'][210],tidy_wrangler_std['Time'][210],tidy_wrangler_std['Time'][214],tidy_wrangler_std['Time'][218],tidy_wrangler_std['Time'][222],tidy_wrangler_std['Time'][211]/tidy_wrangler_std['Time'][214]])

# %%
Sp2meansW = pd.DataFrame(columns=['Cores','Spark Overhead','Spark Edge Disc','Spark ConnComp','Spark Total Time','Speedup'])
# 131
Sp2meansW.loc[1] = np.array([tidy_wrangler['Cores'][95],tidy_wrangler['Time'][95],tidy_wrangler['Time'][99],tidy_wrangler['Time'][103],tidy_wrangler['Time'][107],tidy_wrangler['Time'][99]/tidy_wrangler['Time'][99]])
Sp2meansW.loc[2] = np.array([tidy_wrangler['Cores'][96],tidy_wrangler['Time'][96],tidy_wrangler['Time'][100],tidy_wrangler['Time'][104],tidy_wrangler['Time'][108],tidy_wrangler['Time'][99]/tidy_wrangler['Time'][100]])
Sp2meansW.loc[3] = np.array([tidy_wrangler['Cores'][97],tidy_wrangler['Time'][97],tidy_wrangler['Time'][101],tidy_wrangler['Time'][105],tidy_wrangler['Time'][109],tidy_wrangler['Time'][99]/tidy_wrangler['Time'][101]])
Sp2meansW.loc[4] = np.array([tidy_wrangler['Cores'][98],tidy_wrangler['Time'][98],tidy_wrangler['Time'][102],tidy_wrangler['Time'][106],tidy_wrangler['Time'][110],tidy_wrangler['Time'][99]/tidy_wrangler['Time'][102]])
# 262
Sp2meansW.loc[5] = np.array([tidy_wrangler['Cores'][111],tidy_wrangler['Time'][111],tidy_wrangler['Time'][115],tidy_wrangler['Time'][119],tidy_wrangler['Time'][123],tidy_wrangler['Time'][115]/tidy_wrangler['Time'][115]])
Sp2meansW.loc[6] = np.array([tidy_wrangler['Cores'][112],tidy_wrangler['Time'][112],tidy_wrangler['Time'][116],tidy_wrangler['Time'][120],tidy_wrangler['Time'][124],tidy_wrangler['Time'][115]/tidy_wrangler['Time'][116]])
Sp2meansW.loc[7] = np.array([tidy_wrangler['Cores'][113],tidy_wrangler['Time'][113],tidy_wrangler['Time'][117],tidy_wrangler['Time'][121],tidy_wrangler['Time'][125],tidy_wrangler['Time'][115]/tidy_wrangler['Time'][117]])
Sp2meansW.loc[8] = np.array([tidy_wrangler['Cores'][114],tidy_wrangler['Time'][114],tidy_wrangler['Time'][118],tidy_wrangler['Time'][122],tidy_wrangler['Time'][126],tidy_wrangler['Time'][115]/tidy_wrangler['Time'][118]])
# 524
Sp2meansW.loc[9]  = np.array([tidy_wrangler['Cores'][127],tidy_wrangler['Time'][127],tidy_wrangler['Time'][131],tidy_wrangler['Time'][135],tidy_wrangler['Time'][139],tidy_wrangler['Time'][131]/tidy_wrangler['Time'][131]])
Sp2meansW.loc[10] = np.array([tidy_wrangler['Cores'][128],tidy_wrangler['Time'][128],tidy_wrangler['Time'][132],tidy_wrangler['Time'][136],tidy_wrangler['Time'][140],tidy_wrangler['Time'][131]/tidy_wrangler['Time'][132]])
Sp2meansW.loc[11] = np.array([tidy_wrangler['Cores'][129],tidy_wrangler['Time'][129],tidy_wrangler['Time'][133],tidy_wrangler['Time'][137],tidy_wrangler['Time'][141],tidy_wrangler['Time'][131]/tidy_wrangler['Time'][133]])
Sp2meansW.loc[12] = np.array([tidy_wrangler['Cores'][130],tidy_wrangler['Time'][130],tidy_wrangler['Time'][134],tidy_wrangler['Time'][138],tidy_wrangler['Time'][142],tidy_wrangler['Time'][131]/tidy_wrangler['Time'][134]])

Sp2stdW = pd.DataFrame(columns=['Cores','Spark Overhead','Spark Edge Disc','Spark ConnComp','Spark Total Time','Speedup'])
# 131
Sp2stdW.loc[1] = np.array([tidy_wrangler_std['Cores'][95],tidy_wrangler_std['Time'][95],tidy_wrangler_std['Time'][99],tidy_wrangler_std['Time'][103],tidy_wrangler_std['Time'][107],tidy_wrangler_std['Time'][99]/tidy_wrangler_std['Time'][99]])
Sp2stdW.loc[2] = np.array([tidy_wrangler_std['Cores'][96],tidy_wrangler_std['Time'][96],tidy_wrangler_std['Time'][100],tidy_wrangler_std['Time'][104],tidy_wrangler_std['Time'][108],tidy_wrangler_std['Time'][99]/tidy_wrangler_std['Time'][100]])
Sp2stdW.loc[3] = np.array([tidy_wrangler_std['Cores'][97],tidy_wrangler_std['Time'][97],tidy_wrangler_std['Time'][101],tidy_wrangler_std['Time'][105],tidy_wrangler_std['Time'][109],tidy_wrangler_std['Time'][99]/tidy_wrangler_std['Time'][101]])
Sp2stdW.loc[4] = np.array([tidy_wrangler_std['Cores'][98],tidy_wrangler_std['Time'][98],tidy_wrangler_std['Time'][102],tidy_wrangler_std['Time'][106],tidy_wrangler_std['Time'][110],tidy_wrangler_std['Time'][99]/tidy_wrangler_std['Time'][102]])
# 262
Sp2stdW.loc[5] = np.array([tidy_wrangler_std['Cores'][111],tidy_wrangler_std['Time'][111],tidy_wrangler_std['Time'][115],tidy_wrangler_std['Time'][119],tidy_wrangler_std['Time'][123],tidy_wrangler_std['Time'][115]/tidy_wrangler_std['Time'][115]])
Sp2stdW.loc[6] = np.array([tidy_wrangler_std['Cores'][112],tidy_wrangler_std['Time'][112],tidy_wrangler_std['Time'][116],tidy_wrangler_std['Time'][120],tidy_wrangler_std['Time'][124],tidy_wrangler_std['Time'][115]/tidy_wrangler_std['Time'][116]])
Sp2stdW.loc[7] = np.array([tidy_wrangler_std['Cores'][113],tidy_wrangler_std['Time'][113],tidy_wrangler_std['Time'][117],tidy_wrangler_std['Time'][121],tidy_wrangler_std['Time'][125],tidy_wrangler_std['Time'][115]/tidy_wrangler_std['Time'][117]])
Sp2stdW.loc[8] = np.array([tidy_wrangler_std['Cores'][114],tidy_wrangler_std['Time'][114],tidy_wrangler_std['Time'][118],tidy_wrangler_std['Time'][122],tidy_wrangler_std['Time'][126],tidy_wrangler_std['Time'][115]/tidy_wrangler_std['Time'][118]])
# 524
Sp2stdW.loc[9]  = np.array([tidy_wrangler_std['Cores'][127],tidy_wrangler_std['Time'][127],tidy_wrangler_std['Time'][131],tidy_wrangler_std['Time'][135],tidy_wrangler_std['Time'][139],tidy_wrangler_std['Time'][131]/tidy_wrangler_std['Time'][131]])
Sp2stdW.loc[10] = np.array([tidy_wrangler_std['Cores'][128],tidy_wrangler_std['Time'][128],tidy_wrangler_std['Time'][132],tidy_wrangler_std['Time'][136],tidy_wrangler_std['Time'][140],tidy_wrangler_std['Time'][131]/tidy_wrangler_std['Time'][132]])
Sp2stdW.loc[11] = np.array([tidy_wrangler_std['Cores'][129],tidy_wrangler_std['Time'][129],tidy_wrangler_std['Time'][133],tidy_wrangler_std['Time'][137],tidy_wrangler_std['Time'][141],tidy_wrangler_std['Time'][131]/tidy_wrangler_std['Time'][133]])
Sp2stdW.loc[12] = np.array([tidy_wrangler_std['Cores'][130],tidy_wrangler_std['Time'][130],tidy_wrangler_std['Time'][134],tidy_wrangler_std['Time'][138],tidy_wrangler_std['Time'][142],tidy_wrangler_std['Time'][131]/tidy_wrangler_std['Time'][134]])

# %%
D2meansW = pd.DataFrame(columns=['Cores','Dask Overhead','Dask Edge Disc','Dask ConnComp','Dask Total Time','Speedup'])
#131
D2meansW.loc[1] = np.array([tidy_wrangler['Cores'][223],tidy_wrangler['Time'][223],tidy_wrangler['Time'][227],tidy_wrangler['Time'][231],tidy_wrangler['Time'][235],tidy_wrangler['Time'][227]/tidy_wrangler['Time'][227]])
D2meansW.loc[2] = np.array([tidy_wrangler['Cores'][224],tidy_wrangler['Time'][224],tidy_wrangler['Time'][228],tidy_wrangler['Time'][232],tidy_wrangler['Time'][236],tidy_wrangler['Time'][227]/tidy_wrangler['Time'][228]])
D2meansW.loc[3] = np.array([tidy_wrangler['Cores'][225],tidy_wrangler['Time'][225],tidy_wrangler['Time'][229],tidy_wrangler['Time'][233],tidy_wrangler['Time'][237],tidy_wrangler['Time'][227]/tidy_wrangler['Time'][229]])
D2meansW.loc[4] = np.array([tidy_wrangler['Cores'][226],tidy_wrangler['Time'][226],tidy_wrangler['Time'][230],tidy_wrangler['Time'][234],tidy_wrangler['Time'][238],tidy_wrangler['Time'][227]/tidy_wrangler['Time'][230]])
#262
D2meansW.loc[5] = np.array([tidy_wrangler['Cores'][239],tidy_wrangler['Time'][239],tidy_wrangler['Time'][243],tidy_wrangler['Time'][247],tidy_wrangler['Time'][251],tidy_wrangler['Time'][243]/tidy_wrangler['Time'][243]])
D2meansW.loc[6] = np.array([tidy_wrangler['Cores'][240],tidy_wrangler['Time'][240],tidy_wrangler['Time'][244],tidy_wrangler['Time'][248],tidy_wrangler['Time'][252],tidy_wrangler['Time'][243]/tidy_wrangler['Time'][244]])
D2meansW.loc[7] = np.array([tidy_wrangler['Cores'][241],tidy_wrangler['Time'][241],tidy_wrangler['Time'][245],tidy_wrangler['Time'][249],tidy_wrangler['Time'][253],tidy_wrangler['Time'][243]/tidy_wrangler['Time'][245]])
D2meansW.loc[8] = np.array([tidy_wrangler['Cores'][242],tidy_wrangler['Time'][242],tidy_wrangler['Time'][246],tidy_wrangler['Time'][250],tidy_wrangler['Time'][254],tidy_wrangler['Time'][243]/tidy_wrangler['Time'][246]])
#524
D2meansW.loc[9]  = np.array([tidy_wrangler['Cores'][255],tidy_wrangler['Time'][255],tidy_wrangler['Time'][259],tidy_wrangler['Time'][263],tidy_wrangler['Time'][267],tidy_wrangler['Time'][259]/tidy_wrangler['Time'][259]])
D2meansW.loc[10] = np.array([tidy_wrangler['Cores'][256],tidy_wrangler['Time'][256],tidy_wrangler['Time'][260],tidy_wrangler['Time'][264],tidy_wrangler['Time'][268],tidy_wrangler['Time'][259]/tidy_wrangler['Time'][260]])
D2meansW.loc[11] = np.array([tidy_wrangler['Cores'][257],tidy_wrangler['Time'][257],tidy_wrangler['Time'][261],tidy_wrangler['Time'][265],tidy_wrangler['Time'][269],tidy_wrangler['Time'][259]/tidy_wrangler['Time'][261]])
D2meansW.loc[12] = np.array([tidy_wrangler['Cores'][258],tidy_wrangler['Time'][258],tidy_wrangler['Time'][262],tidy_wrangler['Time'][266],tidy_wrangler['Time'][270],tidy_wrangler['Time'][259]/tidy_wrangler['Time'][262]])

D2stdW = pd.DataFrame(columns=['Cores','Dask Overhead','Dask Edge Disc','Dask ConnComp','Dask Total Time','Speedup'])
#131
D2stdW.loc[1] = np.array([tidy_wrangler_std['Cores'][223],tidy_wrangler_std['Time'][223],tidy_wrangler_std['Time'][227],tidy_wrangler_std['Time'][231],tidy_wrangler_std['Time'][235],tidy_wrangler_std['Time'][227]/tidy_wrangler_std['Time'][227]])
D2stdW.loc[2] = np.array([tidy_wrangler_std['Cores'][224],tidy_wrangler_std['Time'][224],tidy_wrangler_std['Time'][228],tidy_wrangler_std['Time'][232],tidy_wrangler_std['Time'][236],tidy_wrangler_std['Time'][227]/tidy_wrangler_std['Time'][228]])
D2stdW.loc[3] = np.array([tidy_wrangler_std['Cores'][225],tidy_wrangler_std['Time'][225],tidy_wrangler_std['Time'][229],tidy_wrangler_std['Time'][233],tidy_wrangler_std['Time'][237],tidy_wrangler_std['Time'][227]/tidy_wrangler_std['Time'][229]])
D2stdW.loc[4] = np.array([tidy_wrangler_std['Cores'][226],tidy_wrangler_std['Time'][226],tidy_wrangler_std['Time'][230],tidy_wrangler_std['Time'][234],tidy_wrangler_std['Time'][238],tidy_wrangler_std['Time'][227]/tidy_wrangler_std['Time'][230]])
#262
D2stdW.loc[5] = np.array([tidy_wrangler_std['Cores'][239],tidy_wrangler_std['Time'][239],tidy_wrangler_std['Time'][243],tidy_wrangler_std['Time'][247],tidy_wrangler_std['Time'][251],tidy_wrangler_std['Time'][243]/tidy_wrangler_std['Time'][243]])
D2stdW.loc[6] = np.array([tidy_wrangler_std['Cores'][240],tidy_wrangler_std['Time'][240],tidy_wrangler_std['Time'][244],tidy_wrangler_std['Time'][248],tidy_wrangler_std['Time'][252],tidy_wrangler_std['Time'][243]/tidy_wrangler_std['Time'][244]])
D2stdW.loc[7] = np.array([tidy_wrangler_std['Cores'][241],tidy_wrangler_std['Time'][241],tidy_wrangler_std['Time'][245],tidy_wrangler_std['Time'][249],tidy_wrangler_std['Time'][253],tidy_wrangler_std['Time'][243]/tidy_wrangler_std['Time'][245]])
D2stdW.loc[8] = np.array([tidy_wrangler_std['Cores'][242],tidy_wrangler_std['Time'][242],tidy_wrangler_std['Time'][246],tidy_wrangler_std['Time'][250],tidy_wrangler_std['Time'][254],tidy_wrangler_std['Time'][243]/tidy_wrangler_std['Time'][246]])
#524
D2stdW.loc[9]  = np.array([tidy_wrangler_std['Cores'][255],tidy_wrangler_std['Time'][255],tidy_wrangler_std['Time'][259],tidy_wrangler_std['Time'][263],tidy_wrangler_std['Time'][267],tidy_wrangler_std['Time'][259]/tidy_wrangler_std['Time'][259]])
D2stdW.loc[10] = np.array([tidy_wrangler_std['Cores'][256],tidy_wrangler_std['Time'][256],tidy_wrangler_std['Time'][260],tidy_wrangler_std['Time'][264],tidy_wrangler_std['Time'][268],tidy_wrangler_std['Time'][259]/tidy_wrangler_std['Time'][260]])
D2stdW.loc[11] = np.array([tidy_wrangler_std['Cores'][257],tidy_wrangler_std['Time'][257],tidy_wrangler_std['Time'][261],tidy_wrangler_std['Time'][265],tidy_wrangler_std['Time'][269],tidy_wrangler_std['Time'][259]/tidy_wrangler_std['Time'][261]])
D2stdW.loc[12] = np.array([tidy_wrangler_std['Cores'][258],tidy_wrangler_std['Time'][258],tidy_wrangler_std['Time'][262],tidy_wrangler_std['Time'][266],tidy_wrangler_std['Time'][270],tidy_wrangler_std['Time'][259]/tidy_wrangler_std['Time'][262]])

# %%
Sp3meansW = pd.DataFrame(columns=['Cores','Spark Overhead','Spark Edge Disc','Spark Write','Spark Total Time','Speedup'])
#131
Sp3meansW.loc[1] = np.array([tidy_wrangler['Cores'][143],tidy_wrangler['Time'][143],tidy_wrangler['Time'][147],tidy_wrangler['Time'][151],tidy_wrangler['Time'][155],tidy_wrangler['Time'][147]/tidy_wrangler['Time'][147]])
Sp3meansW.loc[2] = np.array([tidy_wrangler['Cores'][144],tidy_wrangler['Time'][144],tidy_wrangler['Time'][148],tidy_wrangler['Time'][152],tidy_wrangler['Time'][156],tidy_wrangler['Time'][147]/tidy_wrangler['Time'][148]])
Sp3meansW.loc[3] = np.array([tidy_wrangler['Cores'][145],tidy_wrangler['Time'][145],tidy_wrangler['Time'][149],tidy_wrangler['Time'][153],tidy_wrangler['Time'][157],tidy_wrangler['Time'][147]/tidy_wrangler['Time'][149]])
Sp3meansW.loc[4] = np.array([tidy_wrangler['Cores'][146],tidy_wrangler['Time'][146],tidy_wrangler['Time'][150],tidy_wrangler['Time'][154],tidy_wrangler['Time'][158],tidy_wrangler['Time'][147]/tidy_wrangler['Time'][150]])
#262
Sp3meansW.loc[5] = np.array([tidy_wrangler['Cores'][159],tidy_wrangler['Time'][159],tidy_wrangler['Time'][163],tidy_wrangler['Time'][167],tidy_wrangler['Time'][171],tidy_wrangler['Time'][163]/tidy_wrangler['Time'][163]])
Sp3meansW.loc[6] = np.array([tidy_wrangler['Cores'][160],tidy_wrangler['Time'][160],tidy_wrangler['Time'][164],tidy_wrangler['Time'][168],tidy_wrangler['Time'][172],tidy_wrangler['Time'][163]/tidy_wrangler['Time'][164]])
Sp3meansW.loc[7] = np.array([tidy_wrangler['Cores'][161],tidy_wrangler['Time'][161],tidy_wrangler['Time'][165],tidy_wrangler['Time'][169],tidy_wrangler['Time'][173],tidy_wrangler['Time'][163]/tidy_wrangler['Time'][165]])
Sp3meansW.loc[8] = np.array([tidy_wrangler['Cores'][162],tidy_wrangler['Time'][162],tidy_wrangler['Time'][166],tidy_wrangler['Time'][170],tidy_wrangler['Time'][174],tidy_wrangler['Time'][163]/tidy_wrangler['Time'][166]])
#524
Sp3meansW.loc[9]  = np.array([tidy_wrangler['Cores'][175],tidy_wrangler['Time'][175],tidy_wrangler['Time'][179],tidy_wrangler['Time'][183],tidy_wrangler['Time'][187],tidy_wrangler['Time'][179]/tidy_wrangler['Time'][179]])
Sp3meansW.loc[10] = np.array([tidy_wrangler['Cores'][176],tidy_wrangler['Time'][176],tidy_wrangler['Time'][180],tidy_wrangler['Time'][184],tidy_wrangler['Time'][188],tidy_wrangler['Time'][179]/tidy_wrangler['Time'][180]])
Sp3meansW.loc[11] = np.array([tidy_wrangler['Cores'][177],tidy_wrangler['Time'][177],tidy_wrangler['Time'][181],tidy_wrangler['Time'][185],tidy_wrangler['Time'][189],tidy_wrangler['Time'][179]/tidy_wrangler['Time'][181]])
Sp3meansW.loc[12] = np.array([tidy_wrangler['Cores'][178],tidy_wrangler['Time'][178],tidy_wrangler['Time'][182],tidy_wrangler['Time'][186],tidy_wrangler['Time'][190],tidy_wrangler['Time'][179]/tidy_wrangler['Time'][182]])

D3meansW = pd.DataFrame(columns=['Cores','Dask Overhead','Dask Edge Disc','Dask ConnComp','Dask Total Time','Speedup'])
#131
D3meansW.loc[1] = np.array([tidy_wrangler['Cores'][271],tidy_wrangler['Time'][271],tidy_wrangler['Time'][275],tidy_wrangler['Time'][279],tidy_wrangler['Time'][283],tidy_wrangler['Time'][275]/tidy_wrangler['Time'][275]])
D3meansW.loc[2] = np.array([tidy_wrangler['Cores'][272],tidy_wrangler['Time'][272],tidy_wrangler['Time'][276],tidy_wrangler['Time'][280],tidy_wrangler['Time'][284],tidy_wrangler['Time'][275]/tidy_wrangler['Time'][276]])
D3meansW.loc[3] = np.array([tidy_wrangler['Cores'][273],tidy_wrangler['Time'][273],tidy_wrangler['Time'][277],tidy_wrangler['Time'][281],tidy_wrangler['Time'][285],tidy_wrangler['Time'][275]/tidy_wrangler['Time'][277]])
D3meansW.loc[4] = np.array([tidy_wrangler['Cores'][274],tidy_wrangler['Time'][274],tidy_wrangler['Time'][278],tidy_wrangler['Time'][282],tidy_wrangler['Time'][286],tidy_wrangler['Time'][275]/tidy_wrangler['Time'][278]])
#262
D3meansW.loc[5] = np.array([tidy_wrangler['Cores'][287],tidy_wrangler['Time'][287],tidy_wrangler['Time'][291],tidy_wrangler['Time'][295],tidy_wrangler['Time'][299],tidy_wrangler['Time'][291]/tidy_wrangler['Time'][291]])
D3meansW.loc[6] = np.array([tidy_wrangler['Cores'][288],tidy_wrangler['Time'][288],tidy_wrangler['Time'][292],tidy_wrangler['Time'][296],tidy_wrangler['Time'][300],tidy_wrangler['Time'][291]/tidy_wrangler['Time'][292]])
D3meansW.loc[7] = np.array([tidy_wrangler['Cores'][289],tidy_wrangler['Time'][289],tidy_wrangler['Time'][293],tidy_wrangler['Time'][297],tidy_wrangler['Time'][301],tidy_wrangler['Time'][291]/tidy_wrangler['Time'][293]])
D3meansW.loc[8] = np.array([tidy_wrangler['Cores'][290],tidy_wrangler['Time'][290],tidy_wrangler['Time'][294],tidy_wrangler['Time'][298],tidy_wrangler['Time'][302],tidy_wrangler['Time'][291]/tidy_wrangler['Time'][294]])
#524
D3meansW.loc[9]  = np.array([tidy_wrangler['Cores'][303],tidy_wrangler['Time'][303],tidy_wrangler['Time'][307],tidy_wrangler['Time'][311],tidy_wrangler['Time'][315],tidy_wrangler['Time'][307]/tidy_wrangler['Time'][307]])
D3meansW.loc[10] = np.array([tidy_wrangler['Cores'][304],tidy_wrangler['Time'][304],tidy_wrangler['Time'][308],tidy_wrangler['Time'][312],tidy_wrangler['Time'][316],tidy_wrangler['Time'][307]/tidy_wrangler['Time'][308]])
D3meansW.loc[11] = np.array([tidy_wrangler['Cores'][305],tidy_wrangler['Time'][305],tidy_wrangler['Time'][309],tidy_wrangler['Time'][313],tidy_wrangler['Time'][317],tidy_wrangler['Time'][307]/tidy_wrangler['Time'][309]])
D3meansW.loc[12] = np.array([tidy_wrangler['Cores'][306],tidy_wrangler['Time'][306],tidy_wrangler['Time'][310],tidy_wrangler['Time'][314],tidy_wrangler['Time'][318],tidy_wrangler['Time'][307]/tidy_wrangler['Time'][310]])

# %%
Sp3stdW = pd.DataFrame(columns=['Cores','Spark Overhead','Spark Edge Disc','Spark Write','Spark Total Time','Speedup'])
#131
Sp3stdW.loc[1] = np.array([tidy_wrangler_std['Cores'][143],tidy_wrangler_std['Time'][143],tidy_wrangler_std['Time'][147],tidy_wrangler_std['Time'][151],tidy_wrangler_std['Time'][155],tidy_wrangler_std['Time'][147]/tidy_wrangler_std['Time'][147]])
Sp3stdW.loc[2] = np.array([tidy_wrangler_std['Cores'][144],tidy_wrangler_std['Time'][144],tidy_wrangler_std['Time'][148],tidy_wrangler_std['Time'][152],tidy_wrangler_std['Time'][156],tidy_wrangler_std['Time'][147]/tidy_wrangler_std['Time'][148]])
Sp3stdW.loc[3] = np.array([tidy_wrangler_std['Cores'][145],tidy_wrangler_std['Time'][145],tidy_wrangler_std['Time'][149],tidy_wrangler_std['Time'][153],tidy_wrangler_std['Time'][157],tidy_wrangler_std['Time'][147]/tidy_wrangler_std['Time'][149]])
Sp3stdW.loc[4] = np.array([tidy_wrangler_std['Cores'][146],tidy_wrangler_std['Time'][146],tidy_wrangler_std['Time'][150],tidy_wrangler_std['Time'][154],tidy_wrangler_std['Time'][158],tidy_wrangler_std['Time'][147]/tidy_wrangler_std['Time'][150]])
#262
Sp3stdW.loc[5] = np.array([tidy_wrangler_std['Cores'][159],tidy_wrangler_std['Time'][159],tidy_wrangler_std['Time'][163],tidy_wrangler_std['Time'][167],tidy_wrangler_std['Time'][171],tidy_wrangler_std['Time'][163]/tidy_wrangler_std['Time'][163]])
Sp3stdW.loc[6] = np.array([tidy_wrangler_std['Cores'][160],tidy_wrangler_std['Time'][160],tidy_wrangler_std['Time'][164],tidy_wrangler_std['Time'][168],tidy_wrangler_std['Time'][172],tidy_wrangler_std['Time'][163]/tidy_wrangler_std['Time'][164]])
Sp3stdW.loc[7] = np.array([tidy_wrangler_std['Cores'][161],tidy_wrangler_std['Time'][161],tidy_wrangler_std['Time'][165],tidy_wrangler_std['Time'][169],tidy_wrangler_std['Time'][173],tidy_wrangler_std['Time'][163]/tidy_wrangler_std['Time'][165]])
Sp3stdW.loc[8] = np.array([tidy_wrangler_std['Cores'][162],tidy_wrangler_std['Time'][162],tidy_wrangler_std['Time'][166],tidy_wrangler_std['Time'][170],tidy_wrangler_std['Time'][174],tidy_wrangler_std['Time'][163]/tidy_wrangler_std['Time'][166]])
#524
Sp3stdW.loc[9]  = np.array([tidy_wrangler_std['Cores'][175],tidy_wrangler_std['Time'][175],tidy_wrangler_std['Time'][179],tidy_wrangler_std['Time'][183],tidy_wrangler_std['Time'][187],tidy_wrangler_std['Time'][179]/tidy_wrangler_std['Time'][179]])
Sp3stdW.loc[10] = np.array([tidy_wrangler_std['Cores'][176],tidy_wrangler_std['Time'][176],tidy_wrangler_std['Time'][180],tidy_wrangler_std['Time'][184],tidy_wrangler_std['Time'][188],tidy_wrangler_std['Time'][179]/tidy_wrangler_std['Time'][180]])
Sp3stdW.loc[11] = np.array([tidy_wrangler_std['Cores'][177],tidy_wrangler_std['Time'][177],tidy_wrangler_std['Time'][181],tidy_wrangler_std['Time'][185],tidy_wrangler_std['Time'][189],tidy_wrangler_std['Time'][179]/tidy_wrangler_std['Time'][181]])
Sp3stdW.loc[12] = np.array([tidy_wrangler_std['Cores'][178],tidy_wrangler_std['Time'][178],tidy_wrangler_std['Time'][182],tidy_wrangler_std['Time'][186],tidy_wrangler_std['Time'][190],tidy_wrangler_std['Time'][179]/tidy_wrangler_std['Time'][182]])

D3stdW = pd.DataFrame(columns=['Cores','Dask Overhead','Dask Edge Disc','Dask ConnComp','Dask Total Time','Speedup'])
#131
D3stdW.loc[1] = np.array([tidy_wrangler_std['Cores'][271],tidy_wrangler_std['Time'][271],tidy_wrangler_std['Time'][275],tidy_wrangler_std['Time'][279],tidy_wrangler_std['Time'][283],tidy_wrangler_std['Time'][275]/tidy_wrangler_std['Time'][275]])
D3stdW.loc[2] = np.array([tidy_wrangler_std['Cores'][272],tidy_wrangler_std['Time'][272],tidy_wrangler_std['Time'][276],tidy_wrangler_std['Time'][280],tidy_wrangler_std['Time'][284],tidy_wrangler_std['Time'][275]/tidy_wrangler_std['Time'][276]])
D3stdW.loc[3] = np.array([tidy_wrangler_std['Cores'][273],tidy_wrangler_std['Time'][273],tidy_wrangler_std['Time'][277],tidy_wrangler_std['Time'][281],tidy_wrangler_std['Time'][285],tidy_wrangler_std['Time'][275]/tidy_wrangler_std['Time'][277]])
D3stdW.loc[4] = np.array([tidy_wrangler_std['Cores'][274],tidy_wrangler_std['Time'][274],tidy_wrangler_std['Time'][278],tidy_wrangler_std['Time'][282],tidy_wrangler_std['Time'][286],tidy_wrangler_std['Time'][275]/tidy_wrangler_std['Time'][278]])
#262
D3stdW.loc[5] = np.array([tidy_wrangler_std['Cores'][287],tidy_wrangler_std['Time'][287],tidy_wrangler_std['Time'][291],tidy_wrangler_std['Time'][295],tidy_wrangler_std['Time'][299],tidy_wrangler_std['Time'][291]/tidy_wrangler_std['Time'][291]])
D3stdW.loc[6] = np.array([tidy_wrangler_std['Cores'][288],tidy_wrangler_std['Time'][288],tidy_wrangler_std['Time'][292],tidy_wrangler_std['Time'][296],tidy_wrangler_std['Time'][300],tidy_wrangler_std['Time'][291]/tidy_wrangler_std['Time'][292]])
D3stdW.loc[7] = np.array([tidy_wrangler_std['Cores'][289],tidy_wrangler_std['Time'][289],tidy_wrangler_std['Time'][293],tidy_wrangler_std['Time'][297],tidy_wrangler_std['Time'][301],tidy_wrangler_std['Time'][291]/tidy_wrangler_std['Time'][293]])
D3stdW.loc[8] = np.array([tidy_wrangler_std['Cores'][290],tidy_wrangler_std['Time'][290],tidy_wrangler_std['Time'][294],tidy_wrangler_std['Time'][298],tidy_wrangler_std['Time'][302],tidy_wrangler_std['Time'][291]/tidy_wrangler_std['Time'][294]])
#524
D3stdW.loc[9]  = np.array([tidy_wrangler_std['Cores'][303],tidy_wrangler_std['Time'][303],tidy_wrangler_std['Time'][307],tidy_wrangler_std['Time'][311],tidy_wrangler_std['Time'][315],tidy_wrangler_std['Time'][307]/tidy_wrangler_std['Time'][307]])
D3stdW.loc[10] = np.array([tidy_wrangler_std['Cores'][304],tidy_wrangler_std['Time'][304],tidy_wrangler_std['Time'][308],tidy_wrangler_std['Time'][312],tidy_wrangler_std['Time'][316],tidy_wrangler_std['Time'][307]/tidy_wrangler_std['Time'][308]])
D3stdW.loc[11] = np.array([tidy_wrangler_std['Cores'][305],tidy_wrangler_std['Time'][305],tidy_wrangler_std['Time'][309],tidy_wrangler_std['Time'][313],tidy_wrangler_std['Time'][317],tidy_wrangler_std['Time'][307]/tidy_wrangler_std['Time'][309]])
D3stdW.loc[12] = np.array([tidy_wrangler_std['Cores'][306],tidy_wrangler_std['Time'][306],tidy_wrangler_std['Time'][310],tidy_wrangler_std['Time'][314],tidy_wrangler_std['Time'][318],tidy_wrangler_std['Time'][307]/tidy_wrangler_std['Time'][310]])

# %%
Sp4meansW = pd.DataFrame(columns=['Cores','Spark Overhead','Spark Edge Disc','Spark Write','Spark Total Time','Speedup'])
#131
Sp4meansW.loc[1] = np.array([tidy_tree_wrangler['Cores'][96],tidy_tree_wrangler['Time'][96],tidy_tree_wrangler['Time'][100],tidy_tree_wrangler['Time'][104],tidy_tree_wrangler['Time'][108],tidy_tree_wrangler['Time'][108]/tidy_tree_wrangler['Time'][108]])
Sp4meansW.loc[2] = np.array([tidy_tree_wrangler['Cores'][97],tidy_tree_wrangler['Time'][97],tidy_tree_wrangler['Time'][101],tidy_tree_wrangler['Time'][105],tidy_tree_wrangler['Time'][109],tidy_tree_wrangler['Time'][108]/tidy_tree_wrangler['Time'][109]])
Sp4meansW.loc[3] = np.array([tidy_tree_wrangler['Cores'][98],tidy_tree_wrangler['Time'][98],tidy_tree_wrangler['Time'][102],tidy_tree_wrangler['Time'][106],tidy_tree_wrangler['Time'][110],tidy_tree_wrangler['Time'][108]/tidy_tree_wrangler['Time'][110]])
Sp4meansW.loc[4] = np.array([tidy_tree_wrangler['Cores'][99],tidy_tree_wrangler['Time'][99],tidy_tree_wrangler['Time'][103],tidy_tree_wrangler['Time'][107],tidy_tree_wrangler['Time'][111],tidy_tree_wrangler['Time'][108]/tidy_tree_wrangler['Time'][111]])
#262
Sp4meansW.loc[5] = np.array([tidy_tree_wrangler['Cores'][112],tidy_tree_wrangler['Time'][112],tidy_tree_wrangler['Time'][116],tidy_tree_wrangler['Time'][120],tidy_tree_wrangler['Time'][124],tidy_tree_wrangler['Time'][124]/tidy_tree_wrangler['Time'][124]])
Sp4meansW.loc[6] = np.array([tidy_tree_wrangler['Cores'][113],tidy_tree_wrangler['Time'][113],tidy_tree_wrangler['Time'][117],tidy_tree_wrangler['Time'][121],tidy_tree_wrangler['Time'][125],tidy_tree_wrangler['Time'][124]/tidy_tree_wrangler['Time'][125]])
Sp4meansW.loc[7] = np.array([tidy_tree_wrangler['Cores'][114],tidy_tree_wrangler['Time'][114],tidy_tree_wrangler['Time'][118],tidy_tree_wrangler['Time'][122],tidy_tree_wrangler['Time'][126],tidy_tree_wrangler['Time'][124]/tidy_tree_wrangler['Time'][126]])
Sp4meansW.loc[8] = np.array([tidy_tree_wrangler['Cores'][115],tidy_tree_wrangler['Time'][115],tidy_tree_wrangler['Time'][119],tidy_tree_wrangler['Time'][123],tidy_tree_wrangler['Time'][127],tidy_tree_wrangler['Time'][124]/tidy_tree_wrangler['Time'][127]])
#524
Sp4meansW.loc[9]  = np.array([tidy_tree_wrangler['Cores'][128],tidy_tree_wrangler['Time'][128],tidy_tree_wrangler['Time'][132],tidy_tree_wrangler['Time'][136],tidy_tree_wrangler['Time'][140],tidy_tree_wrangler['Time'][140]/tidy_tree_wrangler['Time'][140]])
Sp4meansW.loc[10] = np.array([tidy_tree_wrangler['Cores'][129],tidy_tree_wrangler['Time'][129],tidy_tree_wrangler['Time'][133],tidy_tree_wrangler['Time'][137],tidy_tree_wrangler['Time'][141],tidy_tree_wrangler['Time'][140]/tidy_tree_wrangler['Time'][141]])
Sp4meansW.loc[11] = np.array([tidy_tree_wrangler['Cores'][130],tidy_tree_wrangler['Time'][130],tidy_tree_wrangler['Time'][134],tidy_tree_wrangler['Time'][138],tidy_tree_wrangler['Time'][142],tidy_tree_wrangler['Time'][140]/tidy_tree_wrangler['Time'][142]])
Sp4meansW.loc[12] = np.array([tidy_tree_wrangler['Cores'][131],tidy_tree_wrangler['Time'][131],tidy_tree_wrangler['Time'][135],tidy_tree_wrangler['Time'][139],tidy_tree_wrangler['Time'][143],tidy_tree_wrangler['Time'][140]/tidy_tree_wrangler['Time'][143]])


Sp4stdW = pd.DataFrame(columns=['Cores','Spark Overhead','Spark Edge Disc','Spark Write','Spark Total Time','Speedup'])
#131
Sp4stdW.loc[1] = np.array([tidy_tree_wranglerSTD['Cores'][96],tidy_tree_wranglerSTD['Time'][96],tidy_tree_wranglerSTD['Time'][100],tidy_tree_wranglerSTD['Time'][104],tidy_tree_wranglerSTD['Time'][108],tidy_tree_wranglerSTD['Time'][108]/tidy_tree_wranglerSTD['Time'][108]])
Sp4stdW.loc[2] = np.array([tidy_tree_wranglerSTD['Cores'][97],tidy_tree_wranglerSTD['Time'][97],tidy_tree_wranglerSTD['Time'][101],tidy_tree_wranglerSTD['Time'][105],tidy_tree_wranglerSTD['Time'][109],tidy_tree_wranglerSTD['Time'][108]/tidy_tree_wranglerSTD['Time'][109]])
Sp4stdW.loc[3] = np.array([tidy_tree_wranglerSTD['Cores'][98],tidy_tree_wranglerSTD['Time'][98],tidy_tree_wranglerSTD['Time'][102],tidy_tree_wranglerSTD['Time'][106],tidy_tree_wranglerSTD['Time'][110],tidy_tree_wranglerSTD['Time'][108]/tidy_tree_wranglerSTD['Time'][110]])
Sp4stdW.loc[4] = np.array([tidy_tree_wranglerSTD['Cores'][99],tidy_tree_wranglerSTD['Time'][99],tidy_tree_wranglerSTD['Time'][103],tidy_tree_wranglerSTD['Time'][107],tidy_tree_wranglerSTD['Time'][111],tidy_tree_wranglerSTD['Time'][108]/tidy_tree_wranglerSTD['Time'][111]])
#262
Sp4stdW.loc[5] = np.array([tidy_tree_wranglerSTD['Cores'][112],tidy_tree_wranglerSTD['Time'][112],tidy_tree_wranglerSTD['Time'][116],tidy_tree_wranglerSTD['Time'][120],tidy_tree_wranglerSTD['Time'][124],tidy_tree_wranglerSTD['Time'][124]/tidy_tree_wranglerSTD['Time'][124]])
Sp4stdW.loc[6] = np.array([tidy_tree_wranglerSTD['Cores'][113],tidy_tree_wranglerSTD['Time'][113],tidy_tree_wranglerSTD['Time'][117],tidy_tree_wranglerSTD['Time'][121],tidy_tree_wranglerSTD['Time'][125],tidy_tree_wranglerSTD['Time'][124]/tidy_tree_wranglerSTD['Time'][125]])
Sp4stdW.loc[7] = np.array([tidy_tree_wranglerSTD['Cores'][114],tidy_tree_wranglerSTD['Time'][114],tidy_tree_wranglerSTD['Time'][118],tidy_tree_wranglerSTD['Time'][122],tidy_tree_wranglerSTD['Time'][126],tidy_tree_wranglerSTD['Time'][124]/tidy_tree_wranglerSTD['Time'][126]])
Sp4stdW.loc[8] = np.array([tidy_tree_wranglerSTD['Cores'][115],tidy_tree_wranglerSTD['Time'][115],tidy_tree_wranglerSTD['Time'][119],tidy_tree_wranglerSTD['Time'][123],tidy_tree_wranglerSTD['Time'][127],tidy_tree_wranglerSTD['Time'][124]/tidy_tree_wranglerSTD['Time'][127]])
#524
Sp4stdW.loc[9]  = np.array([tidy_tree_wranglerSTD['Cores'][128],tidy_tree_wranglerSTD['Time'][128],tidy_tree_wranglerSTD['Time'][132],tidy_tree_wranglerSTD['Time'][136],tidy_tree_wranglerSTD['Time'][140],tidy_tree_wranglerSTD['Time'][140]/tidy_tree_wranglerSTD['Time'][140]])
Sp4stdW.loc[10] = np.array([tidy_tree_wranglerSTD['Cores'][129],tidy_tree_wranglerSTD['Time'][129],tidy_tree_wranglerSTD['Time'][133],tidy_tree_wranglerSTD['Time'][137],tidy_tree_wranglerSTD['Time'][141],tidy_tree_wranglerSTD['Time'][140]/tidy_tree_wranglerSTD['Time'][141]])
Sp4stdW.loc[11] = np.array([tidy_tree_wranglerSTD['Cores'][130],tidy_tree_wranglerSTD['Time'][130],tidy_tree_wranglerSTD['Time'][134],tidy_tree_wranglerSTD['Time'][138],tidy_tree_wranglerSTD['Time'][142],tidy_tree_wranglerSTD['Time'][140]/tidy_tree_wranglerSTD['Time'][142]])
Sp4stdW.loc[12] = np.array([tidy_tree_wranglerSTD['Cores'][131],tidy_tree_wranglerSTD['Time'][131],tidy_tree_wranglerSTD['Time'][135],tidy_tree_wranglerSTD['Time'][139],tidy_tree_wranglerSTD['Time'][143],tidy_tree_wranglerSTD['Time'][140]/tidy_tree_wranglerSTD['Time'][143]])

# %%
D4meansW = pd.DataFrame(columns=['Cores','Dask Overhead','Dask Edge Disc','Dask ConnComp','Dask Total Time','Speedup'])
#131
D4meansW.loc[1] = np.array([tidy_tree_wrangler['Cores'][224],tidy_tree_wrangler['Time'][224],tidy_tree_wrangler['Time'][228],tidy_tree_wrangler['Time'][232],tidy_tree_wrangler['Time'][236],tidy_tree_wrangler['Time'][236]/tidy_tree_wrangler['Time'][236]])
D4meansW.loc[2] = np.array([tidy_tree_wrangler['Cores'][225],tidy_tree_wrangler['Time'][225],tidy_tree_wrangler['Time'][229],tidy_tree_wrangler['Time'][233],tidy_tree_wrangler['Time'][237],tidy_tree_wrangler['Time'][236]/tidy_tree_wrangler['Time'][237]])
D4meansW.loc[3] = np.array([tidy_tree_wrangler['Cores'][226],tidy_tree_wrangler['Time'][226],tidy_tree_wrangler['Time'][230],tidy_tree_wrangler['Time'][234],tidy_tree_wrangler['Time'][238],tidy_tree_wrangler['Time'][236]/tidy_tree_wrangler['Time'][238]])
D4meansW.loc[4] = np.array([tidy_tree_wrangler['Cores'][227],tidy_tree_wrangler['Time'][227],tidy_tree_wrangler['Time'][231],tidy_tree_wrangler['Time'][235],tidy_tree_wrangler['Time'][239],tidy_tree_wrangler['Time'][236]/tidy_tree_wrangler['Time'][239]])
#262
D4meansW.loc[5] = np.array([tidy_tree_wrangler['Cores'][240],tidy_tree_wrangler['Time'][240],tidy_tree_wrangler['Time'][244],tidy_tree_wrangler['Time'][248],tidy_tree_wrangler['Time'][252],tidy_tree_wrangler['Time'][252]/tidy_tree_wrangler['Time'][252]])
D4meansW.loc[6] = np.array([tidy_tree_wrangler['Cores'][241],tidy_tree_wrangler['Time'][241],tidy_tree_wrangler['Time'][245],tidy_tree_wrangler['Time'][249],tidy_tree_wrangler['Time'][253],tidy_tree_wrangler['Time'][252]/tidy_tree_wrangler['Time'][253]])
D4meansW.loc[7] = np.array([tidy_tree_wrangler['Cores'][242],tidy_tree_wrangler['Time'][242],tidy_tree_wrangler['Time'][246],tidy_tree_wrangler['Time'][250],tidy_tree_wrangler['Time'][254],tidy_tree_wrangler['Time'][252]/tidy_tree_wrangler['Time'][254]])
D4meansW.loc[8] = np.array([tidy_tree_wrangler['Cores'][243],tidy_tree_wrangler['Time'][243],tidy_tree_wrangler['Time'][247],tidy_tree_wrangler['Time'][251],tidy_tree_wrangler['Time'][255],tidy_tree_wrangler['Time'][252]/tidy_tree_wrangler['Time'][255]])
#524
D4meansW.loc[9]  = np.array([tidy_tree_wrangler['Cores'][256],tidy_tree_wrangler['Time'][256],tidy_tree_wrangler['Time'][260],tidy_tree_wrangler['Time'][264],tidy_tree_wrangler['Time'][268],tidy_tree_wrangler['Time'][268]/tidy_tree_wrangler['Time'][268]])
D4meansW.loc[10] = np.array([tidy_tree_wrangler['Cores'][257],tidy_tree_wrangler['Time'][257],tidy_tree_wrangler['Time'][261],tidy_tree_wrangler['Time'][265],tidy_tree_wrangler['Time'][269],tidy_tree_wrangler['Time'][268]/tidy_tree_wrangler['Time'][269]])
D4meansW.loc[11] = np.array([tidy_tree_wrangler['Cores'][258],tidy_tree_wrangler['Time'][258],tidy_tree_wrangler['Time'][262],tidy_tree_wrangler['Time'][266],tidy_tree_wrangler['Time'][270],tidy_tree_wrangler['Time'][268]/tidy_tree_wrangler['Time'][270]])
D4meansW.loc[12] = np.array([tidy_tree_wrangler['Cores'][259],tidy_tree_wrangler['Time'][259],tidy_tree_wrangler['Time'][263],tidy_tree_wrangler['Time'][267],tidy_tree_wrangler['Time'][271],tidy_tree_wrangler['Time'][268]/tidy_tree_wrangler['Time'][271]])

D4stdW = pd.DataFrame(columns=['Cores','Dask Overhead','Dask Edge Disc','Dask ConnComp','Dask Total Time','Speedup'])
#131
D4stdW.loc[1] = np.array([tidy_tree_wranglerSTD['Cores'][224],tidy_tree_wranglerSTD['Time'][224],tidy_tree_wranglerSTD['Time'][228],tidy_tree_wranglerSTD['Time'][232],tidy_tree_wranglerSTD['Time'][236],tidy_tree_wranglerSTD['Time'][236]/tidy_tree_wranglerSTD['Time'][236]])
D4stdW.loc[2] = np.array([tidy_tree_wranglerSTD['Cores'][225],tidy_tree_wranglerSTD['Time'][225],tidy_tree_wranglerSTD['Time'][229],tidy_tree_wranglerSTD['Time'][233],tidy_tree_wranglerSTD['Time'][237],tidy_tree_wranglerSTD['Time'][236]/tidy_tree_wranglerSTD['Time'][237]])
D4stdW.loc[3] = np.array([tidy_tree_wranglerSTD['Cores'][226],tidy_tree_wranglerSTD['Time'][226],tidy_tree_wranglerSTD['Time'][230],tidy_tree_wranglerSTD['Time'][234],tidy_tree_wranglerSTD['Time'][238],tidy_tree_wranglerSTD['Time'][236]/tidy_tree_wranglerSTD['Time'][238]])
D4stdW.loc[4] = np.array([tidy_tree_wranglerSTD['Cores'][227],tidy_tree_wranglerSTD['Time'][227],tidy_tree_wranglerSTD['Time'][231],tidy_tree_wranglerSTD['Time'][235],tidy_tree_wranglerSTD['Time'][239],tidy_tree_wranglerSTD['Time'][236]/tidy_tree_wranglerSTD['Time'][239]])
#262
D4stdW.loc[5] = np.array([tidy_tree_wranglerSTD['Cores'][240],tidy_tree_wranglerSTD['Time'][240],tidy_tree_wranglerSTD['Time'][244],tidy_tree_wranglerSTD['Time'][248],tidy_tree_wranglerSTD['Time'][252],tidy_tree_wranglerSTD['Time'][252]/tidy_tree_wranglerSTD['Time'][252]])
D4stdW.loc[6] = np.array([tidy_tree_wranglerSTD['Cores'][241],tidy_tree_wranglerSTD['Time'][241],tidy_tree_wranglerSTD['Time'][245],tidy_tree_wranglerSTD['Time'][249],tidy_tree_wranglerSTD['Time'][253],tidy_tree_wranglerSTD['Time'][252]/tidy_tree_wranglerSTD['Time'][253]])
D4stdW.loc[7] = np.array([tidy_tree_wranglerSTD['Cores'][242],tidy_tree_wranglerSTD['Time'][242],tidy_tree_wranglerSTD['Time'][246],tidy_tree_wranglerSTD['Time'][250],tidy_tree_wranglerSTD['Time'][254],tidy_tree_wranglerSTD['Time'][252]/tidy_tree_wranglerSTD['Time'][254]])
D4stdW.loc[8] = np.array([tidy_tree_wranglerSTD['Cores'][243],tidy_tree_wranglerSTD['Time'][243],tidy_tree_wranglerSTD['Time'][247],tidy_tree_wranglerSTD['Time'][251],tidy_tree_wranglerSTD['Time'][255],tidy_tree_wranglerSTD['Time'][252]/tidy_tree_wranglerSTD['Time'][255]])
#524
D4stdW.loc[9]  = np.array([tidy_tree_wranglerSTD['Cores'][256],tidy_tree_wranglerSTD['Time'][256],tidy_tree_wranglerSTD['Time'][260],tidy_tree_wranglerSTD['Time'][264],tidy_tree_wranglerSTD['Time'][268],tidy_tree_wranglerSTD['Time'][268]/tidy_tree_wranglerSTD['Time'][268]])
D4stdW.loc[10] = np.array([tidy_tree_wranglerSTD['Cores'][257],tidy_tree_wranglerSTD['Time'][257],tidy_tree_wranglerSTD['Time'][261],tidy_tree_wranglerSTD['Time'][265],tidy_tree_wranglerSTD['Time'][269],tidy_tree_wranglerSTD['Time'][268]/tidy_tree_wranglerSTD['Time'][269]])
D4stdW.loc[11] = np.array([tidy_tree_wranglerSTD['Cores'][258],tidy_tree_wranglerSTD['Time'][258],tidy_tree_wranglerSTD['Time'][262],tidy_tree_wranglerSTD['Time'][266],tidy_tree_wranglerSTD['Time'][270],tidy_tree_wranglerSTD['Time'][268]/tidy_tree_wranglerSTD['Time'][270]])
D4stdW.loc[12] = np.array([tidy_tree_wranglerSTD['Cores'][259],tidy_tree_wranglerSTD['Time'][259],tidy_tree_wranglerSTD['Time'][263],tidy_tree_wranglerSTD['Time'][267],tidy_tree_wranglerSTD['Time'][271],tidy_tree_wranglerSTD['Time'][268]/tidy_tree_wranglerSTD['Time'][271]])

# %%
sp = pd.DataFrame.from_csv('Sparkdataset4M.csv',index_col=None)
da = pd.DataFrame.from_csv('DaskDataSet4M.csv',index_col=None)
sp['TotalTime'] = sp['Write']-sp['Start']
da['TotalTime'] = da['End'] - da['Start']
sp4M4Means = pd.DataFrame(columns=['Cores','Mean','Std'])
da4M4Means = pd.DataFrame(columns=['Cores','Mean','Std'])
for i in range(0,12,3):
    mean = sp[i:i+3]['TotalTime'].mean()
    std = sp[i:i+3]['TotalTime'].std()
    sp4M4Means.loc[len(sp4M4Means)] = [32*sp['Node'][i],mean,std]
    mean = da[i:i+3]['TotalTime'].mean()
    std = da[i:i+3]['TotalTime'].std()
    da4M4Means.loc[len(da4M4Means)] = [32*da['Nodes'][i],mean,std]
    
sp4M4Means['Speedup']=sp4M4Means['Mean'][0]/sp4M4Means['Mean'].values
da4M4Means['Speedup']=da4M4Means['Mean'][0]/da4M4Means['Mean'].values

# %%
sp4M3 = pd.DataFrame(columns=['Cores','Run','Time'])
sp4M3.loc[len(sp4M3)]=[32,1,9173.5065360069]
sp4M3.loc[len(sp4M3)]=[32,2,9153.7635819912]
sp4M3.loc[len(sp4M3)]=[32,3,9182.4670889378]
sp4M3.loc[len(sp4M3)]=[64,1,4545.4923429489]
sp4M3.loc[len(sp4M3)]=[64,2,4532.8439800739]
sp4M3.loc[len(sp4M3)]=[64,3,4527.4764671326]
sp4M3.loc[len(sp4M3)]=[128,1,2384.1899449825]
sp4M3.loc[len(sp4M3)]=[128,2,2380.2248439789]
sp4M3.loc[len(sp4M3)]=[128,3,2380.2551229]
sp4M3.loc[len(sp4M3)]=[256,1,1296.7799069882]
sp4M3.loc[len(sp4M3)]=[256,2,1293.5109817982]
sp4M3.loc[len(sp4M3)]=[256,3,1278.0387458801]

sp4M3Means = pd.DataFrame(columns=['Cores','Mean','Std'])
for i in range(0,12,3):
    mean = sp4M3[i:i+3]['Time'].mean()
    std = sp4M3[i:i+3]['Time'].std()
    sp4M3Means.loc[len(sp4M3Means)] = [sp4M3['Cores'][i],mean,std]
    
sp4M3Means['Speedup']=sp4M3Means['Mean'][0]/sp4M3Means['Mean'].values

# %%
lfbroad = pd.DataFrame.from_csv('mpi4py/LFBroad_mpi4py.csv')
lfcoll  = pd.DataFrame.from_csv('mpi4py/LFColl_mpi4py.csv')
lfparcc = pd.DataFrame.from_csv('mpi4py/LFParCC_mpi4py.csv')
lfbtree = pd.DataFrame.from_csv('mpi4py/LFBTree_mpi4py.csv')

# %%
lfb131 = lfbroad[lfbroad['Atoms']==131072]
lfb131 = lfb131[lfb131['Type']=='total'].reset_index(drop=['index'])
lfb131.drop(['Atoms','Type'],inplace=True,axis=1)
lfb131Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfb131[i:i+10]['Duration'].mean()
    std = lfb131[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfb131Means.loc[len(lfb131Means)] = [lfb131['Cores'][i],mean,std,np.divide(basic,mean)]
    
lfb262 = lfbroad[lfbroad['Atoms']==262144]
lfb262 = lfb262[lfb262['Type']=='total'].reset_index(drop=['index'])
lfb262.drop(['Atoms','Type'],inplace=True,axis=1)
lfb262Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfb262[i:i+10]['Duration'].mean()
    std = lfb262[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfb262Means.loc[len(lfb262Means)] = [lfb262['Cores'][i],mean,std,np.divide(basic,mean)]
lfb262Means

lfb524 = lfbroad[lfbroad['Atoms']==524288]
lfb524 = lfb524[lfb524['Type']=='total'].reset_index(drop=['index'])
lfb524.drop(['Atoms','Type'],inplace=True,axis=1)
lfb524Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfb524[i:i+10]['Duration'].mean()
    std = lfb524[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfb524Means.loc[len(lfb524Means)] = [lfb524['Cores'][i],mean,std,np.divide(basic,mean)]

# %%
lfc131 = lfcoll[lfcoll['Atoms']==131072]
lfc131 = lfc131[lfc131['Type']=='total'].reset_index(drop=['index'])
lfc131.drop(['Atoms','Type'],inplace=True,axis=1)
lfc131Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfc131[i:i+10]['Duration'].mean()
    std = lfc131[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfc131Means.loc[len(lfc131Means)] = [lfc131['Cores'][i],mean,std,np.divide(basic,mean)]
    
lfc262 = lfcoll[lfcoll['Atoms']==262144]
lfc262 = lfc262[lfc262['Type']=='total'].reset_index(drop=['index'])
lfc262.drop(['Atoms','Type'],inplace=True,axis=1)
lfc262Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfc262[i:i+10]['Duration'].mean()
    std = lfc262[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfc262Means.loc[len(lfc262Means)] = [lfc262['Cores'][i],mean,std,np.divide(basic,mean)]
lfc262Means

lfc524 = lfcoll[lfcoll['Atoms']==524288]
lfc524 = lfc524[lfc524['Type']=='total'].reset_index(drop=['index'])
lfc524.drop(['Atoms','Type'],inplace=True,axis=1)
lfc524Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfc524[i:i+10]['Duration'].mean()
    std = lfc524[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfc524Means.loc[len(lfc524Means)] = [lfc524['Cores'][i],mean,std,np.divide(basic,mean)]

# %%
lfpc131 = lfparcc[lfparcc['Atoms']==131072]
lfpc131 = lfpc131[lfpc131['Type']=='total'].reset_index(drop=['index'])
lfpc131.drop(['Atoms','Type'],inplace=True,axis=1)
lfpc131Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfpc131[i:i+10]['Duration'].mean()
    std = lfpc131[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfpc131Means.loc[len(lfpc131Means)] = [lfpc131['Cores'][i],mean,std,np.divide(basic,mean)]
    
lfpc262 = lfparcc[lfparcc['Atoms']==262144]
lfpc262 = lfpc262[lfpc262['Type']=='total'].reset_index(drop=['index'])
lfpc262.drop(['Atoms','Type'],inplace=True,axis=1)
lfpc262Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfpc262[i:i+10]['Duration'].mean()
    std = lfpc262[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfpc262Means.loc[len(lfpc262Means)] = [lfpc262['Cores'][i],mean,std,np.divide(basic,mean)]

lfpc524 = lfparcc[lfparcc['Atoms']==524288]
lfpc524 = lfpc524[lfpc524['Type']=='total'].reset_index(drop=['index'])
lfpc524.drop(['Atoms','Type'],inplace=True,axis=1)
lfpc524Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfpc524[i:i+10]['Duration'].mean()
    std = lfpc524[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfpc524Means.loc[len(lfpc524Means)] = [lfpc524['Cores'][i],mean,std,np.divide(basic,mean)]

# %%
lfbt131 = lfbtree[lfbtree['Atoms']==131072]
lfbt131 = lfbt131[lfbt131['Type']=='total'].reset_index(drop=['index'])
lfbt131.drop(['Atoms','Type'],inplace=True,axis=1)
lfbt131Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfbt131[i:i+10]['Duration'].mean()
    std = lfbt131[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfbt131Means.loc[len(lfbt131Means)] = [lfbt131['Cores'][i],mean,std,np.divide(basic,mean)]
    
lfbt262 = lfbtree[lfbtree['Atoms']==262144]
lfbt262 = lfbt262[lfbt262['Type']=='total'].reset_index(drop=['index'])
lfbt262.drop(['Atoms','Type'],inplace=True,axis=1)
lfbt262Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfbt262[i:i+10]['Duration'].mean()
    std = lfbt262[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfbt262Means.loc[len(lfbt262Means)] = [lfbt262['Cores'][i],mean,std,np.divide(basic,mean)]

lfbt524 = lfbtree[lfbtree['Atoms']==524288]
lfbt524 = lfbt524[lfbt524['Type']=='total'].reset_index(drop=['index'])
lfbt524.drop(['Atoms','Type'],inplace=True,axis=1)
lfbt524Means = pd.DataFrame(columns=['Cores','Mean','Std','Speedup'])
for i in range(0,40,10):
    mean = lfbt524[i:i+10]['Duration'].mean()
    std = lfbt524[i:i+10]['Duration'].std()
    if i==0:
        basic = mean
    lfbt524Means.loc[len(lfbt524Means)] = [lfbt524['Cores'][i],mean,std,np.divide(basic,mean)]

# %%
fig,axes = plt.subplots(nrows=3,ncols=4,sharex=True,sharey=True,gridspec_kw={'wspace':0.05, 'hspace':0.07})
fig.set_size_inches(12,5)
width = 0.2

lfb131Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfb131Means['Std'].values.transpose().tolist(),ax=axes[2,0],width=width,color=[reds(150)],legend=False,position=1.5,log=1)
lfb262Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfb262Means['Std'].values.transpose().tolist(),ax=axes[2,0],width=width,color=[greens(150)],legend=False,position=.5)
lfb524Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfb524Means['Std'].values.transpose().tolist(),ax=axes[2,0],width=width,color=[blues(150)],legend=False,position=-.5)

lfc131Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfc131Means['Std'].values.transpose().tolist(),ax=axes[2,1],width=width,color=[reds(150)],legend=False,position=1.5)
lfc262Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfc262Means['Std'].values.transpose().tolist(),ax=axes[2,1],width=width,color=[greens(150)],legend=False,position=.5)
lfc524Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfc524Means['Std'].values.transpose().tolist(),ax=axes[2,1],width=width,color=[blues(150)],legend=False,position=-.5)

lfpc131Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfpc131Means['Std'].values.transpose().tolist(),ax=axes[2,2],width=width,color=[reds(150)],legend=False,position=1.5)
lfpc262Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfpc262Means['Std'].values.transpose().tolist(),ax=axes[2,2],width=width,color=[greens(150)],legend=False,position=.5)
lfpc524Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfpc524Means['Std'].values.transpose().tolist(),ax=axes[2,2],width=width,color=[blues(150)],legend=False,position=-.5)
                                                                                                                                   
lfbt131Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfbt131Means['Std'].values.transpose().tolist(),ax=axes[2,3],width=width,color=[reds(150)],legend=False,position=1.5)
lfbt262Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfbt262Means['Std'].values.transpose().tolist(),ax=axes[2,3],width=width,color=[greens(150)],legend=False,position=.5)
lfbt524Means.plot(kind='bar',x='Cores',y='Mean',yerr=lfbt524Means['Std'].values.transpose().tolist(),ax=axes[2,3],width=width,color=[blues(150)],legend=False,position=-.5)

D1meansW[0:4].plot(kind='bar',x='Cores',y='Dask Total Time',yerr=D1stdW[0:4]['Dask Total Time'].values.transpose().tolist(),ax=axes[1,0],width=width,color=[reds(150)],legend=False,position=1.5)
D1meansW[4:8].plot(kind='bar',x='Cores',y='Dask Total Time',yerr=D1stdW[4:8]['Dask Total Time'].values.transpose().tolist(),ax=axes[1,0],width=width,color=[greens(150)],legend=False,position=.5)

D2meansW[0:4].plot(kind='bar',x='Cores',y='Dask Total Time',yerr=D2stdW[0:4]['Dask Total Time'].values.transpose().tolist(),ax=axes[1,1],width=width,color=[reds(150)],legend=False,position=1.5)
D2meansW[4:8].plot(kind='bar',x='Cores',y='Dask Total Time',yerr=D2stdW[4:8]['Dask Total Time'].values.transpose().tolist(),ax=axes[1,1],width=width,color=[greens(150)],legend=False,position=.5)
D2meansW[8:12].plot(kind='bar',x='Cores',y='Dask Total Time',yerr=D2stdW[8:12]['Dask Total Time'].values.transpose().tolist(),ax=axes[1,1],width=width,color=[blues(150)],legend=False,position=-.5)

D3meansW[0:4].plot(kind='bar',x='Cores',y='Dask Total Time',yerr=D3stdW[0:4]['Dask Total Time'].values.transpose().tolist(),ax=axes[1,2],width=width,color=[reds(150)],legend=False,position=1.5)
D3meansW[4:8].plot(kind='bar',x='Cores',y='Dask Total Time',yerr=D3stdW[4:8]['Dask Total Time'].values.transpose().tolist(),ax=axes[1,2],width=width,color=[greens(150)],legend=False,position=.5)
D3meansW[8:12].plot(kind='bar',x='Cores',y='Dask Total Time',yerr=D3stdW[8:12]['Dask Total Time'].values.transpose().tolist(),ax=axes[1,2],width=width,color=[blues(150)],legend=False,position=-.5)

D4meansW[0:4].plot(kind='bar',x='Cores',y='Dask Total Time',yerr=D3stdW[0:4]['Dask Total Time'].values.transpose().tolist(),ax=axes[1,3],width=width,color=[reds(150)],legend=False,position=1.5)
D4meansW[4:8].plot(kind='bar',x='Cores',y='Dask Total Time',yerr=D3stdW[4:8]['Dask Total Time'].values.transpose().tolist(),ax=axes[1,3],width=width,color=[greens(150)],legend=False,position=.5)
D4meansW[8:12].plot(kind='bar',x='Cores',y='Dask Total Time',yerr=D3stdW[8:12]['Dask Total Time'].values.transpose().tolist(),ax=axes[1,3],width=width,color=[blues(150)],legend=False,position=-.5)
da4M4Means.plot(kind='bar',x='Cores',y='Mean',yerr='Std',ax=axes[1,3],width=width,color=purples(150),legend=False,position=-1.5)

Sp1meansW[0:4].plot(kind='bar',x='Cores',y='Spark Total Time',yerr=Sp1stdW[0:4]['Spark Total Time'].values.transpose().tolist(),ax=axes[0,0],width=width,color=[reds(150)],legend=False,position=1.5)
Sp1meansW[4:8].plot(kind='bar',x='Cores',y='Spark Total Time',yerr=Sp1stdW[4:8]['Spark Total Time'].values.transpose().tolist(),ax=axes[0,0],width=width,color=[greens(150)],legend=False,position=.5)
Sp1meansW[8:12].plot(kind='bar',x='Cores',y='Spark Total Time',yerr=Sp1stdW[8:12]['Spark Total Time'].values.transpose().tolist(),ax=axes[0,0],width=width,color=[blues(150)],legend=False,position=-.5)

Sp2meansW[0:4].plot(kind='bar',x='Cores',y='Spark Total Time',yerr=Sp2stdW[0:4]['Spark Total Time'].values.transpose().tolist(),ax=axes[0,1],width=width,color=[reds(150)],legend=False,position=1.5)
Sp2meansW[4:8].plot(kind='bar',x='Cores',y='Spark Total Time',yerr=Sp2stdW[4:8]['Spark Total Time'].values.transpose().tolist(),ax=axes[0,1],width=width,color=[greens(150)],legend=False,position=.5)
Sp2meansW[8:12].plot(kind='bar',x='Cores',y='Spark Total Time',yerr=Sp2stdW[8:12]['Spark Total Time'].values.transpose().tolist(),ax=axes[0,1],width=width,color=[blues(150)],legend=False,position=-.5)

Sp3meansW[0:4].plot(kind='bar',x='Cores',y='Spark Total Time',yerr=Sp3stdW[0:4]['Spark Total Time'].values.transpose().tolist(),ax=axes[0,2],width=width,color=[reds(150)],legend=False,position=1.5)
Sp3meansW[4:8].plot(kind='bar',x='Cores',y='Spark Total Time',yerr=Sp3stdW[4:8]['Spark Total Time'].values.transpose().tolist(),ax=axes[0,2],width=width,color=[greens(150)],legend=False,position=.5)
Sp3meansW[8:12].plot(kind='bar',x='Cores',y='Spark Total Time',yerr=Sp3stdW[8:12]['Spark Total Time'].values.transpose().tolist(),ax=axes[0,2],width=width,color=[blues(150)],legend=False,position=-.5)
sp4M3Means.plot(kind='bar',x='Cores',y='Mean',yerr='Std',ax=axes[0,2],width=width,color=purples(150),legend=False,position=-1.5)

Sp4meansW[0:4].plot(kind='bar',x='Cores',y='Spark Total Time',yerr=Sp4stdW[0:4]['Spark Total Time'].values.transpose().tolist(),ax=axes[0,3],width=width,color=[reds(150)],legend=False,position=1.5)
Sp4meansW[4:8].plot(kind='bar',x='Cores',y='Spark Total Time',yerr=Sp4stdW[4:8]['Spark Total Time'].values.transpose().tolist(),ax=axes[0,3],width=width,color=[greens(150)],legend=False,position=.5)
Sp4meansW[8:12].plot(kind='bar',x='Cores',y='Spark Total Time',yerr=Sp4stdW[8:12]['Spark Total Time'].values.transpose().tolist(),ax=axes[0,3],width=width,color=[blues(150)],legend=False,position=-.5)
sp4M4Means.plot(kind='bar',x='Cores',y='Mean',yerr='Std',ax=axes[0,3],width=width,color=purples(150),legend=False,position=-1.5)

axes[0,0].set_title('Broadcast & 1-D Partitioning', fontsize=10)
axes[0,1].set_title('Task API & 2-D Partitioning', fontsize=10)
axes[0,2].set_title('Parallel Connected Components', fontsize=10)
axes[0,3].set_title('Tree-Search & \nParallel-Connected Components', fontsize=10)
axes[2,0].set_xticklabels(['32','64','128','256'], fontsize=12,rotation=0)
axes[2,1].set_xticklabels(['32','64','128','256'], fontsize=12,rotation=0)
axes[2,2].set_xticklabels(['32','64','128','256'], fontsize=12,rotation=0)
axes[2,3].set_xticklabels(['32','64','128','256'], fontsize=12,rotation=0)

axes[0,0].grid('on',which='both',linestyle=':')
axes[0,1].grid('on',which='both',linestyle=':')
axes[0,2].grid('on',which='both',linestyle=':')
axes[0,3].grid('on',which='both',linestyle=':')
axes[1,0].grid('on',which='both',linestyle=':')
axes[1,1].grid('on',which='both',linestyle=':')
axes[1,2].grid('on',which='both',linestyle=':')
axes[1,3].grid('on',which='both',linestyle=':')
axes[2,0].grid('on',which='both',linestyle=':')
axes[2,1].grid('on',which='both',linestyle=':')
axes[2,2].grid('on',which='both',linestyle=':')
axes[2,3].grid('on',which='both',linestyle=':')
axes[2,0].set_xlabel('',fontsize=12)
axes[2,1].set_xlabel('',fontsize=12)
axes[2,2].set_xlabel('',fontsize=12)
axes[2,3].set_xlabel('',fontsize=12)
axes[2,0].set_ylim([1,12000])
axes[2,0].set_yticks([1,10,100,1000,10000])
axes[0,0].set_yticklabels(['1','10','100','1000','10000'])
axes[0,3].text(4.25,1000, 'Spark',fontsize=14,bbox={'facecolor':'grey', 'alpha':0, 'pad':8},horizontalalignment='left',verticalalignment='top',rotation=270)
axes[1,3].text(4.25,1000, 'Dask',fontsize=14,bbox={'facecolor':'grey', 'alpha':0, 'pad':8},horizontalalignment='left',verticalalignment='top',rotation=270)
axes[2,3].text(4.25,1000, 'MPI4py',fontsize=14,bbox={'facecolor':'grey', 'alpha':0, 'pad':8},horizontalalignment='left',verticalalignment='top',rotation=270)
axes[1,0].text(-2.5,1000, 'Runtime',fontsize=14,bbox={'facecolor':'grey', 'alpha':0, 'pad':8},horizontalalignment='left',verticalalignment='top',rotation=90)
axes[2,2].text(-2.5,.1, 'Number of Cores',fontsize=14,bbox={'facecolor':'grey', 'alpha':0, 'pad':8},horizontalalignment='left',verticalalignment='top',rotation=0)
axes[0,0].set_xlim([-.55,4.0])
#axes[1,0].set_yticks([1,2,3,4,5,6,7])

#axes[1,0].set_ylabel('Speedup', fontsize=12)
#axes[1,1].set_xlabel('Number of Cores', fontsize=12)
axes[1,3].legend(['131k','262k','524k','4M'],fontsize=12,bbox_to_anchor=(0., -1.75, -2,0), loc='lower center',ncol=4, borderaxespad=0.)
#fig.savefig('All4approachesWith4M_logscale.png',dpi=800,bbox_inches='tight',pad_inches=0)

# %%
fig,axes = plt.subplots(nrows=3,ncols=4,sharex=True,sharey=True,gridspec_kw={'wspace':0.05, 'hspace':0.07})
fig.set_size_inches(12,5)
width = 0.2

lfb131Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[2,0],color=[reds(150)],legend=False,marker='*')
lfb262Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[2,0],color=[greens(150)],legend=False,marker='*')
lfb524Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[2,0],color=[blues(150)],legend=False,marker='*')

lfc131Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[2,1],color=[reds(150)],legend=False,marker='*')
lfc262Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[2,1],color=[greens(150)],legend=False,marker='*')
lfc524Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[2,1],color=[blues(150)],legend=False,marker='*')

lfpc131Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[2,2],color=[reds(150)],legend=False,marker='*')
lfpc262Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[2,2],color=[greens(150)],legend=False,marker='*')
lfpc524Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[2,2],color=[blues(150)],legend=False,marker='*')

lfbt131Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[2,3],color=[reds(150)],legend=False,marker='*')
lfbt262Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[2,3],color=[greens(150)],legend=False,marker='*')
lfbt524Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[2,3],color=[blues(150)],legend=False,marker='*')
D1meansW[0:4].plot(kind='line',x='Cores',y='Speedup',ax=axes[1,0],color=[reds(150)],legend=False,marker='*')
D1meansW[4:8].plot(kind='line',x='Cores',y='Speedup',ax=axes[1,0],color=[greens(150)],legend=False,marker='*')

D2meansW[0:4].plot(kind='line',x='Cores',y='Speedup',ax=axes[1,1],color=[reds(150)],legend=False,marker='*')
D2meansW[4:8].plot(kind='line',x='Cores',y='Speedup',ax=axes[1,1],color=[greens(150)],legend=False,marker='*')
D2meansW[8:12].plot(kind='line',x='Cores',y='Speedup',ax=axes[1,1],color=[blues(150)],legend=False,marker='*')

D3meansW[0:4].plot(kind='line',x='Cores',y='Speedup',ax=axes[1,2],color=[reds(150)],legend=False,marker='*')
D3meansW[4:8].plot(kind='line',x='Cores',y='Speedup',ax=axes[1,2],color=[greens(150)],legend=False,marker='*')
D3meansW[8:12].plot(kind='line',x='Cores',y='Speedup',ax=axes[1,2],color=[blues(150)],legend=False,marker='*')

D4meansW[0:4].plot(kind='line',x='Cores',y='Speedup',ax=axes[1,3],color=[reds(150)],legend=False,marker='*')
D4meansW[4:8].plot(kind='line',x='Cores',y='Speedup',ax=axes[1,3],color=[greens(150)],legend=False,marker='*')
D4meansW[8:12].plot(kind='line',x='Cores',y='Speedup',ax=axes[1,3],color=[blues(150)],legend=False,marker='*')
da4M4Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[1,3],color=purples(150),legend=False,marker='*')

Sp1meansW[0:4].plot(kind='line',x='Cores',y='Speedup',ax=axes[0,0],color=[reds(150)],legend=False,marker='*')
Sp1meansW[4:8].plot(kind='line',x='Cores',y='Speedup',ax=axes[0,0],color=[greens(150)],legend=False,marker='*')
Sp1meansW[8:12].plot(kind='line',x='Cores',y='Speedup',ax=axes[0,0],color=[blues(150)],legend=False,marker='*')

Sp2meansW[0:4].plot(kind='line',x='Cores',y='Speedup',ax=axes[0,1],color=[reds(150)],legend=False,marker='*')
Sp2meansW[4:8].plot(kind='line',x='Cores',y='Speedup',ax=axes[0,1],color=[greens(150)],legend=False,marker='*')
Sp2meansW[8:12].plot(kind='line',x='Cores',y='Speedup',ax=axes[0,1],color=[blues(150)],legend=False,marker='*')

Sp3meansW[0:4].plot(kind='line',x='Cores',y='Speedup',ax=axes[0,2],color=[reds(150)],legend=False,marker='*')
Sp3meansW[4:8].plot(kind='line',x='Cores',y='Speedup',ax=axes[0,2],color=[greens(150)],legend=False,marker='*')
Sp3meansW[8:12].plot(kind='line',x='Cores',y='Speedup',ax=axes[0,2],color=[blues(150)],legend=False,marker='*')
sp4M3Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[0,2],color=purples(150),legend=False,marker='*')

Sp4meansW[0:4].plot(kind='line',x='Cores',y='Speedup',ax=axes[0,3],color=[reds(150)],legend=False,marker='*')
Sp4meansW[4:8].plot(kind='line',x='Cores',y='Speedup',ax=axes[0,3],color=[greens(150)],legend=False,marker='*')
Sp4meansW[8:12].plot(kind='line',x='Cores',y='Speedup',ax=axes[0,3],color=[blues(150)],legend=False,marker='*')
sp4M4Means.plot(kind='line',x='Cores',y='Speedup',ax=axes[0,3],color=purples(150),legend=False,marker='*')

axes[0,0].set_title('Broadcast & 1-D Partitioning', fontsize=10)
axes[0,1].set_title('Task API & 2-D Partitioning', fontsize=10)
axes[0,2].set_title('Parallel Connected Components', fontsize=10)
axes[0,3].set_title('Tree-Search & \nParallel-Connected Components', fontsize=10)
axes[1,0].set_xscale('log',basex=2)
axes[1,0].set_xticks([32,64,128,256])
axes[1,0].set_xticklabels(['32','64','128','256'], fontsize=12,rotation=0)
axes[1,1].set_xticklabels(['32','64','128','256'], fontsize=12,rotation=0)
axes[1,2].set_xticklabels(['32','64','128','256'], fontsize=12,rotation=0)
axes[1,3].set_xticklabels(['32','64','128','256'], fontsize=12,rotation=0)
axes[1,0].set_yscale('log',basey=2)
axes[1,0].set_yticks([1,2,4,8])
axes[0,0].set_yticks([1,2,4,8])
axes[0,0].set_yticklabels(['1','2','4','8'], fontsize=12,rotation=0)
axes[1,0].set_yticklabels(['1','2','4','8'], fontsize=12,rotation=0)
axes[0,0].grid('on',which='both',linestyle=':')
axes[0,1].grid('on',which='both',linestyle=':')
axes[0,2].grid('on',which='both',linestyle=':')
axes[0,3].grid('on',which='both',linestyle=':')
axes[1,0].grid('on',which='both',linestyle=':')
axes[1,1].grid('on',which='both',linestyle=':')
axes[1,2].grid('on',which='both',linestyle=':')
axes[1,3].grid('on',which='both',linestyle=':')
axes[2,0].grid('on',which='both',linestyle=':')
axes[2,1].grid('on',which='both',linestyle=':')
axes[2,2].grid('on',which='both',linestyle=':')
axes[2,3].grid('on',which='both',linestyle=':')
axes[2,0].set_xlabel('',fontsize=12)
axes[2,1].set_xlabel('',fontsize=12)
axes[2,2].set_xlabel('',fontsize=12)
axes[2,3].set_xlabel('',fontsize=12)
axes[0,3].text(290,4, 'Spark',fontsize=14,bbox={'facecolor':'grey', 'alpha':0, 'pad':8},horizontalalignment='left',verticalalignment='top',rotation=270)
axes[1,3].text(290,4, 'Dask',fontsize=14,bbox={'facecolor':'grey', 'alpha':0, 'pad':8},horizontalalignment='left',verticalalignment='top',rotation=270)
axes[2,3].text(290,4, 'MPI4py',fontsize=14,bbox={'facecolor':'grey', 'alpha':0, 'pad':8},horizontalalignment='left',verticalalignment='top',rotation=270)
axes[1,0].text(16,10, 'Speedup',fontsize=14,bbox={'facecolor':'grey', 'alpha':0, 'pad':8},horizontalalignment='left',verticalalignment='top',rotation=90)
axes[2,2].text(12,0.5,'Number of Cores',fontsize=14,bbox={'facecolor':'grey', 'alpha':0, 'pad':8},horizontalalignment='left',verticalalignment='top',rotation=0)
#axes[0,0].set_xlim([-.55,4.0])
#axes[1,0].set_yticks([1,2,3,4,5,6,7])

#axes[1,0].set_ylabel('Speedup', fontsize=12)
#axes[1,1].set_xlabel('Number of Cores', fontsize=12)
axes[1,3].legend(['131k','262k','524k','4M'],fontsize=12,bbox_to_anchor=(0., -1.85, -2,0), loc='lower center',ncol=4, borderaxespad=0.)
#fig.savefig('All4approachesWith4M_logscale.png',dpi=800,bbox_inches='tight',pad_inches=0)
