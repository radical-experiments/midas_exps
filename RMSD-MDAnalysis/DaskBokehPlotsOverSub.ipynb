# %% [markdown]
# This file brings together code from Dask Distributed Diagnostics
# and Dask Distributed Bokeh. Along with the Dask Distributed Scheduler Plugin
# can be used to create post-mortem Dask Task Stream Bokeh plots
#
# author: iparask

# %%
from bokeh.plotting import figure, output_file,show
from bokeh.models import ColumnDataSource
from bokeh.models.tools import HoverTool
from bokeh.layouts import gridplot
import pandas as pd
from time import sleep
from DaskProfileReader import *

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
file_size=[300]
blocksize=[192]
for size in file_size:
    for block in blocksize:
        for run in range(5,6):
            name = 'XTC_{}_{}_{}'.format(size,block,run)
            profile = DaskProfileReader('OverSub/'+name+'.txt')
            print name
            output_file(name+'.html')
            profile['dt']=profile['start']-profile['start'].min()
            half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
            profile['dt'] = profile['dt']+half.values
            CDS=ColumnDataSource(profile)
            plot=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} blocks 64 cores'.format(size,block),title_text_font_size='12pt')
            hover=HoverTool(point_policy="follow_mouse",
                        tooltips="""
                            <div>
                                <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                                <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                                <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                                <span style="font-size: 10px;">ms</span>&nbsp;
                            </div>
                        """
                    )
            plot.add_tools(hover)
            plot.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',legend='action',source=CDS)
            plot.title_text_font_size = '24pt'
            plot.xaxis.axis_label_text_font_size = '16pt'
            plot.yaxis.axis_label_text_font_size = '16pt'
            plot.xaxis.major_label_text_font_size = '14pt'
            plot.yaxis.major_label_text_font_size = '14pt'
            plot.legend.label_text_font_size = '14pt'
            plot.legend.location='center_right'
            show(plot)
            sleep(10)
# Out:
# INFO:bokeh.core.state:Session output file 'XTC_300_192_5.html' already exists, will be overwritten.
# XTC_300_192_5
# /Users/iparask/anaconda/lib/python2.7/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning: Plot.title_text_font_size was deprecated in Bokeh 0.12.0 and will be removed, use Plot.title.text_font_size instead.
#   warn(message)
# /Users/iparask/anaconda/lib/python2.7/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning: Plot.title_text_font_size was deprecated in Bokeh 0.12.0 and will be removed, use Plot.title.text_font_size instead.
#   warn(message)

# %%
file_size=[300]
blocksize=[64]
for size in file_size:
    for block in blocksize:
        for run in range(1,2):
            name = 'XTC_{}_{}_{}'.format(size,block,run)
            profile = DaskProfileReader('Data/'+name+'.txt')
            print name
            output_file('XTC300_64.html')
            profile['dt']=profile['start']-profile['start'].min()
            half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
            profile['dt'] = profile['dt']+half.values
            CDS=ColumnDataSource(profile)
            plot=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} blocks 64 cores.'.format(size,block,run),title_text_font_size='24pt')
            hover=HoverTool(point_policy="follow_mouse",
                        tooltips="""
                            <div>
                                <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                                <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                                <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                                <span style="font-size: 10px;">ms</span>&nbsp;
                            </div>
                        """
                    )
            plot.add_tools(hover)
            plot.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',legend='action',source=CDS)
            plot.title_text_font_size = '24pt'
            plot.xaxis.axis_label_text_font_size = '16pt'
            plot.yaxis.axis_label_text_font_size = '16pt'
            plot.xaxis.major_label_text_font_size = '14pt'
            plot.yaxis.major_label_text_font_size = '14pt'
            plot.legend.label_text_font_size = '14pt'
            plot.legend.location='bottom_right'
            show(plot)
            sleep(10)
# Out:
# INFO:bokeh.core.state:Session output file 'XTC300_64.html' already exists, will be overwritten.
# XTC_300_64_1
# /Users/iparask/anaconda/lib/python2.7/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning: Plot.title_text_font_size was deprecated in Bokeh 0.12.0 and will be removed, use Plot.title.text_font_size instead.
#   warn(message)
# /Users/iparask/anaconda/lib/python2.7/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning: Plot.title_text_font_size was deprecated in Bokeh 0.12.0 and will be removed, use Plot.title.text_font_size instead.
#   warn(message)

# %%
name = 'XTC_{}_{}_{}'.format(100,16,1)
output_file('XTC_100_16.html')
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_16_1=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(100,16,1))
plot_16_1.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_16_1.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(100,16,2)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_16_2=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(100,16,2))
plot_16_2.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_16_2.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(100,16,3)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_16_3=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(100,16,3))
plot_16_3.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_16_3.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(100,16,4)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_16_4=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(100,16,4))
plot_16_4.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_16_4.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(100,16,5)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_16_5=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(100,16,5))
plot_16_5.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_16_5.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

grid=gridplot([[plot_16_1,plot_16_2,plot_16_3],[plot_16_4,plot_16_5,None]], sizing_mode='stretch_both')
show(grid)

# %%
name = 'XTC_{}_{}_{}'.format(100,32,1)
output_file('XTC_100_32.html')
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_32_1=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(100,32,1))
plot_32_1.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_32_1.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(100,32,2)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_32_2=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(100,32,2))
plot_32_2.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_32_2.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(100,32,3)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_32_3=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(100,32,3))
plot_32_3.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_32_3.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(100,32,4)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_32_4=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(100,32,4))
plot_32_4.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_32_4.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(100,32,5)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_32_5=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(100,32,5))
plot_32_5.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_32_5.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

grid=gridplot([[plot_32_1,plot_32_2,plot_32_3],[plot_32_4,plot_32_5,None]], sizing_mode='stretch_both')
show(grid)

# %%
name = 'XTC_{}_{}_{}'.format(100,48,1)
output_file('XTC_100_48.html')
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_48_1=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(100,48,1))
plot_48_1.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_48_1.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(100,48,2)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_48_2=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(100,48,2))
plot_48_2.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_48_2.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(100,48,3)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_48_3=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(100,48,3))
plot_48_3.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_48_3.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(100,48,4)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_48_4=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(100,48,4))
plot_48_4.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_48_4.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(100,48,5)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_48_5=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(100,48,5))
plot_48_5.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_48_5.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

grid=gridplot([[plot_48_1,plot_48_2,plot_48_3],[plot_48_4,plot_48_5,None]], sizing_mode='stretch_both')
show(grid)

# %%
name = 'XTC_{}_{}_{}'.format(100,64,1)
output_file('XTC_100_64.html')
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_64_1=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(100,64,1))
plot_64_1.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_64_1.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(100,64,2)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_64_2=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(100,64,2))
plot_64_2.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_64_2.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(100,64,3)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_64_3=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(100,64,3))
plot_64_3.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_64_3.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(100,64,4)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_64_4=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(100,64,4))
plot_64_4.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_64_4.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(100,64,5)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_64_5=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(100,64,5))
plot_64_5.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_64_5.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

grid=gridplot([[plot_64_1,plot_64_2,plot_64_3],[plot_64_4,plot_64_5,None]], sizing_mode='stretch_both')
show(grid)

# %%
name = 'XTC_{}_{}_{}'.format(300,16,1)
output_file('XTC_300_16.html')
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_16_1=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(300,16,1))
plot_16_1.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_16_1.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(300,16,2)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_16_2=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(300,16,2))
plot_16_2.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_16_2.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(300,16,3)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_16_3=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(300,16,3))
plot_16_3.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_16_3.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(300,16,4)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_16_4=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(300,16,4))
plot_16_4.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_16_4.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(300,16,5)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_16_5=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(300,16,5))
plot_16_5.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_16_5.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

grid=gridplot([[plot_16_1,plot_16_2,plot_16_3],[plot_16_4,plot_16_5,None]],sizing_mode='stretch_both')
show(grid)

# %%
name = 'XTC_{}_{}_{}'.format(300,32,1)
output_file('XTC_300_32.html')
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_32_1=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(300,32,1))
plot_32_1.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_32_1.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(300,32,2)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_32_2=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(300,32,2))
plot_32_2.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_32_2.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(300,32,3)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_32_3=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(300,32,3))
plot_32_3.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_32_3.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(300,32,4)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_32_4=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(300,32,4))
plot_32_4.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_32_4.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(300,32,5)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_32_5=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(300,32,5))
plot_32_5.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_32_5.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

grid=gridplot([[plot_32_1,plot_32_2,plot_32_3],[plot_32_4,plot_32_5,None]],sizing_mode='stretch_both')
show(grid)

# %%
name = 'XTC_{}_{}_{}'.format(300,48,1)
output_file('XTC_300_48.html')
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_48_1=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(300,48,1))
plot_48_1.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_48_1.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(300,48,2)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_48_2=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(300,48,2))
plot_48_2.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_48_2.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(300,48,3)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_48_3=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(300,48,3))
plot_48_3.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_48_3.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(300,48,4)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_48_4=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(300,48,4))
plot_48_4.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_48_4.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(300,48,5)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_48_5=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(300,48,5))
plot_48_5.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_48_5.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

grid=gridplot([[plot_48_1,plot_48_2,plot_48_3],[plot_48_4,plot_48_5,None]],sizing_mode='stretch_both')
show(grid)

# %%
name = 'XTC_{}_{}_{}'.format(300,64,1)
output_file('XTC_300_64.html')
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_64_1=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(300,64,1))
plot_64_1.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_64_1.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(300,64,2)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_64_2=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(300,64,2))
plot_64_2.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_64_2.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(300,64,3)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_64_3=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(300,64,3))
plot_64_3.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_64_3.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(300,64,4)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_64_4=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(300,64,4))
plot_64_4.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_64_4.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

name = 'XTC_{}_{}_{}'.format(300,64,5)
profile = DaskProfileReader('Data/'+name+'.txt')
profile['dt']=profile['start']-profile['start'].min()
half = (profile['duration'][profile[profile['start']==profile['start'].min()].index])*0.5
profile['dt'] = profile['dt']+half.values
CDS=ColumnDataSource(profile)
plot_64_5=figure(height=600,width=1000,x_axis_label='Time in msec',y_axis_label='Worker Proccess',title='XTC {}x {} cores run {}'.format(300,64,5))
plot_64_5.add_tools(HoverTool(point_policy="follow_mouse",
            tooltips="""
                <div>
                    <span style="font-size: 12px; font-weight: bold;">@name:</span>&nbsp;
                    <span style="font-size: 12px; font-weight: bold;">@action:</span>&nbsp;
                    <span style="font-size: 10px; font-family: Monaco, monospace;">@duration</span>
                    <span style="font-size: 10px;">ms</span>&nbsp;
                </div>
            """
        ))
plot_64_5.rect('dt','y',height=0.5,width='duration',color='color',alpha='alpha',source=CDS)

grid=gridplot([[plot_64_1,plot_64_2,plot_64_3],[plot_64_4,plot_64_5,None]],sizing_mode='stretch_both')
show(grid)
