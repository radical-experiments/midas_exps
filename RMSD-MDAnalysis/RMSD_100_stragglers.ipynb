# %%
# %matplotlib inline
from __future__ import division
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import bokeh.plotting as bplt
from bokeh.models import ColumnDataSource
from bokeh.models.tools import HoverTool
from bokeh.layouts import gridplot,row,column
from bokeh.io import output_notebook
from DaskProfileReader import *
from bokeh.charts import BoxPlot,Bar
from bokeh.models import Range1d
from bokeh.models import CheckboxGroup, CustomJS

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
output_notebook()
# Out:
# <style>.container { width:100% !important; }</style>
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f042243b-0df1-4eb2-be99-661beef82e8c">Loading BokehJS ...</span>
#     </div>

# %%
rmsd100 = pd.DataFrame(columns=['Block','Try','Task','Time'])
block_size = [1,2,3,4,6,8,9,12,16,18,24,36,48,72,144]

for block in block_size:
    temp = pd.DataFrame(columns=['Block','Try','Task','Time'])
    data1 = DaskProfileReader('stragglers/stragglers_test_100_%d_1.txt'%(block))
    temp['Time']=data1[data1['name']=='block_rmsd']['duration'].values/1000
    temp['Task']=range(block)
    temp['Try']='Run 1'
    temp['Block']=block
    rmsd100 = rmsd100.append(temp)
    temp = pd.DataFrame(columns=['Block','Try','Task','Time'])
    data2 = DaskProfileReader('stragglers/stragglers_test_100_%d_2.txt'%(block))
    temp['Time'] = data2[data2['name']=='block_rmsd']['duration'].values/1000
    temp['Task']=range(block)
    temp['Try']='Run 2'
    temp['Block']=block
    rmsd100 = rmsd100.append(temp)
    temp = pd.DataFrame(columns=['Block','Try','Task','Time'])
    data3 = DaskProfileReader('stragglers/stragglers_test_100_%d_3.txt'%(block))
    temp['Time'] = data3[data3['name']=='block_rmsd']['duration'].values/1000
    temp['Task']=range(block)
    temp['Try']='Run 3'
    temp['Block']=block
    rmsd100 = rmsd100.append(temp)
    temp = pd.DataFrame(columns=['Block','Try','Task','Time'])
    data4 = DaskProfileReader('stragglers/stragglers_test_100_%d_4.txt'%(block))
    temp['Time'] = data4[data4['name']=='block_rmsd']['duration'].values/1000
    temp['Task']=range(block)
    temp['Try']='Run 4'
    temp['Block']=block
    rmsd100 = rmsd100.append(temp)
    temp = pd.DataFrame(columns=['Block','Try','Task','Time'])
    data5 = DaskProfileReader('stragglers/stragglers_test_100_%d_5.txt'%(block))
    temp['Time'] = data5[data5['name']=='block_rmsd']['duration'].values/1000
    temp['Task']=range(block)
    temp['Try']='Run 5'
    temp['Block']=block
    rmsd100 = rmsd100.append(temp)

rmsd100=rmsd100.reset_index().drop('index',axis=1)

# %%
def checkboxesFun(bar):
    group = "Try"
    checkboxes = CheckboxGroup(labels=np.unique(df[group]).tolist(),
                           # Make all checkboxes checked by default
                           active=list(range(np.unique(df[group]).size)))
    checkboxes.callback = CustomJS(args=dict(bars=bar), code="""

    var group = '%s';

    function change_bars_visibility(checkbox_name, visible) {
        for (j = 0; j < bars.renderers.length; j++) {
            // Go through rendered objects

            if (bars.renderers[j].attributes.hasOwnProperty('data_source') && 
                bars.renderers[j].data_source.data[group][0] === checkbox_name) {

                // Change the visibility of this rendered object if it belongs to
                // the group determined by the checkbox that was clicked
                bars.renderers[j].visible = visible;
            }
        }
    }

    for (i = 0; i < cb_obj.labels.length; i++) {
        // Go through checkbox labels
        var checkbox_name = cb_obj.labels[i];

        if (cb_obj.active.indexOf(i) >= 0) {
            // alert(checkbox_name + " is activated");
            change_bars_visibility(checkbox_name, true);
        }
        else {
            // alert(checkbox_name + " is disabled");
            change_bars_visibility(checkbox_name, false);
        }
    }
    """ % group)
    return checkboxes

# %%
block_size = [1]
for block in block_size:
    df = rmsd100[rmsd100['Block']==block]
    p = BoxPlot(df, values='Time', label=['Try'],
            title="XTC Dask RMSD task execution time\nfor x100 and %d tasks for 5 runs"%block,plot_width=600,plot_height=400,legend=False)
    p.y_range=Range1d(np.floor(df['Time'].min()*10)/10,np.ceil(df['Time'].max()*10)/10)
    bar = Bar(df, values='Time', label='Task',group='Try',title="Tasks", legend='top_right',plot_width=600 if block<12 else block*50,plot_height=400)
    
    bplt.show(row(p,column(bar,checkboxesFun(bar))))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c3194ba6-43d9-410e-8aa0-c95e30a35830"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
block_size = [2]
for block in block_size:
    df = rmsd100[rmsd100['Block']==block]
    p = BoxPlot(df, values='Time', label=['Try'],
            title="XTC Dask RMSD task execution time\nfor x100 and %d tasks for 5 runs"%block,plot_width=600,plot_height=400,legend=False)
    p.y_range=Range1d(np.floor(df['Time'].min()*10)/10,np.ceil(df['Time'].max()*10)/10)
    bar = Bar(df, values='Time', label='Task',group='Try',title="Tasks", legend='top_right',plot_width=600 if block<12 else block*50,plot_height=400)
    
    bplt.show(row(p,column(bar,checkboxesFun(bar))))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="590ecd8c-cdd4-43fc-a8cc-3f2c8ed8400c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
block_size = [3]
for block in block_size:
    df = rmsd100[rmsd100['Block']==block]
    p = BoxPlot(df, values='Time', label=['Try'],
            title="XTC Dask RMSD task execution time\nfor x100 and %d tasks for 5 runs"%block,plot_width=600,plot_height=400,legend=False)
    p.y_range=Range1d(np.floor(df['Time'].min()*10)/10,np.ceil(df['Time'].max()*10)/10)
    bar = Bar(df, values='Time', label='Task',group='Try',title="Tasks", legend='top_right',plot_width=600 if block<12 else block*50,plot_height=400)
    
    bplt.show(row(p,column(bar,checkboxesFun(bar))))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f2311596-2e83-4c67-a7b9-33fe36dbc643"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
block_size = [4]
for block in block_size:
    df = rmsd100[rmsd100['Block']==block]
    p = BoxPlot(df, values='Time', label=['Try'],
            title="XTC Dask RMSD task execution time\nfor x100 and %d tasks for 5 runs"%block,plot_width=600,plot_height=400,legend=False)
    p.y_range=Range1d(np.floor(df['Time'].min()*10)/10,np.ceil(df['Time'].max()*10)/10)
    bar = Bar(df, values='Time', label='Task',group='Try',title="Tasks", legend='top_right',plot_width=600 if block<12 else block*50,plot_height=400)
    
    bplt.show(row(p,column(bar,checkboxesFun(bar))))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1dcc9909-8431-4e68-81a7-33c87c91945e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
block_size = [6]
for block in block_size:
    df = rmsd100[rmsd100['Block']==block]
    p = BoxPlot(df, values='Time', label=['Try'],
            title="XTC Dask RMSD task execution time\nfor x100 and %d tasks for 5 runs"%block,plot_width=600,plot_height=400,legend=False)
    p.y_range=Range1d(np.floor(df['Time'].min()*10)/10,np.ceil(df['Time'].max()*10)/10)
    bar = Bar(df, values='Time', label='Task',group='Try',title="Tasks", legend='top_right',plot_width=600 if block<12 else block*50,plot_height=400)
    
    bplt.show(row(p,column(bar,checkboxesFun(bar))))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="65c197f3-5938-4507-8f11-27bb72da247f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
block_size = [8]
for block in block_size:
    df = rmsd100[rmsd100['Block']==block]
    p = BoxPlot(df, values='Time', label=['Try'],
            title="XTC Dask RMSD task execution time\nfor x100 and %d tasks for 5 runs"%block,plot_width=600,plot_height=400,legend=False)
    p.y_range=Range1d(np.floor(df['Time'].min()*10)/10,np.ceil(df['Time'].max()*10)/10)
    bar = Bar(df, values='Time', label='Task',group='Try',title="Tasks", legend='top_right',plot_width=600 if block<12 else block*50,plot_height=400)
    
    bplt.show(row(p,column(bar,checkboxesFun(bar))))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d9eed125-a250-47a9-9a13-1014ad7d1fa4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
block_size = [9]
for block in block_size:
    df = rmsd100[rmsd100['Block']==block]
    p = BoxPlot(df, values='Time', label=['Try'],
            title="XTC Dask RMSD task execution time\nfor x100 and %d tasks for 5 runs"%block,plot_width=600,plot_height=400,legend=False)
    p.y_range=Range1d(np.floor(df['Time'].min()*10)/10,np.ceil(df['Time'].max()*10)/10)
    bar = Bar(df, values='Time', label='Task',group='Try',title="Tasks", legend='top_right',plot_width=600 if block<12 else block*50,plot_height=400)
    
    bplt.show(row(p,column(bar,checkboxesFun(bar))))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ac7a8340-72bc-4838-83ae-5bfb9aae115e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
block_size = [12]
for block in block_size:
    df = rmsd100[rmsd100['Block']==block]
    p = BoxPlot(df, values='Time', label=['Try'],
            title="XTC Dask RMSD task execution time\nfor x100 and %d tasks for 5 runs"%block,plot_width=600,plot_height=400,legend=False)
    p.y_range=Range1d(np.floor(df['Time'].min()*10)/10,np.ceil(df['Time'].max()*10)/10)
    bar = Bar(df, values='Time', label='Task',group='Try',title="Tasks", legend='top_right',plot_width=600 if block<12 else block*50,plot_height=400)
    
    bplt.show(row(p,column(bar,checkboxesFun(bar))))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="900ebbc7-1978-4937-a37d-1e0ed3f33287"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
block_size = [24]
for block in block_size:
    df = rmsd100[rmsd100['Block']==block]
    p = BoxPlot(df, values='Time', label=['Try'],
            title="XTC Dask RMSD task execution time\nfor x100 and %d tasks for 5 runs"%block,plot_width=600,plot_height=400,legend=False)
    p.y_range=Range1d(np.floor(df['Time'].min()*10)/10,np.ceil(df['Time'].max()*10)/10)
    bar = Bar(df, values='Time', label='Task',group='Try',title="Tasks", legend='top_right',plot_width=600 if block<12 else block*40,plot_height=400)
    
    bplt.show(row(p,column(bar,checkboxesFun(bar))))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="de81b92b-baad-4eef-a73b-37e585198f65"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
block_size = [36]
for block in block_size:
    df = rmsd100[rmsd100['Block']==block]
    p = BoxPlot(df, values='Time', label=['Try'],
            title="XTC Dask RMSD task execution time\nfor x100 and %d tasks for 5 runs"%block,plot_width=600,plot_height=400,legend=False)
    p.y_range=Range1d(np.floor(df['Time'].min()*10)/10,np.ceil(df['Time'].max()*10)/10)
    bar = Bar(df, values='Time', label='Task',group='Try',title="Tasks", legend='top_right',plot_width=600 if block<12 else block*50,plot_height=400)
    
    bplt.show(row(p,column(bar,checkboxesFun(bar))))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="de9ee09f-58d3-448a-b70e-322a0436d677"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
block_size = [48]
for block in block_size:
    df = rmsd100[rmsd100['Block']==block]
    p = BoxPlot(df, values='Time', label=['Try'],
            title="XTC Dask RMSD task execution time\nfor x100 and %d tasks for 5 runs"%block,plot_width=600,plot_height=400,legend=False)
    p.y_range=Range1d(np.floor(df['Time'].min()*10)/10,np.ceil(df['Time'].max()*10)/10)
    bar = Bar(df, values='Time', label='Task',group='Try',title="Tasks", legend='top_right',plot_width=600 if block<12 else block*50,plot_height=400)
    
    bplt.show(row(p,column(bar,checkboxesFun(bar))))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5db9ad07-70c0-4922-9d4b-547e474a46f1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
block_size = [72]
for block in block_size:
    df = rmsd100[rmsd100['Block']==block]
    p = BoxPlot(df, values='Time', label=['Try'],
            title="XTC Dask RMSD task execution time\nfor x100 and %d tasks for 5 runs"%block,plot_width=600,plot_height=400,legend=False)
    p.y_range=Range1d(np.floor(df['Time'].min()*10)/10,np.ceil(df['Time'].max()*10)/10)
    bar = Bar(df, values='Time', label='Task',group='Try',title="Tasks", legend='top_right',plot_width=600 if block<12 else block*50,plot_height=400)
    
    bplt.show(row(p,column(bar,checkboxesFun(bar))))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2137b919-789b-4d13-a24c-fed1052f7acb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
block_size = [144]
for block in block_size:
    df = rmsd100[rmsd100['Block']==block]
    p = BoxPlot(df, values='Time', label=['Try'],
            title="XTC Dask RMSD task execution time\nfor x100 and %d tasks for 5 runs"%block,plot_width=600,plot_height=400,legend=False)
    p.y_range=Range1d(np.floor(df['Time'].min()*10)/10,np.ceil(df['Time'].max()*10)/10)
    bar = Bar(df, values='Time', label='Task',group='Try',title="Tasks", legend='top_right',plot_width=600 if block<12 else block*50,plot_height=400)
    
    bplt.show(row(p,column(bar,checkboxesFun(bar))))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="100f652c-4859-41ed-a5b4-5be5ca87e249"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...
