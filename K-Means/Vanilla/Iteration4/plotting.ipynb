# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from textwrap import wrap

LeafletFinder_16_Adj=[808.1099548,809.1714,863.6059]
LeafletFinder_16_comp=[1559.909891,1573.002,1630.189]
LeafletFinder_32_Adj=[444.0679,464.008,446.6787]
LeafletFinder_32_comp=[1192.222,1221.107,1208.725]
LeafletFinder_64_Adj=[245.4011,243.2026,246.5395]
LeafletFinder_64_comp=[1012.522,990.1484,1003.133]
LeafletFinder_128_Adj=[213.857,21.7323,214.1853]
LeafletFinder_128_comp=[968.1939,980.2165,964.4475]

# %%
leaflet_16_adj=np.mean(LeafletFinder_16_Adj)
leaflet_16_comp=np.mean(LeafletFinder_16_comp)
leaflet_32_adj=np.mean(LeafletFinder_32_Adj)
leaflet_32_comp=np.mean(LeafletFinder_32_comp)
leaflet_64_adj=np.mean(LeafletFinder_64_Adj)
leaflet_64_comp=np.mean(LeafletFinder_64_comp)
leaflet_128_adj=np.mean(LeafletFinder_128_Adj)
leaflet_128_comp=np.mean(LeafletFinder_128_comp)

# %%
n_groups=4
index=np.arange(n_groups)
bar_width=0.2
opacity=1.0
plt.bar(index,[leaflet_16_comp,leaflet_32_comp,leaflet_64_comp,leaflet_128_comp],bar_width,alpha=opacity,color='darkgreen')
plt.bar(index,[leaflet_16_adj,leaflet_32_adj,leaflet_64_adj,leaflet_128_adj],bar_width,alpha=opacity,color='blue')
plt.legend( ('Connected Components','Adjacency Matrix Calculation'),fancybox=True,framealpha=0.5,prop={'size':9})
plt.xlabel('# of Cores')
plt.ylabel('Time to Completion (secs)')
plt.ylim(ymax=1700)
plt.xticks(index+(0.5*bar_width),('16','32','64','128'))
plt.title('Time to Completion @ Stampede, 51K atoms')
plt.savefig('LeafletFinder.png',dpi=800)

# %%
LeafletFinder_16_Adj=[5846.73257208,]
LeafletFinder_16_comp=[5990.62923503,]
LeafletFinder_32_Adj=[3053.624151,3050.816718,2997.635669]
LeafletFinder_32_comp=[3193.081978,3214.869393,3172.165624]
LeafletFinder_64_Adj=[1558.628683,1579.786536,1537.06449]
LeafletFinder_64_comp=[1693.900145,1710.67076,1671.460436]
LeafletFinder_128_Adj=[811.145082,819.7000909,854.5530279]
LeafletFinder_128_comp=[991.1721919,1009.381608,1039.374543]
LeafletFinder_256_Adj=[548.6114981,567.24702,548.3424671]
LeafletFinder_256_comp=[765.3498521,749.3826041,730.6525459]

leaflet_32_adj=np.mean(LeafletFinder_32_Adj)
leaflet_32_comp=np.mean(LeafletFinder_32_comp)
leaflet_64_adj=np.mean(LeafletFinder_64_Adj)
leaflet_64_comp=np.mean(LeafletFinder_64_comp)
leaflet_128_adj=np.mean(LeafletFinder_128_Adj)
leaflet_128_comp=np.mean(LeafletFinder_128_comp)
leaflet_256_adj=np.mean(LeafletFinder_256_Adj)
leaflet_256_comp=np.mean(LeafletFinder_256_comp)

n_groups=4
index=np.arange(n_groups)
bar_width=0.2
opacity=1.0
plt.bar(index,[leaflet_32_comp,leaflet_64_comp,leaflet_128_comp,leaflet_256_comp],bar_width,alpha=opacity,color='darkgreen')
plt.bar(index,[leaflet_32_adj,leaflet_64_adj,leaflet_128_adj,leaflet_256_adj],bar_width,alpha=opacity,color='blue')
plt.legend( ('Connected Components','Adjacency Matrix Calculation'),fancybox=True,framealpha=0.5,prop={'size':9})
plt.xlabel('# of Cores')
plt.ylabel('Time to Completion (secs)')
plt.ylim(ymax=3300)
plt.xticks(index+(0.5*bar_width),('32','64','128','256'))
plt.title('Time to Completion @ Stampede, 145K atoms')
plt.savefig('LeafletFinder_145K_phosphates_5398WinSize_Stampede.png',dpi=800)

# %%
a=plt.figure()
plt.suptitle('K-Means Execution Time Comparison',y=1.06,fontsize=14)
plt.subplot(1,3,1)
n_groups=3
index=np.arange(n_groups)
bar_width=0.1
opacity=1.0
plt.bar(index,[1,1,1],bar_width,alpha=opacity,color='darkgreen',label='RP Stampede')
plt.bar(index+bar_width,[2,2,2],bar_width,alpha=opacity,color='blue',label='RP-YARN Stampede')
plt.bar(index+2*bar_width,[3,3,3],bar_width,alpha=opacity,color='cyan',label='RP Wrangler')
plt.bar(index+3*bar_width,[4,4,4],bar_width,alpha=opacity,color='red',label='RP-YARN Wrangler')
plt.bar(index+4*bar_width,[5,5,5],bar_width,alpha=opacity,color='orange',label='RP-YARN Chameleon')
plt.bar(index+5*bar_width,[6,6,6],bar_width,alpha=opacity,color='green',label='RP-YARN Amazon')
plt.title('10,000 points'+'\n'+'5,000 clusters')
plt.xticks(index+3*bar_width,('96','192','384'))
plt.ylim(ymax=6.5)
plt.ylabel('Time to Completion (secs)',fontsize=14)
plt.subplot(1,3,2)
n_groups=3
index=np.arange(n_groups)
bar_width=0.1
opacity=1.0
plt.bar(index,[1,1,1],bar_width,alpha=opacity,color='darkgreen',label='RP Stampede')
plt.bar(index+bar_width,[2,2,2],bar_width,alpha=opacity,color='blue',label='RP-YARN Stampede')
plt.bar(index+2*bar_width,[3,3,3],bar_width,alpha=opacity,color='cyan',label='RP Wrangler')
plt.bar(index+3*bar_width,[4,4,4],bar_width,alpha=opacity,color='red',label='RP-YARN Wrangler')
plt.bar(index+4*bar_width,[5,5,5],bar_width,alpha=opacity,color='orange',label='RP-YARN Chameleon')
plt.bar(index+5*bar_width,[6,6,6],bar_width,alpha=opacity,color='green',label='RP-YARN Amazon')
plt.title('100,000 points'+'\n'+'500 clusters')
plt.xticks(index+3*bar_width,('96','192','384'))
plt.ylim(ymax=6.5)
plt.subplot(1,3,3)
n_groups=3
index=np.arange(n_groups)
bar_width=0.1
opacity=1.0
b1=plt.bar(index,[1,1,1],bar_width,alpha=opacity,color='darkgreen',label='RP Stampede')
b2=plt.bar(index+bar_width,[2,2,2],bar_width,alpha=opacity,color='blue',label='RP-YARN Stampede')
b3=plt.bar(index+2*bar_width,[3,3,3],bar_width,alpha=opacity,color='cyan',label='RP Wrangler')
b4=plt.bar(index+3*bar_width,[4,4,4],bar_width,alpha=opacity,color='red',label='RP-YARN Wrangler')
b5=plt.bar(index+4*bar_width,[5,5,5],bar_width,alpha=opacity,color='orange',label='RP-YARN Chameleon')
b6=plt.bar(index+5*bar_width,[6,6,6],bar_width,alpha=opacity,color='green',label='RP-YARN Amazon')
plt.xticks(index+3*bar_width,('96','192','384'))
plt.title('1,000,000 points'+'\n'+'50 clusters')
plt.ylim(ymax=6.5)
lgd=plt.figlegend((b1,b2,b3,b4,b5,b6),('RP Stampede','RP-YARN Stampede','RP Wrangler','RP-YARN Wrangler','RP-YARN Chameleon','RP-YARN Amazon'),
              loc='lower center',mode="expand",ncol=3,fontsize=10,borderaxespad=0.11)
a.text(0.45,0.16,'Number of Cores',ha='center',fontsize=14)
a.subplots_adjust(bottom=0.25)
a.savefig('kmeans-ttc-comp.png',dpi=800,bbox_extra_artists=(lgd,))

# %%
b=plt.figure()
n_groups=4
index=np.arange(n_groups)
bar_width=0.30
opacity=1.0
plt.bar(index+0.25*bar_width,[40, 50, 30, 45],bar_width,alpha=opacity,color='darkgreen')
plt.bar(index+1.25*bar_width,[125,80,100,90],bar_width,alpha=opacity,color='blue')
plt.xticks(index+1.25*bar_width,('Stampede','Wrangler','Chameleon Cloud','Amazon AWS'))
plt.ylim(ymax=150.0)
plt.xlabel('Selected Distributed Computation Resource')
plt.ylabel('Startup time (secs)')
plt.title('RADICAL-Pilot and RADICAL-Pilot-YARN Startup time Time Comparison')
plt.legend(('RP','RP-YARN'),fancybox=True,framealpha=0.5,prop={'size':9})
b.savefig('startup-rp-rpyarn-comp.png',dpi=800)

# %%
a=plt.figure()
plt.suptitle('K-Means Execution Time Comparison',y=1.06,fontsize=14)
n_groups=3
index=np.arange(n_groups)
bar_width=0.1
opacity=1.0
plt.bar(index,[1,1,1],bar_width,alpha=opacity,color='darkgreen',label='RP Stampede')
plt.bar(index+bar_width,[2,2,2],bar_width,alpha=opacity,color='blue',label='RP-YARN Stampede')
plt.bar(index+2*bar_width,[3,3,3],bar_width,alpha=opacity,color='blue',label='RP Wrangler')
plt.bar(index+3*bar_width,[4,4,4],bar_width,alpha=opacity,color='blue',label='RP-YARN Wrangler')
plt.bar(index+4*bar_width,[5,5,5],bar_width,alpha=opacity,color='blue',label='RP-YARN Chameleon')
plt.bar(index+5*bar_width,[6,6,6],bar_width,alpha=opacity,color='blue',label='RP-YARN Amazon')
# Out:
# <Container object of 3 artists>

# %%
help(a.subplots_adjust)
# Out:
# Help on method subplots_adjust in module matplotlib.figure:
#
# subplots_adjust(self, *args, **kwargs) method of matplotlib.figure.Figure instance
#     Call signature::
#
#       subplots_adjust(left=None, bottom=None, right=None, top=None,
#                           wspace=None, hspace=None)
#
#     Update the :class:`SubplotParams` with *kwargs* (defaulting to rc when
#     *None*) and update the subplot locations

# %%
help(plt.bar)
# Out:
# Help on function bar in module matplotlib.pyplot:
#
# bar(left, height, width=0.8, bottom=None, hold=None, data=None, **kwargs)
#     Make a bar plot.
#
#     Make a bar plot with rectangles bounded by:
#
#       `left`, `left` + `width`, `bottom`, `bottom` + `height`
#             (left, right, bottom and top edges)
#
#     Parameters
#     ----------
#     left : sequence of scalars
#         the x coordinates of the left sides of the bars
#
#     height : sequence of scalars
#         the heights of the bars
#
#     width : scalar or array-like, optional
#         the width(s) of the bars
#         default: 0.8
#
#     bottom : scalar or array-like, optional
#         the y coordinate(s) of the bars
#         default: None
#
#     color : scalar or array-like, optional
#         the colors of the bar faces
#
#     edgecolor : scalar or array-like, optional
#         the colors of the bar edges
#
#     linewidth : scalar or array-like, optional
# ...

# %%
lgd
